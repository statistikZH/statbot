# %%
import subprocess
repo_dir = subprocess.Popen(['git', 'rev-parse', '--show-toplevel'], stdout=subprocess.PIPE).communicate()[0].rstrip().decode('utf-8')

# %%
import sys 
sys.path.append(repo_dir) # go to parent dir from customFunctions import *
import statbot_helpers as sbh
from pyaxis import pyaxis
import pandas as pd
import numpy as np
import os
import requests
import json

# %%
# bfs_nr of dataset
BFS_NR = 'px-x-0102020204_102'

STICHTAG =  '-12-31' # -%m-%d

# get asset_nr
asset_nr = sbh.get_bfs_asset_nr(BFS_NR)
BFS_URL = "https://www.bfs.admin.ch/bfsstatic/dam/assets/" + str(asset_nr) + "/master"

file_name="bfs_1_01_001_CH.px"

# download cube
r = requests.get(BFS_URL)
open(os.path.join(repo_dir,"temp/"+file_name), 'wb').write(r.content)
# Out:
# 17093511

# %%
# load data from bfs
px = pyaxis.parse(os.path.join(repo_dir,"temp/"+file_name), encoding='ISO-8859-2')

# %%
px['DATA']
# Out:
#          Jahr Kanton (-) / Bezirk (>>) / Gemeinde (......)  \
# 0        1969                                      Schweiz
# 1        1969                                      Schweiz
# 2        1969                                      Schweiz
# 3        1969                                      Schweiz
# 4        1969                                      Schweiz
# ...       ...                                          ...
# 6649339  2020                        ......6810 La Baroche
# 6649340  2020                        ......6810 La Baroche
# 6649341  2020                        ......6810 La Baroche
# 6649342  2020                        ......6810 La Baroche
# 6649343  2020                        ......6810 La Baroche
#
#                  Geschlecht des Kindes  \
# 0        Geschlecht des Kindes - Total
# 1        Geschlecht des Kindes - Total
# 2        Geschlecht des Kindes - Total
# 3        Geschlecht des Kindes - Total
# 4        Geschlecht des Kindes - Total
# ...                                ...
# 6649339                        Mädchen
# 6649340                        Mädchen
# 6649341                        Mädchen
# 6649342                        Mädchen
# 6649343                        Mädchen
#
#         Staatsangehörigkeit (Kategorie) des Kindes  \
# 0           Staatsangehörigkeit des Kindes - Total
# 1           Staatsangehörigkeit des Kindes - Total
# 2           Staatsangehörigkeit des Kindes - Total
# 3           Staatsangehörigkeit des Kindes - Total
# 4           Staatsangehörigkeit des Kindes - Total
# ...                                            ...
# 6649339                                    Ausland
# 6649340                                    Ausland
# 6649341                                    Ausland
# 6649342                                    Ausland
# 6649343                                    Ausland
#
#                  Altersklasse der Mutter    DATA
# 0        Altersklasse der Mutter - Total  102520
# 1                        Unter 25 Jahren   33884
# 2                            25-29 Jahre   36206
# 3                            30-34 Jahre   20479
# 4                            35-39 Jahre    9077
# ...                                  ...     ...
# 6649339                  Unter 25 Jahren       0
# 6649340                      25-29 Jahre       0
# 6649341                      30-34 Jahre       0
# 6649342                      35-39 Jahre       0
# 6649343                40 Jahre und mehr       0
#
# [6649344 rows x 6 columns]

# %%
# clean df
df = px['DATA']#.loc[px['DATA']
df = df.rename(columns={"Kanton (-) / Bezirk (>>) / Gemeinde (......)": "name"})


# add column with spatialunit_ontology
df.loc[df['name'].str.startswith("......"), "spatialunit_ontology"] = "A.ADM3"
#df.loc[df['name'].str.startswith(">>"), "spatialunit_ontology"] = "A.ADM2"
#df.loc[df['name'].str.startswith("-"), "spatialunit_ontology"] = "A.ADM1"
#df.loc[df['name'].str.startswith("Schweiz"), "spatialunit_ontology"] = "CH"

df = df.dropna(subset=['spatialunit_ontology'])

df['spatialunit_ontology'] = df['spatialunit_ontology'].astype('category') # reduce memory footprint


# extract bfs_nr and name for gemeinde
df.loc[df['spatialunit_ontology'] == 'A.ADM3', 'bfs_nr'] = df['name'].str.slice(6,11)
df.loc[df['spatialunit_ontology'] == 'A.ADM3', 'name'] = df['name'].str.slice(11)

df['bfs_nr'] = df['bfs_nr'].astype('int16')

                    
                    
# extract name for bezirk
#df.loc[df['spatialunit_ontology'] == 'A.ADM2', 'name'] = df['name'].str.slice(3)

# extract name for kanton
#df.loc[df['spatialunit_ontology'] == 'A.ADM1', 'name'] = df['name'].str.slice(2)

# convert origin
df.loc[df['Staatsangehörigkeit (Kategorie) des Kindes'] == 'Staatsangehörigkeit des Kindes - Total', 'Staatsangehörigkeit (Kategorie) des Kindes'] = '-1'
df.loc[df['Staatsangehörigkeit (Kategorie) des Kindes'] == 'Schweiz', 'Staatsangehörigkeit (Kategorie) des Kindes'] = '1'
df.loc[df['Staatsangehörigkeit (Kategorie) des Kindes'] == 'Ausland', 'Staatsangehörigkeit (Kategorie) des Kindes'] = '2'

# convert sex
df.loc[df['Geschlecht des Kindes'] == 'Geschlecht des Kindes - Total', 'Geschlecht des Kindes'] = '-1'
df.loc[df['Geschlecht des Kindes'] == 'Knabe', 'Geschlecht des Kindes'] = '1'
df.loc[df['Geschlecht des Kindes'] == 'Mädchen', 'Geschlecht des Kindes'] = '2'

df['Geschlecht des Kindes'] = df['Geschlecht des Kindes'].astype('category') # reduce memory footprint


# convert age   
df['Altersklasse der Mutter'] = df['Altersklasse der Mutter'].str.split(" ", n=1, expand=True)[0]                    
df.loc[df['Altersklasse der Mutter'] == 'Altersklasse', 'Altersklasse der Mutter'] = '-1'
df.loc[df['Altersklasse der Mutter'] == 'Unter', 'Altersklasse der Mutter'] = '1'
df.loc[df['Altersklasse der Mutter'] == '25-29', 'Altersklasse der Mutter'] = '2'
df.loc[df['Altersklasse der Mutter'] == '30-34', 'Altersklasse der Mutter'] = '3'
df.loc[df['Altersklasse der Mutter'] == '35-39', 'Altersklasse der Mutter'] = '4'
df.loc[df['Altersklasse der Mutter'] == '40', 'Altersklasse der Mutter'] = '5'



df['DATA'] = df['DATA'].astype('int32')
df['Altersklasse der Mutter'] = df['Altersklasse der Mutter'].astype('int32')

maximum=max(df['Jahr'])
df['Jahr'] += STICHTAG

df['period_value'] = np.NAN


df.columns = ['time_value', 'spatialunit_name', 'gender', 'origin', 'age_classes_of_mother', 
              'value', 'spatialunit_ontology', 'spatialunit_current_id', 'period_value']

df = df[['spatialunit_ontology', 'spatialunit_name', 
         'time_value', 'period_value', 'value', 'origin', 'gender', 'age_classes_of_mother', 'spatialunit_current_id']]


df
# Out:
#         spatialunit_ontology spatialunit_name  time_value  period_value  \
# 162                   A.ADM3  Aeugst am Albis  1969-12-31           NaN
# 163                   A.ADM3  Aeugst am Albis  1969-12-31           NaN
# 164                   A.ADM3  Aeugst am Albis  1969-12-31           NaN
# 165                   A.ADM3  Aeugst am Albis  1969-12-31           NaN
# 166                   A.ADM3  Aeugst am Albis  1969-12-31           NaN
# ...                      ...              ...         ...           ...
# 6649339               A.ADM3       La Baroche  2020-12-31           NaN
# 6649340               A.ADM3       La Baroche  2020-12-31           NaN
# 6649341               A.ADM3       La Baroche  2020-12-31           NaN
# 6649342               A.ADM3       La Baroche  2020-12-31           NaN
# 6649343               A.ADM3       La Baroche  2020-12-31           NaN
#
#          value origin gender  age_classes_of_mother  spatialunit_current_id
# 162         13     -1     -1                     -1                       1
# 163          2     -1     -1                      1                       1
# 164          6     -1     -1                      2                       1
# 165          1     -1     -1                      3                       1
# 166          3     -1     -1                      4                       1
# ...        ...    ...    ...                    ...                     ...
# 6649339      0      2      2                      1                    6810
# 6649340      0      2      2                      2                    6810
# 6649341      0      2      2                      3                    6810
# 6649342      0      2      2                      4                    6810
# 6649343      0      2      2                      5                    6810
#
# [6171984 rows x 9 columns]

# %%
df['spatialunit_current_id'].isnull().sum()
# Out:
# 0

# %%
spatial_reference=str(maximum)+"-10-18"
#spatial_reference

df_clean = sbh.convert_current_to_hist_id(df, spatial_reference, os.path.join(repo_dir,"data/spatialunits.csv"))

df_try = df_clean.copy()

#print(df_try.shape)

#print(df_try['spatialunit_hist_id'].isnull().sum())

list_ontologies = ['A.ADM2', 'A.ADM1', 'CH']

list_dimensions = ['origin', 'gender', 'age_classes_of_mother']

#df_adm2 = sbh.add_granularity_levels_up(df_try,list_ontologies, repo_dir, list_dimensions)

df_new = sbh.add_granularity_levels_up(df_try, list_ontologies, repo_dir, list_dimensions)
df_new
# Out:
# /home/b105p02@ji.ktzh.ch/gitrepos/statbot/statbot_helpers/translate_to_spatial_unit_name.py:11: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (2 levels on the left,1 on the right)
#         spatialunit_ontology spatialunit_name  time_value  period_value  \
# 0                     A.ADM3  Aeugst am Albis  1969-12-31           NaN
# 1                     A.ADM3  Aeugst am Albis  1969-12-31           NaN
# 2                     A.ADM3  Aeugst am Albis  1969-12-31           NaN
# 3                     A.ADM3  Aeugst am Albis  1969-12-31           NaN
# 4                     A.ADM3  Aeugst am Albis  1969-12-31           NaN
# ...                      ...              ...         ...           ...
# 6576331                   CH          Schweiz  2020-12-31           NaN
# 6576332                   CH          Schweiz  2020-12-31           NaN
# 6576333                   CH          Schweiz  2020-12-31           NaN
# 6576334                   CH          Schweiz  2020-12-31           NaN
# 6576335                   CH          Schweiz  2020-12-31           NaN
#
#          value origin gender  age_classes_of_mother  spatialunit_hist_id
# 0           13     -1     -1                     -1                13256
# 1            2     -1     -1                      1                13256
# 2            6     -1     -1                      2                13256
# 3            1     -1     -1                      3                13256
# 4            3     -1     -1                      4                13256
# ...        ...    ...    ...                    ...                  ...
# 6576331    874      2      2                      1                    0
# 6576332   2733      2      2                      2                    0
# 6576333   4320      2      2                      3                    0
# 6576334   3291      2      2                      4                    0
# 6576335    955      2      2                      5                    0
#
# [6576336 rows x 9 columns]

# %%
df_new['age_classes_of_mother'].isnull().sum()
# Out:
# 0

# %%
df_new[df_new['spatialunit_name'].isnull()]['spatialunit_hist_id'].unique()
# Out:
# array([10061, 10070, 10093, 10108, 10109, 10110, 10187, 10252, 10320])

# %%
df_new.to_csv(os.path.join(repo_dir,"data/11_11004.csv"), index=False, na_rep='NA')

sys.exit(0)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3457538/891556034.py in <module>
# ----> 1 df_new.to_csv(os.path.join(repo_dir,"data/11_11001.csv"), index=False, na_rep='NA')
#       2
#       3 sys.exit(0)
#
# ~/gitrepos/statbot/statbot_env/lib/python3.9/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3464         )
#    3465
# -> 3466         return DataFrameRenderer(formatter).to_csv(
#    3467             path_or_buf,
#    3468             line_terminator=line_terminator,
#
# ~/gitrepos/statbot/statbot_env/lib/python3.9/site-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# ~/gitrepos/statbot/statbot_env/lib/python3.9/site-packages/pandas/io/formats/csvs.py in save(self)
#     255             )
#     256
# --> 257             self._save()
#     258
#     259     def _save(self) -> None:
#
# ~/gitrepos/statbot/statbot_env/lib/python3.9/site-packages/pandas/io/formats/csvs.py in _save(self)
#     260         if self._need_to_save_header:
#     261             self._save_header()
# --> 262         self._save_body()
#     263
#     264     def _save_header(self) -> None:
#
# ~/gitrepos/statbot/statbot_env/lib/python3.9/site-packages/pandas/io/formats/csvs.py in _save_body(self)
#     298             if start_i >= end_i:
#     299                 break
# --> 300             self._save_chunk(start_i, end_i)
#     301
#     302     def _save_chunk(self, start_i: int, end_i: int) -> None:
#
# ~/gitrepos/statbot/statbot_env/lib/python3.9/site-packages/pandas/io/formats/csvs.py in _save_chunk(self, start_i, end_i)
#     309
#     310         ix = self.data_index[slicer]._format_native_types(**self._number_format)
# --> 311         libwriters.write_csv_rows(
#     312             data,
#     313             ix,
#
# ~/gitrepos/statbot/statbot_env/lib/python3.9/site-packages/pandas/_libs/writers.pyx in pandas._libs.writers.write_csv_rows()
#
# KeyboardInterrupt:
