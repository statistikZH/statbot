# %%
from __future__ import print_function, unicode_literals
import spacy
import warnings
from spacy.util import minibatch, compounding
import de_core_news_lg
import pandas as pd
import numpy as np
from random import sample
import io, csv
import re
import random
import de_core_news_lg
import json
from spacy.training import Example
from spacy.tokens import Doc
nlp = spacy.load('de_core_news_lg')

# %%
# helper function for incrementing the revision counters
def increment_revision_counters(entity_counter, entities):
    for entity in entities:
        label = entity[2]
        if label in entity_counter:
            entity_counter[label] += 1
        else:
            entity_counter[label] = 1

# %%
#out_sentences=open("input/tagged_sentences.csv", "r").readlines()
with open('input/tagged_sentences.json') as json_file:
    out_sentences = json.load(json_file)
print("LENGTH OF DATASET: ",len(out_sentences))
dataset_dict={}

for sent in out_sentences:
    entities = sent[1]["entities"]
    increment_revision_counters(dataset_dict, entities)
#    print(entity[1])
    #helper_dict.append(entity[1]['entities'][0][2])
#out_sentences[:5]
print(dataset_dict)
# Out:
# LENGTH OF DATASET:  1020
# {'DATA': 1010, 'GRAN': 282}

# %%
npr_df = pd.read_csv("external/deu_news_2015_3M-sentences.txt", delimiter = "\t")
npr_df=npr_df.sample(frac=1)
npr_df.head()
# Out:
#                1                                                  ­
# 2504830  2640453  Wer wirklich hinter diesen Straßenbanden steht...
# 2278471  2402490  Um zu retten, was zu retten ist, beantrage Sch...
# 717308    749815  Der Minister war laut Yonhap dabei ertappt wor...
# 2588861  2731655  Zu Beginn der Sommerpause galt der im Juli 201...
# 1602296  1691821  In der Tabelle baute Besiktas (41 Punkte) die ...

# %%
# create an nlp object as we'll use this to seperate the sentences and identify existing entities
#loaded already above
#nlp = spacy.load('de_core_news_lg')

# %%
revision_texts = []

# convert the articles to spacy objects to better identify the sentences. Disabled unneeded components. # takes ~ 4 minutes
for doc in nlp.pipe(npr_df.iloc[:100000,1], batch_size=30, disable=["tagger", "ner"]):
    for sentence in doc.sents:
        if  40 < len(sentence.text) < 80:
            # some of the sentences had excessive whitespace in between words, so we're trimming that
            revision_texts.append(" ".join(re.split("\s+", sentence.text, flags=re.UNICODE)))

# %%
revisions = []

# Use the existing spaCy model to predict the entities, then append them to revision
for doc in nlp.pipe(revision_texts, batch_size=50, disable=["tagger", "parser"]):
    
    # don't append sentences that have no entities
    if len(doc.ents) > 0:
        revisions.append((doc.text, {"entities": [(e.start_char, e.end_char, e.label_) for e in doc.ents]}))

# %%
# print an example of the revision sentence
print(revisions[0][0])

# print an example of the revision data
print(revisions[0][1])
# Out:
# Nö, ich zieh bei einer Paywall oder Desinteresse als Spiele-Nomade weiter.
# {'entities': [(0, 2, 'MISC')]}

# %%
# create arrays to store the revision data
TRAIN_REVISION_DATA = []
TEST_REVISION_DATA = []

# create dictionaries to keep count of the different entities
TRAIN_ENTITY_COUNTER = {}
TEST_ENTITY_COUNTER = {}

# This will help distribute the entities (i.e. we don't want 1000 PERSON entities, but only 80 ORG entities)
REVISION_SENTENCE_SOFT_LIMIT = 100



random.shuffle(revisions)
for revision in revisions:
    # get the entities from the revision sentence
    entities = revision[1]["entities"]

    # simple hack to make sure spaCy entities don't get too one-sided
    should_append_to_train_counter = 0
    for _, _, label in entities:
        if label in TRAIN_ENTITY_COUNTER and TRAIN_ENTITY_COUNTER[label] > REVISION_SENTENCE_SOFT_LIMIT:
            should_append_to_train_counter -= 1
        else:
            should_append_to_train_counter += 1

    # simple switch for deciding whether to append to train data or test data
    if should_append_to_train_counter >= 0:
        TRAIN_REVISION_DATA.append(revision)
        increment_revision_counters(TRAIN_ENTITY_COUNTER, entities)
    else:
        TEST_REVISION_DATA.append(revision)
        increment_revision_counters(TEST_ENTITY_COUNTER, entities)

# %%
TRAIN_ENTITY_COUNTER
# Out:
# {'MISC': 108, 'LOC': 106, 'PER': 101, 'ORG': 104}

# %%
TEST_ENTITY_COUNTER
# Out:
# {'MISC': 7664, 'LOC': 7929, 'ORG': 6219, 'PER': 7331}

# %%
TRAIN_REVISION_DATA
# Out:
# [('Wodka wird trotz Rubel-Krise in Russland billiger',
#   {'entities': [(17, 28, 'MISC'), (32, 40, 'LOC')]}),
#  ('Die aktuelle Rohstoff-Tagesausgabe finden Sie hier.',
#   {'entities': [(13, 34, 'LOC')]}),
#  ('Yanis Varoufakis wird griechischer Finanzminister.',
#   {'entities': [(0, 16, 'PER'), (22, 34, 'MISC')]}),
#  ('Es war eine frustrierende Session, klagt Grosjean über seine Situation:',
#   {'entities': [(41, 49, 'PER')]}),
#  ('Hinter OpenStack stehen Unternehmen wie Cisco, Dell, Intel, HP und SAP.',
#   {'entities': [(7, 16, 'MISC'),
#     (40, 45, 'ORG'),
#     (47, 51, 'ORG'),
#     (53, 58, 'ORG'),
#     (60, 62, 'ORG'),
#     (67, 70, 'ORG')]}),
#  ('Ein Euro-Austritt des Landes werde seitens der Kommission nicht angestrebt.',
#   {'entities': [(22, 28, 'LOC'), (47, 57, 'ORG')]}),
#  ('Damit sind die Kieler Störche seit zwölf Spielen in Folge ungeschlagen.',
#   {'entities': [(15, 29, 'ORG')]}),
#  ('Bahrain: Die Highlights des WEC-Qualifyings: (04:44 Min.)',
#   {'entities': [(0, 7, 'LOC'), (28, 43, 'MISC')]}),
#  ('Die Begründung: Ausgerechnet Latein stelle eine Bildungshürde dar.',
#   {'entities': [(16, 35, 'MISC')]}),
#  ('Master stellt zusätzliche Funktionen für die Zwischenablage bereit.',
#   {'entities': [(0, 6, 'MISC')]}),
#  ('2015 sagt auch mein nicht-russischer Kalendar.',
#   {'entities': [(20, 36, 'MISC')]}),
#  ('Der Traum vom Eigenheim steht und fällt mit dem Kreditgespräch bei der Bank.',
#   {'entities': [(0, 23, 'MISC'), (48, 62, 'MISC')]}),
#  ('Also ich benutze immer Billigtanken Apps für solche Dinge.',
#   {'entities': [(23, 35, 'PER')]}),
#  ('Verantwortlich ist erneut Ghost Games – das Studio entwickelte auch NFS Rivals.',
#   {'entities': [(26, 37, 'MISC'), (68, 78, 'MISC')]}),
#  ('Die clever konternden Gäste gewannen 2:1 im Borussia-Park.',
#   {'entities': [(44, 57, 'LOC')]}),
#  ('«Wirtschaft im Fokus»-Interview mit Felix Schneuwly',
#   {'entities': [(36, 51, 'PER')]}),
#  ('Jonathan versucht, so weit es eben geht, im Hintergrund zu bleiben.',
#   {'entities': [(0, 8, 'PER')]}),
#  ('Von C. Koglbauer-Schöll und R. Pittner Getty Images:',
#   {'entities': [(4, 23, 'PER'), (28, 51, 'PER')]}),
#  ('Kommentarübersicht Gefährdet dies nicht eher die Nutzer?',
#   {'entities': [(0, 28, 'ORG')]}),
#  ('In der Suche tauchen Chromecast, Apple TV und Nexus Player nicht mehr auf.',
#   {'entities': [(33, 41, 'MISC'), (46, 58, 'MISC')]}),
#  ('Büsten berühmter Wissenschaftler, Arkadenhof der Uni Wien.',
#   {'entities': [(49, 57, 'ORG')]}),
#  ('Mit einfachen Worten nimmt ein französischer Vater seinem Sohn die Angst.',
#   {'entities': [(31, 44, 'MISC'), (58, 62, 'PER')]}),
#  ('Der 19-Jährige Pascal Stenzel gibt sein Pflichtspieldebüt für den BVB.',
#   {'entities': [(15, 29, 'PER'), (66, 69, 'ORG')]}),
#  ('Goldene Palme: "Youth" ist der Favorit von Cannes Artikel per E-Mail empfehlen',
#   {'entities': [(0, 13, 'MISC'), (16, 21, 'ORG'), (43, 49, 'LOC')]}),
#  ('Dominik Baumann: Platz fünf im ersten Rennen der Saison war schon in Ordnung.',
#   {'entities': [(0, 15, 'PER')]}),
#  ('Unterstützt werden die beiden außerdem von Dirk Raudies und Lenz Leberkern.',
#   {'entities': [(43, 55, 'PER'), (60, 74, 'PER')]}),
#  ('Uber hat in Frankreich mit einigem Gegenwind zu kämpfen:',
#   {'entities': [(0, 4, 'PER'), (12, 22, 'LOC')]}),
#  ('Einzelkritik zum Bayern-Sieg gegen Zagreb',
#   {'entities': [(17, 28, 'MISC'), (35, 41, 'ORG')]}),
#  ('Sogar der Schulleiter hat Angst gekriegt», sagt Fabrizio.',
#   {'entities': [(48, 56, 'PER')]}),
#  ('Mutter soll Vater zu Mord angestiftet haben',
#   {'entities': [(0, 6, 'PER')]}),
#  ('Axel Springer, ProSiebenSat.1 beteiligen sich an US-Start-up',
#   {'entities': [(0, 13, 'PER'), (15, 29, 'ORG'), (49, 60, 'MISC')]}),
#  ('Die Rheinländer sind vor allem mit der Anbieterwahl beschäftigt:',
#   {'entities': [(4, 15, 'LOC'), (39, 51, 'MISC')]}),
#  ('Update auf Intel "Skylake", neue Modelle mit 16 GB RAM und max. 1',
#   {'entities': [(11, 16, 'ORG'), (18, 25, 'MISC')]}),
#  ('Auch Kammermusik mit dem Klavierhaus Pyschny steht auf dem Programm.',
#   {'entities': [(25, 44, 'LOC')]}),
#  ('Für Spieler hat Amazon 16 verschiedene Titel ausgesucht.',
#   {'entities': [(16, 25, 'MISC')]}),
#  ('Man führt das auf die Omega-3-Fettsäuren zurück.',
#   {'entities': [(22, 40, 'LOC')]}),
#  ('Also weigern wir uns, Angst zu haben", sagt auch Mélodie Beaujeu.',
#   {'entities': [(49, 64, 'PER')]}),
#  ('FUSSBALL Darmstadt 98 erhält Lizenz nur mit Auflagen LEICHTATHLETIK',
#   {'entities': [(0, 21, 'ORG'), (53, 67, 'ORG')]}),
#  ('Zu dem Anschlag bekannten sich die Taliban.',
#   {'entities': [(35, 42, 'ORG')]}),
#  ('Auch Braunschweigs Ken Reichel muss raus - glatt Rot!',
#   {'entities': [(5, 18, 'LOC'), (19, 30, 'PER')]}),
#  ('In diesen Wochen laufen die Fotomaschinen bei Cewe in Germering auf Hochtouren.',
#   {'entities': [(46, 50, 'ORG'), (54, 63, 'LOC')]}),
#  ('Und hat Franziskus nicht schon öfter alle überrascht?',
#   {'entities': [(8, 18, 'PER')]}),
#  ('«Wir glauben, so etwas muss man weltweit machen», sagt Visbeck.',
#   {'entities': [(55, 62, 'PER')]}),
#  ('Ach nein, die sind ja nicht von Microsoft!',
#   {'entities': [(32, 41, 'ORG')]}),
#  ('Tirtza beschreibt die Beziehung zu ihrem Kind als Anomalie.',
#   {'entities': [(0, 6, 'PER')]}),
#  ('Der Polo R WRC präsentiert sich in neuem Gewand.',
#   {'entities': [(4, 14, 'MISC')]}),
#  ('Am Dienstag wurde in Zürich das erste selbstfahrende Auto vorgeführt.',
#   {'entities': [(21, 27, 'LOC')]}),
#  ('Weltweit wird der Boden knapper Jeden Tag werden in Deutschland',
#   {'entities': [(52, 63, 'LOC')]}),
#  ('Kirschbaum kommt vom Bundesligisten VfB Stuttgart nach Mittelfranken.',
#   {'entities': [(0, 10, 'PER'),
#     (21, 35, 'ORG'),
#     (36, 49, 'ORG'),
#     (55, 68, 'LOC')]}),
#  ('Das teilten die Fachleute von "Visit Berlin" mit.',
#   {'entities': [(31, 43, 'ORG')]}),
#  ('Nach Abschluss des Geschäftsjahrs 2014 wurde Catz Co-CEO von Oracle.',
#   {'entities': [(45, 49, 'PER'), (61, 67, 'ORG')]}),
#  ('Wir im reichen Westen haben diesbezüglich eine Verpflichtung», sagt Wildberger.',
#   {'entities': [(68, 78, 'PER')]}),
#  ('Das Griechenland-Drama geht erneut in die Fortsetzung;',
#   {'entities': [(4, 22, 'ORG')]}),
#  ('Mitarbeiter von Schloss Windsor drohen mit Arbeitskampf',
#   {'entities': [(16, 31, 'LOC')]}),
#  ('Zensor Walowski wird von Michael Weibel entsprechend etwas hölzern gegeben.',
#   {'entities': [(7, 15, 'PER'), (25, 39, 'PER')]}),
#  ('Außerdem soll das Open-World-Spektakel nun seltener zu Abstürzen neigen.',
#   {'entities': [(18, 38, 'MISC')]}),
#  ("08:52 Warburg Research belässt Fuchs Petrolub auf 'Hold' - Ziel 42 Euro",
#   {'entities': [(6, 22, 'ORG'), (31, 45, 'ORG')]}),
#  ('Der Auftrag Di Matteos war eindeutig: Den Sieg über die Zeit bringen.',
#   {'entities': [(12, 22, 'PER'), (56, 60, 'MISC')]}),
#  ('Das kleine Land leitet sie zur österreichischen Grenze weiter.',
#   {'entities': [(31, 54, 'LOC')]}),
#  ('Auch nicht näher benannte Grafik-Verbesserungen werden versprochen.',
#   {'entities': [(26, 47, 'MISC')]}),
#  ('Eveline Widmer Schlumpf spricht in Bern über den Gesetztesentwurf zum AIA.',
#   {'entities': [(0, 23, 'PER'), (35, 39, 'LOC'), (70, 73, 'ORG')]}),
#  ('Der deutsche Maschinenbau-Ingenieur ist zu gut für die Welt.',
#   {'entities': [(4, 12, 'MISC')]}),
#  ('Gerüchte sehen Mourinho in Paris schon wieder mit Cristiano Ronaldo vereint.',
#   {'entities': [(15, 23, 'PER'), (27, 32, 'LOC'), (50, 67, 'PER')]}),
#  ('Williams möchte aus eigener Kraft an die Spitze.',
#   {'entities': [(0, 8, 'PER')]}),
#  ('Es gibt VerliererInnen - und zwar diejenigen Menschen, die wenig Geld haben.',
#   {'entities': [(8, 22, 'MISC')]}),
#  ('Damit können auch die Kleinimporteure und Occasionshändler durch\xadatmen.',
#   {'entities': [(42, 58, 'LOC')]}),
#  ('Hopping Reisetipps in Griechenland präsentiert von:',
#   {'entities': [(0, 18, 'MISC'), (22, 34, 'LOC')]}),
#  ('Am Ende ließ Steffens noch das 2:5 folgen.',
#   {'entities': [(13, 21, 'PER')]}),
#  (' 2147850 Roberto Zanetti (SP/SO) sprach sich ebenfalls für die Vorlage aus.',
#   {'entities': [(9, 24, 'PER'), (26, 28, 'ORG')]}),
#  ('Mit dem ist das DS-Topmodell keine Rakete, aber läuft seidig.',
#   {'entities': [(16, 28, 'ORG')]}),
#  ('Allerdings musste Vizebürgermeisterin Louise Madi ihr Amt abgeben, der..',
#   {'entities': [(38, 49, 'PER')]}),
#  ('Der Wille zur Freiheit lässt sich nicht brechen',
#   {'entities': [(0, 22, 'MISC')]}),
#  ("In Kooperation mit O’Reilly verlegt Heise Medien die Zeitschrift c't Make:.",
#   {'entities': [(19, 27, 'MISC'), (36, 48, 'MISC'), (65, 73, 'MISC')]}),
#  ('Das System tritt mit dem Eurobeitritt Litauens zum 1. Januar in Kraft.',
#   {'entities': [(38, 46, 'LOC')]}),
#  ('Der Vorwurf des Landesverrats gegen Journalisten gilt als heikel.',
#   {'entities': [(16, 48, 'LOC')]}),
#  ('Statistik Austria: Zahl der Einbürgerungen im Jahr 2014 um 3,7 % gestiegen',
#   {'entities': [(0, 17, 'ORG')]}),
#  ('Supermarktriese testet Lieferservice zum Festpreis',
#   {'entities': [(23, 36, 'ORG')]}),
#  ('Die Neuerungen von Watch OS 2 waren allerdings schon bekannt.',
#   {'entities': [(19, 29, 'MISC')]}),
#  ('Schweiz erlebt historischen Rechtsruck bei Parlamentswahlen',
#   {'entities': [(0, 7, 'LOC')]}),
#  ('BRÜSSEL - Die Verhandlungen für das transatlantische Handelsabkommen',
#   {'entities': [(0, 7, 'LOC')]}),
#  ('Sich selbst beschreibt sie als "normale Frau aus dem Volk".',
#   {'entities': [(0, 4, 'PER')]}),
#  ('Diesen Prozess in seiner Vollständigkeit findet Woelfl wichtig.',
#   {'entities': [(48, 54, 'PER')]}),
#  ('In der Vorschlussrunde muss Deutschland nun Mitte April in Russland antreten.',
#   {'entities': [(28, 39, 'LOC'), (59, 67, 'LOC')]}),
#  ('Die 180 Franken werden den Parlamentariern darum auf ihr Konto überwiesen.',
#   {'entities': [(8, 15, 'LOC')]}),
#  (' 1148169 Dortmund hat so gut wie keine Chancen.',
#   {'entities': [(9, 17, 'LOC')]}),
#  ('GC-Star mit emotionaler Rede zu Flüchtlings-Krise 23 848 blick.',
#   {'entities': [(0, 7, 'MISC'), (32, 49, 'MISC')]}),
#  ('Auch 2014 gab es für Deutschland bei der Untersuchung den zehnten Platz.',
#   {'entities': [(21, 32, 'LOC'), (58, 71, 'LOC')]}),
#  ('Eva Longoria plauderte ein jahrelang streng gehütetes Geheimnis aus.',
#   {'entities': [(0, 12, 'PER')]}),
#  ('In Ungarn, Italien oder Griechenland würden Flüchtlinge unmenschlich behandelt;',
#   {'entities': [(3, 9, 'LOC'), (11, 18, 'LOC'), (24, 36, 'LOC')]}),
#  ('Eine OFFENE Diskussion über Ihr Buch "Pep Guardiola:',
#   {'entities': [(5, 11, 'ORG'), (28, 36, 'MISC'), (38, 51, 'PER')]}),
#  ('Eine Boeing 777 von Emirates - hier über Dubai.',
#   {'entities': [(5, 15, 'MISC'), (20, 28, 'LOC'), (41, 46, 'LOC')]}),
#  ('Mit den Al-Kaida-nahen Gruppen ist er verfeindet.',
#   {'entities': [(8, 30, 'MISC')]}),
#  ('Der Vorarlberger will auf den kommenden Etappen in Ausreißergruppen mitmischen.',
#   {'entities': [(4, 16, 'LOC'), (51, 67, 'LOC')]}),
#  ('Seit Ende des 2. Weltkrieges handeln die USA nach diesem Muster.',
#   {'entities': [(14, 28, 'MISC'), (41, 44, 'LOC')]}),
#  ('Glauben Sie an die Sommerprognose der "Böögg"-Verbrennung?',
#   {'entities': [(39, 57, 'ORG')]}),
#  ('Erzbischöfliches Diözesanmuseum (Markt 17):',
#   {'entities': [(0, 31, 'LOC')]}),
#  ('Nestlé betreibt heute im Iran zwei Fabriken:',
#   {'entities': [(0, 6, 'ORG'), (25, 29, 'LOC')]}),
#  ('Verfassungsschutz: Der Preis sind unsere Daten',
#   {'entities': [(0, 17, 'ORG')]}),
#  ('Aber auch die aktuelle Terrorbedrohung in Europa laste auf der Stimmung.',
#   {'entities': [(42, 48, 'LOC')]}),
#  ('Wir schicken dann ein ganzes Paket an europäische Radiosender.',
#   {'entities': [(0, 12, 'MISC'), (38, 49, 'MISC')]}),
#  ('Vettel gewinnt irren Nachtspuk in Singapur',
#   {'entities': [(0, 6, 'PER'), (34, 42, 'LOC')]}),
#  ('Zudem sollen mehrere Fremdgeher auch noch Opfer von Erpressungsversuchen sein.',
#   {'entities': [(52, 72, 'MISC')]}),
#  ('Einmal in Front, braust Marquez unaufhaltsam davon.',
#   {'entities': [(24, 31, 'PER')]}),
#  ('Antworten Hansli sagt: 22. April 2015 um 12:33',
#   {'entities': [(10, 16, 'PER')]}),
#  ('Der Bundestag bekommt eine neue IT-Infrastruktur',
#   {'entities': [(4, 13, 'ORG')]}),
#  ('Fehlende staatliche Investitionen reduzieren Produktivitätsfortschritte',
#   {'entities': [(45, 71, 'LOC')]}),
#  ('Und auch Unterhaltungsfilme können es schaffen, Stoff zum nachdenken zu geben.',
#   {'entities': [(9, 27, 'MISC')]}),
#  ('Auch hier: Kein Feature, das wir in Fallout 4 wirklich vermissen.',
#   {'entities': [(36, 45, 'MISC')]}),
#  ('Die Frage ist jetzt, wie die Eurozone und die EZB darauf reagieren.',
#   {'entities': [(29, 37, 'LOC'), (46, 49, 'ORG')]}),
#  ('Von Silke Mülherr, Athen Foto: picture alliance / ZUMAPRESS.com',
#   {'entities': [(4, 17, 'PER'), (19, 24, 'LOC')]}),
#  ('Der "Faux Browser" für iOS: So kommt Ihnen niemand auf die Spur.',
#   {'entities': [(23, 26, 'MISC')]}),
#  ('Fricke ließ vorsichtshalber den Start- und Zielbogen gar nicht erst aufbauen.',
#   {'entities': [(0, 6, 'PER')]}),
#  ('Amnesty wirft Separatisten Hinrichtungen vor',
#   {'entities': [(0, 7, 'ORG')]}),
#  ('Bloodborne habe die Erwartungen übertroffen.',
#   {'entities': [(0, 10, 'MISC')]}),
#  ('Etwa die Hälfte der Deutschen hat noch nie Kleidung zum Schneider gebracht.',
#   {'entities': [(20, 29, 'MISC')]}),
#  ('Schneiter: Wollen wir einen öffentlichen Platz, müssen wir in die Höhe bauen.',
#   {'entities': [(0, 17, 'MISC')]}),
#  ('Bundeskanzlerin Angela Merkel (CDU) trifft auf den YouTuber LeFloid.',
#   {'entities': [(16, 29, 'PER'), (31, 34, 'ORG'), (60, 67, 'PER')]}),
#  ('Im Fiat Multipla erwies sich das als Trugschluss.',
#   {'entities': [(3, 16, 'MISC')]}),
#  ('Außer in Varieté-Clubs in Paris aufzutreten - oder vor dem EU-Parlament.',
#   {'entities': [(9, 22, 'LOC'), (26, 31, 'LOC'), (59, 71, 'ORG')]}),
#  ('Haltern trauert um Opfer des Germanwings-Absturzes DPA',
#   {'entities': [(0, 7, 'PER'), (29, 50, 'MISC')]}),
#  ('Ex-Meister Bayern ist als Gastgeber automatisch qualifiziert.',
#   {'entities': [(0, 17, 'ORG')]}),
#  ('Telekom-Konkurrenz kritisiert Empfehlungen',
#   {'entities': [(0, 18, 'PER')]}),
#  ('AMD Bristol Ridge (Bild: Benchlife) AMD Bristol Ridge (Bild: Benchlife)',
#   {'entities': [(0, 3, 'LOC'),
#     (25, 34, 'PER'),
#     (36, 39, 'LOC'),
#     (40, 53, 'LOC'),
#     (61, 70, 'LOC')]}),
#  ('Die Schwarz-Weiß-Aufnahmen sind derzeit in der Zebra One Gallery zu sehen.',
#   {'entities': [(47, 64, 'LOC')]}),
#  ('Zuvor hatten auch die USA die Taten verurteilt.',
#   {'entities': [(22, 25, 'LOC')]}),
#  ('In England gibt es vier Millionen Aktive, in Österreich 250 in zehn Klubs.',
#   {'entities': [(3, 10, 'LOC'), (45, 55, 'LOC')]}),
#  ('Doch bei Bale ist die Kritik grösser, stärker verzerrt von der Lupe.',
#   {'entities': [(9, 13, 'PER'), (63, 67, 'LOC')]}),
#  ('Tipp: Am Mittwoch, 25. November kommen IAMX in die Wiener Arena.',
#   {'entities': [(0, 4, 'PER'), (39, 43, 'ORG'), (51, 63, 'LOC')]}),
#  ('Zuletzt hat sich der HSV zweimal erst in der Relegation gerettet.',
#   {'entities': [(21, 24, 'ORG')]}),
#  ('Da fiel ihm die Übergabe an Andy Borg so gar nicht leicht.',
#   {'entities': [(28, 37, 'PER')]}),
#  ('Antwort schreiben von Christof Kochanowski',
#   {'entities': [(22, 42, 'PER')]}),
#  ('Hier anmelden und Mitglied im L-IZ Leserclub werden',
#   {'entities': [(35, 44, 'MISC')]}),
#  ('Zum Thema Project Cars ab 47,99 € bei Amazon.de',
#   {'entities': [(10, 22, 'MISC'), (38, 47, 'ORG')]}),
#  ('Der Aktionsplan und Nebenabreden sehen unter anderem Folgendes vor:',
#   {'entities': [(4, 32, 'MISC')]}),
#  ('Die Sicherheitslage in der Ukraine bleibt kritisch.',
#   {'entities': [(27, 34, 'LOC')]}),
#  ('Schluss: Leichte Kursverluste nach Weihnachten',
#   {'entities': [(35, 46, 'MISC')]}),
#  ('EZB prüft Parallelwährung für Griechenland',
#   {'entities': [(0, 3, 'ORG'), (30, 42, 'LOC')]}),
#  ('Mit dem neuen Newsletter des Bieler Tagblatt.',
#   {'entities': [(29, 44, 'ORG')]}),
#  ('Windows 10: ISO-Dateien stehen zum Download bereit (Update)',
#   {'entities': [(0, 10, 'MISC'), (12, 23, 'MISC')]}),
#  ('Schirmherr ist der Bundesminister für Wirtschaft und Energie, Sigmar Gabriel.',
#   {'entities': [(19, 60, 'ORG'), (62, 76, 'PER')]}),
#  ('Ein Leben ohne Arbeit ist für ihn unvorstellbar.',
#   {'entities': [(0, 21, 'MISC')]}),
#  ('Spieler mit schwächeren PCs hätten hier das Nachsehen.',
#   {'entities': [(24, 27, 'MISC')]}),
#  ('Die Firma gehört wie E.ON bereits zu den Betreibern der ersten beiden Stränge.',
#   {'entities': [(21, 25, 'ORG')]}),
#  ('Bei FTI laufen preisreduzierte Zimmer unter unterschiedlichen Namen.',
#   {'entities': [(4, 7, 'ORG')]}),
#  ('Jetzt stimmen die Leser über das schönste dieser Bilder aus dem Jahr 2014 ab.',
#   {'entities': [(64, 73, 'MISC')]}),
#  ('u.a. 3. Deutsche, der Artikel dazu erschien auf SPON, *ohne Kommentarfunktion*.',
#   {'entities': [(5, 16, 'MISC'), (48, 52, 'ORG')]}),
#  ('In Amerika können die Ränder nur in den Vorwahlen auftrumpfen.',
#   {'entities': [(3, 10, 'LOC')]}),
#  ('Gianis Varoufakis sorgt mit seinem Video für Aufsehen.',
#   {'entities': [(0, 17, 'PER')]}),
#  ('Zum Thema Evolve ab 19,99 € bei Amazon.de',
#   {'entities': [(10, 16, 'MISC'), (32, 41, 'ORG')]}),
#  ('Es macht Riesenspaß, in so einer Mannschaft Fußball zu spielen."',
#   {'entities': [(9, 19, 'MISC')]}),
#  ('Biografie und alle Artikel des Autors Facebook Twitter Redakteur',
#   {'entities': [(38, 54, 'MISC')]}),
#  ('Sicherheit und Datenschutz unter Office 2010:',
#   {'entities': [(33, 39, 'ORG')]}),
#  ('Wie sah der Lobbyismus der Deutschen aus?, so Schenk in der "FAS".',
#   {'entities': [(27, 36, 'MISC'), (46, 52, 'PER'), (61, 64, 'ORG')]}),
#  ('Jetzt heiratet das Supermodel einen israelischen Geschäftsmann.',
#   {'entities': [(36, 48, 'MISC')]}),
#  ('Die letztgenannte Option benötigt rund 60 MByte pro Videominute.',
#   {'entities': [(52, 63, 'MISC')]}),
#  (', beschwerte sich der Trainer: "Es sprechen zu viele Leute hier in Deutschland.',
#   {'entities': [(67, 78, 'LOC')]}),
#  ('Die Machthaber in Kiew scheinen nicht gänzlich Herr der Lage zu sein;',
#   {'entities': [(18, 22, 'LOC')]}),
#  ('«Aber wir haben wochenlang nichts von Nez Rouge Schweiz gehört.',
#   {'entities': [(38, 55, 'LOC')]}),
#  ('Das ist das Selbstmörderische an uns Russen.',
#   {'entities': [(12, 29, 'LOC'), (37, 43, 'LOC')]}),
#  ("Gomes' Zugang ist offen und vielgestaltig zugleich:",
#   {'entities': [(0, 5, 'PER')]}),
#  ('Die Premier League läuft auch bei Regen, Schnee und Kälte auf Hochtouren.',
#   {'entities': [(4, 18, 'MISC')]}),
#  ('Eine Haltefrist für diese Aktien wird es nicht geben, so Scheifele.',
#   {'entities': [(57, 66, 'PER')]}),
#  ('Vasks schrieb symphonische Werke, Kammermusik, Orgelmusik und anderes.',
#   {'entities': [(0, 5, 'PER')]}),
#  ('Kenne die Vereinsgeschichte der Foxes nicht, aber meint Er wirklich Inler?',
#   {'entities': [(32, 37, 'ORG')]}),
#  ('Wir haben im Koalitionsvertrag ein Entgeltgleichheitsgesetz festgelegt.',
#   {'entities': [(13, 30, 'MISC')]}),
#  ('Auch im Hauptmarkt China sind die Erlöse rückläufig.',
#   {'entities': [(8, 24, 'LOC')]}),
#  ('Was hat er zu Traditionsstrecken zu sagen?',
#   {'entities': [(14, 32, 'MISC')]}),
#  ('Steinkampstraße in Wetter von einem Pkw angefahren.',
#   {'entities': [(19, 25, 'LOC')]}),
#  ('Sie sehen den sozialen Frieden in Gefahr?',
#   {'entities': [(14, 40, 'MISC')]}),
#  ('Der Arbeitgeber-präsident (heute FAZ) fordert eine Obergrenze.',
#   {'entities': [(33, 36, 'ORG')]}),
#  ('Offiziell führt die Berliner Immobilienmanagement GmbH (BIM) die Verhandlungen.',
#   {'entities': [(20, 28, 'MISC'), (56, 59, 'ORG')]}),
#  ('Das passiert in unserem Gehirn, wenn wir lachen Berlin (Reuters) -',
#   {'entities': [(48, 54, 'LOC'), (56, 63, 'ORG')]}),
#  ('Europäische Union, EZB und IWF könnten helfen.',
#   {'entities': [(0, 17, 'ORG'), (19, 22, 'ORG'), (27, 30, 'ORG')]}),
#  ('08:27 Gerresheimer AG: Ausbruch über kurzfristige Trendlinie (64.93 Euro, Long)',
#   {'entities': [(6, 21, 'ORG'), (74, 78, 'MISC')]}),
#  ('Die Jungs haben für Sonntag ihre Flüge nach Mallorca gebucht.',
#   {'entities': [(44, 52, 'LOC')]}),
#  ('Deutsche Waffenexporte deutlich gestiegen Berlin.',
#   {'entities': [(0, 8, 'MISC'), (42, 48, 'LOC')]}),
#  ('Die Krise, die Hollande meint, ist nicht nur eine der Wirtschaft.',
#   {'entities': [(15, 23, 'LOC')]}),
#  ('Arzneimittel AG: Neues 52-Wochenhoch (34.44 Euro, Long)',
#   {'entities': [(0, 15, 'ORG'), (50, 54, 'MISC')]}),
#  ('Der Rückstand auf Sieger Valentino Rossi war mit mehr als 1:48 Minuten groß.',
#   {'entities': [(25, 40, 'PER')]}),
#  ('Nach dem Handy nun das Tablet mit 3D-Raumerkennung:',
#   {'entities': [(23, 29, 'MISC')]}),
#  ('AFP Lisa Zimmermann gewinnt WM-Gold im Ski-Slopestyle',
#   {'entities': [(0, 3, 'ORG'),
#     (4, 19, 'PER'),
#     (28, 35, 'MISC'),
#     (39, 53, 'MISC')]}),
#  ('In Monza fuhr die Formel 1 bisher am häufigsten.',
#   {'entities': [(3, 8, 'ORG'), (18, 26, 'ORG')]}),
#  ('Matthews ist der ideale Massstab für die NLA.',
#   {'entities': [(0, 8, 'LOC'), (41, 44, 'MISC')]}),
#  ('Blackrock gilt in der Branche als Vorbild.', {'entities': [(0, 9, 'ORG')]}),
#  ('Asylsuchende : Tschechien sperrt Flüchtlinge ein',
#   {'entities': [(15, 25, 'LOC')]}),
#  ('Bier-Trick, Rib-Eye-Steak, Nutella-Dessert',
#   {'entities': [(0, 10, 'LOC'), (12, 25, 'LOC'), (27, 42, 'LOC')]}),
#  ('Die damaligen Abbaupläne haben wir inzwischen korrigiert:',
#   {'entities': [(14, 24, 'MISC')]}),
#  ('Das Unternehmen bestätigte über Twitter einen Medienbericht von CNBC.',
#   {'entities': [(32, 39, 'MISC'), (64, 68, 'ORG')]}),
#  ('R5 weltweit in zahlreichen Rallye-Serien vertreten sein.',
#   {'entities': [(0, 2, 'MISC')]}),
#  ('Seit gestern Morgen stauen sich die Fahrzeuge vor dem Gotthard-Nordportal.',
#   {'entities': [(54, 73, 'MISC')]}),
#  ('Sie treffen ja morgen auf Kanzlerin Merkel.',
#   {'entities': [(36, 42, 'PER')]}),
#  ('Der Kurs der Suzuki-Aktie hat sich seit dem Jahr 2009 beinahe verdoppelt.',
#   {'entities': [(44, 53, 'MISC')]}),
#  ('Wien (OTS) - "Gleiche Chancen, gleiche Rechte, gleicher Respekt.',
#   {'entities': [(0, 4, 'LOC'), (6, 9, 'ORG')]}),
#  ('Weebly will sein Europageschäft ausbauen.', {'entities': [(0, 6, 'MISC')]}),
#  ('Weniger ist, gerade bei zu erwartenden Netzzugriffen mehr.',
#   {'entities': [(39, 52, 'LOC')]}),
#  ('Dinamo steckt derzeit ohnehin in den Negativ-Schlagzeilen.',
#   {'entities': [(0, 6, 'ORG'), (37, 57, 'LOC')]}),
#  ('Merkel warb auf dem EU-Balkangipfel dafür, die Grenzen abzudichten.',
#   {'entities': [(0, 6, 'PER'), (20, 35, 'MISC')]}),
#  ('Diffiziler gestaltet sich die Angelegenheit bei Ingrid Korosec.',
#   {'entities': [(0, 10, 'PER'), (48, 62, 'PER')]}),
#  ('Tipp: das Bild anklicken um den Code neu zu generieren',
#   {'entities': [(0, 4, 'PER')]}),
#  ('Sein Rückstand auf Aru beträgt 19 Sekunden.',
#   {'entities': [(19, 22, 'PER')]}),
#  ('Die Schweizer machen ihre Grenze für deutsche Bringdienste dicht.',
#   {'entities': [(4, 13, 'MISC'), (37, 45, 'MISC')]}),
#  ('Die Begeisterung für Technik und Forschung wird ihm bei der Esa Antrieb sein.',
#   {'entities': [(60, 63, 'ORG')]}),
#  ('Game of Thrones: Trailer zur 3. Episode des Videospiels Aktuelle',
#   {'entities': [(0, 15, 'MISC')]}),
#  ('Genießen Sie alle Vorteile Ihres persönlichen RP',
#   {'entities': [(46, 48, 'MISC')]}),
#  ('DGAP-PVR: Stabilus S.A.: Veröffentlichung gemäß § 26 Abs. 1',
#   {'entities': [(0, 8, 'MISC'), (25, 41, 'LOC')]}),
#  ('Antwort schreiben von Alfred Neumann 08:26',
#   {'entities': [(22, 36, 'PER')]}),
#  ('BL macht Spass mit anderen Mannschaften und nicht nur mit den Bayern.',
#   {'entities': [(0, 2, 'LOC'), (62, 68, 'LOC')]}),
#  ('Nach Abschluss der WM gab es einen sauberen Prüfungsbericht.',
#   {'entities': [(19, 21, 'MISC')]}),
#  ('Der Spielehersteller Valve hat ein eigenes Betriebssystem angekündigt.',
#   {'entities': [(21, 26, 'ORG')]}),
#  ('Das umgekehrte Bild bot sich beim 3:1-Sieg in Mainz.',
#   {'entities': [(46, 51, 'ORG')]}),
#  ('Henkel AG : Kreuzen des GD 38 nach oben (92.62 Euro, Long)',
#   {'entities': [(0, 9, 'ORG'), (24, 29, 'MISC'), (53, 57, 'MISC')]}),
#  ('Barclays hat ihre Brent-Schätzung sogar auf 44 Dollar von 72 Dollar gesenkt.',
#   {'entities': [(0, 8, 'ORG'), (18, 33, 'MISC')]}),
#  ('All diese Faktoren tragen auch dazu bei, dass Wien immer jünger wird.',
#   {'entities': [(46, 50, 'LOC')]}),
#  ('Dabei hat vor \xadallem Vocento viel aufzuholen.',
#   {'entities': [(14, 28, 'ORG')]}),
#  ('Jay Z stellt sein Streaming-Service Tidal vor Eklig!',
#   {'entities': [(0, 5, 'PER'), (36, 41, 'MISC'), (46, 52, 'ORG')]}),
#  ('Über den Ursprung des Gänsebratens gibt es zahlreiche Legenden.',
#   {'entities': [(22, 34, 'LOC')]}),
#  ('Das Mittelstands- und Immobiliengeschäft soll wachsen.',
#   {'entities': [(4, 40, 'ORG')]}),
#  ('In der Schweiz ist der Umgang damit sprachregional verschieden.',
#   {'entities': [(7, 14, 'LOC')]}),
#  ('Eine der drei USB-Schnittstellen unterstützt den USB-3.0-Standard.',
#   {'entities': [(49, 65, 'LOC')]}),
#  ('Berlin: Mann, der in S-Bahn auf Kinder urinierte, wurde verhaftet',
#   {'entities': [(0, 6, 'LOC'), (8, 12, 'PER'), (21, 27, 'LOC')]}),
#  ('Einen Nachfolger haben die Volleys noch nicht gefunden.',
#   {'entities': [(27, 34, 'ORG')]}),
#  ('Als Geldgeber saßen 2008 noch das Land NRW und Evonik Industries im Boot.',
#   {'entities': [(34, 42, 'LOC'), (47, 64, 'ORG')]}),
#  ("Im nächsten Serien-Teil Mirror's Edge Catalyst soll das nun anders werden.",
#   {'entities': [(24, 46, 'MISC')]}),
#  ('Dies führte zu Protest der AKW-Betreiber, die teure Nachrüstungen fürchteten.',
#   {'entities': [(27, 40, 'ORG')]}),
#  ('Die Sanktionen gegen Russland hätten "nicht die Wirkung, die man sich erhofft";',
#   {'entities': [(21, 29, 'LOC')]}),
#  ('Euro-Gruppe: Keine Einigung mit Griechenland Direkt aus dem Reuters-Videokanal',
#   {'entities': [(0, 11, 'ORG'), (32, 44, 'LOC'), (60, 78, 'LOC')]}),
#  ('Wendt schlägt am Ball vorbei, Klaus schießt aber am Tor vorbei.',
#   {'entities': [(0, 5, 'PER'), (30, 35, 'PER')]}),
#  ('Nach Angaben der Volkswehr zog das Militär seine Waffen nur teilweise ab.',
#   {'entities': [(35, 42, 'ORG')]}),
#  ('Schluss: ATX klettert bis Handelsende ins Plus',
#   {'entities': [(9, 12, 'MISC')]}),
#  ('Julius-Bär reagiert auf den starken Franken und baut 200 Stellen ab.',
#   {'entities': [(0, 10, 'PER'), (36, 43, 'LOC')]}),
#  ('Für ihn ist es die vierte Saison bei Zurbuchen.',
#   {'entities': [(37, 46, 'ORG')]}),
#  ('Die Eurogruppe will Reformen sehen, dann wird gezahlt.',
#   {'entities': [(4, 14, 'ORG'), (20, 28, 'MISC')]}),
#  ('Sie rät auch, die Wirkung von Gingium zu testen.',
#   {'entities': [(30, 37, 'LOC')]}),
#  ('In die Zukunft blickt Valora trotz des schwachen Euro optimistisch.',
#   {'entities': [(22, 28, 'ORG')]}),
#  ('FOCUS-Online-Quiz: Können wir erraten, ob Sie Rechts- oder Linkshänder sind?',
#   {'entities': [(0, 17, 'MISC')]}),
#  (' 21659 70-Quadratmeter-Wohnungen sind heiß begehrt',
#   {'entities': [(7, 32, 'MISC')]}),
#  ('Ein Verbot der Protestmärsche lehnt Maas aber ab.',
#   {'entities': [(36, 40, 'PER')]}),
#  ('Woran genau ist die Nato, ist Deutschland, in Afghanistan gescheitert?',
#   {'entities': [(20, 24, 'ORG'), (30, 41, 'LOC'), (46, 57, 'LOC')]}),
#  ('Dort führt seit dem Tod seines Vaters Bill Shea junior die Geschäfte.',
#   {'entities': [(38, 54, 'PER')]}),
#  ('Der Zoo Leipzig feierte am 10. August 2013 seine exotische Dschungelnacht.',
#   {'entities': [(4, 15, 'LOC')]}),
#  ('Sie Fleischsuppe mit viel Ge\xadmüse, bis Sie satt sind.',
#   {'entities': [(4, 16, 'LOC'), (26, 33, 'ORG')]}),
#  ('Fotostrecke: Das Leben von Helmut Schmidt',
#   {'entities': [(27, 41, 'PER')]}),
#  ('Und das war mit dem Konzept von Ben Bowlby nicht der Fall.',
#   {'entities': [(32, 42, 'PER')]}),
#  ('Die Geschäftsleitung der Firma ReinSaat KG aus St. Leonhard am..',
#   {'entities': [(31, 42, 'ORG'), (47, 64, 'LOC')]}),
#  ('Seinen Teil dazu beigetragen hat der heutige HSV-Coach Bruno Labbadia.',
#   {'entities': [(55, 69, 'PER')]}),
#  ('Zwar soll mehr Geld in die Frontex-Grenzschutzoperation Triton gesteckt werden.',
#   {'entities': [(27, 62, 'MISC')]}),
#  ('Doch diesmal gehen die Konservativen weiter.',
#   {'entities': [(23, 36, 'ORG')]}),
#  ('Der grosse Beobachter-Ratgeber 30 Jahre Beobachter-Ratgeber:',
#   {'entities': [(11, 59, 'MISC')]}),
#  ('Zuletzt ist die Infineon-Aktie erneut an der 12-Euro-Marke abgeprallt.',
#   {'entities': [(16, 30, 'ORG')]}),
#  ('Riesenschreck am Sonntag Abend für die Bewohner eines Hauses in Wulfen.',
#   {'entities': [(0, 13, 'PER'), (64, 70, 'LOC')]}),
#  ('Nachrichten, aktuelle Schlagzeilen und Videos: n-tv.de',
#   {'entities': [(39, 45, 'MISC'), (47, 54, 'ORG')]}),
#  ('Zum Jahresauftakt steigt das Topspiel gegen Elversberg',
#   {'entities': [(44, 54, 'ORG')]}),
#  ('Büste von Claudio Abbado enthüllt Sie ist in der Berliner Philharmonie zu sehen',
#   {'entities': [(10, 24, 'PER'), (49, 70, 'LOC')]}),
#  ('Lasogga (re.) traf doppelt, Müller (li.) erhöhte.',
#   {'entities': [(0, 7, 'PER')]}),
#  (' 2163259 Sankt Augustins Bürgermeister dankte allen Beteiligten:',
#   {'entities': [(15, 24, 'PER')]}),
#  ('Carljn Smallenburgs Leiche wurde in den Trümmern gefunden.',
#   {'entities': [(0, 19, 'PER')]}),
#  ('Vor dem Parlament in Kapstadt herrschte Chaos.',
#   {'entities': [(21, 29, 'LOC'), (40, 45, 'PER')]}),
#  ('Der militante Hirte in der samtenen Robe PORTRÄT',
#   {'entities': [(14, 19, 'PER'), (41, 48, 'MISC')]}),
#  ('Audi, BMW und Daimler kaufen Nokias HERE Maps:',
#   {'entities': [(0, 4, 'ORG'),
#     (6, 9, 'ORG'),
#     (14, 21, 'ORG'),
#     (29, 35, 'MISC'),
#     (36, 40, 'MISC')]}),
#  ('Sommerurlaub und wichtige DAX-Szenarien Nachrichten zu den Werten',
#   {'entities': [(0, 12, 'PER')]}),
#  ('Allegri: "Wir sind bereit für 95 endlose Minuten"',
#   {'entities': [(0, 7, 'PER')]}),
#  ('Clemens Stork vor 7 Stunden Artikel kommentieren Melden Sie sich jetzt an!',
#   {'entities': [(0, 13, 'PER')]}),
#  ('Parteigranden lehnen von JVP favorisiertes Mehrheitswahlrecht ab.',
#   {'entities': [(0, 13, 'ORG'), (25, 28, 'ORG')]}),
#  ('Hinweise für die Redaktion Info Zebinix(R)(Eslicarbazepinacetat)',
#   {'entities': [(27, 39, 'ORG'), (40, 63, 'MISC')]}),
#  ('Sandro Brotz war ein sehr guter Interviewer.',
#   {'entities': [(0, 12, 'PER')]}),
#  ('1. Training mit der Mannschaft in Graubünden», twitterte der HSV.',
#   {'entities': [(34, 44, 'LOC'), (61, 64, 'ORG')]}),
#  ('Ich glaube, Ferrari hat den größten Schritt gemacht."',
#   {'entities': [(12, 19, 'ORG')]}),
#  ('Der FC Bayern siegte ohne große Mühe gegen Frankfurt.',
#   {'entities': [(4, 13, 'ORG'), (43, 52, 'ORG')]}),
#  ('«Das ist die höchste Ausstellerzahl seit der Jahrhundertwende», sagte Wissmann.',
#   {'entities': [(70, 78, 'PER')]}),
#  ('Wo Hitler drauf ist, muss Hitler nicht drin sein',
#   {'entities': [(3, 9, 'PER'), (26, 32, 'PER')]}),
#  ('SPD-Politiker Steinbrück verrät sogar etwas zu seinen Lesegewohnheiten.',
#   {'entities': [(0, 13, 'ORG'), (14, 24, 'PER')]}),
#  ('Auf dem Perron gehen sie vorbei an einer Gedenktafel für Ungarn-Flüchtlinge:',
#   {'entities': [(57, 75, 'PER')]}),
#  ('Juventus-Spieler feiern den Finaleinzug FOTO:',
#   {'entities': [(0, 16, 'PER'), (40, 44, 'MISC')]}),
#  ('Artikel Peter Grubmüller 23. Januar 2015 - 00:04 Uhr',
#   {'entities': [(8, 24, 'PER')]}),
#  ('TV-Kolumne „Stepping Out“: Juror Llambi ätzt über Ex-Kicker Basler:',
#   {'entities': [(12, 24, 'MISC'), (33, 39, 'PER'), (50, 66, 'PER')]}),
#  ('Bei den Gastgebern kam Center Brook Lopez ebenfalls auf 22 Punkte.',
#   {'entities': [(8, 18, 'LOC'), (23, 41, 'PER')]}),
#  ('Bruno Spengler schaffte es jeweils Audi zu schlagen.',
#   {'entities': [(0, 14, 'PER'), (35, 39, 'ORG')]}),
#  ('Gestohlener Maibaum wird von Löwen bewacht',
#   {'entities': [(0, 19, 'PER'), (29, 34, 'LOC')]}),
#  ('Selbst Dyson habe solch einen zuverlässigen Test nicht nachweisen können.',
#   {'entities': [(7, 12, 'PER')]})]

# %%
random.shuffle(out_sentences)
TRAIN_STAT_DATA=out_sentences[:len(out_sentences)//2]
TEST_STAT_DATA=out_sentences[len(out_sentences)//2:]

# %%
print(len(out_sentences))
print(len(TRAIN_STAT_DATA))
print(len(TEST_STAT_DATA))
print("REVISION", len(TRAIN_REVISION_DATA))
TRAIN_DATA = TRAIN_REVISION_DATA + TRAIN_STAT_DATA
print("COMBINED", len(TRAIN_DATA))
# Out:
# 1020
# 510
# 510
# REVISION 279
# COMBINED 789

# %%
ner = nlp.get_pipe("ner")
ner.add_label("GRAN")
ner.add_label("DATA")



# get the names of the components we want to disable during training
pipe_exceptions = ["ner", "trf_wordpiecer", "trf_tok2vec"]
other_pipes = [pipe for pipe in nlp.pipe_names if pipe not in pipe_exceptions]

# start the training loop, only training NER
epochs = 30
#optimizer = nlp.resume_training()
#optimizer = nlp.initialize()
with nlp.disable_pipes(*other_pipes), warnings.catch_warnings():
    warnings.filterwarnings("once", category=UserWarning, module='spacy')
    sizes = compounding(1.0, 4.0, 1.001)
    
    # batch up the examples using spaCy's minibatc
    for epoch in range(epochs):
        random.shuffle(TRAIN_DATA)
        #text = []
        #annots=[]
        examples=[]


        for text,annots in TRAIN_DATA:
            #text.append(t)
            #annots.append(a)
            doc = nlp.make_doc(text)    
            example = Example.from_dict(doc, annots)
            examples.append(example)
        
        losses = {}
        
        nlp.update(examples, drop=0.35, losses=losses)#,sgd=optimizer)

        print("Losses ({}/{})".format(epoch + 1, epochs), losses)
# Out:
# Losses (1/30) {'ner': 2209.544247150421}
# Losses (2/30) {'ner': 1916.1894636750221}
# Losses (3/30) {'ner': 1874.5526918172836}
# Losses (4/30) {'ner': 1647.1635103821754}
# Losses (5/30) {'ner': 1620.7749798893929}
# Losses (6/30) {'ner': 1573.4089802503586}
# Losses (7/30) {'ner': 1434.5390892624855}
# Losses (8/30) {'ner': 1387.2959500292782}
# Losses (9/30) {'ner': 1319.2121549844742}
# Losses (10/30) {'ner': 1244.5019130408764}
# Losses (11/30) {'ner': 1096.9259266243316}
# Losses (12/30) {'ner': 998.9878923632205}
# Losses (13/30) {'ner': 964.4241520593278}
# Losses (14/30) {'ner': 963.216992600821}
# Losses (15/30) {'ner': 948.7985789775848}
# Losses (16/30) {'ner': 997.9088933165986}
# Losses (17/30) {'ner': 1015.0706471204758}
# Losses (18/30) {'ner': 962.7696940898895}
# Losses (19/30) {'ner': 908.8512578904629}
# Losses (20/30) {'ner': 855.6864865246462}
# Losses (21/30) {'ner': 826.1343455111255}
# Losses (22/30) {'ner': 845.9458135262037}
# Losses (23/30) {'ner': 846.8364398970734}
# Losses (24/30) {'ner': 821.0681529026333}
# Losses (25/30) {'ner': 779.399128840334}
# Losses (26/30) {'ner': 703.070523329538}
# Losses (27/30) {'ner': 650.377842191665}
# Losses (28/30) {'ner': 685.9452213626355}
# Losses (29/30) {'ner': 724.2267904868095}
# Losses (30/30) {'ner': 669.6416615682441}

# %%
statbot_colors = {"GRAN": "linear-gradient(90deg, #aa9cfc, #fc9ce7)",
                  "DATA": "linear-gradient(90deg, #ffff00, #ff8c00)"}
statbot_options = {"ents": ["PER","LOC","ORG","MISC","GRAN","DATA"], "colors": statbot_colors}
spacy.displacy.render(nlp("Ich heisse Christian und war heute in Zürich bei IBM im Internet."), style="ent",options=statbot_options)
spacy.displacy.render(nlp("Wie viele Kühe hat die Gemeinde Bülach?"), style="ent",options=statbot_options)
spacy.displacy.render(nlp("Wie hoch ist Eigenkapital auf Bezirksebene?"), style="ent",options=statbot_options)
spacy.displacy.render(nlp("Ich brauche die Daten pro Bezirk"), style="ent",options=statbot_options)
spacy.displacy.render(nlp("Ich brauche die Daten für den gesamten Kanton."), style="ent",options=statbot_options)
spacy.displacy.render(nlp("Wie viel Bauinv. EFH 5 Jahre  hat  in Regensdorf  ?"), style="ent",options=statbot_options)
spacy.displacy.render(nlp("Was ist der Anteil an MIV-Anteil (Modal Split)   auf Bezirksebene ?"), style="ent",options=statbot_options)
spacy.displacy.render(nlp("Was ist der Anteil an Geb.Vol. Dienstleistungen: Zunahme   in Flaach ?"), style="ent",options=statbot_options)
spacy.displacy.render(nlp("Welches ist das Schül. Sekundarstufe II   für den gesamten Kanton ?"), style="ent",options=statbot_options)
spacy.displacy.render(nlp("Welche Gemeinde hat die grösste Bevölkerung?"), style="ent",options=statbot_options)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Ich heisse
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Christian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  und war heute in
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Zürich
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  bei
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     IBM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  im
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Internet
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# .</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Wie viele Kühe hat die
# <mark class="entity" style="background: linear-gradient(90deg, #ffff00, #ff8c00); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gemeinde Bülach?
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATA</span>
# </mark>
# </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Wie hoch ist Eigenkapital auf
# <mark class="entity" style="background: linear-gradient(90deg, #ffff00, #ff8c00); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bezirksebene?
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATA</span>
# </mark>
# </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Ich brauche die Daten pro
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bezirk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GRAN</span>
# </mark>
# </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Ich brauche die Daten für den gesamten
# <mark class="entity" style="background: linear-gradient(90deg, #ffff00, #ff8c00); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kanton.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATA</span>
# </mark>
# </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Wie viel
# <mark class="entity" style="background: linear-gradient(90deg, #ffff00, #ff8c00); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bauinv.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATA</span>
# </mark>
#  EFH 5 Jahre  hat  in Regensdorf  ?</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Was ist der Anteil an MIV-Anteil (Modal Split)   auf
# <mark class="entity" style="background: linear-gradient(90deg, #ffff00, #ff8c00); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bezirksebene ?
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATA</span>
# </mark>
# </div></span>
# /home/z01/nlp_learn/statbot/.statbot/lib/python3.8/site-packages/spacy/displacy/__init__.py:189: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   warnings.warn(Warnings.W006)
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Was ist der Anteil an Geb.Vol. Dienstleistungen: Zunahme   in Flaach ?</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Welches ist das Schül. Sekundarstufe II   für den gesamten
# <mark class="entity" style="background: linear-gradient(90deg, #ffff00, #ff8c00); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kanton ?
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATA</span>
# </mark>
# </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Welche Gemeinde hat die grösste
# <mark class="entity" style="background: linear-gradient(90deg, #ffff00, #ff8c00); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bevölkerung?
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATA</span>
# </mark>
# </div></span>

# %%
# dictionary to hold our evaluation data
stat_evaluation = {
    "GRAN": {
        "correct": 0,
        "total": 0,
    },
    "DATA": {
        "correct": 0,
        "total": 0,
    }
}

word_evaluation = {
    "GRAN": {
        "correct": 0,
        "total": 0
    },
    "DATA": {
        "correct": 0,
        "total": 0,
    }

}


for stat in TEST_STAT_DATA:
    # extract the sentence and correct stat entities according to our test data
    sentence = stat[0]
    entities = stat[1]["entities"]

    # for each entity, use our updated model to make a prediction on the sentence
    for entity in entities:
        doc = nlp(sentence)
        correct_text = sentence[entity[0]:entity[1]]
        n_worded_stat =  len(correct_text.split())
        print(n_worded_stat)

        # if we find that there's a match for predicted entity and predicted text, increment correct counters
        for ent in doc.ents:
            print("ENT_LABEL",ent.label_)
            print("ENTITY2",entity[2])
            print("ENT_TEXT",ent.text)
            print("CORRECT:TEXT",correct_text)
            if ent.label_ == entity[2] and ent.text == correct_text:
                
                stat_evaluation[entity[2]]["correct"] += 1
                if n_worded_stat > 0:
                    word_evaluation[entity[2]]["correct"] += 1

                # this break is important, ensures that we're not double counting on a correct match
                break

        #  increment total counters after each entity loop
        stat_evaluation[entity[2]]["total"] += 1
        if n_worded_stat > 0:
            word_evaluation[entity[2]]["total"] += 1
# Out:
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Apotheken  in Oberrieden ?
# CORRECT:TEXT Apotheken
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Anteil Verkehrsflaeche  fuer alle Gemeinden ?
# CORRECT:TEXT Gemeinden
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil Verkehrsflaeche  fuer alle Gemeinden ?
# CORRECT:TEXT Anteil Verkehrsflaeche
# 4
# 4
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung:
# CORRECT:TEXT Bevoelkerung: Maenner
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Beschaeftigte im Sekundaersektor hat  Glattfelden  ?
# CORRECT:TEXT Beschaeftigte im Sekundaersektor
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerb.
# CORRECT:TEXT Steuerb. Einkommen natuerl. Pers. 75%Quantil
# 1
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Steuerkraft
# CORRECT:TEXT Steuerkraft
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand Bildung hat  in Wiesendangen  ?
# CORRECT:TEXT Nettoaufwand Bildung
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerkraft pro Kopf
# CORRECT:TEXT Steuerkraft pro Kopf
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Zahnaerzte
# CORRECT:TEXT Zahnaerzte
# 3
# ENT_LABEL MISC
# ENTITY2 DATA
# ENT_TEXT Total
# CORRECT:TEXT Total ordentlich Besteuerte
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Besteuerte hat
# CORRECT:TEXT Total ordentlich Besteuerte
# 1
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Finanzvermoegen  in Opfikon ?
# CORRECT:TEXT Finanzvermoegen
# 1
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirke ?
# CORRECT:TEXT Bezirke
# 6
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirke ?
# CORRECT:TEXT Anteil natuerl. Pers. an allg. Gemeindesteuern
# 6
# 2
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT 2Personenhaushalte hat  pro Gemeinde  ?
# CORRECT:TEXT Gemeinde
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT 2Personenhaushalte hat  pro Gemeinde  ?
# CORRECT:TEXT 2Personenhaushalte
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geb.
# CORRECT:TEXT Geb.Vol. Dienstleistungen: Zunahme
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT PWNeuzulassungen pro 1000 Einw.
# CORRECT:TEXT PWNeuzulassungen pro 1000 Einw.
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerungszunahme 5 Jahre
# CORRECT:TEXT Bevoelkerungszunahme 5 Jahre
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Ø steuerbares Einkommen natuerliche Pers.
# CORRECT:TEXT Ø steuerbares Einkommen natuerliche Pers.
# 1
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT MIVWege Quell, Ziel und Binnenverkehr  pro Gemeinde ?
# CORRECT:TEXT Gemeinde
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT MIVWege Quell, Ziel und Binnenverkehr  pro Gemeinde ?
# CORRECT:TEXT MIVWege Quell, Ziel und Binnenverkehr
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung:
# CORRECT:TEXT Bevoelkerung: Frauen
# 1
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Kanton Zuerich
# CORRECT:TEXT Kanton
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kanton Zuerich
# CORRECT:TEXT Bestand Benzinmotor
# 4
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geb.
# CORRECT:TEXT Geb.Vol. Infrastruktur: Zunahme
# 2
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT KRW Waehleranteil
# CORRECT:TEXT Kanton
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Kanton ?
# CORRECT:TEXT Kanton
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT KRW Waehleranteil
# CORRECT:TEXT KRW Waehleranteil GP
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kanton ?
# CORRECT:TEXT KRW Waehleranteil GP
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT EFHBestand
# CORRECT:TEXT EFHBestand
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeindebeitrag an ZVV
# CORRECT:TEXT Gemeindebeitrag an ZVV
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT MotorradNeuzulasssungen pro 1000 Einw.
# CORRECT:TEXT MotorradNeuzulasssungen pro 1000 Einw.
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Region Oberland
# CORRECT:TEXT Region
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Region Oberland
# CORRECT:TEXT Anteil ohne GK
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Auslaenderanteil in Prozent  in Wallisellen
# CORRECT:TEXT Auslaenderanteil
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Wegzuege in Prozent  Affoltern a.A., Opfikon und Kleinandelfingen
# CORRECT:TEXT Wegzuege
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerb.
# CORRECT:TEXT Steuerb. Vermoegen natuerl. Pers. 75%Quantil
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerb.
# CORRECT:TEXT Steuerb. Vermoegen natuerl. Pers. 25%Quantil
# 1
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirk  ?
# CORRECT:TEXT Bezirk
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirk  ?
# CORRECT:TEXT Weg zur naechsten Haltestelle
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand Finanzen und Steuern
# CORRECT:TEXT Nettoaufwand Finanzen und Steuern
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirk  ?
# CORRECT:TEXT Bezirk
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirk  ?
# CORRECT:TEXT Baulandpreis Modell Median
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Schuel.
# CORRECT:TEXT Bezirk
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirk ?
# CORRECT:TEXT Bezirk
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Berufsschule
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirk ?
# CORRECT:TEXT Schuel. Berufsschule
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Region Zimmerberg  ?
# CORRECT:TEXT Region
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Region Zimmerberg  ?
# CORRECT:TEXT VZÄ im Tertiaersektor
# 2
# 5
# 1
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Flaeche  pro Gemeinde ?
# CORRECT:TEXT Gemeinde
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Flaeche  pro Gemeinde ?
# CORRECT:TEXT Anteil unproduktive Flaeche
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Region Limmattal und Henggart ?
# CORRECT:TEXT Region
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Region Limmattal und Henggart ?
# CORRECT:TEXT Geb.Vol. Nebengebaeude: Zunahme
# 4
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Neu gegruendete Unternehmen Total
# CORRECT:TEXT Neu gegruendete Unternehmen Total
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauzonen nicht ueberbaut
# CORRECT:TEXT Bauzonen nicht ueberbaut
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand Gesundheit
# CORRECT:TEXT Nettoaufwand Gesundheit
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. Wohnen
# 4
# 1
# ENT_LABEL LOC
# ENTITY2 GRAN
# ENT_TEXT NRW
# CORRECT:TEXT Bezirk
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirk Dielsdorf
# CORRECT:TEXT Bezirk
# 3
# ENT_LABEL LOC
# ENTITY2 DATA
# ENT_TEXT NRW
# CORRECT:TEXT NRW Waehleranteil AL
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirk Dielsdorf
# CORRECT:TEXT NRW Waehleranteil AL
# 1
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gemeinde  ?
# CORRECT:TEXT Gemeinde
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeinde  ?
# CORRECT:TEXT Arbeitslose
# 3
# ENT_LABEL MISC
# ENTITY2 DATA
# ENT_TEXT Total
# CORRECT:TEXT Total ordentlich Besteuerte
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geburten
# CORRECT:TEXT Geburten
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Anteil 1Personenhaushalte in Prozent  Bezirk Buelach
# CORRECT:TEXT Bezirk
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil 1Personenhaushalte in Prozent  Bezirk Buelach
# CORRECT:TEXT Anteil 1Personenhaushalte
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT MIVAnteil Modal Split
# CORRECT:TEXT Gemeindeebene
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gemeindeebene ?
# CORRECT:TEXT Gemeindeebene
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT MIVAnteil Modal Split
# CORRECT:TEXT MIVAnteil Modal Split
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Steuerkraft ber. arith.
# CORRECT:TEXT Kanton
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Kanton  ?
# CORRECT:TEXT Kanton
# 6
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerkraft ber. arith.
# CORRECT:TEXT Steuerkraft ber. arith. Mittel 3 Jahre
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kanton  ?
# CORRECT:TEXT Steuerkraft ber. arith. Mittel 3 Jahre
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Finanzvermoegen
# CORRECT:TEXT Finanzvermoegen
# 5
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gemeinde ?
# CORRECT:TEXT Gemeinde
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeinde ?
# CORRECT:TEXT Ausserhalb des Kt. wohnhaft Besteuerte
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Berufsschule
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Oberstufe
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerungszunahme 1
# CORRECT:TEXT Bevoelkerungszunahme 1 Jahr
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung:
# CORRECT:TEXT Bevoelkerung: Maenneranteil
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Total ordentlich
# CORRECT:TEXT Total ordentlich Besteuerte
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Wohnungen:
# CORRECT:TEXT Kanton
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Kanton
# CORRECT:TEXT Kanton
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Wohnungen:
# CORRECT:TEXT Wohnungen: Anteil Eigentumsobjekte
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Kanton
# CORRECT:TEXT Wohnungen: Anteil Eigentumsobjekte
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand Gesundheit  Urdorf, Aeugst a.A. und Egg ?
# CORRECT:TEXT Nettoaufwand Gesundheit
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Wahlbeteiligung Nationalrat
# CORRECT:TEXT Wahlbeteiligung Nationalrat
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerertrag
# CORRECT:TEXT Steuerertrag Kirchgemeinden
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Beschaeftigte im Primaersektor
# CORRECT:TEXT Beschaeftigte im Primaersektor
# 1
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bevoelkerung:
# CORRECT:TEXT Bezirk
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirk Winterthur
# CORRECT:TEXT Bezirk
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung:
# CORRECT:TEXT Bevoelkerung: Anteil 1519Jaehrige
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirk Winterthur
# CORRECT:TEXT Bevoelkerung: Anteil 1519Jaehrige
# 2
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT 3Personenhaushalte  fuer alle Bezirke ?
# CORRECT:TEXT Bezirke
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT 3Personenhaushalte  fuer alle Bezirke ?
# CORRECT:TEXT 3Personenhaushalte
# 1
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT KRW Waehleranteil AL in Prozent  in Bezirk Andelfingen
# CORRECT:TEXT Bezirk
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT KRW Waehleranteil AL in Prozent  in Bezirk Andelfingen
# CORRECT:TEXT KRW Waehleranteil AL
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Landwirtschaftliche Nutzflaeche  in Egg ?
# CORRECT:TEXT Landwirtschaftliche Nutzflaeche
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirksebene ?
# CORRECT:TEXT Bezirksebene
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirksebene ?
# CORRECT:TEXT Total Quellensteuerpflichtige
# 1
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Neuerstellte EFH  Mettmenstetten ?
# CORRECT:TEXT Neuerstellte EFH
# 1
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Bauzonen
# CORRECT:TEXT Bauzonen
# 1
# ENT_LABEL MISC
# ENTITY2 GRAN
# ENT_TEXT Ø
# CORRECT:TEXT Bezirksebene
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirksebene  ?
# CORRECT:TEXT Bezirksebene
# 5
# ENT_LABEL MISC
# ENTITY2 DATA
# ENT_TEXT Ø
# CORRECT:TEXT Ø steuerbares Einkommen natuerliche Pers.
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirksebene  ?
# CORRECT:TEXT Ø steuerbares Einkommen natuerliche Pers.
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT MIVWege Quell, Ziel und Binnenverkehr hat  auf Gemeindeebene  ?
# CORRECT:TEXT Gemeindeebene
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT MIVWege Quell, Ziel und Binnenverkehr hat  auf Gemeindeebene  ?
# CORRECT:TEXT MIVWege Quell, Ziel und Binnenverkehr
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT 4Personenhaushalte
# CORRECT:TEXT 4Personenhaushalte
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Anteil 4Personenhaushalte in Prozent  pro Bezirk
# CORRECT:TEXT Bezirk
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil 4Personenhaushalte in Prozent  pro Bezirk
# CORRECT:TEXT Anteil 4Personenhaushalte
# 2
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Selbstfinanzierung  Glattfelden und Neftenbach ?
# CORRECT:TEXT Selbstfinanzierung
# 3
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Schuel.
# CORRECT:TEXT Bezirk
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirk  ?
# CORRECT:TEXT Bezirk
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Berufsschule
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirk  ?
# CORRECT:TEXT Schuel. Berufsschule
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand Bildung  Zell, Bauma und Richterswil ?
# CORRECT:TEXT Nettoaufwand Bildung
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung:
# CORRECT:TEXT Bevoelkerung: katholisch
# 2
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezuegerquote der bedarfsabh.
# CORRECT:TEXT Bezuegerquote der bedarfsabh. Sozialleistungen
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Katholische Kirchensteuerpflichtige
# CORRECT:TEXT Katholische Kirchensteuerpflichtige
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Zuzuege in Prozent  fuer alle Gemeinden
# CORRECT:TEXT Gemeinden
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Zuzuege in Prozent  fuer alle Gemeinden
# CORRECT:TEXT Zuzuege
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirk Pfaeffikon, Region
# CORRECT:TEXT Bezirk
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirk Pfaeffikon, Region
# CORRECT:TEXT Aerzte
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Restaurants hat  in Oberglatt  ?
# CORRECT:TEXT Restaurants
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bauinv.
# CORRECT:TEXT Region
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Region Unterland ?
# CORRECT:TEXT Region
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. Landwirtschaft 5 Jahre
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Region Unterland ?
# CORRECT:TEXT Bauinv. Landwirtschaft 5 Jahre
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirke ?
# CORRECT:TEXT Bezirke
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirke ?
# CORRECT:TEXT Geb.Vol. Infrastruktur: Zunahme
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Zahnaerzte hat
# CORRECT:TEXT Zahnaerzte
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Anteil Teilzeitbeschaeftigte Landwirtschaft  fuer alle Gemeinden ?
# CORRECT:TEXT Gemeinden
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil Teilzeitbeschaeftigte Landwirtschaft  fuer alle Gemeinden ?
# CORRECT:TEXT Anteil Teilzeitbeschaeftigte Landwirtschaft
# 5
# ENT_LABEL MISC
# ENTITY2 DATA
# ENT_TEXT Ø
# CORRECT:TEXT Ø Reingewinn steuerpfl. jur. Pers.
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Neuerstellte
# CORRECT:TEXT Neuerstellte Wohnungen
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Ø Reingewinn steuerpfl.
# CORRECT:TEXT Ø Reingewinn steuerpfl. jur. Pers.
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Landwirtschaftliche Nutzflaeche hat  in Turbenthal  ?
# CORRECT:TEXT Landwirtschaftliche Nutzflaeche
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung
# CORRECT:TEXT Bevoelkerung
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Region Furttal
# CORRECT:TEXT Region
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Region Furttal
# CORRECT:TEXT Wasserverbrauch pro Tag und Kopf
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Kanton  ?
# CORRECT:TEXT Kanton
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kanton  ?
# CORRECT:TEXT Apotheken
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Jugendquotient in Prozent  Wiesendangen
# CORRECT:TEXT Jugendquotient
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Kanton  ?
# CORRECT:TEXT Kanton
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kanton  ?
# CORRECT:TEXT Verkaeufe MFH
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Steuerertrag von natuerlichen Personen hat  fuer alle Gemeinden  ?
# CORRECT:TEXT Gemeinden
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerertrag von natuerlichen Personen hat  fuer alle Gemeinden  ?
# CORRECT:TEXT Steuerertrag von natuerlichen Personen
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Anteil GK F in Prozent  Uitikon, Bezirk Affoltern und Kloten
# CORRECT:TEXT Bezirk
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil GK F in Prozent  Uitikon, Bezirk Affoltern und Kloten
# CORRECT:TEXT Anteil GK F
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Geb.Vol.
# CORRECT:TEXT Gemeindeebene
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geb.Vol.
# CORRECT:TEXT Geb.Vol. Wohnen: Anteil
# 1
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Steuerkraft hat  auf Gemeindeebene  ?
# CORRECT:TEXT Gemeindeebene
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerkraft hat  auf Gemeindeebene  ?
# CORRECT:TEXT Steuerkraft
# 1
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bestand Hybridantrieb in Prozent  auf Bezirksebene
# CORRECT:TEXT Bezirksebene
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bestand Hybridantrieb in Prozent  auf Bezirksebene
# CORRECT:TEXT Bestand Hybridantrieb
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Mittlere Betriebe 50249 VZÄ hat  Region Unterland und Knonau
# CORRECT:TEXT Region
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Mittlere Betriebe 50249 VZÄ hat  Region Unterland und Knonau
# CORRECT:TEXT Mittlere Betriebe 50249 VZÄ
# 6
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. Spital, Kultur usw. 5 J.
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT MIVAnteil Modal Split in Prozent  pro Gemeinde
# CORRECT:TEXT Gemeinde
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT MIVAnteil Modal Split in Prozent  pro Gemeinde
# CORRECT:TEXT MIVAnteil Modal Split
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Neuerstellte Wohnungen hat  in Bezirk Buelach  ?
# CORRECT:TEXT Bezirk
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Neuerstellte Wohnungen hat  in Bezirk Buelach  ?
# CORRECT:TEXT Neuerstellte Wohnungen
# 1
# ENT_LABEL LOC
# ENTITY2 DATA
# ENT_TEXT Hoehe
# CORRECT:TEXT Hoehe
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung:
# CORRECT:TEXT Bevoelkerung: Frauenanteil
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Ø steuerbares Vermoegen natuerliche Pers.
# CORRECT:TEXT Ø steuerbares Vermoegen natuerliche Pers.
# 1
# ENT_LABEL LOC
# ENTITY2 GRAN
# ENT_TEXT NRW
# CORRECT:TEXT Gemeinden
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Gemeinden
# CORRECT:TEXT Gemeinden
# 3
# ENT_LABEL LOC
# ENTITY2 DATA
# ENT_TEXT NRW
# CORRECT:TEXT NRW Waehleranteil GLP
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Gemeinden
# CORRECT:TEXT NRW Waehleranteil GLP
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirk Zuerich  ?
# CORRECT:TEXT Bezirk
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirk Zuerich  ?
# CORRECT:TEXT Verkaeufe Stockwerkeigentum
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gebaeudevolumen hat  auf Bezirksebene  ?
# CORRECT:TEXT Bezirksebene
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gebaeudevolumen hat  auf Bezirksebene  ?
# CORRECT:TEXT Gebaeudevolumen
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerkraft pro Kopf
# CORRECT:TEXT Steuerkraft pro Kopf
# 1
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Neuerstellte Wohnungen
# CORRECT:TEXT Neuerstellte Wohnungen
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bauzonen ueberbaut pro Kopf hat  fuer den gesamten Kanton  ?
# CORRECT:TEXT Kanton
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauzonen ueberbaut pro Kopf hat  fuer den gesamten Kanton  ?
# CORRECT:TEXT Bauzonen ueberbaut pro Kopf
# 1
# 1
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. EFH 5 Jahre
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Anteil 6 und mehr Personenhaushalte in Prozent  auf Bezirksebene
# CORRECT:TEXT Bezirksebene
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil 6 und mehr Personenhaushalte in Prozent  auf Bezirksebene
# CORRECT:TEXT Anteil 6 und mehr Personenhaushalte
# 1
# 2
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung: uebrige/andere/ohne Konfession  in Boppelsen ?
# CORRECT:TEXT Bevoelkerung: uebrige/andere/ohne Konfession
# 2
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Motorraeder hat  in Hofstetten bis 2017  ?
# CORRECT:TEXT Motorraeder
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Schuel.
# CORRECT:TEXT Kanton
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Kanton Zuerich
# CORRECT:TEXT Kanton
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Primarschule
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kanton Zuerich
# CORRECT:TEXT Schuel. Primarschule
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Schuel.
# CORRECT:TEXT Gemeinde
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gemeinde ?
# CORRECT:TEXT Gemeinde
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Oberstufe
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeinde ?
# CORRECT:TEXT Schuel. Oberstufe
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerkraft berichtigt pro Kopf  in Elgg ?
# CORRECT:TEXT Steuerkraft berichtigt pro Kopf
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Schweizer Buergerrechts  fuer den gesamten Kanton ?
# CORRECT:TEXT Kanton
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schweizer Buergerrechts  fuer den gesamten Kanton ?
# CORRECT:TEXT Erwerb des Schweizer Buergerrechts
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung:
# CORRECT:TEXT Bevoelkerung: Anteil 014Jaehrige
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bezirksebene
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirksebene  ?
# CORRECT:TEXT Bezirksebene
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. MFH 5 Jahre
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirksebene  ?
# CORRECT:TEXT Bauinv. MFH 5 Jahre
# 2
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil Gewaesserflaeche in Prozent
# CORRECT:TEXT Anteil Gewaesserflaeche
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Kindergarten
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand Volkswirtschaft hat  in Fischenthal  ?
# CORRECT:TEXT Nettoaufwand Volkswirtschaft
# 4
# 3
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT KRW Waehleranteil
# CORRECT:TEXT KRW Waehleranteil SD
# 3
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kleine Betriebe 1049 VZÄ
# CORRECT:TEXT Kleine Betriebe 1049 VZÄ
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Geb.
# CORRECT:TEXT Kanton
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Kanton
# CORRECT:TEXT Kanton
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geb.
# CORRECT:TEXT Geb.Vol. Infrastruktur: Anteil
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Kanton
# CORRECT:TEXT Geb.Vol. Infrastruktur: Anteil
# 1
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Apotheken  in Maschwanden ?
# CORRECT:TEXT Apotheken
# 6
# 1
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Wanderungsbilanz  in Seegraeben ?
# CORRECT:TEXT Wanderungsbilanz
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bevoelkerungszunahme 1 Jahr  Region Knonaueramt ?
# CORRECT:TEXT Region
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerungszunahme 1 Jahr  Region Knonaueramt ?
# CORRECT:TEXT Bevoelkerungszunahme 1 Jahr
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Oberstufe
# 4
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Hotelbetten pro 1000 Einwohner
# CORRECT:TEXT Hotelbetten pro 1000 Einwohner
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Steuerb.
# CORRECT:TEXT Gemeindeebene
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gemeindeebene ?
# CORRECT:TEXT Gemeindeebene
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerb.
# CORRECT:TEXT Steuerb. Einkommen natuerl. Pers. Durchschn.
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeindeebene ?
# CORRECT:TEXT Steuerb. Einkommen natuerl. Pers. Durchschn.
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Total Beschaeftigte
# CORRECT:TEXT Total Beschaeftigte
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Ø steuerbares Einkommen natuerliche Pers.
# CORRECT:TEXT Bezirksebene
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirksebene ?
# CORRECT:TEXT Bezirksebene
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Ø steuerbares Einkommen natuerliche Pers.
# CORRECT:TEXT Ø steuerbares Einkommen natuerliche Pers.
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. Wohnen
# 1
# 4
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bevoelkerungsdichte hat  Bezirk Winterthur, Waedenswil bis 2018 und Horgen bis 2017  ?
# CORRECT:TEXT Bezirk
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerungsdichte hat  Bezirk Winterthur, Waedenswil bis 2018 und Horgen bis 2017  ?
# CORRECT:TEXT Bevoelkerungsdichte
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Steuerertrag allgemeine Gemeindesteuern  pro Bezirk ?
# CORRECT:TEXT Bezirk
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerertrag allgemeine Gemeindesteuern  pro Bezirk ?
# CORRECT:TEXT Steuerertrag allgemeine Gemeindesteuern
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Wahlbeteiligung Nationalrat
# CORRECT:TEXT Gemeindeebene
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Wahlbeteiligung Nationalrat
# CORRECT:TEXT Wahlbeteiligung Nationalrat
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil 2Personenhaushalte in Prozent
# CORRECT:TEXT Anteil 2Personenhaushalte
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Steuerbares Vermoegen natuerliche Pers.
# CORRECT:TEXT Kanton
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Kanton  ?
# CORRECT:TEXT Kanton
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerbares Vermoegen natuerliche Pers.
# CORRECT:TEXT Steuerbares Vermoegen natuerliche Pers.
# 3
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung:
# CORRECT:TEXT Bevoelkerung: Frauen
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerertrag von juristischen Personen
# CORRECT:TEXT Steuerertrag von juristischen Personen
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Sekundarstufe II
# 3
# ENT_LABEL LOC
# ENTITY2 DATA
# ENT_TEXT NRW
# CORRECT:TEXT NRW Waehleranteil FDP
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Reformierte Kirchensteuerpflichtige
# CORRECT:TEXT Reformierte Kirchensteuerpflichtige
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirke ?
# CORRECT:TEXT Bezirke
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirke ?
# CORRECT:TEXT Hoehe
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Zinsbelastungsanteil  fuer den gesamten Kanton ?
# CORRECT:TEXT Kanton
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Zinsbelastungsanteil  fuer den gesamten Kanton ?
# CORRECT:TEXT Zinsbelastungsanteil
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Total Beschaeftigte  Thalwil ?
# CORRECT:TEXT Total Beschaeftigte
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Arbeitsstaetten im Primaersektor
# CORRECT:TEXT Arbeitsstaetten im Primaersektor
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Neuerstellte MFHWohnungen
# CORRECT:TEXT Neuerstellte MFHWohnungen
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Personalsteuerpflichtige  pro Gemeinde ?
# CORRECT:TEXT Gemeinde
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Personalsteuerpflichtige  pro Gemeinde ?
# CORRECT:TEXT Personalsteuerpflichtige
# 1
# 2
# 1
# 1
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Personenhaushalte  in Uster ?
# CORRECT:TEXT Anteil 6 und mehr Personenhaushalte
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerbares Einkommen natuerliche Pers.
# CORRECT:TEXT Steuerbares Einkommen natuerliche Pers.
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung: reformiert
# CORRECT:TEXT Bevoelkerung: reformiert
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT MotorradNeuzulasssungen pro 1000 Einw.
# CORRECT:TEXT MotorradNeuzulasssungen pro 1000 Einw.
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Geburtenueberschuss 5J.mittel  im Kanton Zuerich ?
# CORRECT:TEXT Kanton
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geburtenueberschuss 5J.mittel  im Kanton Zuerich ?
# CORRECT:TEXT Geburtenueberschuss 5J.mittel
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT KRW Waehleranteil
# CORRECT:TEXT Kanton
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Kanton Zuerich ?
# CORRECT:TEXT Kanton
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT KRW Waehleranteil
# CORRECT:TEXT KRW Waehleranteil BDP
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kanton Zuerich ?
# CORRECT:TEXT KRW Waehleranteil BDP
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bezirke
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirke  ?
# CORRECT:TEXT Bezirke
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. Industr./Lager 5 Jahre
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirke  ?
# CORRECT:TEXT Bauinv. Industr./Lager 5 Jahre
# 4
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. Industr./Lager 5 Jahre
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Baulandpreis Median hat  in Staefa  ?
# CORRECT:TEXT Baulandpreis Median
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerb.
# CORRECT:TEXT Steuerb. Vermoegen natuerl. Pers. Durchschn.
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Sozialhilfequote in Prozent  in Winterthur
# CORRECT:TEXT Sozialhilfequote
# 1
# 2
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Verkaeufe von unbebautem Land
# CORRECT:TEXT Verkaeufe von unbebautem Land
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT KRW Waehleranteil
# CORRECT:TEXT Gemeindeebene
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gemeindeebene ?
# CORRECT:TEXT Gemeindeebene
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT KRW Waehleranteil
# CORRECT:TEXT KRW Waehleranteil CVP
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeindeebene ?
# CORRECT:TEXT KRW Waehleranteil CVP
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Primarschule
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerertrag allgemeine Gemeindesteuern
# CORRECT:TEXT Steuerertrag allgemeine Gemeindesteuern
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung:
# CORRECT:TEXT Bevoelkerung: Durchschnittsalter
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Anteil GK A in Prozent  auf Bezirksebene
# CORRECT:TEXT Bezirksebene
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil GK A in Prozent  auf Bezirksebene
# CORRECT:TEXT Anteil GK A
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Grosse Betriebe 250+ VZÄ hat  pro Bezirk  ?
# CORRECT:TEXT Bezirk
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung:
# CORRECT:TEXT Bevoelkerung: Maenneranteil
# 1
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Sekundarstufe II
# 6
# ENT_LABEL MISC
# ENTITY2 DATA
# ENT_TEXT ZLBezuegerquote
# CORRECT:TEXT ZLBezuegerquote der Personen ab 65 Jahren
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Steuerkraft  Unterstammheim bis 2018 und Region Glattal ?
# CORRECT:TEXT Region
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerkraft  Unterstammheim bis 2018 und Region Glattal ?
# CORRECT:TEXT Steuerkraft
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geburtenrate 5J.mittel
# CORRECT:TEXT Geburtenrate 5J.mittel
# 3
# ENT_LABEL LOC
# ENTITY2 DATA
# ENT_TEXT NRW
# CORRECT:TEXT NRW Waehleranteil GLP
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung: katholisch  Rueti und Waltalingen bis 2018 ?
# CORRECT:TEXT Bevoelkerung: katholisch
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Neuzulassungen  Dieselmotor in Prozent  Huentwangen und Wiesendangen bis 2013
# CORRECT:TEXT Neuzulassungen  Dieselmotor
# 3
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Sekundarstufe I
# 1
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Personenhaushalte  fuer alle Bezirke ?
# CORRECT:TEXT Bezirke
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Personenhaushalte  fuer alle Bezirke ?
# CORRECT:TEXT 6 und mehr Personenhaushalte
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirksebene  ?
# CORRECT:TEXT Bezirksebene
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirksebene  ?
# CORRECT:TEXT Scheidungen
# 6
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Anteil GK A  Bezirk Dielsdorf und FreiensteinTeufen ?
# CORRECT:TEXT Bezirk
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil GK A  Bezirk Dielsdorf und FreiensteinTeufen ?
# CORRECT:TEXT Anteil GK A
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT 3Personenhaushalte hat
# CORRECT:TEXT 3Personenhaushalte
# 1
# 2
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. Ver/Entsorg. 5 Jahre
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Nettoaufwand Umweltschutz und Raumordnung hat  im Kanton Zuerich  ?
# CORRECT:TEXT Kanton
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand Umweltschutz und Raumordnung hat  im Kanton Zuerich  ?
# CORRECT:TEXT Nettoaufwand Umweltschutz und Raumordnung
# 1
# 2
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geb.Vol.
# CORRECT:TEXT Geb.Vol. Wohnen: Zunahme
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil 2 Zi.
# CORRECT:TEXT Anteil 2 Zi.Wohnungen
# 1
# ENT_LABEL LOC
# ENTITY2 GRAN
# ENT_TEXT NRW
# CORRECT:TEXT Kanton
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Kanton ?
# CORRECT:TEXT Kanton
# 3
# ENT_LABEL LOC
# ENTITY2 DATA
# ENT_TEXT NRW
# CORRECT:TEXT NRW Waehleranteil SP
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kanton ?
# CORRECT:TEXT NRW Waehleranteil SP
# 1
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Altersquotient in Prozent  Oberengstringen und Zell
# CORRECT:TEXT Altersquotient
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bruttoverschuldungsanteil in Prozent  fuer alle Bezirke
# CORRECT:TEXT Bezirke
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bruttoverschuldungsanteil in Prozent  fuer alle Bezirke
# CORRECT:TEXT Bruttoverschuldungsanteil
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bezirk
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirk  ?
# CORRECT:TEXT Bezirk
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. Landwirtschaft 5 Jahre
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirk  ?
# CORRECT:TEXT Bauinv. Landwirtschaft 5 Jahre
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Region Oberland ?
# CORRECT:TEXT Region
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Region Oberland ?
# CORRECT:TEXT Fremdkapital
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT 4Personenhaushalte  im Kanton Zuerich ?
# CORRECT:TEXT Kanton
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT 4Personenhaushalte  im Kanton Zuerich ?
# CORRECT:TEXT 4Personenhaushalte
# 2
# 3
# ENT_LABEL LOC
# ENTITY2 DATA
# ENT_TEXT NRW
# CORRECT:TEXT NRW Waehleranteil BDP
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Zahnaerzte
# CORRECT:TEXT Zahnaerzte
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Wegzuege hat  in Flaach  ?
# CORRECT:TEXT Wegzuege
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirksebene ?
# CORRECT:TEXT Bezirksebene
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirksebene ?
# CORRECT:TEXT Geb.Vol. Nebengebaeude: Anteil
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirk Andelfingen  ?
# CORRECT:TEXT Bezirk
# 6
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirk Andelfingen  ?
# CORRECT:TEXT Nur an der Quelle besteuerte Quellensteuerpfl.
# 1
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerb.
# CORRECT:TEXT Steuerb. Einkommen natuerl. Pers. Median
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Restaurants pro 1000 Einwohner
# CORRECT:TEXT Restaurants pro 1000 Einwohner
# 2
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bauinv.
# CORRECT:TEXT Kanton
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Kanton ?
# CORRECT:TEXT Kanton
# 6
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. Spital, Kultur usw. 5 J.
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kanton ?
# CORRECT:TEXT Bauinv. Spital, Kultur usw. 5 J.
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Schuel.
# CORRECT:TEXT Region
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Mittelschule
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung:
# CORRECT:TEXT Bevoelkerung: Anteil 2039Jaehrige
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerungszunahme 1
# CORRECT:TEXT Bevoelkerungszunahme 1 Jahr
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Mikrobetriebe 09 VZÄ hat  in Bezirk Uster  ?
# CORRECT:TEXT Bezirk
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Mikrobetriebe 09 VZÄ hat  in Bezirk Uster  ?
# CORRECT:TEXT Mikrobetriebe 09 VZÄ
# 3
# 2
# 2
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT ÖVWege Quell, Ziel und Binnenverkehr  auf Gemeindeebene ?
# CORRECT:TEXT Gemeindeebene
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT ÖVWege Quell, Ziel und Binnenverkehr  auf Gemeindeebene ?
# CORRECT:TEXT ÖVWege Quell, Ziel und Binnenverkehr
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand Verkehr und Nachrichtenuebermittlung  in Waltalingen bis 2018 ?
# CORRECT:TEXT Nettoaufwand Verkehr und Nachrichtenuebermittlung
# 1
# 1
# 1
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Wanderungsbilanz  in Urdorf ?
# CORRECT:TEXT Wanderungsbilanz
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauzonen  in Winterthur ?
# CORRECT:TEXT Bauzonen
# 1
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Kehrichtmengen hat  fuer alle Gemeinden  ?
# CORRECT:TEXT Gemeinden
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kehrichtmengen hat  fuer alle Gemeinden  ?
# CORRECT:TEXT Kehrichtmengen
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauzonen ueberbaut
# CORRECT:TEXT Bauzonen ueberbaut
# 1
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Wanderungsbilanz hat  fuer alle Gemeinden  ?
# CORRECT:TEXT Gemeinden
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Wanderungsbilanz hat  fuer alle Gemeinden  ?
# CORRECT:TEXT Wanderungsbilanz
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Auslaenderanteil  fuer alle Bezirke ?
# CORRECT:TEXT Bezirke
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Auslaenderanteil  fuer alle Bezirke ?
# CORRECT:TEXT Auslaenderanteil
# 1
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bestand Dieselmotor in Prozent  in Oberembrach
# CORRECT:TEXT Bestand Dieselmotor
# 2
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand Volkswirtschaft
# CORRECT:TEXT Nettoaufwand Volkswirtschaft
# 1
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil GK D in Prozent  in Dielsdorf
# CORRECT:TEXT Anteil GK D
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT MotorradNeuzulassungen
# CORRECT:TEXT MotorradNeuzulassungen
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Steuerb.
# CORRECT:TEXT Gemeinde
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gemeinde  ?
# CORRECT:TEXT Gemeinde
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerb.
# CORRECT:TEXT Steuerb. Vermoegen natuerl. Pers. 25%Quantil
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeinde  ?
# CORRECT:TEXT Steuerb. Vermoegen natuerl. Pers. 25%Quantil
# 3
# ENT_LABEL LOC
# ENTITY2 DATA
# ENT_TEXT NRW
# CORRECT:TEXT NRW Waehleranteil GP
# 1
# 1
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT PWNeuzulassungen pro 1000 Einw.
# CORRECT:TEXT Bezirk
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirk ?
# CORRECT:TEXT Bezirk
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT PWNeuzulassungen pro 1000 Einw.
# CORRECT:TEXT PWNeuzulassungen pro 1000 Einw.
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Anteil Verkehrsflaeche in Prozent  auf Bezirksebene
# CORRECT:TEXT Bezirksebene
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil Verkehrsflaeche in Prozent  auf Bezirksebene
# CORRECT:TEXT Anteil Verkehrsflaeche
# 3
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil EFH am Wohnungsbestand in Prozent  Schlatt und Glattfelden
# CORRECT:TEXT Anteil EFH am Wohnungsbestand
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Oberstufe
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Personalsteuerpflichtige hat  Huetten bis 2018 und Niederweningen  ?
# CORRECT:TEXT Personalsteuerpflichtige
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Motorraeder
# CORRECT:TEXT Motorraeder
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerungszunahme 1 Jahr in Prozent  in Schoefflisdorf
# CORRECT:TEXT Bevoelkerungszunahme 1 Jahr
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Zahnaerzte
# CORRECT:TEXT Zahnaerzte
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerb.
# CORRECT:TEXT Steuerb. Vermoegen natuerl. Pers. Median
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerkraft arith.
# CORRECT:TEXT Steuerkraft arith. Mittel 3 Jahre
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirksebene  ?
# CORRECT:TEXT Bezirksebene
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirksebene  ?
# CORRECT:TEXT Wohnungsbestand
# 2
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Leerwohnungsquote in Prozent  Winkel und Maennedorf
# CORRECT:TEXT Leerwohnungsquote
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Kanton ?
# CORRECT:TEXT Kanton
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kanton ?
# CORRECT:TEXT Hotelbetten pro 1000 Einwohner
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. EFH 5 Jahre
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettovermoegen hat  in Schoefflisdorf  ?
# CORRECT:TEXT Nettovermoegen
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bauinv.
# CORRECT:TEXT Gemeinden
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gemeinden  ?
# CORRECT:TEXT Gemeinden
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. ÖV, Kommunik. 5 Jahre
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeinden  ?
# CORRECT:TEXT Bauinv. ÖV, Kommunik. 5 Jahre
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Neuerstellte MFHWohnungen  fuer alle Gemeinden ?
# CORRECT:TEXT Gemeinden
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Neuerstellte MFHWohnungen  fuer alle Gemeinden ?
# CORRECT:TEXT Neuerstellte MFHWohnungen
# 1
# 2
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Arbeitsstaetten im Sekundaersektor hat  fuer alle Bezirke  ?
# CORRECT:TEXT Bezirke
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Arbeitsstaetten im Sekundaersektor hat  fuer alle Bezirke  ?
# CORRECT:TEXT Arbeitsstaetten im Sekundaersektor
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Anteil 6+ Zi.
# CORRECT:TEXT Bezirksebene
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirksebene
# CORRECT:TEXT Bezirksebene
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Beschaeftigte im Gastgewerbe: Anteil  Rheinau ?
# CORRECT:TEXT Beschaeftigte im Gastgewerbe: Anteil
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. EFH 5 Jahre
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerertrag von juristischen Personen
# CORRECT:TEXT Steuerertrag von juristischen Personen
# 1
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Kanton Zuerich ?
# CORRECT:TEXT Kanton
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kanton Zuerich ?
# CORRECT:TEXT Anteil 2 Zi.Wohnungen
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT KRW Waehleranteil GLP  in Urdorf ?
# CORRECT:TEXT KRW Waehleranteil GLP
# 1
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kuehe
# CORRECT:TEXT Kuehe
# 3
# ENT_LABEL LOC
# ENTITY2 DATA
# ENT_TEXT NRW
# CORRECT:TEXT NRW Waehleranteil SVP
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand Volkswirtschaft
# CORRECT:TEXT Nettoaufwand Volkswirtschaft
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil GK D
# CORRECT:TEXT Anteil GK D
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Schuel.
# CORRECT:TEXT Bezirk
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirk Andelfingen, Urdorf und Neftenbach  ?
# CORRECT:TEXT Bezirk
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Tertiaerstufe
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirk Andelfingen, Urdorf und Neftenbach  ?
# CORRECT:TEXT Schuel. Tertiaerstufe
# 1
# 4
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirke ?
# CORRECT:TEXT Bezirke
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirke ?
# CORRECT:TEXT Hotelbetten
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT MotorradNeuzulassungen hat  in Rifferswil  ?
# CORRECT:TEXT MotorradNeuzulassungen
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeindesteuern  in FreiensteinTeufen ?
# CORRECT:TEXT Anteil Pol./Schulgem. an allg. Gemeindesteuern
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerertrag
# CORRECT:TEXT Steuerertrag Kirchgemeinden
# 1
# 1
# ENT_LABEL LOC
# ENTITY2 GRAN
# ENT_TEXT NRW
# CORRECT:TEXT Bezirksebene
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirksebene ?
# CORRECT:TEXT Bezirksebene
# 3
# ENT_LABEL LOC
# ENTITY2 DATA
# ENT_TEXT NRW
# CORRECT:TEXT NRW Waehleranteil SVP
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirksebene ?
# CORRECT:TEXT NRW Waehleranteil SVP
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Zuzuege hat  in Winkel  ?
# CORRECT:TEXT Zuzuege
# 1
# ENT_LABEL LOC
# ENTITY2 GRAN
# ENT_TEXT Hoehe
# CORRECT:TEXT Gemeinden
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gemeinden  GEBIET_NAME?
# CORRECT:TEXT Gemeinden
# 1
# ENT_LABEL LOC
# ENTITY2 DATA
# ENT_TEXT Hoehe
# CORRECT:TEXT Hoehe
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeinden  GEBIET_NAME?
# CORRECT:TEXT Hoehe
# 3
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil GK C in Prozent  in Pfaeffikon
# CORRECT:TEXT Anteil GK C
# 4
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Total VZÄ
# CORRECT:TEXT Total VZÄ
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirk  ?
# CORRECT:TEXT Bezirk
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirk  ?
# CORRECT:TEXT Aerzte
# 1
# ENT_LABEL LOC
# ENTITY2 GRAN
# ENT_TEXT NRW
# CORRECT:TEXT Kanton
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Kanton Zuerich ?
# CORRECT:TEXT Kanton
# 3
# ENT_LABEL LOC
# ENTITY2 DATA
# ENT_TEXT NRW
# CORRECT:TEXT NRW Waehleranteil AL
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kanton Zuerich ?
# CORRECT:TEXT NRW Waehleranteil AL
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Beschaeftigte Landwirtschaft
# CORRECT:TEXT Beschaeftigte Landwirtschaft
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. Strassen, PP 5 Jahre
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT KRW Waehleranteil EVP in Prozent  Thalheim a.d.
# CORRECT:TEXT KRW Waehleranteil EVP
# 1
# 3
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bezirksebene
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirksebene  ?
# CORRECT:TEXT Bezirksebene
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. Strassen, PP 5 Jahre
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirksebene  ?
# CORRECT:TEXT Bauinv. Strassen, PP 5 Jahre
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Restaurants pro 1000 Einwohner hat
# CORRECT:TEXT Restaurants pro 1000 Einwohner
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT PWNeuzulassungen
# CORRECT:TEXT PWNeuzulassungen
# 1
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Zahnaerzte  in Daegerlen ?
# CORRECT:TEXT Zahnaerzte
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kapitaldienstanteil in Prozent  Gossau
# CORRECT:TEXT Kapitaldienstanteil
# 1
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Arbeitsstaetten im Sekundaersektor
# CORRECT:TEXT Arbeitsstaetten im Sekundaersektor
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Arbeitslose  auf Bezirksebene ?
# CORRECT:TEXT Bezirksebene
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Arbeitslose  auf Bezirksebene ?
# CORRECT:TEXT Arbeitslose
# 2
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Hauptberufliche Landwirtschaftsbetriebe
# CORRECT:TEXT Hauptberufliche Landwirtschaftsbetriebe
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand soziale Sicherheit  Zell und Zuerich ?
# CORRECT:TEXT Nettoaufwand soziale Sicherheit
# 1
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bezirksebene
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirksebene  ?
# CORRECT:TEXT Bezirksebene
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. Dienstl. 5 Jahre
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirksebene  ?
# CORRECT:TEXT Bauinv. Dienstl. 5 Jahre
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand Kultur, Sport und Freizeit
# CORRECT:TEXT Nettoaufwand Kultur, Sport und Freizeit
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Anteil GK E in Prozent  im Kanton Zuerich
# CORRECT:TEXT Kanton
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil GK E in Prozent  im Kanton Zuerich
# CORRECT:TEXT Anteil GK E
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerb.
# CORRECT:TEXT Steuerb. Einkommen natuerl. Pers. 25%Quantil
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Beschaeftigte im Primaersektor  Wila ?
# CORRECT:TEXT Beschaeftigte im Primaersektor
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung:
# CORRECT:TEXT Bevoelkerung: Frauen
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Leerwohnungsquote  pro Bezirk ?
# CORRECT:TEXT Bezirk
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Leerwohnungsquote  pro Bezirk ?
# CORRECT:TEXT Leerwohnungsquote
# 4
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand Kultur, Sport und Freizeit
# CORRECT:TEXT Nettoaufwand Kultur, Sport und Freizeit
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Neuerstellte
# CORRECT:TEXT Neuerstellte EFH
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Geburtenrate  auf Gemeindeebene ?
# CORRECT:TEXT Gemeindeebene
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geburtenrate  auf Gemeindeebene ?
# CORRECT:TEXT Geburtenrate
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geburtenueberschuss 5J.mittel
# CORRECT:TEXT Geburtenueberschuss 5J.mittel
# 2
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Privathaushalte
# CORRECT:TEXT Privathaushalte Total
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerungszunahme 5 Jahre  in Zell ?
# CORRECT:TEXT Bevoelkerungszunahme 5 Jahre
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bevoelkerung hat  pro Bezirk  ?
# CORRECT:TEXT Bezirk
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung hat  pro Bezirk  ?
# CORRECT:TEXT Bevoelkerung
# 1
# 1
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung:
# CORRECT:TEXT Bevoelkerung: Durchschnittsalter
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gemeinde  ?
# CORRECT:TEXT Gemeinde
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeinde  ?
# CORRECT:TEXT Nettoinvestitionen
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Zahnaerzte hat  in Neftenbach  ?
# CORRECT:TEXT Zahnaerzte
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Erwerb des Schweizer Buergerrechts
# CORRECT:TEXT Erwerb des Schweizer Buergerrechts
# 5
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Steuerb.
# CORRECT:TEXT Bezirk
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirk  ?
# CORRECT:TEXT Bezirk
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerb.
# CORRECT:TEXT Steuerb. Einkommen natuerl. Pers. Median
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirk  ?
# CORRECT:TEXT Steuerb. Einkommen natuerl. Pers. Median
# 3
# ENT_LABEL LOC
# ENTITY2 DATA
# ENT_TEXT NRW
# CORRECT:TEXT NRW Waehleranteil SP
# 2
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Sekundarstufe I
# 4
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeindebeitrag an ZVV
# CORRECT:TEXT Gemeindebeitrag an ZVV
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Steuerb.
# CORRECT:TEXT Gemeinden
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gemeinden ?
# CORRECT:TEXT Gemeinden
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerb.
# CORRECT:TEXT Steuerb. Vermoegen natuerl. Pers. 75%Quantil
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeinden ?
# CORRECT:TEXT Steuerb. Vermoegen natuerl. Pers. 75%Quantil
# 1
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. Ver/Entsorg. 5 Jahre
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Schuel.
# CORRECT:TEXT Bezirke
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirke  ?
# CORRECT:TEXT Bezirke
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Kindergarten
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirke  ?
# CORRECT:TEXT Schuel. Kindergarten
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerungsdichte  in Waedenswil bis 2018 ?
# CORRECT:TEXT Bevoelkerungsdichte
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Anteil Waldflaeche in Prozent  fuer den gesamten Kanton
# CORRECT:TEXT Kanton
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil Waldflaeche in Prozent  fuer den gesamten Kanton
# CORRECT:TEXT Anteil Waldflaeche
# 1
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Nettoaufwand Finanzen und Steuern hat  auf Bezirksebene  ?
# CORRECT:TEXT Bezirksebene
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand Finanzen und Steuern hat  auf Bezirksebene  ?
# CORRECT:TEXT Nettoaufwand Finanzen und Steuern
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Landwirtschaftsbetriebe  in Hittnau ?
# CORRECT:TEXT Landwirtschaftsbetriebe
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Sterbefaelle  Wila ?
# CORRECT:TEXT Sterbefaelle
# 2
# 3
# ENT_LABEL LOC
# ENTITY2 DATA
# ENT_TEXT NRW
# CORRECT:TEXT NRW Waehleranteil BDP
# 1
# ENT_LABEL MISC
# ENTITY2 GRAN
# ENT_TEXT ZLBezuegerquote
# CORRECT:TEXT Gemeindeebene
# 6
# ENT_LABEL MISC
# ENTITY2 DATA
# ENT_TEXT ZLBezuegerquote
# CORRECT:TEXT ZLBezuegerquote der Personen ab 65 Jahren
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Berufsschule
# 3
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Anteil 2Personenhaushalte  Region Zuerich ?
# CORRECT:TEXT Region
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil 2Personenhaushalte  Region Zuerich ?
# CORRECT:TEXT Anteil 2Personenhaushalte
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Selbstfinanzierungsgrad  Dachsen ?
# CORRECT:TEXT Selbstfinanzierungsgrad
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Tertiaerstufe
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Leerwohnungen Total
# CORRECT:TEXT Leerwohnungen Total
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauzonen ueberbaut  in Lindau ?
# CORRECT:TEXT Bauzonen ueberbaut
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Arbeitsstaetten im Tertiaersektor
# CORRECT:TEXT Arbeitsstaetten im Tertiaersektor
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung:
# CORRECT:TEXT Bevoelkerung: Maenner
# 3
# 4
# 1
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Restaurants pro 1000 Einwohner  Adlikon, Bachenbuelach und Schlatt ?
# CORRECT:TEXT Restaurants pro 1000 Einwohner
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerb.
# CORRECT:TEXT Steuerb. Einkommen natuerl. Pers. Durchschn.
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT EFHBestand
# CORRECT:TEXT EFHBestand
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung:
# CORRECT:TEXT Bevoelkerung: Durchschnittsalter
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirksebene ?
# CORRECT:TEXT Bezirksebene
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirksebene ?
# CORRECT:TEXT Bestand anderer Antrieb
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand Umweltschutz und Raumordnung  Stallikon und Daettlikon ?
# CORRECT:TEXT Nettoaufwand Umweltschutz und Raumordnung
# 4
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Baulandpreis Median  fuer alle Gemeinden ?
# CORRECT:TEXT Gemeinden
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Baulandpreis Median  fuer alle Gemeinden ?
# CORRECT:TEXT Baulandpreis Median
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geb.Vol.
# CORRECT:TEXT Geb.Vol. Landwirtschaft: Anteil
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Primarschule
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil 4 Zi.
# CORRECT:TEXT Anteil 4 Zi.Wohnungen
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung: uebrige/andere/ohne Konfession hat  Hittnau, Rueti und Flurlingen  ?
# CORRECT:TEXT Bevoelkerung: uebrige/andere/ohne Konfession
# 2
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gemeindebeitrag an ZVV hat  in Region Winterthur u. Umg.
# CORRECT:TEXT Region
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeindebeitrag an ZVV hat  in Region Winterthur u. Umg.
# CORRECT:TEXT Gemeindebeitrag an ZVV
# 4
# 1
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bevoelkerung:
# CORRECT:TEXT Gemeindeebene
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gemeindeebene ?
# CORRECT:TEXT Gemeindeebene
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung:
# CORRECT:TEXT Bevoelkerung: Frauen
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeindeebene ?
# CORRECT:TEXT Bevoelkerung: Frauen
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Wasserverbrauch pro Tag und Kopf
# CORRECT:TEXT Wasserverbrauch pro Tag und Kopf
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Privathaushalte Total  Daenikon ?
# CORRECT:TEXT Privathaushalte Total
# 1
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Reformierte Kirchensteuerpflichtige
# CORRECT:TEXT Reformierte Kirchensteuerpflichtige
# 1
# 3
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Steuerb.
# CORRECT:TEXT Bezirk
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirk  ?
# CORRECT:TEXT Bezirk
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerb.
# CORRECT:TEXT Steuerb. Einkommen natuerl. Pers. 75%Quantil
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirk  ?
# CORRECT:TEXT Steuerb. Einkommen natuerl. Pers. 75%Quantil
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung: katholisch
# CORRECT:TEXT Bevoelkerung: katholisch
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung:
# CORRECT:TEXT Bevoelkerung: Frauenanteil
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Steuerertrag Total hat  fuer alle Bezirke  ?
# CORRECT:TEXT Bezirke
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerertrag Total hat  fuer alle Bezirke  ?
# CORRECT:TEXT Steuerertrag Total
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bauinvestitionen  in Region Glattal ?
# CORRECT:TEXT Region
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinvestitionen  in Region Glattal ?
# CORRECT:TEXT Bauinvestitionen
# 1
# 6
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerkraft ber. arith.
# CORRECT:TEXT Steuerkraft ber. arith. Mittel 3 Jahre
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauzonen ueberbaut pro Kopf
# CORRECT:TEXT Bauzonen ueberbaut pro Kopf
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bauzonen hat  pro Gemeinde  ?
# CORRECT:TEXT Gemeinde
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauzonen hat  pro Gemeinde  ?
# CORRECT:TEXT Bauzonen
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kapitaldienstanteil  Erlenbach ?
# CORRECT:TEXT Kapitaldienstanteil
# 1
# 2
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Steuerbares Vermoegen natuerliche Pers.
# CORRECT:TEXT Bezirk
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirk Buelach ?
# CORRECT:TEXT Bezirk
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerbares Vermoegen natuerliche Pers.
# CORRECT:TEXT Steuerbares Vermoegen natuerliche Pers.
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Baulandpreis
# CORRECT:TEXT Baulandpreis Modell Median
# 2
# 6
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Kanton ?
# CORRECT:TEXT Kanton
# 6
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kanton ?
# CORRECT:TEXT Anteil jur. Pers. an allg. Gemeindesteuern
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerb.
# CORRECT:TEXT Steuerb. Vermoegen natuerl. Pers. Durchschn.
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand oeffentliche Ordnung und Sicherheit
# CORRECT:TEXT Nettoaufwand oeffentliche Ordnung und Sicherheit
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Beschaeftigte im Primaersektor hat  fuer den gesamten Kanton  ?
# CORRECT:TEXT Kanton
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Beschaeftigte im Primaersektor hat  fuer den gesamten Kanton  ?
# CORRECT:TEXT Beschaeftigte im Primaersektor
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Motorraeder pro 1000 Einwohner
# CORRECT:TEXT Motorraeder pro 1000 Einwohner
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Anteil 5Personenhaushalte  im Kanton Zuerich ?
# CORRECT:TEXT Kanton
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil 5Personenhaushalte  im Kanton Zuerich ?
# CORRECT:TEXT Anteil 5Personenhaushalte
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. ÖV, Kommunik. 5 Jahre
# 1
# 4
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Region Furttal  ?
# CORRECT:TEXT Region
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Region Furttal  ?
# CORRECT:TEXT Steuerpflichtige juristische Personen
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Kindergarten
# 1
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirk
# CORRECT:TEXT Bezirk
# 3
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Bezirk
# CORRECT:TEXT Anteil unproduktive Flaeche
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. EFH 5 Jahre
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Schuel.
# CORRECT:TEXT Gemeinde
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gemeinde ?
# CORRECT:TEXT Gemeinde
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Kindergarten
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeinde ?
# CORRECT:TEXT Schuel. Kindergarten
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gemeinden  ?
# CORRECT:TEXT Gemeinden
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeinden  ?
# CORRECT:TEXT Flaeche
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerertrag allgemeine Gemeindesteuern hat  in Buelach  ?
# CORRECT:TEXT Steuerertrag allgemeine Gemeindesteuern
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Altersquotient  in Wetzikon ?
# CORRECT:TEXT Altersquotient
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerb.
# CORRECT:TEXT Steuerb. Vermoegen natuerl. Pers. Median
# 3
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Verkaeufe EFH
# CORRECT:TEXT Bezirksebene
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirksebene ?
# CORRECT:TEXT Bezirksebene
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Verkaeufe EFH
# CORRECT:TEXT Verkaeufe EFH
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT KRW Waehleranteil CVP in Prozent  in Dietikon
# CORRECT:TEXT KRW Waehleranteil CVP
# 3
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand Umweltschutz und Raumordnung
# CORRECT:TEXT Nettoaufwand Umweltschutz und Raumordnung
# 1
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Flaeche
# CORRECT:TEXT Flaeche
# 1
# 1
# 3
# ENT_LABEL LOC
# ENTITY2 DATA
# ENT_TEXT NRW
# CORRECT:TEXT NRW Waehleranteil CVP
# 3
# ENT_LABEL LOC
# ENTITY2 DATA
# ENT_TEXT NRW
# CORRECT:TEXT NRW Waehleranteil EDU
# 3
# 4
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. Strassen, PP 5 Jahre
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerb.
# CORRECT:TEXT Steuerb. Vermoegen natuerl. Pers. 25%Quantil
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand Bildung
# CORRECT:TEXT Nettoaufwand Bildung
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeindebeitrag an ZVV
# CORRECT:TEXT Gemeindebeitrag an ZVV
# 1
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Sekundarstufe II
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gemeinde  ?
# CORRECT:TEXT Gemeinde
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeinde  ?
# CORRECT:TEXT Christkatholische Kirchensteuerpflichtige
# 1
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bauzonen ueberbaut hat  pro Bezirk  ?
# CORRECT:TEXT Bezirk
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauzonen ueberbaut hat  pro Bezirk  ?
# CORRECT:TEXT Bauzonen ueberbaut
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Neuerstellte
# CORRECT:TEXT Gemeindeebene
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gemeindeebene  ?
# CORRECT:TEXT Gemeindeebene
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Neuerstellte
# CORRECT:TEXT Neuerstellte EFH
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeindeebene  ?
# CORRECT:TEXT Neuerstellte EFH
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Anteil Siedlungsflaeche in Prozent  pro Bezirk
# CORRECT:TEXT Bezirk
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil Siedlungsflaeche in Prozent  pro Bezirk
# CORRECT:TEXT Anteil Siedlungsflaeche
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerkraft berichtigt pro Kopf
# CORRECT:TEXT Steuerkraft berichtigt pro Kopf
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT 1Personenhaushalte hat  pro Gemeinde  ?
# CORRECT:TEXT Gemeinde
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT 1Personenhaushalte hat  pro Gemeinde  ?
# CORRECT:TEXT 1Personenhaushalte
# 3
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Nettoaufwand oeffentliche Ordnung und Sicherheit hat  pro Gemeinde  ?
# CORRECT:TEXT Gemeinde
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand oeffentliche Ordnung und Sicherheit hat  pro Gemeinde  ?
# CORRECT:TEXT Nettoaufwand oeffentliche Ordnung und Sicherheit
# 3
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Zuzuege  Adlikon, Hochfelden und Bauma ?
# CORRECT:TEXT Zuzuege
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Verkaeufe von unbebautem Land
# CORRECT:TEXT Verkaeufe von unbebautem Land
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Neuzulassungen  Elektromotor  in Bauma bis 2014 ?
# CORRECT:TEXT Neuzulassungen  Elektromotor
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bezirke
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirke ?
# CORRECT:TEXT Bezirke
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. Wohnen
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirke ?
# CORRECT:TEXT Bauinv. Wohnen
# 1
# ENT_LABEL LOC
# ENTITY2 GRAN
# ENT_TEXT NRW
# CORRECT:TEXT Kanton
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Kanton Zuerich ?
# CORRECT:TEXT Kanton
# 3
# ENT_LABEL LOC
# ENTITY2 DATA
# ENT_TEXT NRW
# CORRECT:TEXT NRW Waehleranteil EDU
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kanton Zuerich ?
# CORRECT:TEXT NRW Waehleranteil EDU

# %%
for key in word_evaluation:
    correct = word_evaluation[key]["correct"]
    total = word_evaluation[key]["total"]

    print(f"{key}: {correct / total * 100:.2f}%")

stat_total_sum = 0
stat_correct_sum = 0

print("---")
for key in stat_evaluation:
    correct = stat_evaluation[key]["correct"]
    total = stat_evaluation[key]["total"]
    
    stat_total_sum += total
    stat_correct_sum += correct

    print(f"{key}: {correct / total * 100:.2f}%")

print(f"\nTotal: {stat_correct_sum/stat_total_sum * 100:.2f}%")
# Out:
# GRAN: 3.42%
# DATA: 15.08%
# ---
# GRAN: 3.42%
# DATA: 15.08%
#
# Total: 12.46%

# %%
# dictionary which will be populated with the entities and result information
entity_evaluation = {}

# helper function to udpate the entity_evaluation dictionary
def update_results(entity, metric):
    if entity not in entity_evaluation:
        entity_evaluation[entity] = {"correct": 0, "total": 0}
    
    entity_evaluation[entity][metric] += 1

# same as before, see if entities from test set match what spaCy currently predicts
for data in TEST_REVISION_DATA:
    sentence = data[0]
    entities = data[1]["entities"]

    for entity in entities:
        doc = nlp(sentence)
        correct_text = sentence[entity[0]:entity[1]]

        for ent in doc.ents:
            if ent.label_ == entity[2] and ent.text == correct_text:
                update_results(ent.label_, "correct")
                break

        update_results(entity[2], "total")

# %%
sum_total = 0
sum_correct = 0

for entity in entity_evaluation:
    total = entity_evaluation[entity]["total"]
    correct = entity_evaluation[entity]["correct"]

    sum_total += total
    sum_correct += correct
    
    print("{} | {:.2f}%".format(entity, correct / total * 100))

print()
print("Overall accuracy: {:.2f}%".format(sum_correct / sum_total * 100))
# Out:
# MISC | 65.11%
# LOC | 66.60%
# ORG | 79.32%
# PER | 92.48%
#
# Overall accuracy: 75.43%

# %%
nlp.meta["name"] = "stat_entity_extractor_v1"
nlp.to_disk("./models/v1")

# %%
TRAIN_STAT_DATA[5]
# Out:
# ['Ich brauche Bauzonen ', {'entities': [[12, 20, 'DATA']]}]

# %%
doc = nlp(u'Welche Gemeinde hat die grösste Bevölkerung und welche hatte im 2019 den höchsten Ausländeranteil?')

# show universal pos tags
print(' '.join('{word}/{tag}'.format(word=t.orth_, tag=t.pos_) for t in doc))
# output: Ich/PRON bin/AUX ein/DET Berliner/NOUN ./PUNCT

# show German specific pos tags (STTS)
print(' '.join('{word}/{tag}'.format(word=t.orth_, tag=t.tag_) for t in doc))
# output: Ich/PPER bin/VAFIN ein/ART Berliner/NN ./$.

# show dependency arcs
print('\n'.join('{child:<8} <{label:-^7} {head}'.format(child=t.orth_, label=t.dep_, head=t.head.orth_) for t in doc))
# output: (sb: subject, nk: noun kernel, pd: predicate)

#named entities
print("Named Entity Recognition:")
for ent in doc.ents:
    print(ent.text)
print("Noun chunks:")
for chunk in doc.noun_chunks:
    print(chunk.text)
# Out:
# Welche/DET Gemeinde/NOUN hat/AUX die/DET grösste/ADJ Bevölkerung/NOUN und/CCONJ welche/PRON hatte/AUX im/ADP 2019/PROPN den/DET höchsten/ADJ Ausländeranteil/NOUN ?/PUNCT
# Welche/PWAT Gemeinde/NN hat/VAFIN die/ART grösste/ADJA Bevölkerung/NN und/KON welche/PDS hatte/VAFIN im/APPRART 2019/CARD den/ART höchsten/ADJA Ausländeranteil/NN ?/$.
# Welche   <--nk--- Gemeinde
# Gemeinde <--sb--- hat
# hat      <-ROOT-- hat
# die      <--nk--- Bevölkerung
# grösste  <--nk--- Bevölkerung
# Bevölkerung <--oa--- hat
# und      <--cd--- Bevölkerung
# welche   <--cj--- und
# hatte    <--cj--- hat
# im       <--mo--- hatte
# 2019     <--nk--- im
# den      <--nk--- Ausländeranteil
# höchsten <--nk--- Ausländeranteil
# Ausländeranteil <--oa--- hatte
# ?        <-punct- hat
# Named Entity Recognition:
# Noun chunks:
# Welche Gemeinde
# die grösste Bevölkerung
# welche
# 2019
# den höchsten Ausländeranteil
