# %%
# DISCLAIMER: Large part of this code for training new entities based on a pre-trained model, 
# is taken from Isaac Aderogba under the following link https://deepnote.com/publish/2cc2d19c-c3ac-4321-8853-0bcf2ef565b3
# 
# Statistics Canton Zurich humbly tried to adapt his code to our purposes of training
#statistically relevant entities

# %%
from __future__ import print_function, unicode_literals
import pandas as pd
import numpy as np
import spacy
from random import sample
import io, csv
import re
import thinc
import random
import warnings
from spacy.util import minibatch, compounding
import de_core_news_lg

# %%
#spacy3.0.0
#nlp = spacy.load('de_core_news_lg')
#spacy2.3
nlp = spacy.load('de_core_news_lg')

df=pd.read_csv("data/datasets_overview.csv")

#one more prepatation
df['question_type'] = df['dataset_title'].str.extract(r"\[(.*?)\]", expand=False)
df['question_type'] = np.where(df['question_type']== '%', "percent", "cardinal")
df['dataset_title'] = df['dataset_title'].str.replace(r"\[(.*?)\]", "")
#structurize relevant informations such as variables
#load content of datasets

#generate sentences

sentences=pd.read_csv("input/question_generator.csv")
#locations=pd.read_csv("data/1.csv",usecols = ['GEBIET_NAME'])#using this right now for every variable
out_sentences=[]

for i in df['index'].unique():
    filename="data/"+str(i)+".csv"
    with io.open(filename, 'r', encoding="latin-1") as csvfile:
        dialect = csv.Sniffer().sniff(csvfile.readline(), [',',';'])
        csvfile.seek(0)
        mydelimiter=dialect.delimiter
    this_data=pd.read_csv(filename,delimiter=dialect.delimiter)
    vars=df['var'].loc[df['index'] == i]
    dataset_title=df['dataset_title'].loc[df['index']==i].any()
    question_type=df['question_type'].loc[df['index']==i].any()
    if vars.str.contains("INDIKATOR_VALUE").sum():
        main=dataset_title
        filter_vars=vars
        #print(filter_vars)
    else:
        continue #temporary so that all variables look alike
        print("ATTRIBUTING MAIN VARIABLE TO: ",dataset_title)
        length_title_string=len(dataset_title.split())
        highest_similarity=0
        which=None
        for var in vars:
            temp_string=dataset_title+" "+var
            #print(temp_string)
            doc = nlp(temp_string)
            assert len(doc.vector) == len(doc[0].vector)
            calc_similarity=doc[:length_title_string].similarity(doc[length_title_string:])
            if  calc_similarity> highest_similarity:
                highest_similarity=calc_similarity
                which=var

        print("Highest similarity:",var,highest_similarity)
        main=var
        vars=vars.tolist()
        print(vars)
        print(main)
        filter_vars=vars.remove(main)
    #the following temporary because it is standardized
    filter_vars=list(filter_vars)
    filter_vars.append("")
    try:
        filter_vars.remove("INDIKATOR_JAHR")
        filter_vars.remove("GEBIET_NAME")
        filter_vars.remove("BFS_NR")
        filter_vars.remove("INDIKATOR_VALUE")
    except:
        print("variable removing empty")

    for sentence in sentences['question'].loc[sentences['main_type'] == question_type]:
        out_entities = []
        sentence=sentence.replace("{main}",main)
        sentence=sentence.replace("{localitylevel}","")#at the moment empty
        #TODO either one locality, one level, or several localities
        random_value=sample(["one locality","one level","several localities"],1)[0]
        if random_value=="one locality":
            locality_insert="in "+sample(list(this_data['GEBIET_NAME']),1)[0]
        if random_value=="one level":
            locality_insert=sample(["für den gesamten Kanton","im Kanton Zürich","auf Bezirksebene",
            "für alle Bezirke","pro Bezirk","auf Gemeindeebene","für alle Gemeinden","pro Gemeinde"],1)[0]
        if random_value=="several localities":
            locality_insert=""
            local_loop=sample([1,2,3],1)[0]
            for local in range(0,local_loop):
                if local!=0 and local!=(local_loop-1):
                    locality_insert+=", "
                if local!=0 and local==(local_loop-1):
                    locality_insert+=" und "
                locality_insert+=sample(list(this_data['GEBIET_NAME']),1)[0]
        sentence=sentence.replace("{locality}",locality_insert)
        sentence=sentence.replace("{yeartime}","")#TODO no,aktuellste,neuste, value from list, from to year
        sentence=sentence.replace("{filter}",sample(list(filter_vars),1)[0])

        for mat in re.findall(r'.*?\[(.*)].*', sentence):
            which_part=sample([1,2],1)

            if which_part==1:
                sentence=sentence.replace("["+mat+"]",mat.partition("|")[0])
                #sentence=re.sub("["+mat+"]",mat.partition("|")[0],sentence)
            else:
                sentence=sentence.replace("["+mat+"]",mat.partition("|")[2])
                #sentence=re.sub("["+mat+"]",mat.partition("|")[2],sentence)

        match_span = re.search(r'\bGEMEINDE\b | \bGEMEINDEN\b | \bGEMEINDEEBENE\b | \bBEZIRK\b | \bBEZIRKSEBENE\b | \bBEZIRKE\b | \bKANTON\b | \bKANTONSEBENE\b | \bREGION\b', sentence,flags=re.IGNORECASE)

        if match_span is not None:
            match_span=match_span.span()
            out_entities.append((match_span[0], match_span[1], "GRAN"))

        #out_entities.append((match_span[0], match_span[1], "LOCALITY"))


        #out_sentences.append(sentence)
        #print(sentence)
        out_sentences.append((sentence, {"entities": out_entities}))
# Out:
# <ipython-input-45-f21d32f07a7c>:11: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['dataset_title'] = df['dataset_title'].str.replace(r"\[(.*?)\]", "")
# variable removing empty

# %%
print(out_sentences[:10])
pd.DataFrame(out_sentences).to_csv("input/generated_sentences.csv",index=False)
# Out:
# [('Wie viel Eigenkapital  hat  in Hedingen  ?', {'entities': []}), ('Welches ist das Eigenkapital   Hagenbuch und Region Zimmerberg ?', {'entities': []}), ('Was ist der Anteil an Bruttoverschuldungsanteil   in Hittnau ?', {'entities': []}), ('Wie viel Steuerbares Vermögen natürliche Pers.  hat  Freienstein-Teufen und Hochfelden  ?', {'entities': []}), ('Welches ist das Steuerbares Vermögen natürliche Pers.   für alle Bezirke ?', {'entities': [(64, 73, 'GRAN')]}), ('Wie viel Sterbefälle  hat  Winkel  ?', {'entities': []}), ('Welches ist das Sterbefälle   Regensdorf ?', {'entities': []}), ('Was ist der Anteil an Jugendquotient   pro Bezirk ?', {'entities': [(42, 50, 'GRAN')]}), ('Was ist der Anteil an Geb.Vol. Dienstleistungen: Zunahme   Wangen-Brüttisellen und Kloten ?', {'entities': []}), ('Wie viel Bevölkerungszunahme 5 Jahre  hat  in Region Zimmerberg  ?', {'entities': []})]

# %%
npr_df = pd.read_csv("external/deu_news_2015_3M-sentences.txt", delimiter = "\t")
npr_df=npr_df.sample(frac=1)
npr_df.head()
# Out:
#                1                                                  ­
# 10844      11127  22034 Nordkorea feuert Raketen ab – Seoul mach...
# 1883317  1989557  Nachhaltigkeitsexperte Giuseppe van der Helm r...
# 1771042  1869752  Manchmal hat man ja den Eindruck, dass sich de...
# 205260    213267       Auch dort ist die Börse ins Taumeln geraten.
# 1972227  2082678  Ohne dabei in einen bedeutungsschweren Symboli...

# %%
# create an nlp object as we'll use this to seperate the sentences and identify existing entities
#loaded already above
#nlp = spacy.load('de_core_news_lg')

# %%
revision_texts = []

# convert the articles to spacy objects to better identify the sentences. Disabled unneeded components. # takes ~ 4 minutes
for doc in nlp.pipe(npr_df.iloc[:10000,1], batch_size=30, disable=["tagger", "ner"]):
    for sentence in doc.sents:
        if  40 < len(sentence.text) < 80:
            # some of the sentences had excessive whitespace in between words, so we're trimming that
            revision_texts.append(" ".join(re.split("\s+", sentence.text, flags=re.UNICODE)))

# %%
revisions = []

# Use the existing spaCy model to predict the entities, then append them to revision
for doc in nlp.pipe(revision_texts, batch_size=50, disable=["tagger", "parser"]):
    
    # don't append sentences that have no entities
    if len(doc.ents) > 0:
        revisions.append((doc.text, {"entities": [(e.start_char, e.end_char, e.label_) for e in doc.ents]}))

# %%
# print an example of the revision sentence
print(revisions[0][0])

# print an example of the revision data
print(revisions[0][1])
# Out:
# Letztere steigt nach oben und erzeugt starke Aufwinde in der Wolke.
# {'entities': [(61, 66, 'LOC')]}

# %%
# create arrays to store the revision data
TRAIN_REVISION_DATA = []
TEST_REVISION_DATA = []

# create dictionaries to keep count of the different entities
TRAIN_ENTITY_COUNTER = {}
TEST_ENTITY_COUNTER = {}

# This will help distribute the entities (i.e. we don't want 1000 PERSON entities, but only 80 ORG entities)
REVISION_SENTENCE_SOFT_LIMIT = 200

# helper function for incrementing the revision counters
def increment_revision_counters(entity_counter, entities):
    for entity in entities:
        label = entity[2]
        if label in entity_counter:
            entity_counter[label] += 1
        else:
            entity_counter[label] = 1

random.shuffle(revisions)
for revision in revisions:
    # get the entities from the revision sentence
    entities = revision[1]["entities"]

    # simple hack to make sure spaCy entities don't get too one-sided
    should_append_to_train_counter = 0
    for _, _, label in entities:
        if label in TRAIN_ENTITY_COUNTER and TRAIN_ENTITY_COUNTER[label] > REVISION_SENTENCE_SOFT_LIMIT:
            should_append_to_train_counter -= 1
        else:
            should_append_to_train_counter += 1

    # simple switch for deciding whether to append to train data or test data
    if should_append_to_train_counter >= 0:
        TRAIN_REVISION_DATA.append(revision)
        increment_revision_counters(TRAIN_ENTITY_COUNTER, entities)
    else:
        TEST_REVISION_DATA.append(revision)
        increment_revision_counters(TEST_ENTITY_COUNTER, entities)

# %%
TRAIN_ENTITY_COUNTER
# Out:
# {'PER': 206, 'MISC': 207, 'LOC': 203, 'ORG': 201}

# %%
TEST_ENTITY_COUNTER
# Out:
# {'MISC': 675, 'LOC': 651, 'PER': 566, 'ORG': 400}

# %%
TRAIN_REVISION_DATA
# Out:
# [('16 Kommentare Klaus Schwab reckt den Kopf.',
#   {'entities': [(14, 26, 'PER')]}),
#  ('Hallo wie geht es dir?, fragte Douglas Costa seine Fans via Twitter.',
#   {'entities': [(31, 44, 'PER'), (60, 67, 'MISC')]}),
#  ('Es verlief ähnlich wie das Beben in Haiti ein paar Monate zuvor.',
#   {'entities': [(36, 41, 'LOC')]}),
#  ('Reinigung des Rathausplatzes unmittelbar nach Public Viewing',
#   {'entities': [(14, 28, 'LOC'), (46, 60, 'LOC')]}),
#  ('Ein Argument, dem sich auch Walsh nicht verschließen kann.',
#   {'entities': [(28, 33, 'PER')]}),
#  ('Christian Schwerdtfeger und Christoph Reichwein',
#   {'entities': [(0, 23, 'PER'), (28, 47, 'PER')]}),
#  ('Die Nacht im Bernabéu-Stadion ist historisch.',
#   {'entities': [(13, 29, 'MISC')]}),
#  ('Verspätungen und Ausfälle an deutschen Flughäfen',
#   {'entities': [(29, 38, 'MISC')]}),
#  ('Kuipers gibt ihn aber nicht, die nächste Fehlentscheidung.',
#   {'entities': [(0, 7, 'PER')]}),
#  ('Was ihre Kollegin Sila Sahin sehr gut versteht: „Lieber Bad Boy als Weichei.',
#   {'entities': [(18, 28, 'PER'), (49, 63, 'MISC')]}),
#  ('Dringende Suche nach vermisstem Senior Karlsruhe',
#   {'entities': [(21, 38, 'PER'), (39, 48, 'MISC')]}),
#  ('Hierzulande macht es die Sprache diesen Kindern zusätzlich schwer:',
#   {'entities': [(25, 32, 'MISC')]}),
#  ('Mit maximal acht Airbags setzt der Metris Tourer Maßstäbe unter seinesgleichen.',
#   {'entities': [(35, 48, 'ORG')]}),
#  ('Nicht viel besser erging es dem Stadtrivalen AS Rom.',
#   {'entities': [(45, 51, 'ORG')]}),
#  ('Gallen: Ein solcher Streit habe sich abgezeichnet.',
#   {'entities': [(0, 6, 'LOC')]}),
#  ('Islamischer Staat sorgen seit Monaten für Entsetzen weltweit.',
#   {'entities': [(0, 17, 'LOC')]}),
#  ('Merkel hält Euro-Austritt Griechenlands für verkraftbar',
#   {'entities': [(0, 6, 'PER'), (26, 39, 'LOC')]}),
#  ('Aber klar, der Grund dafür ist wieder einmal die drohende russische Gefahr.',
#   {'entities': [(58, 67, 'MISC')]}),
#  ('Auch das Aufzeichnen des PC-Bildschirms ist möglich.',
#   {'entities': [(25, 39, 'ORG')]}),
#  ('In Zukunft wollen wir unseren Platz auf den europäischen Märkten finden.',
#   {'entities': [(44, 56, 'MISC')]}),
#  ('Die weiteren Resultate vom Mittwoch: Basel - Maccabi Tel Aviv',
#   {'entities': [(37, 42, 'LOC'), (45, 61, 'ORG')]}),
#  ('Mit dem Finger allein auf die Schweiz zu zeigen, wäre falsch.',
#   {'entities': [(30, 37, 'LOC')]}),
#  ('Die FSA kämpft übrigens unter der alten französischen Kollonialflagge.. ',
#   {'entities': [(4, 7, 'ORG'), (40, 53, 'MISC')]}),
#  ('Umfragen sehen die AfD in Sachsen zwischen sechs und acht Prozent.',
#   {'entities': [(19, 22, 'ORG'), (26, 33, 'LOC')]}),
#  ('Klitschko hat die blutdürstige Mücke unterschätzt',
#   {'entities': [(0, 9, 'PER')]}),
#  ('In Al-Sayyid könnte "Schaf" tatsächlich eines der ersten Worte gewesen sein.',
#   {'entities': [(3, 12, 'LOC')]}),
#  ('Die Firma sitzt in Kfar-Netter knapp 30 Kilometer nördlich von Tel Aviv.',
#   {'entities': [(19, 30, 'LOC'), (63, 71, 'LOC')]}),
#  ('Suche nach Verschütteten nach einer Lawine in Afghanistan (Archiv) (Keystone)',
#   {'entities': [(46, 57, 'LOC'), (68, 76, 'LOC')]}),
#  ('Damit war die Sache auch für den Thomas erledigt", sagt Klinar.',
#   {'entities': [(33, 39, 'PER'), (56, 62, 'PER')]}),
#  ('Wann diese nach Klingnau ziehen können, ist ungewiss.',
#   {'entities': [(16, 24, 'LOC')]}),
#  ('Von Februar bis November 2016 wird deshalb die Deichstraße dort gesperrt sein.',
#   {'entities': [(47, 58, 'LOC')]}),
#  ('Addyi soll diesen Frauen die Lust zurückbringen.',
#   {'entities': [(0, 5, 'PER')]}),
#  ('Der Mann, der sich Legida entgegenstellte:',
#   {'entities': [(19, 25, 'ORG')]}),
#  ('Auf Twitter geht es nach diesem Auftritt rund.',
#   {'entities': [(4, 11, 'MISC')]}),
#  ('Den Bauplan inklusive Hillsize und Auslauf als pdf-Datei vergrößern.',
#   {'entities': [(47, 56, 'MISC')]}),
#  ('Das rührt nicht nur daher, dass beide Schweizerdeutsch sprechen.',
#   {'entities': [(38, 54, 'MISC')]}),
#  ('Nino Niederreiter weist eine Minus-1-Bilanz auf.',
#   {'entities': [(0, 17, 'PER'), (29, 43, 'ORG')]}),
#  ('3. Bis zum 30. November sind im Rahmen der Amazon Cyber Monday-Woche',
#   {'entities': [(43, 68, 'MISC')]}),
#  ('Augsburg sei "sicher kein super Spiel von uns" gewesen.',
#   {'entities': [(0, 8, 'LOC')]}),
#  ('Nur im Tablet-Segment sind die Atom-Chips erfolgreich.',
#   {'entities': [(31, 41, 'MISC')]}),
#  ('Die Therme gehört zur deutschen Bädergruppe',
#   {'entities': [(22, 31, 'MISC'), (32, 43, 'LOC')]}),
#  ('Grazer Gerichtsmediziner geben Schülern Einblick',
#   {'entities': [(0, 6, 'LOC')]}),
#  ('Die 16 Achtelfinalisten der Champions League stehen fest.',
#   {'entities': [(28, 44, 'MISC')]}),
#  ('Bis heute wurde jedoch kein Friedensvertrag unterzeichnet.',
#   {'entities': [(28, 43, 'MISC')]}),
#  ('Gewerbedirektor Barell ist überzeugt, dass sich die Anstrengungen lohnen. ',
#   {'entities': [(0, 22, 'PER')]}),
#  ('Eine interessante Station ist das Städtchen Medora in Norddakota.',
#   {'entities': [(44, 50, 'LOC'), (54, 64, 'LOC')]}),
#  ('Die Schweizer Staatsfinanzen sind eigentlich grundsolide.',
#   {'entities': [(4, 13, 'MISC')]}),
#  ('Dass es in Leverkusen ganz anders lief, tat den Schwaben deshalb richtig gut.',
#   {'entities': [(11, 21, 'LOC'), (48, 56, 'MISC')]}),
#  ('Der Spanier nahm wie Coman auf der Bank Platz.',
#   {'entities': [(4, 11, 'LOC'), (21, 26, 'PER'), (35, 45, 'ORG')]}),
#  ('Auf Indiegogo war der Handgepäckkoffer schon erfolgreich:',
#   {'entities': [(4, 13, 'MISC')]}),
#  ('Am Kapitol in Columbia weht sie nun jedenfalls nicht mehr.',
#   {'entities': [(3, 10, 'LOC'), (14, 22, 'LOC')]}),
#  ('Und der Londoner «Guardian» meinte: «Hut ab vor Nico Rosberg».',
#   {'entities': [(8, 16, 'MISC'), (18, 26, 'MISC'), (48, 60, 'PER')]}),
#  ('Waren das nicht die, mit denen unser Justizminister gemeinsam marschiert ist?',
#   {'entities': [(37, 51, 'ORG')]}),
#  ('Wie registriere ich mich für «MEIN PCtipp»?',
#   {'entities': [(30, 41, 'ORG')]}),
#  ('803474 Derzeit läuft ein geschlossener Betatest. ',
#   {'entities': [(39, 47, 'MISC')]}),
#  ('Dralle: Wir merken, dass es im Moment eine deutliche Belebung gibt.',
#   {'entities': [(0, 6, 'PER')]}),
#  ('Letztere steigt nach oben und erzeugt starke Aufwinde in der Wolke.',
#   {'entities': [(61, 66, 'LOC')]}),
#  ('Apples Sprachsteuerung Siri hat mit Arabisch eine neue Sprache gelernt.',
#   {'entities': [(0, 27, 'MISC'), (36, 44, 'MISC')]}),
#  ('Wie viele Lautsprecher betroffen sind, verriet Apple nicht.',
#   {'entities': [(47, 52, 'ORG')]}),
#  ('Werbung Börsenseminare – speziell für Privatanleger.',
#   {'entities': [(8, 22, 'PER')]}),
#  ('Der Preis für ein Fass der US-Sorte WTI stieg um 1,23 Dollar auf 47,37 Dollar.',
#   {'entities': [(36, 39, 'ORG')]}),
#  ('Ein Rettungswagen im Einsatz auf der Warschauer Brücke.',
#   {'entities': [(37, 54, 'LOC')]}),
#  ('Als Kassenwartin hatte sich Sylvia Eisenberg nicht mehr aufstellen lassen.',
#   {'entities': [(28, 44, 'PER')]}),
#  ('Berlin heißt die Dokumentation von Andreas Christoph Schmidt.',
#   {'entities': [(0, 6, 'LOC'), (35, 60, 'PER')]}),
#  ('Dazu werden mehrere hundert Bundespolizisten eingesetzt.',
#   {'entities': [(28, 44, 'ORG')]}),
#  ('Bei Sony sieht man die Funktion gelassen, vergleichbare Pläne hat man nicht.',
#   {'entities': [(4, 8, 'ORG')]}),
#  ('Frappierend, titelte am Mittwoch das Tour-Zentralorgan "L\'Équipe".',
#   {'entities': [(0, 11, 'PER'), (37, 54, 'MISC')]}),
#  ('Alle Bundesliga-Spiele des WAC im Live-Ticker!',
#   {'entities': [(5, 22, 'MISC'), (27, 30, 'ORG')]}),
#  ('Selbst heutige Serienautos erreichen diese Werte nicht einmal annähernd.',
#   {'entities': [(15, 26, 'LOC')]}),
#  ('Ansonsten setzt das Tempelhof-Gesetz enge Grenzen.',
#   {'entities': [(20, 36, 'MISC')]}),
#  ('Seine erste Auftragsarbeit machte Giselbert Hoke über Nacht berühmt.',
#   {'entities': [(34, 48, 'PER')]}),
#  ('Am 1. Februar 2011 übernahm er den Vorsitz des Vorstands der Salzgitter AG.',
#   {'entities': [(61, 74, 'ORG')]}),
#  ('Neapel hat die Roma zu Gast, Florenz gastiert bei Juventus.',
#   {'entities': [(0, 6, 'LOC'),
#     (15, 19, 'LOC'),
#     (23, 27, 'LOC'),
#     (29, 36, 'LOC'),
#     (50, 58, 'ORG')]}),
#  ('hob den Ball nach einem Zuckerpass von Thiago über das Inter-Tor (64.).',
#   {'entities': [(39, 45, 'PER'), (55, 64, 'LOC')]}),
#  ('Coster-Waldau: Darüber haben wir viel gesprochen.',
#   {'entities': [(0, 13, 'LOC')]}),
#  ('Parkinson, befindet Wagner, sei eine Krankheit für Einzelgänger.',
#   {'entities': [(0, 9, 'PER'), (20, 26, 'PER')]}),
#  ('Die Zuschauer sahen in Florida ein aufregendes Rennen.',
#   {'entities': [(23, 30, 'LOC')]}),
#  ('Weich soll es liegen, wenn es nun in sein Grab kommt.',
#   {'entities': [(0, 5, 'LOC')]}),
#  ('675LT auf dem Genfer Autosalon Modifiziert für die Rundstrecke Mittwoch',
#   {'entities': [(0, 5, 'MISC'), (14, 30, 'MISC')]}),
#  ('Er sagt sie hätten das Gerät von Apple bekommen.',
#   {'entities': [(33, 38, 'ORG')]}),
#  ('Schneider zufolge traten bei Williams 2013 erste Beschwerden auf.',
#   {'entities': [(0, 9, 'PER'), (29, 37, 'PER')]}),
#  ('803453 Derzeit läuft dessen Entwicklung auf Hochtouren. ',
#   {'entities': [(44, 54, 'MISC')]}),
#  ('Äussern möchte er sich nur zurückhaltend:', {'entities': [(0, 7, 'PER')]}),
#  ('Kann der SCB in den verbleibenden 1,5 Minuten in Überzahl die Führung ausbauen?',
#   {'entities': [(9, 12, 'ORG')]}),
#  ('nur so würde sich der Dienst für Apple rentieren.',
#   {'entities': [(33, 38, 'ORG')]}),
#  ('Das Medion-Telefon wird es in den Farbvarianten Schwarz und Weiß geben.',
#   {'entities': [(4, 18, 'MISC')]}),
#  ('Dessen Dämonen sind auch die Dämonen dieser riesigen Stadt.',
#   {'entities': [(53, 58, 'LOC')]}),
#  ('6. Oktober, 19 Uhr, im Bürgerzentrum Brackenheim statt.',
#   {'entities': [(37, 48, 'LOC')]}),
#  ('Schon jetzt meiden viele Reiseunternehmen die Sinai-Halbinsel.',
#   {'entities': [(46, 61, 'LOC')]}),
#  ('POL-BI: Neue Entwicklungen an den Unfallstellen auf der BAB 2',
#   {'entities': [(0, 6, 'ORG'), (56, 61, 'LOC')]}),
#  ('In einer Werkshalle in Bregenz hat sich am Mittwoch ein Arbeitsunfall ereignet.',
#   {'entities': [(23, 30, 'LOC')]}),
#  ('Knackige Farbenwiedergabe und gutes Touch-Display',
#   {'entities': [(0, 25, 'MISC')]}),
#  ('Antworten Populär auf Facebook – Privatsphäre',
#   {'entities': [(22, 30, 'MISC')]}),
#  ('Das Bezirksgericht in Zürich hatte den Entertainer im Dezember freigesprochen.',
#   {'entities': [(22, 28, 'LOC')]}),
#  ('Franken an Währung gebunden, die nicht funktioniert?',
#   {'entities': [(0, 7, 'LOC')]}),
#  ('Hecking: Er hat gesehen, wie wir uns entwickelt haben.',
#   {'entities': [(0, 7, 'ORG')]}),
#  ('Weich in Kanada und Österreich: Vorteil Ferrari?',
#   {'entities': [(9, 15, 'LOC'), (20, 30, 'LOC'), (40, 47, 'ORG')]}),
#  ('Fromme ist auch Herausgeber des Online-Newsletters Versicherungsmonitor.de.',
#   {'entities': [(0, 6, 'PER'), (32, 74, 'MISC')]}),
#  ('Erst am Gate und dann im Flieger Swiss lässt Passagiere sieben Stunden warten',
#   {'entities': [(8, 12, 'LOC')]}),
#  ('Westberlin lag damals als Insel, von einer Mauer umgeben, mitten in der DDR.',
#   {'entities': [(0, 10, 'LOC'), (72, 75, 'ORG')]}),
#  ('Wir leben nun mal in der Marktwirtschaft, auch wenn Gysi zu den Linken gehört.',
#   {'entities': [(52, 56, 'PER')]}),
#  ('So manches lief ähnlich ab wie an Olympischen Spielen.',
#   {'entities': [(34, 53, 'MISC')]}),
#  ('Für Holländer wurde der Hunger bald unerträglich:',
#   {'entities': [(4, 13, 'LOC')]}),
#  ('Das Agrarministerium informiert zur Erdbeerernte.',
#   {'entities': [(4, 20, 'ORG')]}),
#  ('herrscht in der Redaktion Ausnahmezustand.',
#   {'entities': [(26, 41, 'MISC')]}),
#  ('Im Vergleich zu Merkel würden einige Millionen Deutsche den besseren Kanzler/',
#   {'entities': [(16, 22, 'PER'), (47, 55, 'MISC')]}),
#  ('Diese Geldquelle bleibt Griechenland schon seit langem versagt.',
#   {'entities': [(24, 36, 'LOC')]}),
#  ('Von NEUE/Seff Dünser am 28. November 2015',
#   {'entities': [(4, 8, 'MISC'), (9, 20, 'PER')]}),
#  ("Der Dow-Jones-Index schloss 0,04 Prozent tiefer auf 18'105 Punkten.",
#   {'entities': [(4, 19, 'ORG')]}),
#  ('» Boulevard vor 23 Minuten Charlie Sheen bestätigt HIV-Infektion',
#   {'entities': [(2, 11, 'PER'), (27, 40, 'PER')]}),
#  ('Dabei schlug sich auch Spahn gar nicht schlecht.',
#   {'entities': [(23, 28, 'PER')]}),
#  ('Das Ganze reicht weit über den VW-Konzern hinaus.',
#   {'entities': [(31, 41, 'ORG')]}),
#  ('Die SPD rutscht den Angaben zufolge um einen halben Punkt auf 23,5 Prozent.',
#   {'entities': [(4, 7, 'ORG')]}),
#  ('Danach starten Sie die Sicherung mit Start-AzureStorageBlobCopy.',
#   {'entities': [(37, 63, 'MISC')]}),
#  ('Darüber klagen laut BDU fast 90 Prozent der Headhunter.',
#   {'entities': [(20, 23, 'ORG')]}),
#  ('aktuelle Nachrichten auf stuttgarter-nachrichten.',
#   {'entities': [(25, 48, 'MISC')]}),
#  ('Und diese Gläubigen haben jetzt eben einen neuen Helden namens Hersh gefunden.',
#   {'entities': [(63, 68, 'PER')]}),
#  ('Den Sieg holte sich der Österreicher Stefan Kraft.',
#   {'entities': [(24, 36, 'LOC'), (37, 49, 'PER')]}),
#  ('In welchen Ligen spielen die Fußball-Teams nun?',
#   {'entities': [(29, 42, 'MISC')]}),
#  ('Das augenfälligste Projekt ist ein neuer Quartiertreffpunkt samt Quartierbüro.',
#   {'entities': [(65, 77, 'LOC')]}),
#  ('Radikale fühlen sich von Ruckrede Rivlins provoziert Kultur',
#   {'entities': [(0, 8, 'PER'), (25, 41, 'PER')]}),
#  ('Die Welt: Sehen Sie die FDP als Opfer der Finanzkrise?',
#   {'entities': [(24, 27, 'ORG')]}),
#  ('Derzeit laufen verschiedene Rechtshilfeersuchen mit den Niederlanden. ',
#   {'entities': [(56, 68, 'LOC')]}),
#  ('Der Auftakt des Hessentags ist trotz Regenwetter gelungen.',
#   {'entities': [(16, 26, 'MISC')]}),
#  ('Vertrauensentzug für chinafreundliche Politik',
#   {'entities': [(0, 16, 'PER')]}),
#  ('JOLLY JOKER", Made in China, gekauft in Tschechien.',
#   {'entities': [(0, 11, 'ORG'), (22, 27, 'LOC'), (40, 50, 'LOC')]}),
#  ('Richard Lugners Opern-Ladies der letzten Jahre30 Fotos',
#   {'entities': [(0, 15, 'PER'), (41, 48, 'MISC')]}),
#  ('Das wäre nach den Anteilsverhältnissen nämlich normalerweise nicht so.',
#   {'entities': [(18, 38, 'MISC')]}),
#  ('Höhepunkt zum Messeauftakt war die Verleihung des CMS Purus Awards.',
#   {'entities': [(14, 26, 'MISC'), (50, 66, 'MISC')]}),
#  ('FPÖ und ÖVP stellen nicht amtsführende Stadträte.',
#   {'entities': [(0, 3, 'ORG'), (8, 11, 'ORG')]}),
#  ('A3 bei Bessenbach - Mann flüchtet bei Polizeikontrolle',
#   {'entities': [(0, 2, 'LOC'), (7, 17, 'LOC')]}),
#  ('Die Firma dahinter, Kromtech, hat das Problem mittlerweile gelöst.',
#   {'entities': [(20, 28, 'PER')]}),
#  ('Drinnen im Laden, alles andere als ein herzlicher Empfang.',
#   {'entities': [(0, 16, 'MISC')]}),
#  ('Darüber hinaus war Iwata für den neuen Kurs von Nintendo verantwortlich:',
#   {'entities': [(19, 24, 'PER'), (48, 56, 'ORG')]}),
#  ('gültige E-Mail-Adresse fehlt «Der Franz hat gesagt, dass alles sauber war.»',
#   {'entities': [(8, 22, 'MISC'), (34, 39, 'PER')]}),
#  ('Betrunkene Mutter torkelt mit Kleinkind durch Mainz',
#   {'entities': [(46, 51, 'LOC')]}),
#  ('Diese Pressemitteilung wurde auf openPR veröffentlicht.',
#   {'entities': [(33, 39, 'ORG')]}),
#  ('Für das Jahr 2015 rechnet das Management wiederum mit einem "guten Ergebnis".',
#   {'entities': [(8, 17, 'MISC')]}),
#  ('Der Nasdaq-Composite brachte es 2014 auf einen Anstieg von 13,4 Prozent.',
#   {'entities': [(4, 20, 'MISC')]}),
#  ('803456 Derzeit läuft die Debatte im virtuellen Raum über die Mailing-Liste. ',
#   {'entities': [(61, 74, 'LOC')]}),
#  ('Sie machen die Uhren unabhängiger vom Handy.',
#   {'entities': [(38, 43, 'MISC')]}),
#  ('"Ich bin absolut nicht zufrieden mit dem Qualifying.',
#   {'entities': [(41, 51, 'MISC')]}),
#  ('1573755 Ich bin vor einem Jahr auch nochmal einen Polo 1 gefahren. ',
#   {'entities': [(50, 56, 'MISC')]}),
#  ('Auch der von Usain Bolt in Peking gedemütigte Justin Gatlin ist saisonmüde.',
#   {'entities': [(13, 23, 'PER'), (27, 33, 'LOC'), (46, 59, 'PER')]}),
#  ('TSV 1860-News So stoßen die Löwen auf der Wiesn an Hoffnung & Angst:',
#   {'entities': [(0, 33, 'MISC'), (42, 47, 'LOC')]}),
#  ('Stickstoffberge würden unter ihrem eigenen Gewicht zusammenbrechen.',
#   {'entities': [(0, 15, 'PER')]}),
#  ('Ihr Browser kann leider keine eingebetteten Frames anzeigen.',
#   {'entities': [(4, 11, 'MISC')]}),
#  ('Diese Show repräsentierte Amerika dem Rest der Welt.',
#   {'entities': [(26, 33, 'LOC')]}),
#  ('Von Paris per TGV weiter nach Mannheim, zur TSG 1899 Hoffenheim.',
#   {'entities': [(4, 9, 'LOC'),
#     (14, 17, 'MISC'),
#     (30, 38, 'LOC'),
#     (44, 63, 'ORG')]}),
#  ('Die Baufirma Imtech ist pleite und bringt den Zeitplan durcheinander.',
#   {'entities': [(13, 19, 'ORG')]}),
#  ('Ein Hoch auf die russische Ankündigung von ganz großen Dingen.',
#   {'entities': [(17, 26, 'MISC')]}),
#  ('VoloMetrix Kommentar hinzufügen Vielen dank für Ihren Kommentar.',
#   {'entities': [(0, 20, 'MISC')]}),
#  ('Nachrichten, aktuelle Schlagzeilen und Videos:',
#   {'entities': [(39, 45, 'MISC')]}),
#  ('Nur Channel Politik durchsuchen Aussendersuche Personensuche',
#   {'entities': [(4, 19, 'ORG')]}),
#  ('Habs gesehen und wenn man böse fällt kann wohl der Gegenmann nichts dafür. ',
#   {'entities': [(0, 4, 'PER')]}),
#  ('Schmerzhafter Abgang: David Alaba wird in Gelsenkirchen vom Platz geleitet.',
#   {'entities': [(22, 33, 'PER'), (42, 55, 'LOC')]}),
#  ('Bekannt wurde die Existenz erst im vergangenen Jahr.',
#   {'entities': [(35, 51, 'MISC')]}),
#  ('Nur Schalke muss sich noch mit den Italienern einigen.',
#   {'entities': [(4, 11, 'ORG'), (35, 45, 'LOC')]}),
#  ('Für die besten Nachwuchsteams von Swiss Volley',
#   {'entities': [(34, 46, 'ORG')]}),
#  ('Das verriet er in einem Interview mit "Bloomberg Markets".',
#   {'entities': [(39, 56, 'ORG')]}),
#  ('Nur im Bezirk Dietikon war ihr Wähleranteil mit 5,7 Prozent tiefer.',
#   {'entities': [(7, 22, 'LOC')]}),
#  ('Es ist nämlich so, dass wir noch nie eine buntere Nationalmannschaft hatten.',
#   {'entities': [(50, 68, 'ORG')]}),
#  ('PAION: Rücksetzer auffangen, PAION-Aktie mit Potenzial',
#   {'entities': [(0, 5, 'ORG'), (29, 40, 'MISC')]}),
#  ('Die schweren Waffen im Donbass sind abgezogen, doch der Tonfall bleibt scharf:',
#   {'entities': [(23, 30, 'LOC')]}),
#  ('Das sei ein Alter für rebellische Phasen, so Neumann.',
#   {'entities': [(45, 52, 'PER')]}),
#  ('Das war ein Schlag ins Gesicht, sagt Bubnow.',
#   {'entities': [(37, 43, 'PER')]}),
#  ('Einblick in Gefängniszellen und die japanische Gesellschaft',
#   {'entities': [(36, 46, 'MISC')]}),
#  ('«Wir verlassen uns da voll auf unseren Publicist», sagt Eichenberger.',
#   {'entities': [(56, 68, 'PER')]}),
#  ('Google: Project Fi gibt es nun auch für Tablets und Gadgets ohne SIM-Karte.',
#   {'entities': [(0, 6, 'MISC'), (8, 18, 'MISC')]}),
#  ('Amazon begeistert Anleger mit überraschendem Gewinn Seattle.',
#   {'entities': [(0, 6, 'ORG'), (52, 59, 'LOC')]}),
#  ('Oh ja, aber ich fühlte mich noch zu schwach für den offenen Krieg.',
#   {'entities': [(0, 5, 'MISC')]}),
#  ('Carrey wollte offenbar nur eine Beziehungspause.',
#   {'entities': [(0, 6, 'PER')]}),
#  ('Die DayZ Server sind sofort nach der Bestellung verfügbar.',
#   {'entities': [(4, 15, 'MISC')]}),
#  ('Im Gegensatz zum Digitaldruck sind keine Punkteraster oder Pixel erkennbar.',
#   {'entities': [(41, 53, 'MISC')]}),
#  ('Treffpunkt ist in der Fußgängerzone Reichsstraße vor der Europagalerie.',
#   {'entities': [(36, 48, 'LOC'), (57, 70, 'LOC')]}),
#  ('Was Marquez kann, kann auch Lorenzo MotoGP Biaggi testet',
#   {'entities': [(4, 11, 'PER'), (28, 49, 'PER')]}),
#  ('Bankvolkswirte hatten nur mit einem Zuwachs von 2,0 Prozent gerechnet.',
#   {'entities': [(0, 14, 'PER')]}),
#  ('Kommentarübersicht Re: Wie kommt ihr darauf, das Daten gesammelt und..',
#   {'entities': [(0, 21, 'PER')]}),
#  ('Wir haben aktuell eine Quote an Non-Performing Loans von 23 Prozent. ',
#   {'entities': [(32, 52, 'ORG')]}),
#  ('Die Frustration geht über die Städtchen rund um den Lake Tahoe hinaus. ',
#   {'entities': [(52, 62, 'LOC')]}),
#  ('Mazyek signalisiert genau das, Inhalte müssen warten:',
#   {'entities': [(0, 6, 'PER')]}),
#  ('Die Internet-Suchmaschine hatte mit ihren Zahlen überzeugt.',
#   {'entities': [(4, 25, 'MISC')]}),
#  ('Es ist ein Experiment", meint Elisabeth Putz.',
#   {'entities': [(30, 44, 'PER')]}),
#  ('Keine weiteren Sparmaßnahmen, zitiert Reuters den UN-Beauftragten.',
#   {'entities': [(38, 45, 'PER'), (50, 65, 'ORG')]}),
#  ('In Dollar ist der Preis um etwa 1,3 Prozent gefallen.',
#   {'entities': [(3, 9, 'MISC')]}),
#  ('Matthias Lassnig und Karl Grammer, Kronen Zeitung/',
#   {'entities': [(0, 16, 'PER'), (21, 33, 'PER'), (35, 49, 'ORG')]}),
#  ('Die Geburtsstunde der Bundeswehr sollte erst im November 1955 schlagen.',
#   {'entities': [(22, 32, 'ORG')]}),
#  ('Vielfach in einer eigenwilligen Mischung aus Deutsch und Englisch.',
#   {'entities': [(45, 52, 'MISC'), (57, 65, 'MISC')]}),
#  ("Von iPhone und iPad drucken - so geht's 23.04.2015",
#   {'entities': [(4, 10, 'MISC'), (15, 19, 'MISC'), (33, 50, 'MISC')]}),
#  ('Herausforderer Robert erkämpft sich das Spiel und erhöht die Führung auf 11:4.',
#   {'entities': [(0, 21, 'PER')]}),
#  ('In beiden Sessions war es Felipe Nasr, der den achten Platz erringen konnte.',
#   {'entities': [(26, 37, 'PER')]}),
#  ('In diesen Moment ist Selam einfach ein Mädchen.',
#   {'entities': [(21, 26, 'MISC')]}),
#  ('Dass dies bisher nicht gelungen ist, liegt auch an den Lanserhof-Ansprüchen.',
#   {'entities': [(55, 75, 'MISC')]}),
#  ('Sie blicken auf meinen Zettel, auf dem in chinesischen Zeichen "Taktser" steht.',
#   {'entities': [(42, 54, 'MISC')]}),
#  ('STANDARD: Was ist mit dem niedergelassenen Bereich?',
#   {'entities': [(0, 8, 'ORG')]}),
#  ('Einen Einblick in die Bücher erhielt die Runde nach Angaben Merkels nicht.',
#   {'entities': [(60, 67, 'PER')]}),
#  ('Der SMI notierte 0,2 Prozent tiefer mit 8874 Zählern.',
#   {'entities': [(4, 7, 'MISC')]}),
#  ('Amazons Echo präsentiert sich schlicht, verspricht aber guten Klang.',
#   {'entities': [(0, 12, 'MISC')]}),
#  ('Ich bin mir nicht sicher, warum das Urteil einen Artikel bei Spiegel wert ist.',
#   {'entities': [(61, 68, 'ORG')]}),
#  ('Internationale Pressestimmen zum 5:1 "Angeber" Bayern "zermalmen"',
#   {'entities': [(47, 53, 'LOC')]}),
#  ('Die FSA spielt heute aber keine Rolle mehr. ',
#   {'entities': [(4, 7, 'ORG')]}),
#  ('Trailershow zu Nischenspielen - Folge 47/',
#   {'entities': [(15, 29, 'MISC')]}),
#  ('Auch aus Amerika kommen keine guten Nachrichten.',
#   {'entities': [(9, 16, 'LOC')]}),
#  ('Als die C-Klasse verlagert werden sollte, gab es viel Wirbel, klar.',
#   {'entities': [(8, 16, 'MISC')]}),
#  ('Der Schadcode befand sich dabei in einem Willkommens-Pop-up auf Flash-Basis.',
#   {'entities': [(64, 75, 'LOC')]}),
#  ('Die Papiere waren seit dem Sommer allerdings stärker als der Index gestiegen.',
#   {'entities': [(61, 66, 'MISC')]}),
#  ('Momentan liege er deutlich auf Rang eins, erklärt Murer.',
#   {'entities': [(50, 55, 'PER')]}),
#  ('Schwer verletzt wurde am Sonntagvormittag ein 52-jähriger Landwirt in Kainach.',
#   {'entities': [(70, 77, 'LOC')]}),
#  ('Internet- und Telefonanbieter aus anderen EU-Staaten würden so benachteiligt.',
#   {'entities': [(42, 52, 'LOC')]}),
#  ('Dann wendet er noch Benjamins Gewaltanalyse auf den israelischen "Feind" an.',
#   {'entities': [(20, 43, 'PER'), (52, 64, 'MISC')]}),
#  ('Barca ist gegen Juve Favorit bei den Wettanbietern',
#   {'entities': [(0, 5, 'PER'), (16, 20, 'ORG')]}),
#  ('Das Innenministerium hält sich zu Details komplett bedeckt.',
#   {'entities': [(4, 20, 'ORG')]}),
#  ('Man stelle sich vor, der "Übermensch" hätte die Juden gehätschelt und umworben.',
#   {'entities': [(48, 53, 'MISC')]}),
#  ('Dazu kommt die Klage des Verbands von kleinen Solarstromerzeugern (Anpier).',
#   {'entities': [(25, 65, 'ORG')]}),
#  ('Aktuell ist Danica Patrick (32) jedoch in ihrer wichtigsten Rolle gefordert.',
#   {'entities': [(12, 26, 'PER')]}),
#  (': Polizei fahndet nach anonymer Anruferin DPA',
#   {'entities': [(42, 45, 'ORG')]}),
#  ('Im vergangenen Jahr wurde Thomas Gottschalk mit der Platin-Romy geehrt.',
#   {'entities': [(26, 43, 'PER'), (52, 63, 'MISC')]}),
#  ('Als letzten Hilferuf wandten sie sich an einen bekannten US-Fernsehpsychologen.',
#   {'entities': [(57, 78, 'ORG')]}),
#  ('Frage: Hatte Frau Merkel schon irgend einmal eine eigene Meinung?',
#   {'entities': [(18, 24, 'PER')]}),
#  ('Nirgendwo wurde die Lübecker Kunst um 1500 bisher so umfassend präsentiert.',
#   {'entities': [(20, 28, 'LOC')]}),
#  ('"Ich will keine Kommunisten auf der Veranstaltung haben."',
#   {'entities': [(16, 27, 'ORG')]}),
#  ('Nun haben wir es im Meisterrennen in der eigenen Hand.',
#   {'entities': [(20, 33, 'LOC')]}),
#  ('Mit anderen Worten: Beate Zschäpes Aussage war ein schwerer Fehler.',
#   {'entities': [(20, 34, 'PER')]}),
#  ('München steht im Achtelfinale der Königsklasse Köln (SID) -',
#   {'entities': [(0, 7, 'LOC'), (34, 51, 'ORG'), (53, 56, 'ORG')]}),
#  ('Bei den Produzenten geben Dragon 7,9% und Millennium 7,1% nach.',
#   {'entities': [(26, 32, 'MISC'), (42, 52, 'MISC')]}),
#  ('Es seien 4 russische "Kampfflugzeuge" oder Kampfjets gesehen worden!',
#   {'entities': [(11, 20, 'MISC')]}),
#  ('Metallica teilten 2014 das gleiche Schicksal.',
#   {'entities': [(0, 9, 'ORG')]}),
#  ('Das EBIT stieg um 13,6 % auf 39,6 Mio. EUR (Vorjahr: 34,9 Mio. EUR).',
#   {'entities': [(4, 8, 'ORG'), (39, 42, 'MISC'), (63, 66, 'MISC')]}),
#  ('Er wechselt mit sofortiger Wirkung zurück zu den Saale Bulls.',
#   {'entities': [(49, 60, 'ORG')]}),
#  ('Er nennt zum Beispiel den Smog in Peking.',
#   {'entities': [(34, 40, 'LOC')]}),
#  ('Nur fünf Mal in der Geschichte von Olympia fiel das Ergebnis noch knapper aus!',
#   {'entities': [(35, 42, 'PER')]}),
#  ('Als klassisches Beispiel dafür gilt die Modefirma Charles Vögele.',
#   {'entities': [(50, 64, 'PER')]}),
#  ('Mit einem Erstligaklub sei nun Darmstadt noch attraktiver geworden.',
#   {'entities': [(31, 40, 'LOC')]}),
#  ('Dann haben wir einen Glaubens- und Kulturenkrieg vom feinsten.',
#   {'entities': [(35, 48, 'MISC')]}),
#  ('Die Verordnungstexte sind auf der Internetseite www.amtsblatt.llv.li abrufbar.',
#   {'entities': [(4, 20, 'MISC'), (48, 68, 'MISC')]}),
#  ('09:35 Lufthansa: Flugbegleiter streiken doch nicht',
#   {'entities': [(6, 15, 'ORG')]}),
#  ('Swiss Life schlug 19 Mio CHF pro Jahr vor, gut dreimal mehr als bisher.',
#   {'entities': [(0, 10, 'ORG')]}),
#  ('Die im Frankfurter Nordend lebende Frau war seit dem 8. Juli verschwunden.',
#   {'entities': [(7, 26, 'LOC')]}),
#  ('Kein Bargeld in Athen - Automaten werden angeblich um 12 Uhr befüllt 08.50 Uhr:',
#   {'entities': [(16, 21, 'LOC')]}),
#  ('«Noch habe ich kein Flugticket bestellt», sagt der Bieler.',
#   {'entities': [(51, 57, 'LOC')]}),
#  ('Das gab das UEFA-Exekutivkomitee nach seiner Sitzung am Montag in Nyon bekannt.',
#   {'entities': [(12, 32, 'MISC'), (66, 70, 'LOC')]}),
#  ('Nummer eins der Kiezkicker um Trainer Ewald Lienen ist Robin Himmelmann.',
#   {'entities': [(16, 26, 'ORG'), (38, 50, 'PER'), (55, 71, 'PER')]}),
#  ('Rechtsschutz\xadversicherung Festplatte / SSD',
#   {'entities': [(0, 25, 'MISC')]}),
#  ('Auf Twitter brachten zahlreiche Kollegen ihre Fassungslosigkeit zum Ausdruck.',
#   {'entities': [(4, 11, 'MISC')]}),
#  ('Holocaust-Überlebende: Artikel per E-Mail empfehlen "Geh!',
#   {'entities': [(53, 57, 'MISC')]}),
#  ('World of Warcraft-Spieler kennen das Problem:',
#   {'entities': [(0, 25, 'MISC')]}),
#  ('Die Westhafen-Bebauung ist anders als der Theodor-Stern-Kai.',
#   {'entities': [(4, 22, 'LOC'), (42, 59, 'LOC')]}),
#  ('1990 – Ein blutiger Generalstreik erschüttert Marokko.',
#   {'entities': [(7, 33, 'MISC'), (46, 53, 'LOC')]}),
#  ('Toro Rosso hat allerhand neue Teile an den STR10 geschraubt.',
#   {'entities': [(0, 10, 'PER'), (43, 48, 'ORG')]}),
#  ('Neu ist das Heartbeat User Rating System.',
#   {'entities': [(12, 40, 'MISC')]}),
#  ('Nach dem 2. Weltkrieg wurde die Ultrakurzwelle für den Hörfunk freigegeben.',
#   {'entities': [(9, 21, 'MISC')]}),
#  ('Auch dagegen will die BI gerichtlich vorgehen.',
#   {'entities': [(22, 24, 'ORG')]}),
#  ('Herr Babikian spielte eine Schlüsselrolle in Arevas Uranbergbauabteilung.',
#   {'entities': [(5, 13, 'PER'), (45, 51, 'LOC')]}),
#  ('Häufig veröffentlichten sie daher ihre Papers nur auf Konferenzen.',
#   {'entities': [(39, 45, 'MISC')]}),
#  ('Der wird seine geheime Mission heute in Obertilliach fortsetzen.',
#   {'entities': [(40, 52, 'LOC')]}),
#  ('«Flüchtlingskinder sollen sich in Deutschland wohl fühlen.»',
#   {'entities': [(34, 45, 'LOC')]}),
#  ('Dass dieser immer wieder mit scharfen Aussagen auffällt, ist nichts Neues.',
#   {'entities': [(68, 73, 'MISC')]}),
#  ('Gwens logische Reaktion: Sie trennte sich!', {'entities': [(0, 5, 'PER')]}),
#  ('In den Packstellen und Färbereien wird quasi Tag und Nacht gearbeitet.',
#   {'entities': [(45, 58, 'MISC')]}),
#  ('Die Rückkehr des lange verletzten Javi Martinez rückt näher.',
#   {'entities': [(34, 47, 'PER')]}),
#  ('Gerade hat ein Foto den World Press Photo Award bekommen.',
#   {'entities': [(24, 47, 'MISC')]}),
#  ('Wer nicht Nein sagen kann, sollte es schleunigst lernen.',
#   {'entities': [(37, 48, 'PER')]}),
#  ('Teheran empfing sie zwar mit offenen Armen und schickte humanitäre Hilfe.',
#   {'entities': [(0, 7, 'LOC')]}),
#  ('Zwölf Jahre lang sind Handball und die tägliche Arbeit Hand in Hand gegangen.',
#   {'entities': [(0, 16, 'MISC')]}),
#  ('Für seinen Cox ist jedenfalls heute "Weihnachten und Ostern gleichzeitig".',
#   {'entities': [(11, 14, 'PER'), (37, 48, 'MISC'), (53, 59, 'MISC')]}),
#  ('Zudem werden für die schwächeren Märkte sogenannte Feature-Phones produziert.',
#   {'entities': [(51, 65, 'ORG')]}),
#  ('Diese Frage richten Kritiker auch an Mazyeks Zentralrat;',
#   {'entities': [(37, 55, 'ORG')]}),
#  ('Die Migranten, die Nation und ich Deutschland, 25 Jahre nach dem Mauerfall.',
#   {'entities': [(34, 45, 'LOC'), (65, 74, 'MISC')]}),
#  ('Merkel kann ihm wenig raten, sie hat keine Lösung.',
#   {'entities': [(0, 6, 'PER')]}),
#  ('Am 2. September wird der Tag der russischen Garde begangen.',
#   {'entities': [(33, 43, 'MISC')]}),
#  ('Der Verdächtige aus Ungarn hat aus der Not heraus gehandelt. ',
#   {'entities': [(20, 26, 'LOC')]}),
#  ('Einen Online-Shop hat Ikea auch – der ist aber nicht so dominant. ',
#   {'entities': [(22, 26, 'ORG')]}),
#  ('Das zeigt sich am deutlichsten in Sachsen.',
#   {'entities': [(34, 41, 'LOC')]}),
#  ('Das HTC One (M8) bekommt aktuell ein Update auf Android 5.0 Lollipop.',
#   {'entities': [(4, 11, 'MISC'), (13, 15, 'MISC'), (48, 55, 'MISC')]}),
#  ('Am Genfer Autosalon waren sich die Branchenvertreter einig:',
#   {'entities': [(3, 19, 'MISC')]}),
#  ('Sorain betonte, bislang sei kein weiteres Wrackteil identifiziert worden.',
#   {'entities': [(0, 6, 'PER')]}),
#  ('Da bedarf es unter anderem natürlich weiterer Gespräche mit der Türkei."',
#   {'entities': [(64, 70, 'LOC')]}),
#  ("Im Anschluss lief's dann ganz nach Bayer-Plan.",
#   {'entities': [(35, 45, 'LOC')]}),
#  ('Der Marktanteil im Premium-Segment liege für die Münchner bei etwa 30 Prozent.',
#   {'entities': [(49, 57, 'MISC')]}),
#  ('Die Bilder von Surf-Profi Mick Fanning gingen um die Welt.',
#   {'entities': [(15, 38, 'PER')]}),
#  ('MOPO-Kommentar Nehmt die Kritik des Rechnungshofs bloß ernst!',
#   {'entities': [(0, 14, 'MISC')]}),
#  ('Wer hat bei den Power Units noch den Überblick?',
#   {'entities': [(16, 27, 'ORG')]}),
#  ('Der ATX stieg um 0,07 Prozent auf 2502,80 Punkte.',
#   {'entities': [(4, 7, 'MISC')]}),
#  ('Der deutsche Leitindex stand zuletzt ein knappes halbes Prozent im Minus.',
#   {'entities': [(4, 12, 'MISC')]}),
#  ('Für Star-Wars-Fans dürften rosige Zeiten anbrechen.',
#   {'entities': [(4, 18, 'MISC')]}),
#  ('Der renommierte Branchenpreis feiert in diesem Jahr sein zehntes Jubiläum.',
#   {'entities': [(40, 51, 'MISC')]}),
#  ('Steinmeier will Engagement in Mali weiterhin ausweiten',
#   {'entities': [(0, 10, 'PER'), (30, 34, 'LOC')]}),
#  ('So etwas sollte uns im Derby nicht passieren.',
#   {'entities': [(23, 28, 'MISC')]}),
#  ('Das Spiel zum Wochenende: Sir, You Are Being Hunted',
#   {'entities': [(31, 51, 'MISC')]}),
#  ('Mike Newton hat das 2013 angekündigte Projekt Tiga LM214 gestoppt.',
#   {'entities': [(0, 11, 'PER'), (46, 56, 'MISC')]}),
#  ('Der Spülknopf des WCs im Flugzeug ist sogar noch etwas dreckiger.',
#   {'entities': [(4, 13, 'LOC')]}),
#  ('Hat es denn Flecki überhaupt jemals gegeben?',
#   {'entities': [(12, 18, 'PER')]}),
#  ('Ich kann aber nicht sagen, dass uns das irgendwie beunruhigt Buuaah, echt?',
#   {'entities': [(61, 67, 'PER')]}),
#  (': So kann man Lenovos Ideapad Miix 300 wohl am besten zusammenfassen.',
#   {'entities': [(14, 38, 'MISC')]}),
#  ('Enttäuscht reagiert Israel auf die Entscheidung des Vatikans:',
#   {'entities': [(20, 26, 'LOC'), (52, 60, 'ORG')]}),
#  ('803446 Derzeit läuft dazu ein Verfahren am Bezirksgericht Klagenfurt. ',
#   {'entities': [(58, 68, 'LOC')]}),
#  ('Hauptsache man konnte die Linken diskreditieren.',
#   {'entities': [(26, 32, 'ORG')]}),
#  ('Rentner schnappt einem kleinen Fan den Puck weg',
#   {'entities': [(39, 43, 'MISC')]}),
#  ('Im März 2013 rückte dann Karl-Thoms Neumann an die Spitze.',
#   {'entities': [(25, 43, 'PER')]}),
#  ('Liebe entwickelt sich und ich werde versuchen das Beste daraus zu machen.',
#   {'entities': [(0, 5, 'MISC')]}),
#  ('Letztes aktuelles Video: LiveCast-Coverage',
#   {'entities': [(25, 42, 'MISC')]}),
#  ('Es gibt Grenzen, die nicht überschritten werden dürfen, findet die CSU.',
#   {'entities': [(67, 70, 'ORG')]}),
#  ('Sie fordern eine sofort spürbare Eindämmung des Flüchtlings\xadzuzugs.',
#   {'entities': [(48, 66, 'MISC')]}),
#  ('Nutzer der Xbox One können nun im Abo zunächst…',
#   {'entities': [(11, 19, 'MISC')]}),
#  ('Wood Treatment wurde im Sommer 2103 zum Verkauf ausgeschrieben;',
#   {'entities': [(0, 14, 'PER')]}),
#  ('Die Comic Con wird 2016 zum ersten Mal in Stuttgart stattfinden.',
#   {'entities': [(4, 13, 'MISC'), (42, 51, 'LOC')]}),
#  ('Nur Suzanne Mubarak konnte ich leider nicht treffen.',
#   {'entities': [(4, 19, 'PER')]}),
#  ('Girard war ein Sonderling im besten Sinne.', {'entities': [(0, 6, 'PER')]}),
#  ('Mit Okore und Vlaar sind zwei Innenverteidiger verletzt.',
#   {'entities': [(4, 9, 'LOC'), (14, 19, 'MISC')]}),
#  ('Viele Fragen zu TTIP müssen schnell geklärt werden – das ist ein Kraftakt.',
#   {'entities': [(16, 20, 'ORG')]}),
#  ('Komplettlösung: Über die iFruit-App kann Hund Chop verbessert werden.',
#   {'entities': [(41, 50, 'MISC')]}),
#  ('Das Abschaffen von Live TV ist nichts anderes als Zensur.',
#   {'entities': [(19, 26, 'MISC')]}),
#  ('Bombendrohung bei "Germany\'s Next Topmodel"',
#   {'entities': [(19, 42, 'MISC')]}),
#  ('Dies wurde von ägyptischen und russischen Offiziellen umgehend dementiert.',
#   {'entities': [(15, 26, 'MISC'), (31, 41, 'MISC')]}),
#  ('Timo Burger knüpft hier neue Kontakte oder frischt alte auf.',
#   {'entities': [(0, 11, 'PER')]}),
#  ('Heute verfinstert sich der Himmel über Deutschland.',
#   {'entities': [(39, 50, 'LOC')]}),
#  ('Begründet wurde dies mit Verstößen gegen Hygienebestimmungen.',
#   {'entities': [(41, 60, 'MISC')]}),
#  ('Denn wer in Peking mit dem Fahrrad fährt, atmet eine Menge Smog ein.',
#   {'entities': [(12, 18, 'LOC')]}),
#  ('Aufstieg und Fall von „DSK“ (1) Wegen Zuhälterei vor Gericht',
#   {'entities': [(23, 26, 'ORG')]}),
#  ('Das hat Bethesdas Pete Hines nun via Twitter mitgeteilt.',
#   {'entities': [(8, 17, 'PER'), (18, 28, 'PER'), (37, 44, 'MISC')]}),
#  ('Die Elise von Lotus wird 20 und das muss gefeiert werden.',
#   {'entities': [(4, 19, 'MISC')]}),
#  ('Themen: Musik, Film, Heiteres Aktuelle FM4-Schwerpunkte',
#   {'entities': [(39, 55, 'MISC')]}),
#  ('So schwächt das Virus nach und nach die Körperabwehr.',
#   {'entities': [(16, 21, 'MISC')]}),
#  ('Anschließend lädt Spitzbergen zum Abenteuer.',
#   {'entities': [(18, 29, 'LOC')]}),
#  ('Beißer, Oddjob und Co gibt es auch als Actionfiguren.',
#   {'entities': [(0, 6, 'LOC'), (8, 14, 'PER'), (19, 21, 'ORG')]}),
#  ('Wie heißt es so schön: "Wer im Glashaus sitzt..',
#   {'entities': [(31, 39, 'LOC')]}),
#  ('Harnik stand 2014/2015 nur zweimal nicht in der Startelf.',
#   {'entities': [(0, 6, 'PER')]}),
#  ('Griechenland bleibt weiter im Fokus der Anleger.',
#   {'entities': [(0, 12, 'LOC')]}),
#  ('Die letzten Ausrufezeichen setzt jedoch der Verbandsligist.',
#   {'entities': [(44, 58, 'ORG')]}),
#  ('Aber ich denke nicht, dass das einen Ausschlag gibt für die EM."',
#   {'entities': [(60, 62, 'MISC')]}),
#  ('Die Bundesnetzagentur erklärte den Block im Februar aber für systemrelevant:',
#   {'entities': [(4, 21, 'ORG')]}),
#  ('Wien braucht eine vernünftige Mülltrennung', {'entities': [(0, 4, 'LOC')]}),
#  ('In Syrien haben Jihadisten weitere antike Bauwerke gesprengt.',
#   {'entities': [(3, 9, 'LOC')]}),
#  ('Toni Kroos, Lukas Podolski und Miroslav Klose kennt jeder.',
#   {'entities': [(0, 10, 'PER'), (12, 26, 'PER'), (31, 45, 'PER')]}),
#  ('Mandelas Irrfahrt durch den europäischen Spitzenfußball ging weiter:',
#   {'entities': [(0, 8, 'PER'), (28, 40, 'MISC')]}),
#  ('Stillstand bei den Griechenland-Kontrollen bis Mitte April:',
#   {'entities': [(19, 42, 'LOC')]}),
#  ('Eine Burka ist das perfekte Bühnen-Outfit',
#   {'entities': [(28, 41, 'LOC')]}),
#  ('284612 Bayerns Trainerfrage: Ein Plädoyer pro Pep',
#   {'entities': [(7, 14, 'LOC')]}),
#  ('An der Matif war die Tonne Weizen nur noch 146,75 Euro je Tonne wert.',
#   {'entities': [(7, 12, 'MISC')]}),
#  ('Syrische Flüchtlinge kommen erst an neunter Stelle, nach den Russen.',
#   {'entities': [(0, 20, 'MISC'), (61, 67, 'MISC')]}),
#  ('Die TV-Rolle half auch, das Baryshnikov Arts Center zu finanzieren.',
#   {'entities': [(4, 12, 'ORG'), (28, 51, 'LOC')]}),
#  ('Der Palast will gegen ein brisantes Video aus den 30er-Jahren vorgehen.',
#   {'entities': [(4, 10, 'LOC')]}),
#  ('09:00 drucken mailen als pdf als Text AK-Kalliauer:',
#   {'entities': [(14, 20, 'ORG'), (38, 50, 'ORG')]}),
#  ('Verlag Hybrider Nachwuchs trifft rennerprobten Ahn auf dem Nürburgring.',
#   {'entities': [(0, 25, 'ORG'), (33, 50, 'PER'), (59, 70, 'LOC')]}),
#  ('Die Pläne werden zeitgleich mit dem Syrien-Gipfel in Wien bekannt.',
#   {'entities': [(36, 49, 'ORG'), (53, 57, 'LOC')]}),
#  ('PSK Vorstand aus dem Nahebereich ÖGB, schon wieder ein Zufall.',
#   {'entities': [(0, 12, 'ORG'), (21, 36, 'ORG')]}),
#  ('Sie ist Redakteurin im Ressort Gesundheit bei SPIEGEL',
#   {'entities': [(46, 53, 'ORG')]}),
#  ('Wie groß ist Kanada im Vergleich zu Deutschland?',
#   {'entities': [(13, 19, 'LOC'), (36, 47, 'LOC')]}),
#  ('Zu diesem Thema wurden noch keine Kommmentare geschrieben',
#   {'entities': [(34, 45, 'MISC')]}),
#  ('Die meisten Klubs in der Fußballbundesliga wünschen sich mehr Geld.',
#   {'entities': [(25, 42, 'ORG')]}),
#  ('Per Holmich in Kopenhagen zu unterziehen.',
#   {'entities': [(0, 11, 'PER'), (15, 25, 'LOC')]}),
#  ('Damit wird immer klarer, dass Piëch einen Alleingang hingelegt hat.',
#   {'entities': [(30, 35, 'PER')]}),
#  ('So hat auch Beate Tiranno-Rötzel davon erfahren.',
#   {'entities': [(12, 32, 'PER')]}),
#  ('Will startet am 17. Januar auf dem Sendeplatz am Sonntagabend.',
#   {'entities': [(0, 4, 'PER')]}),
#  ('Mit einem süßen Facebook-Post präsentiert sie ihr Mutter-Glück.',
#   {'entities': [(10, 29, 'MISC'), (50, 62, 'MISC')]}),
#  ('Über die Planungen des Attentats war die DDR-Staatssicherheit bestens im Bilde.',
#   {'entities': [(41, 61, 'MISC')]}),
#  ('Die SPD zerstörte mit der Agenda rüde einen Teil ihrer Kernidentität.',
#   {'entities': [(4, 7, 'ORG')]}),
#  ('Die Amerikaner lassen die Russen deshalb erst einmal machen. ',
#   {'entities': [(4, 14, 'LOC'), (26, 32, 'MISC')]}),
#  ('ZEIT: Wie kann man überhaupt Stürme vergleichen?',
#   {'entities': [(0, 4, 'MISC')]}),
#  ('Lazio im Pech - Juventus mischt wieder mit Juve',
#   {'entities': [(0, 5, 'ORG'), (16, 24, 'ORG'), (43, 47, 'ORG')]}),
#  ('Die EZB sei unberechenbar für den Markt geworden, sagen die einen.',
#   {'entities': [(4, 7, 'ORG')]}),
#  ('Patrick Beuth ist Redakteur im Ressort Digital bei',
#   {'entities': [(0, 13, 'PER')]}),
#  ('So erlitt Weidenfeller keinen Gesichtsverlust.',
#   {'entities': [(10, 22, 'PER')]}),
#  ('Bouygues aber schmetterte die Offerte erst einmal ab.',
#   {'entities': [(0, 8, 'PER')]}),
#  ('Dieses Video wird Ihnen vom Intel IT Center zur Verfügung gestellt. ',
#   {'entities': [(28, 43, 'ORG')]}),
#  ('Warten auf Brüssel, Warten auf Karlsruhe.',
#   {'entities': [(11, 18, 'LOC'), (31, 40, 'MISC')]}),
#  ('inklusive Betreibungskosten sofort zahlen wird, wenn er',
#   {'entities': [(10, 27, 'MISC')]}),
#  ('Politisch inkorrekt Bertolt Brecht war schlimmer als Thilo Sarrazin Kultur',
#   {'entities': [(20, 34, 'PER'), (53, 67, 'PER')]}),
#  ('Als Chef der Armee hat man auch eine Kommunikationsaufgabe.',
#   {'entities': [(13, 18, 'ORG')]}),
#  ('zumindest ist das in einem LG-Werbevideo zu sehen.',
#   {'entities': [(27, 40, 'ORG')]}),
#  ('Am Samstag findet zum siebten Mal der Berner Umwelttag statt.',
#   {'entities': [(38, 54, 'ORG')]}),
#  ('Die WebOS-Plattform soll außerdem für Geschäftskunden interessant werden.',
#   {'entities': [(4, 19, 'MISC')]}),
#  ('Die Zen-Prozessoren von AMD sind bereits jetzt in den Medien präsent.',
#   {'entities': [(24, 27, 'ORG')]}),
#  ('Die Vorbereitung aufs Spiel war laut Dardai wenig beeinträchtigt:',
#   {'entities': [(37, 43, 'PER')]}),
#  ('Der HSV hat die Richterskala des Dilettantismus gerade nach oben durchbrochen.',
#   {'entities': [(4, 7, 'ORG')]}),
#  ('1990 wurde sie von ihrer Partei zum Rücktritt gezwungen.',
#   {'entities': [(25, 31, 'ORG')]}),
#  ('Roberto Hilbert: Genau, das ist die Frage.',
#   {'entities': [(0, 15, 'PER')]}),
#  ('Die Stadt räumt und kontrolliert hinterher, obwohl sie nicht zuständig ist.',
#   {'entities': [(4, 9, 'LOC')]}),
#  ('Die IS-Miliz habe rund 40 Prozent der bewohnten Gebiete im Irak verloren.',
#   {'entities': [(4, 12, 'ORG'), (59, 63, 'LOC')]}),
#  ('Rachel Lambert zeigte sich am Mittwoch bestürzt über das Video.',
#   {'entities': [(0, 14, 'PER')]}),
#  ('Redakteur Peter Bathge beschreibt seine Empfindungen beim Spielen.',
#   {'entities': [(10, 22, 'PER')]}),
#  ('Toll, wie Nasr das Brasil-Duo gegen Massa mit einem souveränen Manöver gewann.',
#   {'entities': [(0, 4, 'PER'),
#     (10, 14, 'PER'),
#     (19, 29, 'LOC'),
#     (36, 41, 'PER')]}),
#  ('Er galt lange als Favorit für den SP-Präsidentschaftskandidaten.',
#   {'entities': [(34, 63, 'ORG')]}),
#  ('zwischendurch Giraffen zieren die Stadt Bern.',
#   {'entities': [(34, 39, 'LOC'), (40, 44, 'LOC')]}),
#  ('Das berichtet die amtliche iranische Nachrichtenagentur IRNA.',
#   {'entities': [(27, 36, 'MISC'), (56, 60, 'ORG')]}),
#  ('Dieser wird in die Arbeiten zur Unternehmenssteuerreform III einfliessen.',
#   {'entities': [(57, 60, 'MISC')]}),
#  ('Die Frau des getöteten Psychologen verfolgte das Verfahren als Nebenklägerin.',
#   {'entities': [(0, 34, 'MISC')]}),
#  ('Wachstumsmotor Mobile: Investitionen in Online-Werbung nehmen weiter zu',
#   {'entities': [(0, 21, 'MISC')]}),
#  ('Allerdings werde sich mittelfristig an der Ölschwemme nichts ändern.',
#   {'entities': [(43, 53, 'LOC')]}),
#  ('Iran ist verantwortlich für den Angriff aus dem Libanon.',
#   {'entities': [(0, 4, 'LOC'), (32, 55, 'MISC')]}),
#  ('Xavier Naidoo war es schon immer wichtig, sich mit anderen auszutauschen.',
#   {'entities': [(0, 13, 'PER')]}),
#  ('Es sollte verboten werden, also Scientology, USA und Russland Antwort schreiben',
#   {'entities': [(32, 43, 'ORG'), (45, 48, 'LOC'), (53, 61, 'LOC')]}),
#  ('Auch bei den Bildungsausgaben kann Deutschland punkten. ',
#   {'entities': [(35, 46, 'LOC')]}),
#  ('Sie haben sich fast acht Monate vorbereiten können, sagt Cañellas.',
#   {'entities': [(57, 65, 'PER')]}),
#  ('stabile Staaten können nur Zusammenwachsen.',
#   {'entities': [(8, 15, 'LOC')]}),
#  ('Hier helfe die Erfahrung der Vergangenheit, so Elsener.',
#   {'entities': [(47, 54, 'PER')]}),
#  ('Vorheriges Bild 59 freche Antworten von Cortana.',
#   {'entities': [(0, 35, 'MISC'), (40, 47, 'MISC')]}),
#  ('Die EVP wird ihr Mandat zweifellos verteidigen.',
#   {'entities': [(4, 7, 'ORG')]}),
#  ('Cheschirkow sagte: «Wir sind tief schockiert und bedauern den Vorfall.',
#   {'entities': [(0, 11, 'PER')]}),
#  ('Es heißt gegen Stellungen der Terrormiliz Islamischer Staat. ',
#   {'entities': [(30, 59, 'ORG')]}),
#  ('Zielsetzung für das Junioren-Turnier war das Erreichen des Viertelfinals.',
#   {'entities': [(20, 36, 'MISC')]}),
#  ('Schürrle ist weg – Ersatz ist schon gefunden!',
#   {'entities': [(0, 8, 'PER')]}),
#  ('Zudem muss ich Herrn Schmadtke etwas in Schutz nehmen.',
#   {'entities': [(15, 30, 'PER')]}),
#  ('Aus der Erde sind diese Viecher bei mir noch nicht gekommen.',
#   {'entities': [(8, 12, 'LOC')]}),
#  ('Seine Installation ist dank Online-Installer schnell erledigt.',
#   {'entities': [(28, 44, 'PER')]}),
#  ('Dennoch fallen laut Landkreis täglich 3.000 Euro an Kosten an.',
#   {'entities': [(20, 29, 'LOC')]}),
#  ('«Das ist erst der Anfang», sagt auch Smith.',
#   {'entities': [(37, 42, 'PER')]}),
#  ('Ermittlungen gegen Celler Staatsanwalt Lüttig eingestellt',
#   {'entities': [(19, 25, 'PER'), (39, 45, 'PER')]}),
#  ('Das Athener Finanzministerium bezeichnete den Bericht als "Provokation".',
#   {'entities': [(4, 11, 'LOC')]}),
#  ('Einer, der sagt, er trete zurück, bleibt nicht noch Monate im Amt.',
#   {'entities': [(62, 65, 'LOC')]}),
#  ('Der selbstbewusste Auftritt sorgt in der Rechtspartei für Stirnrunzeln.',
#   {'entities': [(41, 70, 'ORG')]}),
#  ('Heidelore Bieler hält es kaum in ihrem Ohrensessel.',
#   {'entities': [(0, 16, 'PER')]}),
#  ('Hagenbuch hat ein Budget aus dem Fotokopierer',
#   {'entities': [(0, 9, 'PER')]}),
#  ('Politische Scharmützel sind Hans Jörg Schellings Sache nicht.',
#   {'entities': [(0, 22, 'PER'), (28, 48, 'PER')]}),
#  ('Zwei Aubameyang-Tore reichten dem BVB nicht zum Sieg Dortmund (SID) -',
#   {'entities': [(34, 37, 'ORG'), (48, 61, 'MISC'), (63, 66, 'ORG')]}),
#  ('Alle Rechte vorbehalten Panorama Ralf Kabelka',
#   {'entities': [(24, 45, 'PER')]}),
#  ('Und was hat dieser Verein vor mit dem Schweizer Nati-Star?',
#   {'entities': [(38, 47, 'MISC')]}),
#  ('simonweber1, ja das hoffe ich allerdings auch.',
#   {'entities': [(0, 11, 'MISC')]}),
#  ('Der Hund der Zuhälter "Ich hatte eine Weile sogar Akademieverbot.',
#   {'entities': [(0, 21, 'MISC')]}),
#  ('In Istanbul sollen sie laut Cumhuriyet geschrien haben:',
#   {'entities': [(3, 11, 'LOC'), (28, 38, 'PER')]}),
#  ('Ein Ziel der Euratom-Gemeinschaft ist also nicht automatisch ein Ziel der EU.',
#   {'entities': [(13, 33, 'ORG'), (74, 76, 'ORG')]}),
#  ('Ich denke, das sollte man im Auge haben,wenn man mit Russland verhandelt.',
#   {'entities': [(53, 61, 'LOC')]}),
#  ('"Das Gehirn ist ein Organ, das auf Veränderungen reagiert.',
#   {'entities': [(1, 11, 'MISC')]}),
#  ('Die Winterpause war lang, wie groß ist jetzt die Vorfreude bei Dir?"',
#   {'entities': [(63, 66, 'MISC')]}),
#  ('Bemerkenswert waren die Veränderungen in der „Wiener Jause“.',
#   {'entities': [(46, 52, 'MISC')]}),
#  ('Im TecDax schnellten die Papiere von Evotec um mehr als 5 Prozent hoch.',
#   {'entities': [(3, 9, 'MISC'), (37, 43, 'ORG')]}),
#  ('Android Muffin oder Marshmallow als neues Google-Update?',
#   {'entities': [(0, 14, 'MISC')]}),
#  ('Das sei wichtig für die Entwicklung der Gemeinde.',
#   {'entities': [(40, 48, 'LOC')]}),
#  ('Die FSG war für einen A-Ligisten taktisch erste Sahne aufgestellt. ',
#   {'entities': [(4, 7, 'ORG')]}),
#  ('Baader-Helvea setzte in der Vorwoche das Kursziel sogar erneut auf 44 Euro.',
#   {'entities': [(0, 13, 'PER')]}),
#  ('Doch für einen Haftbefehl reichte es gegen „Mongols“-Boss Erkan U. nicht.',
#   {'entities': [(44, 66, 'MISC')]}),
#  ('› Athen lehnt Reformvorschläge seiner Geldgeber ab',
#   {'entities': [(2, 7, 'LOC')]}),
#  ('Auch Patrizia will nichts von Sebastian wissen.',
#   {'entities': [(5, 13, 'PER'), (30, 39, 'PER')]}),
#  ('Als ich den Vertrag für dieses Buch unterschrieben hatte dachte ich:',
#   {'entities': [(12, 35, 'MISC')]}),
#  ('Nun schreit Wehner regelrecht und fuchtelt mit einem Blumenstrauß herum:',
#   {'entities': [(12, 18, 'PER')]}),
#  ('Neulich schon dieser Kommentar in der Frankfurter Allgemeinen.',
#   {'entities': [(38, 61, 'ORG')]}),
#  ('Bilder aus der Serie «Endangered Species » im Andy Warhol Museum in Pittsburgh.',
#   {'entities': [(22, 40, 'MISC'), (46, 57, 'PER'), (68, 78, 'LOC')]}),
#  ('in einer Kapelle auf dem Campus wird eine Flagge der Konföderierten aufbewahrt.',
#   {'entities': [(53, 67, 'MISC')]}),
#  ('EU-Kommission begrüßte neue Reformvorschläge',
#   {'entities': [(0, 13, 'ORG')]}),
#  ('In den USA wird Vice vorgeworfen, liberal zu sein.',
#   {'entities': [(3, 10, 'LOC'), (16, 20, 'PER')]}),
#  ('Noch mysteriöser scheint laut ESO eine weitere Entdeckung:',
#   {'entities': [(30, 33, 'MISC')]}),
#  ('Außenseiter Schweden zog durch ein 4:1 gegen Rivale Dänemark ins Finale ein.',
#   {'entities': [(12, 20, 'LOC'), (52, 60, 'ORG')]}),
# ...
#   {'entities': [(6, 15, 'MISC'), (39, 51, 'LOC')]}),
#  ('Das ergab eine repräsentative GfK-Online-Umfrage im Auftrag von Greven Medien.',
#   {'entities': [(30, 48, 'MISC'), (52, 77, 'MISC')]}),
#  ('Den Lehrern und Schulleitern ist es allerdings sehr Ernst.',
#   {'entities': [(52, 57, 'PER')]}),
#  ('Und auch daran, dass wir die Rettung noch schaffen», erklärte Holtby.',
#   {'entities': [(62, 68, 'PER')]}),
#  ('Re: Mädchen wollen nicht programmieren plutoniumsulfat',
#   {'entities': [(0, 2, 'PER')]}),
#  ('Mit Ausnahme Indonesiens, dem Ursprungsland des Übels.',
#   {'entities': [(13, 24, 'LOC')]}),
#  ('Dies würde auf eine Schengen-Suspendierung des Landes hinauslaufen.',
#   {'entities': [(47, 53, 'LOC')]}),
#  ('neuer Vorsitzender der Mindestlohn-Kommission',
#   {'entities': [(23, 45, 'LOC')]}),
#  ('Tatenlosigkeit bei Edathy-Affäre und Mindestlohn vor Osnabrück.',
#   {'entities': [(19, 32, 'ORG'), (53, 62, 'LOC')]}),
#  ('Datensicherung auf USB-Stick oder externe Festplatte',
#   {'entities': [(19, 28, 'MISC')]}),
#  ('Der für Mittwoch geplante Start wurde nun verschoben auf..',
#   {'entities': [(8, 16, 'ORG')]}),
#  ('Vom Amtsitz des Premierministers, dem Megaron Maximou, gab es Rückendeckung.',
#   {'entities': [(38, 53, 'PER')]}),
#  ('Hicks ist wegen dreifachen Mordes angeklagt.',
#   {'entities': [(0, 5, 'PER')]}),
#  ('Nach endlosen 80 Minuten war dann auch Bieber dran.',
#   {'entities': [(39, 45, 'PER')]}),
#  ('Direkt zu den Torjäger-Wetten-Wette geht es unter folgendem Link:',
#   {'entities': [(14, 35, 'LOC')]}),
#  ('Kommissar Borowski (Axel Milberg,li.) und Leon (Amar Saaifan)',
#   {'entities': [(0, 18, 'PER'),
#     (20, 32, 'PER'),
#     (33, 36, 'PER'),
#     (42, 46, 'PER'),
#     (48, 60, 'PER')]}),
#  ('Erst im Juni vergangenen Jahres hatten die Libyer eine neue Regierung gewählt.',
#   {'entities': [(43, 49, 'LOC')]}),
#  ('Meinethalben kann man die Ehe auch für alle abschaffen.',
#   {'entities': [(0, 12, 'PER')]}),
#  ('Douglas Costa ließ noch eine Großchance fahrlässig liegen',
#   {'entities': [(0, 13, 'PER')]}),
#  ('Ihr Bruder Alexander Wussow war 2008 als Old Firehand inBad Segeberg dabei.',
#   {'entities': [(11, 27, 'PER'), (41, 68, 'MISC')]}),
#  ('Auf dem Parkplatz im Schatten der Grossen Mauer: Subways und McDonald’s.',
#   {'entities': [(34, 47, 'LOC'), (49, 56, 'LOC'), (61, 71, 'LOC')]}),
#  ('Robert Halver in Aktion an der Frankfurter Börse AP',
#   {'entities': [(0, 13, 'PER'), (31, 48, 'ORG'), (49, 51, 'ORG')]}),
#  ('Schließlich wurde er aber an die Athener Uni als Professor berufen.',
#   {'entities': [(33, 40, 'LOC')]}),
#  ('Passwort vergessen Schneespaß rund um Karlsruhe:',
#   {'entities': [(38, 47, 'MISC')]}),
#  ('Spark bietet für Einsteiger eine Arduino-ähnliche IDE sowie eine Web-IDE an.',
#   {'entities': [(0, 5, 'MISC'), (33, 49, 'MISC')]}),
#  ('Heißer Kuranyi lässt Millionen sausen Fiese Gabelstapler-Konstruktion:',
#   {'entities': [(0, 14, 'PER')]}),
#  ('Diese Unwissenheit hat wesentlich zum Verschwinden des Bartgeiers geführt.',
#   {'entities': [(55, 65, 'LOC')]}),
#  ('Wechsel im Vorstand weitere Nachrichten zu NORDWEST HANDEL AG',
#   {'entities': [(43, 51, 'ORG')]}),
#  ('Zum Thema Impfpflicht kommentiert unser Nutzer Ralf Schrader:',
#   {'entities': [(47, 60, 'PER')]}),
#  ('Nummer vier in der Partie war ein Eigentor von Sidnei (83.).',
#   {'entities': [(47, 53, 'PER')]}),
#  ('Leserempfehlungen Reaktionen auf diesen Kommentar anzeigen ich zwiegespalten.',
#   {'entities': [(0, 17, 'PER')]}),
#  ('Mindestens 150 russische Soldaten in Ukraine getötet',
#   {'entities': [(15, 24, 'MISC'), (37, 44, 'LOC')]}),
#  ('Die Folge war, dass die Aufenthaltsgestattung des Afghanen ablief.',
#   {'entities': [(50, 58, 'LOC')]}),
#  ('Mit diesem hat die aktuelle Ausgabe des Stadtclubs aber kaum noch etwas gemein.',
#   {'entities': [(40, 50, 'MISC')]}),
#  ('Siganidou ist tatsächlich beides – Nachrichtensprecherin und Piratin.',
#   {'entities': [(0, 9, 'PER')]}),
#  ('Mehr als 6000 Nutzer haben sie unterschrieben und fordern rothaarige Emoji.',
#   {'entities': [(69, 74, 'MISC')]}),
#  ('Zeig uns deine Fußball-Szene der Hinrunde!',
#   {'entities': [(0, 28, 'MISC')]}),
#  ('Das aber sei „nicht sehr konkret“ gewesen, gibt Weiser zu.',
#   {'entities': [(48, 54, 'PER')]}),
#  ('SPD und Grüne schon - doch sie haben Zweifel.',
#   {'entities': [(0, 3, 'ORG'), (8, 13, 'ORG')]}),
#  ('803462 Derzeit läuft die Expo in Mailand vom 1. Mai bis 31. Oktober. ',
#   {'entities': [(25, 29, 'MISC'), (33, 40, 'LOC')]}),
#  ('Bundesweit gelingt dies ohne Förderung durchschnittlich nur 60 Prozent.',
#   {'entities': [(0, 10, 'LOC')]}),
#  ('Fivers bauen Vorsprung an der HLA-Spitze aus',
#   {'entities': [(0, 6, 'ORG'), (30, 40, 'ORG')]}),
#  ('Inzwischen haben sich die Sportkommissare der Sache angenommen.',
#   {'entities': [(26, 41, 'MISC')]}),
#  ('In den USA spielt zu den Weihnachtsfeiertagen das Wetter verrückt.',
#   {'entities': [(3, 10, 'LOC')]}),
#  ('Die große ImPulsTanz Party im Kasino am Schwarzenbergplatz.',
#   {'entities': [(10, 26, 'ORG'), (40, 58, 'LOC')]}),
#  ('Als der, der die Methoden in Englands Fußball veränderte.',
#   {'entities': [(29, 37, 'LOC')]}),
#  ('Kuwait bestellt 28 Eurofighter weitere Nachrichten zu BOEING',
#   {'entities': [(0, 6, 'ORG'), (19, 30, 'MISC'), (54, 60, 'ORG')]}),
#  ('Du musst Dein Baby stillen, dann fällt das Gewicht von allein.',
#   {'entities': [(0, 18, 'MISC')]}),
#  ('Alt ist für Jung da und später umgekehrt.',
#   {'entities': [(0, 3, 'LOC'), (12, 16, 'PER')]}),
#  ('Mit seiner Kritik steht Niki Lauda nicht allein da. ',
#   {'entities': [(24, 34, 'PER')]}),
#  ('Anders sieht es beim sächsischen Landesamt für Verfassungsschutz aus.',
#   {'entities': [(21, 64, 'ORG')]}),
#  ('Der Audioprozessor muss auch nach vielen Stunden noch bequem am Kopf sitzen."',
#   {'entities': [(4, 18, 'LOC')]}),
#  ('Nach nur einem Jahr verliert Bern die Miss-Schweiz-Wahl bereits wieder.',
#   {'entities': [(29, 33, 'LOC'), (38, 55, 'MISC')]}),
#  ('Paukenschlag nach Wiederanpfiff - Sukalo macht alles klar',
#   {'entities': [(18, 31, 'LOC'), (34, 40, 'LOC')]}),
#  ("Christa Dygatz zeigt in ihrem Merler Haus Glaskunst wie das Werk '",
#   {'entities': [(0, 14, 'PER')]}),
#  ('BorgWarner underperform Robert W. Baird & Co. Incorporated',
#   {'entities': [(0, 10, 'ORG'), (24, 39, 'PER')]}),
#  ('Franz Lederer war wieder als Journalist tätig.',
#   {'entities': [(0, 13, 'PER')]}),
#  ('Kelly und Raimond sind seit 2005 verheiratet.',
#   {'entities': [(0, 5, 'PER'), (10, 17, 'PER')]}),
#  ('Das Mobilfunk-Angebot ist bereits im Dezember 2014 gestartet.',
#   {'entities': [(4, 21, 'LOC')]}),
#  ('ManUnited gegen Chelsea torlos - Van Gaal bleibt',
#   {'entities': [(0, 9, 'ORG'), (16, 23, 'ORG'), (33, 41, 'PER')]}),
#  ('Aus der globalen Verflechtung kann und will die Schweiz nicht ausscheren.',
#   {'entities': [(48, 55, 'LOC')]}),
#  ('In Europa läuft nur noch London der deutschen Hauptstadt den Rang ab.',
#   {'entities': [(3, 9, 'LOC'), (25, 31, 'LOC'), (36, 45, 'MISC')]}),
#  ('Hierfür warte die Stadt noch auf die Einschätzung der Polizeiakademie.',
#   {'entities': [(18, 23, 'LOC')]}),
#  ('Italiens skandalumwitterter früherer Freimaurerchef Licio Gelli ist gestorben.',
#   {'entities': [(0, 8, 'LOC'), (37, 63, 'PER')]}),
#  ('Gegen die Fehlerkanzlerin Merkel wird er keine Chance haben.',
#   {'entities': [(26, 32, 'PER')]}),
#  ('Das entscheidende Manöver setzt Rossi eingangs der vorletzten Runde. ',
#   {'entities': [(32, 37, 'PER')]}),
#  ('Schiedsrichter Sippel leistet sich heute Patzer.',
#   {'entities': [(15, 21, 'PER')]}),
#  ('dpa, msc Hausding und Klein haben eine schwierige Vorbereitung hinter sich.',
#   {'entities': [(0, 3, 'ORG'), (5, 17, 'ORG'), (22, 27, 'ORG')]}),
#  ('«Hey Eintracht Frankfurt» schallt durch die Arena.',
#   {'entities': [(1, 24, 'ORG')]}),
#  ('Besser schneiden einzig Kleingemeinden wie Rebévelier ab.',
#   {'entities': [(43, 53, 'LOC')]}),
#  ('Harte Sportler-Worte für Blatter«Diebe müssen ins Gefängnis!»',
#   {'entities': [(0, 20, 'PER')]}),
#  ('Das antikommunistische Bündnis wurde in der Schweiz geschmiedet."',
#   {'entities': [(44, 51, 'LOC')]}),
#  ('Die Standard-Uhr in 42 mm beginnt 50 Dollar teurer.',
#   {'entities': [(4, 16, 'ORG')]}),
#  ('Aus dem Spiel heraus gelang Bayer jedoch kein Tor.',
#   {'entities': [(28, 33, 'PER')]}),
#  ('Der breiter gefasste S&P-500 sank fast 0,9 Prozent auf 2095 Zähler.',
#   {'entities': [(21, 28, 'LOC')]}),
#  ('Bundestrainer Frank Ullrich ist derzeit kein Thema", so Orgeldinger.',
#   {'entities': [(14, 27, 'PER'), (56, 67, 'PER')]}),
#  ('Der mutmaßliche Haupttäter, ein Brite, sitzt in Untersuchungshaft.',
#   {'entities': [(32, 37, 'LOC')]}),
#  ('Keystone Sven Andrighetto (22) hat den Sprung ins NHL-Kader nicht geschafft.',
#   {'entities': [(0, 25, 'PER'), (50, 59, 'ORG')]}),
#  ('Weidmann: Geldpolitik verhindert Zahlungsausfall',
#   {'entities': [(0, 8, 'PER')]}),
#  ('Wer diesen urbayerischen Charakterkopf live sehen will, kann das im Zoom tun.',
#   {'entities': [(68, 72, 'LOC')]}),
#  ('Die Polizei sicherte DNA-Spuren des Angeklagten am Opfer',
#   {'entities': [(36, 47, 'PER')]}),
#  ('Alle in der Regierung seien einer Meinung, dass man Griechenland helfen müsse.',
#   {'entities': [(52, 64, 'LOC')]}),
#  ('Der EuroSTOXX 50 als Leitindex der Eurozone büßte fast 1 Prozent ein.',
#   {'entities': [(4, 16, 'MISC'), (35, 43, 'LOC')]}),
#  ('Der Teufel und die heile westliche Welt na hat Russland dabei nicht recht?',
#   {'entities': [(47, 55, 'LOC')]}),
#  ('Das Entscheidende ist, dass wir die Punkte in der EM-Qualifikation holen. ',
#   {'entities': [(50, 66, 'ORG')]}),
#  ('Die Höhe des Verwalterhonorars richtet sich nach der jeweiligen Vereinbarung.',
#   {'entities': [(13, 30, 'LOC')]}),
#  ("DIENSTAG UBS hebt Daimler auf 'Buy' und Ziel auf 105 Euro",
#   {'entities': [(0, 12, 'ORG'), (18, 25, 'ORG')]}),
#  ('Zwei Elfmetertore durch Ja-Cheol Koo (78./90.',
#   {'entities': [(5, 17, 'ORG'), (24, 36, 'PER')]}),
#  ('Das findet doch statt - nur nicht im Discounter, sondern eher in Kleinläden.',
#   {'entities': [(65, 75, 'LOC')]}),
#  ('Prinz heiratet seine Sofia und küsst sie gleich nach der Trauung.',
#   {'entities': [(0, 5, 'PER'), (21, 26, 'LOC')]}),
#  ('Trotzdem müssen seine Schanzer nun im Erzgebirge liefern.',
#   {'entities': [(38, 48, 'LOC')]}),
#  ('Herr Brand, herrscht in der Schweiz ein Asylchaos?',
#   {'entities': [(5, 10, 'PER'), (28, 35, 'LOC')]}),
#  ('Aber es geht einher mit der veränderten Wahrnehmung des gesamten Vereins.',
#   {'entities': [(65, 72, 'ORG')]}),
#  ('BVB plagt sich vor Pokalspiel mit Offensivsorgen',
#   {'entities': [(0, 3, 'ORG')]}),
#  ('Er scheiterte dort in drei Sätzen an Rafael Nadal.',
#   {'entities': [(37, 49, 'PER')]}),
#  ('Dazu lernten wir noch andere Hunde kennen, die auch im Haus wohnten.',
#   {'entities': [(55, 59, 'LOC')]}),
#  ('Die politischen Gespräche hatten im Januar in Genf begonnen.',
#   {'entities': [(46, 50, 'LOC')]}),
#  ('1946978 Mit seiner Kritik erreichte Nemzow vor allem Intellektuelle in Moskau. ',
#   {'entities': [(36, 42, 'PER'), (71, 77, 'LOC')]}),
#  ('Die Notbremse wurde bei den Rheinhessen nach dem 21. Spieltag gezogen.',
#   {'entities': [(28, 39, 'LOC')]}),
#  ("Hyrule Warriors - Majora's Mask DLC Trailer (jap.)",
#   {'entities': [(0, 15, 'ORG'), (18, 43, 'MISC')]}),
#  ('Die Polizei in Bremen gibt vorerst Entwarnung.',
#   {'entities': [(15, 21, 'LOC')]}),
#  ('Und wird plötzlich der Rücktritt Blatters begrüßt?',
#   {'entities': [(33, 41, 'PER')]}),
#  ('Dominique Aegerter wird nach Valencia reisen.',
#   {'entities': [(0, 18, 'PER'), (29, 37, 'LOC')]}),
#  ('Hanlin sprach von einem "schrecklichen Tag."',
#   {'entities': [(0, 6, 'PER')]}),
#  ('Beim Unglück in Beaune vor 33 Jahren kamen 53 Menschen ums Leben.',
#   {'entities': [(16, 22, 'LOC')]}),
#  ('IN die EU die Grenzwerte für radioaktive Isotope die Japaner(!',
#   {'entities': [(7, 9, 'ORG'), (53, 60, 'LOC')]}),
#  ('o2 weitet das Rabatt-Programm auf einige Kunden im E-Plus-Netz aus.',
#   {'entities': [(0, 2, 'ORG'), (14, 29, 'ORG'), (51, 62, 'LOC')]}),
#  ('Alle Rechte vorbehalten Artikelfunktionen Kommentare (1)',
#   {'entities': [(24, 41, 'PER')]}),
#  ('Gegen Herthas Salomon Kalou wurde Anzeige erstattet.',
#   {'entities': [(6, 27, 'PER')]}),
#  ("„Dann brauch ich extra wieder 'ne Bio-Tonne.“",
#   {'entities': [(30, 43, 'ORG')]}),
#  ('Das letzte Wort in Sachen Armeereform ist damit noch nicht gesprochen.',
#   {'entities': [(26, 37, 'PER')]}),
#  ('Alle Rezepte finden Sie auch in der aktuellen Ausgabe der ORF Nachlese.',
#   {'entities': [(58, 61, 'ORG')]}),
#  ('Unklar ist, ob Falciani tatsächlich vor Gericht auftaucht.',
#   {'entities': [(15, 23, 'PER')]}),
#  ('Hier erklärt er, was ihn bewegt - von neuem Job bis Hypo.',
#   {'entities': [(52, 56, 'ORG')]}),
#  ('DGAP-DD: Gerry Weber International AG deutsch',
#   {'entities': [(0, 7, 'PER'), (9, 37, 'ORG')]}),
#  ('Der Iran und die UN fordern ein Ende der Kämpfe.',
#   {'entities': [(4, 8, 'LOC'), (17, 19, 'ORG')]}),
#  ('Die nächste Unternehmung der Landfrauen ist am 13. Mai.',
#   {'entities': [(29, 39, 'ORG')]}),
#  ('AK: Passagiere verzichten oft auf Entschädigung',
#   {'entities': [(0, 2, 'ORG')]}),
#  ('ROUNDUP: AstraZeneca muss höhere Kosten und starken Dollar verdauen',
#   {'entities': [(0, 7, 'ORG'), (9, 20, 'ORG')]}),
#  ('Jetzt ist Microsoft unter den Google-Kritikern in dem EU-Verfahren.',
#   {'entities': [(10, 19, 'ORG'), (30, 46, 'MISC'), (54, 66, 'ORG')]}),
#  ('Der „Magdeburger Volksstimme“ sagte Kultusminister Stephan Dorgerloh (SPD):',
#   {'entities': [(5, 28, 'ORG'), (51, 68, 'PER'), (70, 73, 'ORG')]}),
#  ('Zalando hatte die Messe im Herbst übernommen.',
#   {'entities': [(0, 7, 'ORG')]}),
#  ('Antworten: Bundesministerium der Finanzen',
#   {'entities': [(11, 41, 'ORG')]}),
#  ('Petr Cech wird wie 2012 zu Bayerns Nemesis."',
#   {'entities': [(0, 9, 'PER'), (27, 42, 'ORG')]}),
#  ('Auf 130 Jahre blickt die Firmengeschichte von Deiss-Schuhe zurück.',
#   {'entities': [(46, 58, 'ORG')]}),
#  ('ONLINE: Haben Sie momentan eigentlich Lagerraum gemietet?',
#   {'entities': [(0, 6, 'ORG')]}),
#  ('US-Skistar Julia Mancuso ist ja für ihre lustigen Videos bekannt.',
#   {'entities': [(0, 10, 'ORG'), (11, 24, 'PER')]}),
#  ('Die Papiere der Ölriesen ExxonMobil und Chevron Corp.',
#   {'entities': [(16, 35, 'ORG'), (40, 52, 'ORG')]}),
#  ('TBF ist auf das quantitative Fondsmanagement spezialisiert.',
#   {'entities': [(0, 3, 'ORG')]}),
#  ('High-Tech Gründerfonds Management GmbH zum newsroom',
#   {'entities': [(0, 38, 'ORG')]}),
#  ('AG: Vollständige Übernahme der LSE Leading Security Experts GmbH abgeschlossen',
#   {'entities': [(0, 2, 'ORG'), (31, 64, 'ORG')]}),
#  ('Mein ganz herzlicher Glückwunsch an die beiden Laureates!',
#   {'entities': [(47, 56, 'ORG')]}),
#  ('Die einfache Lösung hat die SPÖ den Wählern verkündet.',
#   {'entities': [(28, 31, 'ORG')]}),
#  ('Landrat Andreas Müller (SPD) hält er für das Amt nicht.',
#   {'entities': [(8, 22, 'PER'), (24, 27, 'ORG')]}),
#  ('Bei der SG Kaarst kassierte sein Team eine 0:4-Niederlage.',
#   {'entities': [(8, 17, 'ORG')]}),
#  ('Der Stabilitas Pacific Gold+Metals Fonds (A0ML6U) verliert 4,7% auf 53,10 Euro.',
#   {'entities': [(4, 40, 'ORG'), (42, 48, 'ORG')]}),
#  ('Wer beim THW unterschreibt, will Titel gewinnen"',
#   {'entities': [(9, 12, 'ORG')]}),
#  ('Die Amerikaner können ja mit den dicken EU Krediten bezahlt werden. ',
#   {'entities': [(4, 14, 'LOC'), (40, 42, 'ORG')]}),
#  ('Auch die herkömmlichen Cloud-Funktionen werden unterstützt.',
#   {'entities': [(23, 39, 'ORG')]}),
#  ('Bei Maccabi Tel Aviv brachen nach dem Ausgleich in der 96. Minute alle Dämme.',
#   {'entities': [(4, 20, 'ORG')]}),
#  ('US-Notenbankchefin will Zinswende bald einleiten',
#   {'entities': [(0, 18, 'ORG')]}),
#  ('Das berichtet die "Frankfurter Allgemeine Sonntagszeitung" (F.',
#   {'entities': [(19, 57, 'ORG')]}),
#  ('Maximale Verweildauer der Politiker im Parlament: Zwei Legislaturperioden.',
#   {'entities': [(39, 48, 'ORG')]}),
#  ('«Die Migros Bank hat total versagt, ihr Geschäftsmodell war himmeltraurig.',
#   {'entities': [(5, 16, 'ORG'), (60, 73, 'PER')]}),
#  ('Was ist mit der arbeitslosen Jugend im Süden der EU?',
#   {'entities': [(49, 51, 'ORG')]}),
#  ('VIDEO: Das sind die teuersten Bauflops aller Zeiten Huffington Post/Wochit',
#   {'entities': [(0, 5, 'MISC'), (52, 67, 'ORG')]})]

# %%
random.shuffle(out_sentences)
TRAIN_STAT_DATA=out_sentences[:len(out_sentences)//2]
TEST_STAT_DATA=out_sentences[len(out_sentences)//2:]

# %%
print(len(out_sentences))
print(len(TRAIN_STAT_DATA))
print(len(TEST_STAT_DATA))
print("REVISION", len(TRAIN_REVISION_DATA))
TRAIN_DATA = TRAIN_REVISION_DATA + TRAIN_STAT_DATA
print("COMBINED", len(TRAIN_DATA))
# Out:
# 510
# 255
# 255
# REVISION 606
# COMBINED 861

# %% [raw]
# #translated to spacy3.0 and not working - do not run
#
# # add NER to the pipeline and the new label
# import de_core_news_lg
# nlp = spacy.load('de_core_news_lg')
# ner = nlp.get_pipe("ner")
# ner.add_label("LOCALITY")
# from spacy.training import Example
# from spacy.tokens import Doc
#
#
# # get the names of the components we want to disable during training
# pipe_exceptions = ["ner", "trf_wordpiecer", "trf_tok2vec"]
# other_pipes = [pipe for pipe in nlp.pipe_names if pipe not in pipe_exceptions]
#
# # start the training loop, only training NER
# epochs = 30
# optimizer = nlp.resume_training()
# #optimizer = nlp.initialize()
# with nlp.disable_pipes(*other_pipes), warnings.catch_warnings():
#     warnings.filterwarnings("once", category=UserWarning, module='spacy')
#     sizes = compounding(1.0, 4.0, 1.001)
#
#     # batch up the examples using spaCy's minibatc
#     for epoch in range(epochs):
#         #examples = TRAIN_DATA
#         random.shuffle(TRAIN_DATA)
#         text = []
#         annots=[]
#         #examples=[]
#         #text, annots = TRAIN_DATA
#
#         #for text,annots in TRAIN_DATA:
#             #text.append(t)
#             #annots.append(a)
#         #    doc = nlp(text)
#         #    example = Example.from_dict(doc, annots)
#         #    examples.append(example)
#         #nlp.initialize(lambda: examples)
#
#         #example = Example.from_dict(dictionary)
#         #example = Example(doc, annotations)
#         losses = {}
#
#         #for batch in minibatch(TRAIN_DATA, size=5000):
#         #    text, annotations = batch
#         #        doc = nlp(text)
#         #        example = Example.from_dict(doc, annotations)
#         #        print(text)
#         #nlp.update([example])#, drop=0.35, sgd=optimizer, losses=losses)
#         print(len(examples))
#         nlp.update(examples, sgd=optimizer, drop=0.35, losses=losses)
#
#         print("Losses ({}/{})".format(epoch + 1, epochs), losses)

# %%
#original Spacy 2 element
#add NER to the pipeline and the new label
ner = nlp.get_pipe("ner")
ner.add_label("GRAN")

# get the names of the components we want to disable during training
pipe_exceptions = ["ner", "trf_wordpiecer", "trf_tok2vec"]
other_pipes = [pipe for pipe in nlp.pipe_names if pipe not in pipe_exceptions]

# start the training loop, only training NER
epochs = 30
optimizer = nlp.resume_training()
with nlp.disable_pipes(*other_pipes), warnings.catch_warnings():
    warnings.filterwarnings("once", category=UserWarning, module='spacy')
    sizes = compounding(1.0, 4.0, 1.001)
    
    # batch up the examples using spaCy's minibatc
    for epoch in range(epochs):
        examples = TRAIN_DATA
        random.shuffle(examples)
        batches = minibatch(examples, size=sizes)
        losses = {}
        
        for batch in batches:
            texts, annotations = zip(*batch)
            nlp.update(texts, annotations, sgd=optimizer, drop=0.35, losses=losses)

        print("Losses ({}/{})".format(epoch + 1, epochs), losses)
# Out:
# Losses (1/30) {'ner': 5626.127417761176}
# Losses (2/30) {'ner': 5026.556430973746}
# Losses (3/30) {'ner': 4979.874209005386}
# Losses (4/30) {'ner': 4820.882608399828}
# Losses (5/30) {'ner': 4807.665453582536}
# Losses (6/30) {'ner': 4629.65185273331}
# Losses (7/30) {'ner': 4704.627862648107}
# Losses (8/30) {'ner': 4778.3485091365}
# Losses (9/30) {'ner': 4566.294394211989}
# Losses (10/30) {'ner': 4700.082158950856}
# Losses (11/30) {'ner': 4542.75442699375}
# Losses (12/30) {'ner': 4594.969098531728}
# Losses (13/30) {'ner': 4696.371374459821}
# Losses (14/30) {'ner': 4579.45151969837}
# Losses (15/30) {'ner': 4591.810923534154}
# Losses (16/30) {'ner': 4555.210315534263}
# Losses (17/30) {'ner': 4556.156783767536}
# Losses (18/30) {'ner': 4527.469745555471}
# Losses (19/30) {'ner': 4543.978831553803}
# Losses (20/30) {'ner': 4479.127136367417}
# Losses (21/30) {'ner': 4586.63888386651}
# Losses (22/30) {'ner': 4622.996985101374}
# Losses (23/30) {'ner': 4454.581270019365}
# Losses (24/30) {'ner': 4498.5575423604805}
# Losses (25/30) {'ner': 4469.689368417195}
# Losses (26/30) {'ner': 4544.763849870658}
# Losses (27/30) {'ner': 4546.940153823554}
# Losses (28/30) {'ner': 4472.592059623157}
# Losses (29/30) {'ner': 4473.9725143615215}
# Losses (30/30) {'ner': 4434.903326787211}

# %%
spacy.displacy.render(nlp("Ich heisse Christian und war heute in Zürich bei IBM."), style="ent")
spacy.displacy.render(nlp("Wie viele Kühe hat die Gemeinde Bülach?"), style="ent")
spacy.displacy.render(nlp("Wie hoch ist Eigenkapital auf Bezirksebene?"), style="ent")
spacy.displacy.render(nlp("Ich brauche die Daten pro Bezirk"), style="ent")
spacy.displacy.render(nlp("Ich brauche die Daten für den gesamten Kanton."), style="ent")
spacy.displacy.render(nlp("Wie viel Bauinv. EFH 5 Jahre  hat  in Regensdorf  ?"), style="ent")
spacy.displacy.render(nlp("Was ist der Anteil an MIV-Anteil (Modal Split)   auf Bezirksebene ?"), style="ent")
spacy.displacy.render(nlp("Was ist der Anteil an Geb.Vol. Dienstleistungen: Zunahme   in Flaach ?"), style="ent")
spacy.displacy.render(nlp("Welches ist das Schül. Sekundarstufe II   für den gesamten Kanton ?"), style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Ich heisse
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Christian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  und war heute in
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Zürich
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  bei
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     IBM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Wie viele Kühe hat die
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gemeinde Bülach
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SGRAN</span>
# </mark>
# ?</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Wie hoch ist Eigenkapital auf
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bezirksebene
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ?</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Ich brauche die Daten pro Bezirk</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Ich brauche die Daten für den gesamten Kanton.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Wie viel Bauinv. EFH 5 Jahre  hat
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     in Regensdorf
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SGRAN</span>
# </mark>
#   ?</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Was ist der Anteil an MIV-Anteil (Modal Split)
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     auf Bezirksebene
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SGRAN</span>
# </mark>
#  ?</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Was ist der Anteil an Geb.Vol. Dienstleistungen: Zunahme
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     in Flaach
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SGRAN</span>
# </mark>
#  ?</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Welches ist das Schül. Sekundarstufe II
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     für den gesamten Kanton
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SGRAN</span>
# </mark>
#  ?</div></span>

# %%
# dictionary to hold our evaluation data
stat_evaluation = {
    "locality": {
        "correct": 0,
        "total": 0,
    }
}

word_evaluation = {
    "locality": {
        "correct": 0,
        "total": 0
    }

}

for stat in TEST_STAT_DATA:
    # extract the sentence and correct stat entities according to our test data
    sentence = stat[0]
    entities = stat[1]["entities"]

    # for each entity, use our updated model to make a prediction on the sentence
    for entity in entities:
        doc = nlp(sentence)
        correct_text = sentence[entity[0]:entity[1]]
        n_worded_stat =  len(correct_text.split())

        # if we find that there's a match for predicted entity and predicted text, increment correct counters
        for ent in doc.ents:
            if ent.label_ == entity[2] and ent.text == correct_text:
                stat_evaluation["locality"]["correct"] += 1
                if n_worded_stat > 0:
                    word_evaluation["locality"]["correct"] += 1

                # this break is important, ensures that we're not double counting on a correct match
                break

        #  increment total counters after each entity loop
        stat_evaluation["locality"]["total"] += 1
        if n_worded_stat > 0:
            word_evaluation["locality"]["total"] += 1

# %%
for key in word_evaluation:
    correct = word_evaluation[key]["correct"]
    total = word_evaluation[key]["total"]

    print(f"{key}: {correct / total * 100:.2f}%")

stat_total_sum = 0
stat_correct_sum = 0

print("---")
for key in stat_evaluation:
    correct = stat_evaluation[key]["correct"]
    total = stat_evaluation[key]["total"]
    
    stat_total_sum += total
    stat_correct_sum += correct

    print(f"{key}: {correct / total * 100:.2f}%")

print(f"\nTotal: {stat_correct_sum/stat_total_sum * 100:.2f}%")
# Out:
# locality: 93.39%
# ---
# locality: 93.39%
#
# Total: 93.39%

# %%
# dictionary which will be populated with the entities and result information
entity_evaluation = {}

# helper function to udpate the entity_evaluation dictionary
def update_results(entity, metric):
    if entity not in entity_evaluation:
        entity_evaluation[entity] = {"correct": 0, "total": 0}
    
    entity_evaluation[entity][metric] += 1

# same as before, see if entities from test set match what spaCy currently predicts
for data in TEST_REVISION_DATA:
    sentence = data[0]
    entities = data[1]["entities"]

    for entity in entities:
        doc = nlp(sentence)
        correct_text = sentence[entity[0]:entity[1]]

        for ent in doc.ents:
            if ent.label_ == entity[2] and ent.text == correct_text:
                update_results(ent.label_, "correct")
                break

        update_results(entity[2], "total")

# %%
sum_total = 0
sum_correct = 0

for entity in entity_evaluation:
    total = entity_evaluation[entity]["total"]
    correct = entity_evaluation[entity]["correct"]

    sum_total += total
    sum_correct += correct
    
    print("{} | {:.2f}%".format(entity, correct / total * 100))

print()
print("Overall accuracy: {:.2f}%".format(sum_correct / sum_total * 100))
# Out:
# MISC | 50.22%
# LOC | 70.51%
# PER | 83.39%
# ORG | 74.25%
#
# Overall accuracy: 68.37%

# %%
nlp.meta["name"] = "stat_entity_extractor_v1"
nlp.to_disk("./models/v1")

# %%
TRAIN_STAT_DATA[5]
# Out:
# ('Welches ist das Schül. Sekundarstufe II   für den gesamten Kanton ?',
#  {'entities': [(42, 65, 'SGRAN')]})
