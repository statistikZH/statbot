# %%
from __future__ import print_function, unicode_literals
import spacy
import warnings
from spacy.util import minibatch, compounding
import de_core_news_lg
import pandas as pd
import numpy as np
from random import sample
import io, csv
import re
import random
import de_core_news_lg
import json
nlp = spacy.load('de_core_news_lg')

# %%
#out_sentences=open("input/tagged_sentences.csv", "r").readlines()
with open('input/tagged_sentences.json') as json_file:
    out_sentences = json.load(json_file)
out_sentences[:5]
# Out:
# [['Wie viel Eigenkapital  hat  in Bauma  ?', {'entities': []}],
#  ['Welches ist das Eigenkapital   in Marthalen ?', {'entities': []}],
#  ['Was ist der Anteil an Bruttoverschuldungsanteil   in Kleinandelfingen ?',
#   {'entities': []}],
#  ['Wie viel Steuerbares Vermögen natürliche Pers.  hat  Birmensdorf  ?',
#   {'entities': []}],
#  ['Welches ist das Steuerbares Vermögen natürliche Pers.   in Rorbas ?',
#   {'entities': []}]]

# %%
npr_df = pd.read_csv("external/deu_news_2015_3M-sentences.txt", delimiter = "\t")
npr_df=npr_df.sample(frac=1)
npr_df.head()
# Out:
#                1                                                  ­
# 1753803  1851654  Letztes aktuelles Video: Die Jordas-Regel Quel...
# 1188595  1250516  ElektromobilitätDie Stromverschenker Aldi Süd ...
# 757695    792404  Der vermutliche Pilot des Phantom wurde damals...
# 24426      25059             Ab Berlin gelangt man mit United (www.
# 2559025  2700206  Wirtschafts- & Finanzinfo Banking & Trading » ...

# %%
# create an nlp object as we'll use this to seperate the sentences and identify existing entities
#loaded already above
#nlp = spacy.load('de_core_news_lg')

# %%
revision_texts = []

# convert the articles to spacy objects to better identify the sentences. Disabled unneeded components. # takes ~ 4 minutes
for doc in nlp.pipe(npr_df.iloc[:10000,1], batch_size=30, disable=["tagger", "ner"]):
    for sentence in doc.sents:
        if  40 < len(sentence.text) < 80:
            # some of the sentences had excessive whitespace in between words, so we're trimming that
            revision_texts.append(" ".join(re.split("\s+", sentence.text, flags=re.UNICODE)))

# %%
revisions = []

# Use the existing spaCy model to predict the entities, then append them to revision
for doc in nlp.pipe(revision_texts, batch_size=50, disable=["tagger", "parser"]):
    
    # don't append sentences that have no entities
    if len(doc.ents) > 0:
        revisions.append((doc.text, {"entities": [(e.start_char, e.end_char, e.label_) for e in doc.ents]}))

# %%
# print an example of the revision sentence
print(revisions[0][0])

# print an example of the revision data
print(revisions[0][1])
# Out:
# ElektromobilitätDie Stromverschenker Aldi
# {'entities': [(0, 36, 'ORG'), (37, 41, 'ORG')]}

# %%
# create arrays to store the revision data
TRAIN_REVISION_DATA = []
TEST_REVISION_DATA = []

# create dictionaries to keep count of the different entities
TRAIN_ENTITY_COUNTER = {}
TEST_ENTITY_COUNTER = {}

# This will help distribute the entities (i.e. we don't want 1000 PERSON entities, but only 80 ORG entities)
REVISION_SENTENCE_SOFT_LIMIT = 200

# helper function for incrementing the revision counters
def increment_revision_counters(entity_counter, entities):
    for entity in entities:
        label = entity[2]
        if label in entity_counter:
            entity_counter[label] += 1
        else:
            entity_counter[label] = 1

random.shuffle(revisions)
for revision in revisions:
    # get the entities from the revision sentence
    entities = revision[1]["entities"]

    # simple hack to make sure spaCy entities don't get too one-sided
    should_append_to_train_counter = 0
    for _, _, label in entities:
        if label in TRAIN_ENTITY_COUNTER and TRAIN_ENTITY_COUNTER[label] > REVISION_SENTENCE_SOFT_LIMIT:
            should_append_to_train_counter -= 1
        else:
            should_append_to_train_counter += 1

    # simple switch for deciding whether to append to train data or test data
    if should_append_to_train_counter >= 0:
        TRAIN_REVISION_DATA.append(revision)
        increment_revision_counters(TRAIN_ENTITY_COUNTER, entities)
    else:
        TEST_REVISION_DATA.append(revision)
        increment_revision_counters(TEST_ENTITY_COUNTER, entities)

# %%
TRAIN_ENTITY_COUNTER
# Out:
# {'MISC': 202, 'LOC': 206, 'ORG': 202, 'PER': 211}

# %%
TEST_ENTITY_COUNTER
# Out:
# {'PER': 553, 'LOC': 581, 'ORG': 393, 'MISC': 545}

# %%
TRAIN_REVISION_DATA
# Out:
# [('Das hast Du jetzt auch wieder Recht, stimmt.',
#   {'entities': [(9, 17, 'MISC')]}),
#  ('Gewürdigt wurde auch das Aktienresearch der Bank.',
#   {'entities': [(25, 39, 'MISC')]}),
#  ('Die Kluft zwischen Arm und Reich darf nicht weiter auseinandergehen.',
#   {'entities': [(27, 32, 'LOC')]}),
#  ('"Behörden wie die EPA sind inzwischen bis aufs Blut gereizt.',
#   {'entities': [(18, 21, 'ORG')]}),
#  ('Hier gibt es aktuelle TV-News im Überblick.',
#   {'entities': [(22, 29, 'MISC')]}),
#  ('Seine Lieder handeln von Schönheit, von der Schönheit Rio de Janeiros.',
#   {'entities': [(54, 69, 'LOC')]}),
#  ('Gewerkschaft der Polizei findet das bedenklich.',
#   {'entities': [(0, 24, 'ORG')]}),
#  ('ORF.at / Meldung: "Musik trennt und verbindet"',
#   {'entities': [(0, 6, 'MISC')]}),
#  ('Guardiola: "Das interessiert mich überhaupt nicht"',
#   {'entities': [(0, 9, 'PER')]}),
#  ('Er plant offensichtlich lieber mit Leipzig.',
#   {'entities': [(35, 42, 'LOC')]}),
#  ('Das Windows-Geschäft schrumpfte dagegen im weiterhin schwachen PC-Markt.',
#   {'entities': [(4, 20, 'MISC'), (63, 71, 'ORG')]}),
#  ('Die Bilder zum Federer-Sieg über Gasquet Saisonstart misslungen',
#   {'entities': [(15, 27, 'MISC'), (33, 40, 'PER')]}),
#  ('Wenn die EZB die Geldschleusen öffnet, schwächt das den Kurs des Euro weiter.',
#   {'entities': [(9, 12, 'ORG'), (17, 30, 'LOC'), (65, 69, 'MISC')]}),
#  ('Viele Legenden ranken sich um den jung verstorbenen Pharao Tutanchamun.',
#   {'entities': [(59, 70, 'PER')]}),
#  ('Berner Science-Fiction-Kino Kulturell interessiert?',
#   {'entities': [(0, 37, 'LOC')]}),
#  ('Wikileaks und das Internet: Warum wir eine *fünfte Gewalt* brauchen..',
#   {'entities': [(0, 9, 'MISC'), (18, 26, 'MISC')]}),
#  ('Darf man folglich mit der "Hannover-Clique" auch in der Gründerszene rechnen?',
#   {'entities': [(27, 42, 'LOC')]}),
#  ('Für Facebook spielt das allerdings keine Rolle.',
#   {'entities': [(4, 12, 'MISC')]}),
#  ('Der frühere GC-Keeper erhält einen Vierjahres-Vertrag.',
#   {'entities': [(12, 21, 'ORG')]}),
#  ('Das wäre das falsche Signal, so Oettinger.',
#   {'entities': [(32, 41, 'PER')]}),
#  ('Inzwischen befinde sich der General zur Behandlung in Teheran.',
#   {'entities': [(54, 61, 'LOC')]}),
#  ('Overwatch hat in der Betaversion drei Neuzugänge erhalten.',
#   {'entities': [(0, 9, 'ORG')]}),
#  ('Ich wüsste auch nicht, das VW jemals das Gegenteil behauptet hätte.',
#   {'entities': [(27, 29, 'ORG')]}),
#  ('68 36 Sophie Hunger findets «widerlich» U2, die Anti-Terror-Band',
#   {'entities': [(6, 19, 'PER'), (40, 42, 'ORG')]}),
#  ('Zudem generierten die Walldorfer kräftig Cash.',
#   {'entities': [(22, 32, 'MISC'), (41, 45, 'ORG')]}),
#  ('Olexander Scherba ist seit November 2014 Botschafter der Ukraine in Wien.',
#   {'entities': [(0, 17, 'PER'), (57, 64, 'LOC'), (68, 72, 'LOC')]}),
#  ('Im zweien Lauf verdoppelt Schneider ihren Vorsprung.',
#   {'entities': [(26, 35, 'PER')]}),
#  ('Fragen und Antworten zu Android Wear auf iOS 29.09.2015',
#   {'entities': [(24, 36, 'MISC'), (41, 44, 'MISC')]}),
#  ('Die aktuellen Formel-1-Motoren wissen nicht mit lautem Sound zu überzeugen',
#   {'entities': [(14, 30, 'MISC')]}),
#  ('Ein Marktliberaler im Auftrag der linken Regierung von Alexis Tsipras?',
#   {'entities': [(55, 69, 'PER')]}),
#  ('Wie wichtig war Ihnen, dass möglichst viele Fans den EL-Auftakt erleben?',
#   {'entities': [(53, 63, 'ORG')]}),
#  ('Tschechien, der zu Hause gegen Lettland spielt.',
#   {'entities': [(0, 10, 'LOC'), (19, 24, 'LOC'), (31, 39, 'ORG')]}),
#  ('Thomy Graber (42) wehrt sich gegen Roaming-Irrsinn bei Salt.',
#   {'entities': [(0, 12, 'PER'), (35, 50, 'ORG'), (55, 59, 'ORG')]}),
#  ('Der FC Schalke 04 startet zwar vom Ergebnis gegen Hannover 96 her..',
#   {'entities': [(4, 17, 'ORG'), (50, 61, 'ORG')]}),
#  ('Die PKK will mit blutigen Anschlägen offen Landraub begehen.',
#   {'entities': [(4, 7, 'ORG'), (26, 51, 'MISC')]}),
#  ('Hier sind Oskar (8) und Luis (17) beim Spiel „Spinderella“ zu sehen.',
#   {'entities': [(10, 15, 'PER'), (17, 28, 'MISC'), (46, 57, 'MISC')]}),
#  ('Die Kulisse der Thunerseespiele ist heuer eine Halfpipe.',
#   {'entities': [(16, 31, 'MISC')]}),
#  ('Immerhin ist Hermann einer, der den Schneid hat, dieses Dilemma zuzugeben.',
#   {'entities': [(13, 20, 'PER')]}),
#  ('Anzeige Medici - das klingt nach mediterraner Entspannung und Sonnenschein.',
#   {'entities': [(0, 14, 'PER')]}),
#  ('Das ändert sich, so Verkehrsstadtrat Zöttl.',
#   {'entities': [(20, 42, 'PER')]}),
#  ('Die Veranstaltung wird von Apple im Livestream online übertragen.',
#   {'entities': [(27, 32, 'ORG')]}),
#  ('Am Samstag soll er sein Comeback im Stadtderby gegen Quilmes AC geben.',
#   {'entities': [(53, 63, 'ORG')]}),
#  ('Freihandel ist richtig und gut, aber kein Wert an sich.',
#   {'entities': [(0, 10, 'PER')]}),
#  (' 2297239 Sony sollte also dringend den Preis nach unten korrigieren.',
#   {'entities': [(9, 13, 'ORG')]}),
#  ('Nur elf Tracks, und die grässliche 15-Minuten-Improvisation Going Home fehlt.',
#   {'entities': [(35, 59, 'MISC')]}),
#  ('Räikönnen hat es somit selber in der Hand.',
#   {'entities': [(0, 9, 'MISC')]}),
#  ('Zu Hause müssen wir die Big Points holen."',
#   {'entities': [(24, 34, 'LOC')]}),
#  ('Das Warten auf Salatic Flugzeug mit Brille warten?',
#   {'entities': [(15, 22, 'MISC')]}),
#  ('Das Video hat bei YouTube 1,5 Millionen Abrufe.',
#   {'entities': [(18, 25, 'MISC')]}),
#  ('Blog MagGlauben Sie wirklich, Kamele tragen Wasser in ihren Höckern?',
#   {'entities': [(0, 15, 'PER')]}),
#  ('Die südkoreanische Armee erwiderte das Feuer.',
#   {'entities': [(4, 24, 'ORG')]}),
#  ('Flüchtlingskrise: Angela Merkel ist nicht mehr unantastbar Flüchtlingskrise:',
#   {'entities': [(0, 16, 'ORG'), (18, 31, 'PER')]}),
#  ('250 haben Stadtwerke und MVG in den vergangenen zehn Jahren schon ersetzt.',
#   {'entities': [(25, 28, 'ORG')]}),
#  ('Der vermutliche Pilot des Phantom wurde damals festgenommen.',
#   {'entities': [(26, 33, 'MISC')]}),
#  ('Im Zeitraum von 2007-2013 bekam Serbien rund 1,2 Milliarden Euro Hilfe.',
#   {'entities': [(32, 39, 'LOC')]}),
#  ('Foto: Hauke-Christian Dittrich Martin Gerten, Bild 1 von 2',
#   {'entities': [(6, 44, 'PER')]}),
#  ('Der Sturz ist Vergangenheit, ich packe für die WM!',
#   {'entities': [(47, 50, 'ORG')]}),
#  ('Grund dafür seien die kleinen Bildschirme des 3DS.',
#   {'entities': [(46, 49, 'MISC')]}),
#  ('Seit heute können Kunden die Computer\xadhilfe auch per Prepaid-Guthaben nutzen.',
#   {'entities': [(29, 43, 'ORG')]}),
#  ('Russland bietet jetzt einen Welpen als "Diesel-Ersatz" an.',
#   {'entities': [(0, 8, 'LOC'), (40, 53, 'LOC')]}),
#  ('Die Hotelbranche fürchtet um ihre deutschen Gäste.',
#   {'entities': [(34, 43, 'MISC')]}),
#  ('Autoraser leben dennoch oft nicht länger.', {'entities': [(0, 9, 'LOC')]}),
#  ('Die Olympischen Sommerspiele in München und die Winterspiele in Innsbruck.',
#   {'entities': [(4, 28, 'MISC'),
#     (32, 39, 'LOC'),
#     (48, 60, 'MISC'),
#     (64, 73, 'LOC')]}),
#  ('Tylinski hat seit dem Sommer an den beiden gebaggert.',
#   {'entities': [(0, 8, 'PER')]}),
#  ('Zuletzt in Topform, aktuell angeschlagen: Gladbachs "Sechser" Granit Xhaka.',
#   {'entities': [(11, 18, 'LOC'), (42, 51, 'PER'), (69, 74, 'LOC')]}),
#  ('Aalen verließ sich zusehends auf Standards und Konterchancen.',
#   {'entities': [(0, 5, 'LOC')]}),
#  ('Auch ein Sender wie das ZDF wird in der Zukunft über das Internet übertragen.“',
#   {'entities': [(24, 27, 'ORG'), (57, 65, 'MISC')]}),
#  ('indem Sie für die Flüchtlingshilfe spenden.',
#   {'entities': [(18, 34, 'ORG')]}),
#  ('Selbstverständlich soll er aber nicht auf die USA überspringen.',
#   {'entities': [(46, 49, 'LOC')]}),
#  ('Gegen Apples iPhone 6 hat das Unternehmen an allen Fronten verloren.',
#   {'entities': [(6, 21, 'MISC')]}),
#  ('Der Skandal Putenfleisch in Deutschland bleibt also bestehen.',
#   {'entities': [(28, 39, 'LOC')]}),
#  ('Nach den heftigen Kämpfen bei Mariupol hatte die EU weitere Sanktionen erwogen.',
#   {'entities': [(30, 38, 'LOC'), (49, 51, 'ORG')]}),
#  ('Re: Alice Madness Returns Doomchild 30. Mär 2015',
#   {'entities': [(0, 2, 'PER'), (4, 35, 'MISC')]}),
#  ('Aber als ich in Rom landete, standen hunderte Menschen am Flughafen.',
#   {'entities': [(16, 19, 'LOC'), (58, 67, 'LOC')]}),
#  ('Gute Kontakte zu Ducati pflegte Redding schon vor seiner MotoGP-Rookie.',
#   {'entities': [(17, 23, 'ORG'), (32, 39, 'PER'), (57, 70, 'LOC')]}),
#  ('Brent erreichte in der Spitze 59,5 USD je Barrel, WTI 53 USD je Barrel.',
#   {'entities': [(0, 5, 'PER'), (50, 53, 'ORG')]}),
#  ('EL-GAWHARY: Ich finde eines sehr interessant:',
#   {'entities': [(0, 10, 'MISC')]}),
#  ('Ideen gibt es wie Sand am Meer, es kommt darauf an, wie man sie umsetzt.“',
#   {'entities': [(18, 30, 'LOC')]}),
#  ('Voting: Blau gegen Pink Welchen Haartrend finden Sie schöner?',
#   {'entities': [(0, 6, 'PER'), (8, 12, 'PER'), (19, 41, 'ORG')]}),
#  ('Alle Tore des SCB fielen nach ähnlichem Muster:',
#   {'entities': [(14, 17, 'ORG')]}),
#  ('sie dient Firmen dazu, ihre Markenrechte im Internet wahrzunehmen.',
#   {'entities': [(44, 52, 'MISC')]}),
#  ('Birgit Schrowange moderiert sei 20 Jahren das Magazin „Extra“ bei RTL.',
#   {'entities': [(0, 17, 'PER'), (66, 69, 'ORG')]}),
#  ('Eine Kröte schlucken muss die UBS im Libor-Fall – nachträglich.',
#   {'entities': [(30, 33, 'ORG'), (37, 47, 'LOC')]}),
#  ('So muss ein Cockpit eines britischen Luxus-Herstellers aussehen.',
#   {'entities': [(26, 36, 'MISC')]}),
#  ('Er wollte eine Briefbombe an die Redaktion der Zeitung schicken.',
#   {'entities': [(15, 25, 'PER')]}),
#  ('Der DAX verliert 0,1 Prozent auf 11.314 Punkte.',
#   {'entities': [(4, 7, 'MISC')]}),
#  ('Die dritte Saison von Diablo 3 endet am 23. August 2015 um 17:00 Uhr.',
#   {'entities': [(22, 30, 'MISC')]}),
#  ('3 von 6 Vorheriges Bild Nächstes Bild Apachenhäupling, hoch zu Ross:',
#   {'entities': [(8, 18, 'MISC'), (38, 53, 'PER')]}),
#  ('Die Befragten in Deutschlands Nachbarländern sehen das anders.',
#   {'entities': [(17, 29, 'LOC')]}),
#  ('Die neue Gear VR kann mit dem Galaxy S6, S6 edge und S6 edge+ genutzt werden.',
#   {'entities': [(9, 16, 'MISC'),
#     (30, 39, 'MISC'),
#     (41, 43, 'LOC'),
#     (53, 55, 'LOC'),
#     (56, 61, 'LOC')]}),
#  ('Toller Kampf, mangelnde Chancenverwertung - mal wieder.',
#   {'entities': [(0, 6, 'PER')]}),
#  ('Stevens änderte nach dem 3:3 gegen Gladbach nichts an seiner Startformation.',
#   {'entities': [(0, 7, 'PER'), (35, 43, 'ORG')]}),
#  ('Stabsgefreite Schneckerl • vor 11 Stunden', {'entities': [(0, 24, 'PER')]}),
#  ('Das wird sicher ein Stadionverbot nach sich ziehen", sagte Watzke.',
#   {'entities': [(59, 65, 'PER')]}),
#  ('Das Geheimnis der Runenschrift ist entschlüsselt.',
#   {'entities': [(0, 30, 'MISC')]}),
#  ('Philipp, Lavita wird der Mund enger genäht',
#   {'entities': [(0, 7, 'PER'), (9, 15, 'PER')]}),
#  ('Volkswagen will sich laut einem Bericht bis zu 20 Milliarden Euro leihen.',
#   {'entities': [(0, 10, 'ORG')]}),
#  ('Doch die AKP arbeitet mit der Angst der Türken vor den Feinden.',
#   {'entities': [(9, 12, 'ORG'), (40, 46, 'LOC')]}),
#  ('Deutschland darf bei der Aufnahme von Flüchtlingen nicht überfordert werden!',
#   {'entities': [(0, 11, 'LOC')]}),
#  ('Wüsste er, Ceslanski, wo der zweite Rimon ist, "wäre dieser längst in Amerika".',
#   {'entities': [(11, 20, 'PER'), (36, 41, 'PER'), (70, 77, 'LOC')]}),
#  ('Russland fliegt unabhängig von einer US-geführten Koalition',
#   {'entities': [(0, 8, 'LOC')]}),
#  ('Und auch Kapitän Benedikt Höwedes sparte nicht mit Lob für den Matchwinner.',
#   {'entities': [(17, 33, 'PER')]}),
#  ('Für Interims-Captain Sneijder war es im 118. Länderspiel das 29. Tor.',
#   {'entities': [(4, 29, 'PER')]}),
#  ('Timea Bacsinszky scheitert im Wimbledon-Viertelfinal an der Spanierin',
#   {'entities': [(0, 16, 'PER'), (30, 52, 'LOC'), (60, 69, 'LOC')]}),
#  ('Doch die VW-Verantwortlichen dürften schon viel früher Bescheid gewusst haben.',
#   {'entities': [(9, 28, 'ORG')]}),
#  ('Gianis Varoufakis war gestern bei Günther Jauch in der ARD zu sehen.',
#   {'entities': [(0, 17, 'PER'), (34, 47, 'PER'), (55, 58, 'ORG')]}),
#  ('Auch Seat bestätigte den Einsatz der manipulierten Technologie.',
#   {'entities': [(5, 9, 'ORG')]}),
#  ('Höhe Bocklemünd ein Fahrzeug mit gestohlenem Kennzeichen aufgefallen.',
#   {'entities': [(5, 15, 'LOC')]}),
#  ('Putin und Berlusconi - ziemlich beste Freunde dpa, mau',
#   {'entities': [(0, 5, 'PER'), (10, 20, 'PER')]}),
#  ('Wir \xadhören dann auf, wenn wir wollen, nicht, wenn wir müssen», so Rhyn.',
#   {'entities': [(66, 70, 'LOC')]}),
#  ('Auch die bekannten Comedians von Y-Titty haben sich Mediakraft angeschlossen.',
#   {'entities': [(33, 40, 'PER')]}),
#  ('Gouverneur Suhaib al-Rawi forderte die Behörden auf zu helfen.',
#   {'entities': [(11, 25, 'PER')]}),
#  ('Die Landesregierungen halten das für nicht bezahlbar.',
#   {'entities': [(4, 21, 'ORG')]}),
#  ('Eine alte, indische Witwe namens Lakshmi erzählte mir von ihrem schweren Leben.',
#   {'entities': [(11, 19, 'MISC'), (33, 40, 'PER')]}),
#  ('Die SPÖ wiederum sah die gemeinsame Ganztagsschule als bestes Zukunftsmodell.',
#   {'entities': [(4, 7, 'ORG')]}),
#  ('Das gab US-Präsident Barack Obama heute in Washington bekannt.',
#   {'entities': [(8, 20, 'LOC'), (21, 33, 'PER'), (43, 53, 'LOC')]}),
#  ('PS: Ich fahre keinen VW, bin also kein Fanboy',
#   {'entities': [(0, 2, 'ORG'), (21, 23, 'ORG')]}),
#  ('Moskaus Wirtschaftskraft dominiert die der Partner',
#   {'entities': [(0, 7, 'LOC')]}),
#  ('Das Open-Source-Programm MediathekView sorgt für kompakten Überblick.',
#   {'entities': [(4, 38, 'MISC')]}),
#  ('Mit 45 musste ich einsehen, dass es nicht mehr für die Europatour reicht.',
#   {'entities': [(55, 65, 'ORG')]}),
#  ('Dennoch schaffte es Cuche bis nach Hause.',
#   {'entities': [(20, 25, 'PER'), (35, 40, 'LOC')]}),
#  ('GT3 soll sogar mehr als 500.000 Euro kosten.',
#   {'entities': [(0, 3, 'MISC')]}),
#  ('Sie reden, lachen und gehen an der Themse spazieren.',
#   {'entities': [(35, 41, 'LOC')]}),
#  ('Notfalls muss der Arbeitgeber Urlaub genehmigen.',
#   {'entities': [(30, 36, 'LOC')]}),
#  ('Auch in Sachen Staatsanleihekäufe ergreift Schmieding Partei für die EZB.',
#   {'entities': [(43, 60, 'ORG'), (69, 72, 'ORG')]}),
#  ('Ebenfalls eine dauerhafte Institution sollen die KA300-Volunteers werden.',
#   {'entities': [(49, 65, 'LOC')]}),
#  (' 2297224 Sonys gerade erst vorgestellte Edel-Smartphone',
#   {'entities': [(9, 14, 'ORG'), (40, 55, 'ORG')]}),
#  ('Ob Marco Reus das besser hinbekommen hätte?',
#   {'entities': [(3, 13, 'PER')]}),
#  ('Außerdem zahlt Karstadt 2,5 Millionen Euro in einen Fonds für die Betroffenen.',
#   {'entities': [(15, 23, 'ORG')]}),
#  ('Sie überbrachten unter anderem Geldspenden von Bad Honnefer Bürgern.',
#   {'entities': [(47, 59, 'LOC')]}),
#  ('Jetzt kehrt sie den Grünen entnervt den Rücken.',
#   {'entities': [(20, 26, 'ORG')]}),
#  ('Es wird Zanders letztes Derby als OB sein.',
#   {'entities': [(8, 15, 'PER')]}),
#  ('Auch Trainer Alois Schwartz will das nicht abstreiten:',
#   {'entities': [(13, 27, 'PER')]}),
#  ('Private Equity ist inzwischen wieder draußen.',
#   {'entities': [(0, 14, 'ORG')]}),
#  ('PolitblogEinst war die Volksschule die Klammer unserer Gesellschaft.',
#   {'entities': [(0, 14, 'ORG')]}),
#  ('Der nicaraguanische Staat soll mit 51 Prozent Mehrheitseigentümer werden.',
#   {'entities': [(4, 25, 'LOC')]}),
#  ('Entwickler Cloud Imperium Games wurde erst später gegründet.',
#   {'entities': [(17, 31, 'MISC')]}),
#  ('Schweinevogel feiert mit Dir 10 Jahre Kiwara-Savanne',
#   {'entities': [(0, 13, 'PER'), (25, 52, 'MISC')]}),
#  ('Mein Motorsport-Magazin.com Login merken?',
#   {'entities': [(28, 41, 'MISC')]}),
#  ('Wie hat denn Ihre Tanzpartnerin Isabel Edvardsson auf den Tanz reagiert?',
#   {'entities': [(32, 49, 'PER')]}),
#  ('Das Werbegeld ist hier also an den Staat zurückgeflossen.',
#   {'entities': [(4, 13, 'LOC')]}),
#  ('Vor 14 Stunden Toriyamafans Worte stimmen mich noch optimistischer.',
#   {'entities': [(15, 27, 'LOC')]}),
#  ('Tatort Erfurt: Es kann nur einen Maulwurf geben',
#   {'entities': [(0, 13, 'MISC')]}),
#  ('TV-Sender "Sky" meldete den Deal am Sonntag bereits als fix.',
#   {'entities': [(11, 14, 'ORG')]}),
#  ('Die Staatsanwaltschaft Erfurt ermittelt gegen Mike Mohring.',
#   {'entities': [(23, 29, 'LOC'), (46, 58, 'PER')]}),
#  ('Allana besitzt rund 325,2 Millionen ausstehende Stammaktien.',
#   {'entities': [(0, 6, 'LOC')]}),
#  ('Welch ein großes Zeichen für eine Nationen übergreifende Solidarität!',
#   {'entities': [(0, 5, 'PER')]}),
#  ('In Singapur sind zwei Deutsche wegen Graffiti-Sprühens verurteilt worden.',
#   {'entities': [(3, 11, 'LOC'), (22, 30, 'MISC')]}),
#  ('Mehr, versichert Pascal Morenos, ginge einfach nicht.',
#   {'entities': [(17, 31, 'PER')]}),
#  ('Imdahl: Der Widerstand entsteht unbewusst - egal ob Frau oder Mann.',
#   {'entities': [(0, 6, 'PER')]}),
#  ('Tom Walek hat bei Hans Knauss nachgefragt.',
#   {'entities': [(0, 9, 'PER'), (18, 29, 'PER')]}),
#  ('Die Sonde hatte Cape Canaveral in Florida damals am 19. Januar verlassen.',
#   {'entities': [(16, 30, 'LOC'), (34, 41, 'LOC')]}),
#  ('Der 6. Januar ist in Sachsen-Anhalt traditionell Feiertag.',
#   {'entities': [(21, 35, 'LOC')]}),
#  ('Gesucht wird nach weiteren 15 Crew-Mitgliedern.',
#   {'entities': [(0, 7, 'LOC')]}),
#  ('Bei der IV reicht eine qualitative Reform deshalb nicht.',
#   {'entities': [(8, 10, 'MISC')]}),
#  ('Facelift für den kleinen Löwen – der neue Peugeot 208 ÖSTERREICH.',
#   {'entities': [(42, 64, 'MISC')]}),
#  ('Carlos baut mit Ann Millers Hilfe den Mährhof für die Pferdezucht um.',
#   {'entities': [(0, 6, 'PER'), (16, 27, 'PER')]}),
#  ('Die Geberkantone verlangen ultimativ Reformen.',
#   {'entities': [(4, 16, 'LOC')]}),
#  ('Das Problem von der US Armee ist es, keine Bodentruppen dort zu haben.',
#   {'entities': [(20, 28, 'ORG')]}),
#  ('Teilen auf Facebook: 3Teilen auf Twitter:',
#   {'entities': [(11, 19, 'MISC'), (21, 28, 'LOC'), (33, 40, 'MISC')]}),
#  ('Ergebnis: Im Kanzleramt war nur mit Mühe ein Kompromiss zu finden.',
#   {'entities': [(13, 23, 'LOC')]}),
#  ('Zweimal out in Runde eins Saisonstart für Bencic komplett in die Hose!',
#   {'entities': [(42, 48, 'ORG')]}),
#  ('Unterstützung bekommt sie von Großbritannien und Frankreich.',
#   {'entities': [(30, 44, 'LOC'), (49, 59, 'LOC')]}),
#  ('Irgendwo scheint was in Österreich grundsätzlich schief zu laufen.',
#   {'entities': [(24, 34, 'LOC')]}),
#  ('Moto2 - Zarco kommt in Motegi kampflos zum WM-Titel',
#   {'entities': [(0, 5, 'MISC'),
#     (8, 13, 'PER'),
#     (23, 29, 'LOC'),
#     (43, 51, 'MISC')]}),
#  ('Die griechische Regierung will Steuerhinterziehern eine Amnestie anbieten.',
#   {'entities': [(4, 15, 'MISC'), (31, 50, 'ORG')]}),
#  ('«Wir sind die zweitstärkste Partei in Renzis Heimat Toskana.',
#   {'entities': [(38, 44, 'LOC'), (52, 59, 'LOC')]}),
#  ('Von Microsoft gibt es in dieser Hinsicht noch keine offiziellen Informationen.',
#   {'entities': [(4, 13, 'ORG')]}),
#  ('In Estland will keiner von Putin gerettet werden "',
#   {'entities': [(3, 10, 'LOC'), (27, 32, 'PER')]}),
#  ('Valve hat ihnen tolle Angebote gemacht, die haben sie angenommen.',
#   {'entities': [(0, 5, 'ORG')]}),
#  ('Funkstille nach Feierabend und im Urlaub?', {'entities': [(0, 10, 'LOC')]}),
#  ('Das entscheidende Tor für den FCA gelang Dominik Kohr (63.).',
#   {'entities': [(30, 33, 'ORG'), (41, 53, 'PER')]}),
#  ('Leider folgt HTC beim Akku anderen Herstellern.',
#   {'entities': [(13, 16, 'ORG')]}),
#  ('»Die Koran-Verteiler sind das Einfallstor«, sagt Trusheim.',
#   {'entities': [(5, 20, 'LOC'), (49, 57, 'MISC')]}),
#  ('Frankreich war bereit, die Befehle waren erteilt, die Vorbereitungen getroffen.',
#   {'entities': [(0, 10, 'LOC')]}),
#  ('Shell lud Anwohner gestern auch zur Vorstellung des Gutachtens ein.',
#   {'entities': [(0, 5, 'ORG')]}),
#  ('Auch der Koalitionspartner SPD ist dagegen.',
#   {'entities': [(27, 30, 'ORG')]}),
#  ('Warum gibt es so wenige islamische Länder, die demokratisch sind?',
#   {'entities': [(24, 34, 'MISC')]}),
#  ('An Instapaper senden Hochzeit mit Urlaub:',
#   {'entities': [(3, 13, 'MISC')]}),
#  ('Das Deutsche Rote Kreuz (DRK) beklagt Engpässe bei den Blutvorräten.',
#   {'entities': [(4, 23, 'ORG'), (25, 28, 'ORG')]}),
#  ('Zuvor wurde er jedoch von unserem Erlkönig-Jäger in voller Tarnmontur erlegt.',
#   {'entities': [(34, 48, 'MISC')]}),
#  ('Google ändert die eigene Preispolitik bei Nexus-Smartphones deutlich.',
#   {'entities': [(0, 6, 'MISC'), (42, 59, 'ORG')]}),
#  ('Einfach nur falsch erinnert, kann doch mal passieren.',
#   {'entities': [(0, 7, 'MISC')]}),
#  ('Die Eichstätter Malteser haben bereits 2014 die ersten Teams ausgebildet.',
#   {'entities': [(4, 24, 'ORG')]}),
#  ('Der Klub hatte 1985 seinen ersten MLB-Titel geholt.',
#   {'entities': [(34, 43, 'LOC')]}),
#  ('Der Kanton Aargau hat seine 196 Millionen bereits bewilligt.',
#   {'entities': [(4, 17, 'LOC')]}),
#  ('McGrath will "dem Überwachungsstaat ein Gesicht geben", sagt er.',
#   {'entities': [(0, 7, 'PER')]}),
#  ('Yonny schaffte nach zwei unglücklichen Rennen den Sprung zurück in die Top',
#   {'entities': [(0, 5, 'PER')]}),
#  ('Hier kann man untergehen, das ist Porto passiert.',
#   {'entities': [(34, 39, 'LOC')]}),
#  ('Auf Texel beim "Fly-In Cinema" ist das am 09. Mai möglich.',
#   {'entities': [(4, 9, 'LOC'), (16, 22, 'MISC')]}),
#  ('Ich schreibe vielleicht auch mal einen SPON-Artikel..',
#   {'entities': [(0, 23, 'MISC'), (39, 53, 'MISC')]}),
#  ('ONLINE: Welcher Serientod ist für Sie als Medienwissenschaftler interessant?',
#   {'entities': [(0, 6, 'ORG')]}),
#  ('Der Freistaat wolle dann die Förderprämie in eigener Regie zahlen.',
#   {'entities': [(4, 13, 'LOC'), (29, 41, 'ORG')]}),
#  ('Foto: Willi Weber Kann billige Ware vom Discounter wirklich gut sein?',
#   {'entities': [(0, 4, 'PER'), (6, 17, 'PER')]}),
#  ('Konzernergebnisse, Teil 3: Die Verlierertypen Heidelberger Druck:',
#   {'entities': [(31, 64, 'ORG')]}),
#  ('Die Tatorte waren in beiden Fällen Einkaufszentren in Neusiedl am See.',
#   {'entities': [(54, 69, 'LOC')]}),
#  ('Frühlings-Wetter lässt die Organisatoren kalt',
#   {'entities': [(0, 16, 'PER')]}),
#  ('Nachrichten, aktuelle Schlagzeilen und Videos: n-tv.de',
#   {'entities': [(39, 45, 'MISC'), (47, 54, 'ORG')]}),
#  ('Nach dem Rechtsrutsch werde es im Nationalrat nicht einfacher.',
#   {'entities': [(34, 45, 'ORG')]}),
#  ('Türpitz muss sich einem operativen Eingriff im Magen-Darmbereich unterziehen.',
#   {'entities': [(0, 7, 'LOC'), (47, 64, 'MISC')]}),
#  ('Er, das ist Geschäftsführer Jörg Schmadtke.',
#   {'entities': [(28, 42, 'PER')]}),
#  ('Die härteste Strafe im Devisen-Skandal erhielt Barclays.',
#   {'entities': [(23, 38, 'LOC'), (47, 55, 'ORG')]}),
#  ('Testen Sie Ihr Wissen – mit 14 Fragen auf ITespresso.',
#   {'entities': [(42, 52, 'ORG')]}),
#  ('Nachrichten, aktuelle Schlagzeilen und Videos: n-tv.de',
#   {'entities': [(39, 45, 'MISC'), (47, 54, 'ORG')]}),
#  ('Ich würde es da eher mit Hillary Clinton halten, die jetzt auch alle fragen.',
#   {'entities': [(25, 40, 'PER')]}),
#  ('Die regierungstreuen Behörden schlossen im Gegenzug den Flughafen von Aden.',
#   {'entities': [(56, 74, 'LOC')]}),
#  ('Der Putzhilfe-Vermittler Homejoy nimmt sein Geschäft vom Netz:',
#   {'entities': [(4, 32, 'MISC')]}),
#  ('Zudem war der Stiftung Warentest der Preis zu hoch.',
#   {'entities': [(14, 32, 'ORG')]}),
#  ('Das grosse Polit-RankingDas sind die grössten Hinterbänkler in Bern',
#   {'entities': [(11, 27, 'MISC'), (63, 67, 'LOC')]}),
#  ('Den ersten Saisonsieg feierte der Lokalrivale aus St. Pölten:',
#   {'entities': [(50, 60, 'LOC')]}),
#  ('Als Doppelweltmeister kassiert Mercedes 2016 dann richtig ab.',
#   {'entities': [(31, 39, 'ORG')]}),
#  ('Dessen Befindlichkeiten interessieren Guardiola sicher nicht weiter.',
#   {'entities': [(38, 47, 'PER')]}),
#  ('Auch das griechische Schuldendrama belastet den Gipfel, der am Sonntag beginnt.',
#   {'entities': [(9, 20, 'MISC'), (21, 34, 'LOC')]}),
#  ('Auch Schweizer wechseln manchmal den Anbieter',
#   {'entities': [(5, 14, 'MISC')]}),
#  ('anStresstest "Großraum Krefeld"(Kommentar anzeigenKommentar ausblenden)',
#   {'entities': [(0, 12, 'MISC'), (23, 59, 'LOC')]}),
#  ('Herr Seidel, Das ist leider nicht ganz richtig.',
#   {'entities': [(0, 11, 'PER')]}),
#  ('SPD-Vize Stegner: "Die Öffentlichkeit verliert das Verständnis" 16.55 Uhr:',
#   {'entities': [(0, 16, 'PER')]}),
#  ('ORF.at Startseite Informationen zum Programm',
#   {'entities': [(0, 6, 'MISC')]}),
#  ('„Du hast Großes geleistet für Deutschland und für Europa.“',
#   {'entities': [(1, 15, 'MISC'), (30, 41, 'LOC'), (50, 56, 'LOC')]}),
#  ('Trainer Ciriaco Sforza passte nicht zum FC Thun und umgekehrt.',
#   {'entities': [(8, 22, 'PER'), (40, 47, 'ORG')]}),
#  ('Auch in Sagno hat das 21. Jahrhundert Einzug gehalten.',
#   {'entities': [(8, 13, 'LOC')]}),
#  ('Neu-Delhi - Der Fuhrpark von Mohammed Nisham umfasst etwa 20 Luxuskarossen.',
#   {'entities': [(0, 9, 'LOC'), (29, 44, 'PER')]}),
#  ('Sony hat Details zum geplanten Bloodborne Patch 1.03 verraten.',
#   {'entities': [(0, 4, 'ORG'), (31, 41, 'MISC')]}),
#  ('Der Sohn des früheren Energieministers von Katar gilt als Multitalent.',
#   {'entities': [(43, 48, 'ORG')]}),
#  ('Anschauung bieten die Fälle Strauss-Kahn und Sarkozy.',
#   {'entities': [(28, 40, 'PER'), (45, 52, 'PER')]}),
#  ('Obendrein werden in den kommenden Jahren Auktionsverfahren eingeführt:',
#   {'entities': [(0, 9, 'MISC')]}),
#  ('Sie bestätigte am Samstag eine Meldung des "Tages-Anzeigers".',
#   {'entities': [(44, 59, 'ORG')]}),
#  ('«Eine meiner besten Freundinnen habe ich auf Twitter kennengelernt.',
#   {'entities': [(45, 52, 'MISC')]}),
#  ("Wenn's beim FCB nicht läuft, wechseln sie Lewandowski ein.",
#   {'entities': [(12, 15, 'ORG'), (42, 53, 'PER')]}),
#  ('Das Neuste Wirtschaft Piccard fliegt auf Lantal-Luftkissen um die Welt',
#   {'entities': [(22, 29, 'PER'), (41, 58, 'LOC')]}),
#  ('Immer mehr Bekleidungsketten geraten ins Schwanken.',
#   {'entities': [(11, 28, 'PER')]}),
#  ('Die Skigirls haben um 22.00 Uhr schon geschlafen?',
#   {'entities': [(4, 12, 'MISC')]}),
#  ('Auch dort am Neusiedler See verdoppelten sich Blauen auf zehn Prozent.',
#   {'entities': [(13, 27, 'LOC'), (46, 52, 'ORG')]}),
#  ('Burgstaller erhielt 9.501 und damit 33,8 Prozent aller Stimmen.',
#   {'entities': [(0, 11, 'PER')]}),
#  ('Die Schweiz ist ein sehr schönes Land, es liegt zentral und alles funktioniert.',
#   {'entities': [(4, 11, 'LOC')]}),
#  ('Lawine reisst Skifahrer 700 Meter in die Tiefe',
#   {'entities': [(0, 6, 'LOC')]}),
#  ('Von FOCUS-Online-Autorin Kathrin Steinbeißer » Ausraster am Flughafen:',
#   {'entities': [(25, 44, 'PER'), (60, 69, 'LOC')]}),
#  ('Der Plauener war soeben unter einem VW Passat hervor gekrochen.',
#   {'entities': [(4, 12, 'LOC'), (36, 45, 'MISC')]}),
#  ('Da ist Jean-Claude Juncker mal richtig sauer auf Tsipras.',
#   {'entities': [(7, 26, 'PER'), (49, 56, 'PER')]}),
#  ('Dieser Hamburger kämpft in Brüssel für den Datenschutz Foto:',
#   {'entities': [(7, 16, 'MISC'), (27, 34, 'LOC')]}),
#  ('Nachrichten, aktuelle Schlagzeilen und Videos:',
#   {'entities': [(39, 45, 'MISC')]}),
#  ('Als Erste hatten die Iren den neuen Sturm aus dem Atlantik zu spüren bekommen.',
#   {'entities': [(21, 25, 'LOC'), (50, 58, 'LOC')]}),
#  ('Letzterer wird als Nachfolger der Catalyst/',
#   {'entities': [(34, 42, 'PER')]}),
#  ('Beethovenpreis für syrisch-palästinensischen Flüchtling',
#   {'entities': [(0, 14, 'MISC')]}),
#  ('Die Kritik an ihm sieht Völkel allerdings gelassen.',
#   {'entities': [(24, 30, 'PER')]}),
#  ('Das geht nicht“, sagte sie bei Günther Jauch.',
#   {'entities': [(31, 44, 'PER')]}),
#  ('Ich jedenfalls bin überzeugt, dass er das schaffen kann.',
#   {'entities': [(0, 18, 'MISC')]}),
#  ('Stephan: Das kleine Kerlchen kann definitiv klettern.',
#   {'entities': [(0, 7, 'PER')]}),
#  ('Stephan-Andreas Casdorff Wolfgang Bosbach ist ein wirklicher Volksvertreter.',
#   {'entities': [(0, 41, 'PER')]}),
#  ('In der deutschen Bundesregierung sind die Pläne umstritten.',
#   {'entities': [(7, 16, 'MISC')]}),
#  ('Und das schon vor dem Test gegen St. Gallen (1:2).',
#   {'entities': [(33, 43, 'LOC')]}),
#  ('Gegen die Bieler haben wir eine 1:3-Bilanz in dieser Saison.',
#   {'entities': [(10, 16, 'LOC')]}),
#  ('Tipp: das Bild anklicken um den Code neu zu generieren',
#   {'entities': [(0, 4, 'PER')]}),
#  ('Auch der CDU-Gesundheitspolitiker Jens Spahn befürwortete eine klare Regelung.',
#   {'entities': [(34, 44, 'PER')]}),
#  ('Bei den so veränderten Mäusen waren nur Dimere im Hirnwasser nachweisbar.',
#   {'entities': [(23, 29, 'MISC'), (40, 46, 'MISC')]}),
#  ('Wobei wenn es echt nur ums bummel geht, müsste das ja DA:',
#   {'entities': [(54, 56, 'ORG')]}),
#  ('Den entscheidenden Treffer erzielte Alan Dzagoew (76.).',
#   {'entities': [(36, 48, 'PER')]}),
#  ('Er hatte bei Basel eine gute Zeit, und auch bei Bayern ist es ihm gut gelaufen.',
#   {'entities': [(13, 18, 'LOC'), (48, 54, 'LOC')]}),
#  ('2297222 Sony setzt künftig voll auf PlayStation und Bildsensoren',
#   {'entities': [(8, 12, 'ORG'), (36, 47, 'MISC')]}),
#  ('Dabei Vergriff sich der Arbeitgeber-Chef jedoch völlig im Ton:',
#   {'entities': [(24, 40, 'ORG')]}),
#  ('Aber es war eine Entscheidung des Trainers, sagte der Pole.',
#   {'entities': [(54, 58, 'LOC')]}),
#  ('Der IS hat sich zu den Anschlägen von Paris bekannt.',
#   {'entities': [(4, 6, 'ORG'), (23, 43, 'MISC')]}),
#  ('Die Separatisten bezichtigen Kiew der Tat.',
#   {'entities': [(29, 33, 'LOC')]}),
#  ('Köln verbannt Fernbusse aus der Innenstadt Köln (dpa) -',
#   {'entities': [(0, 4, 'LOC'), (32, 47, 'LOC')]}),
#  ('Zahlreiche Neumarkter Firmen und Behörden stellen Lastwägen zur Verfügung.',
#   {'entities': [(11, 21, 'LOC')]}),
#  ('Polo-Fahrer mit gestohlenem Kennzeichen entkommt der Polizei',
#   {'entities': [(0, 11, 'ORG')]}),
#  ('Neuer Chef: Schoenaich-Carolath macht Tempo.',
#   {'entities': [(12, 31, 'MISC'), (38, 43, 'LOC')]}),
#  ('Bei Star Trek DS9 hat sie zumindest eine ganze Staffel mitgespielt.',
#   {'entities': [(4, 17, 'MISC')]}),
#  ('Niemand will orange Zuckerln und grüne Oliven Foto:',
#   {'entities': [(0, 7, 'ORG')]}),
#  ('Sommers Ziel ist nun der dritte Null-Coup.',
#   {'entities': [(0, 7, 'MISC'), (32, 41, 'MISC')]}),
#  ('«Unser wirtschaftliches Umfeld ist wenig stabil», sagte Reithofer.',
#   {'entities': [(56, 65, 'PER')]}),
#  ('Angesichts der Affäre sagte Diess vor den Managern in Dresden:',
#   {'entities': [(28, 33, 'PER'), (54, 61, 'LOC')]}),
#  ('Bei Apple machen Männer jetzt 69 Prozent der Belegschaft aus.',
#   {'entities': [(4, 9, 'ORG')]}),
#  ('Zumindest aber gab es Saltos vom Top-Torschützen.',
#   {'entities': [(22, 28, 'ORG'), (33, 48, 'ORG')]}),
#  ('Konkurrent Microsoft hatte das bei der Xbox One bereits vor einiger Zeit getan.',
#   {'entities': [(11, 20, 'ORG'), (39, 47, 'MISC')]}),
#  ('Außer Randolf, den einstigen Betreiber, kannte ich aber keinen.',
#   {'entities': [(6, 13, 'PER')]}),
#  ('Wuchernde Flüchtlingssiedlung erschüttert', {'entities': [(0, 29, 'PER')]}),
#  ('Damit das funktioniert, müssen die Chirurgen im Dunkeln arbeiten.',
#   {'entities': [(48, 55, 'LOC')]}),
#  ('Ein 139-minütiges Fest für Freunde des trockenen Humors.',
#   {'entities': [(18, 55, 'MISC')]}),
#  ('Der Kampf in Düsseldorf wird im Weltergewicht stattfinden.',
#   {'entities': [(13, 23, 'LOC')]}),
#  ('Die halten doch immer gerne die Hand auf und tingeln bei den ÖR hin und her!',
#   {'entities': [(61, 63, 'ORG')]}),
#  ('Die Wege sind völlig aufgeweicht, knietief versinken die Flüchtlinge im Matsch.',
#   {'entities': [(72, 78, 'LOC')]}),
#  ('Julian Assange Anfang 2012 vor einem Gerichtsgebäude in London.',
#   {'entities': [(0, 14, 'PER'), (56, 62, 'LOC')]}),
#  ('Ausserdem können SMS versendet und Anrufe initiiert werden.',
#   {'entities': [(17, 20, 'MISC')]}),
#  ('Sturmtrio mit Podolski, Icardi und Shaqiri',
#   {'entities': [(0, 9, 'PER'),
#     (14, 22, 'PER'),
#     (24, 30, 'PER'),
#     (35, 42, 'PER')]}),
#  ('Vor zwei Jahren noch ein Blue Chip national und in der Champions League.',
#   {'entities': [(55, 71, 'MISC')]}),
#  ('Mit ihren Verschachtelungen macht es Ackrill dem Leser aber nicht einfach.',
#   {'entities': [(37, 44, 'PER')]}),
#  ('Dreyer erwartet viele unbegleitete junge Flüchtlinge (Langweiler (dpa/lrs))',
#   {'entities': [(0, 6, 'PER'), (54, 64, 'LOC')]}),
#  ('In diesem Video befassen wir uns mit VMware vSphere und VMware vCenter Suite.',
#   {'entities': [(37, 51, 'MISC'), (56, 76, 'MISC')]}),
#  ('In jeder zehnten Wohnung leben laut Statistikinstitut',
#   {'entities': [(36, 53, 'LOC')]}),
#  ('HDR-Foto einsenden, Preise im Wert von über 3.000 Euro gewinnen:',
#   {'entities': [(0, 8, 'ORG')]}),
#  ('Auch deshalb bitten wir, bitte ich, um Ihr Vertrauen auf dem weiteren Weg.',
#   {'entities': [(39, 52, 'MISC')]}),
#  ('Mit dieser Begründung verurteilte ein Berner Gericht zwei SVP-Kader.',
#   {'entities': [(38, 44, 'LOC'), (58, 67, 'MISC')]}),
#  ('Der Hinweis auf den Kinderschänder kam aus Amerika.',
#   {'entities': [(43, 50, 'LOC')]}),
#  ('Das GIF zur unauffälligen Exfiltration der Daten hat gerade einmal 145 Bytes.',
#   {'entities': [(4, 7, 'MISC')]}),
#  ('Die MEM-Industrie exportiert fast 80 Prozent ihrer Produkte.',
#   {'entities': [(4, 17, 'MISC')]}),
#  ('Anstand zählt dazu, Integrität und Lauterkeit.',
#   {'entities': [(0, 7, 'LOC')]}),
#  ('Nur drei der vielen Symptome gingen mit sinkenden Testosteronwerten einher:',
#   {'entities': [(50, 67, 'MISC')]}),
#  ('Schaue er sich bei Kant um, von dem er lernen könnt.',
#   {'entities': [(19, 23, 'PER')]}),
#  ('Das Konzernergebnis 2014 fiel um 78% im Jahresvergleich auf EUR 126,1 Mio.',
#   {'entities': [(60, 63, 'MISC')]}),
#  ('Im zweiten Quartal hat Berkshire Hathaway einen Gewinnrückgang verbucht.',
#   {'entities': [(23, 41, 'PER')]}),
#  ('Doch viele der Anekdoten über ihn seien laut Stenebo frei erfunden.',
#   {'entities': [(45, 52, 'LOC')]}),
#  ('Der Schönheitschirurg Wolfgang Funk hat seine Klinik am Rande Münchens.',
#   {'entities': [(22, 35, 'PER'), (62, 70, 'LOC')]}),
#  ('Der japanische Künstler Satoshi Kon verwischt in "Opus" gekonnt die Grenze.',
#   {'entities': [(4, 14, 'MISC'), (24, 35, 'PER'), (50, 54, 'ORG')]}),
#  ('Als schließlich Mechthild in unsere Familie kam, wurde vieles einfacher.',
#   {'entities': [(16, 25, 'PER')]}),
#  ('Grässlich war das, die haben nur gestritten.',
#   {'entities': [(0, 9, 'PER')]}),
#  ('Amimour wurde seit Ende 2013 international gesucht.',
#   {'entities': [(0, 7, 'PER')]}),
#  ('Tipp: das Bild anklicken um den Code neu zu generieren',
#   {'entities': [(0, 4, 'PER')]}),
#  ('Bei der Rallye Italien fuhr Ogier einmal mehr makellos.',
#   {'entities': [(8, 22, 'MISC'), (28, 33, 'PER')]}),
#  ('Leichtfertig wurden die Bälle verloren, im Angriff fand Kiel kaum Lösungen.',
#   {'entities': [(0, 12, 'PER'), (43, 60, 'MISC')]}),
#  (' 163076 Angst vor dem Jobverlust: Bauarbeiter in Peking.',
#   {'entities': [(22, 32, 'MISC'), (49, 55, 'LOC')]}),
#  ('Ansonsten gibt es eine Helden-Rotation - wie z.B. in League of Legends.',
#   {'entities': [(53, 70, 'MISC')]}),
#  ('Dann folgen Punktevergaben der Mitglieder und des Landesvorstands.',
#   {'entities': [(12, 26, 'PER'), (50, 65, 'ORG')]}),
#  ('Sindelic hat nicht immer die Wahrheit gesagt.',
#   {'entities': [(0, 8, 'PER')]}),
#  ('Am meisten lagert momentan in New York, gefolgt von Frankfurt.',
#   {'entities': [(30, 38, 'LOC'), (52, 61, 'LOC')]}),
#  ('Ab in die Boxengasse: Strafe für Rowdy Hanika Tweets werden geladen..',
#   {'entities': [(10, 20, 'LOC'), (33, 45, 'PER')]}),
#  ('Auch beim Laden will Audi schneller werden:',
#   {'entities': [(21, 25, 'ORG')]}),
#  ('Video: SpaceX CRS-5 - Transport-Mission zur ISS',
#   {'entities': [(0, 5, 'MISC'), (7, 19, 'MISC'), (44, 47, 'MISC')]}),
#  ('Binder + Co: Pohl wird berufen weitere Nachrichten zu BINDER + CO.',
#   {'entities': [(0, 12, 'ORG'), (13, 17, 'PER'), (54, 65, 'ORG')]}),
#  ('Die Fragen stellten Andreas Niesmann und Ulrich Reitz.',
#   {'entities': [(20, 36, 'PER'), (41, 53, 'PER')]}),
#  ('Antwort Liebe Redaktion, wie menschenverachtend ist das denn:',
#   {'entities': [(8, 23, 'MISC')]}),
#  ('Für Klubchef Reinhold Lopatka wäre Pröll ein "exzellenter" Kandidat.',
#   {'entities': [(13, 29, 'PER'), (35, 40, 'PER')]}),
#  ('Taliban finden IS-Massaker "entsetzlich" Straßenkontrolle bei Dschalalabad.',
#   {'entities': [(0, 7, 'ORG'), (15, 26, 'ORG')]}),
#  ('Am 7. September will das Bakom richtig informieren und werben.',
#   {'entities': [(25, 30, 'ORG')]}),
#  ('Douglas setzt mit Helene-Fischer-Duft auf Wachstumskurs',
#   {'entities': [(0, 7, 'MISC'), (18, 37, 'PER')]}),
#  ('In Miami holte er sich nach Satzrückstand das Ticket ab - und nicht nur er.',
#   {'entities': [(3, 8, 'LOC')]}),
#  ('Themen: Staat, Syrien, Intervention Bewerten Sie diesen Artikel:',
#   {'entities': [(15, 21, 'LOC')]}),
#  ('Erscheinen soll The Mystery of Oak Island im Herbst',
#   {'entities': [(16, 41, 'MISC')]}),
#  ('Quirky 7.3 ist dafür gedacht, auf einen Massenspeicher installiert zu werden.',
#   {'entities': [(0, 6, 'PER')]}),
#  ('Mediathek Hans-Werner Sinn im n-tv Interview "',
#   {'entities': [(0, 26, 'LOC')]}),
#  ('Marktkommentar pro aurum: Gastbeitrag von Claus Vogt',
#   {'entities': [(42, 52, 'PER')]}),
#  ('Schlechtwetter droht: Wein im Park in den Casino Festsaal verlegt!',
#   {'entities': [(0, 14, 'PER')]}),
#  ('Und Jörn macht Sport und hat eine tolle Föhnwelle, also Obacht.',
#   {'entities': [(4, 8, 'PER')]}),
#  ('Dabei ist Sprache die Möglichkeit schlechthin, etwas zu verändern.',
#   {'entities': [(10, 17, 'MISC')]}),
#  ('Badespass: Bär tobt sich im Swimmingpool aus Vogelnest lockt Bär auf Strommast',
#   {'entities': [(0, 14, 'LOC')]}),
#  ('Die Skala geht von A 1 (Anfänger) bis C 2 (Muttersprachler).',
#   {'entities': [(19, 22, 'LOC'), (38, 41, 'MISC')]}),
#  ('Finanzausgleich: Finanzminister Schelling macht Tempo bei Steuer-Autonomie.',
#   {'entities': [(32, 41, 'PER'), (48, 53, 'PER'), (58, 74, 'ORG')]}),
#  ('Die weiteren Resultate der 18. Runde: Newcastle United - Everton',
#   {'entities': [(38, 54, 'ORG'), (57, 64, 'ORG')]}),
#  ('Dieser Brite erklärt den Deutschen, wer sie sind:',
#   {'entities': [(7, 12, 'LOC'), (25, 34, 'MISC')]}),
#  ('Hier hatten Bankvolkswirte mit einem Zuwachs um 0,2 Prozent gerechnet.',
#   {'entities': [(12, 26, 'PER')]}),
#  ('Unterstützt werden die beiden außerdem von Dirk Raudies und Lenz Leberkern.',
#   {'entities': [(43, 55, 'PER'), (60, 74, 'PER')]}),
#  ('15 Spieler haben den Dino nach der vergangenen Saison verlassen.',
#   {'entities': [(21, 25, 'MISC')]}),
#  ('Diese werden laut Fanbeirat derzeit noch ausgewertet.',
#   {'entities': [(18, 27, 'PER')]}),
#  ('In BaWü gibt es einen Migrantenanteil von fast 30%.',
#   {'entities': [(3, 7, 'LOC')]}),
#  ('Moto3 Le Mans: Bastianini mit FP3-Bestzeit, Öttl stark',
#   {'entities': [(0, 13, 'MISC'),
#     (15, 25, 'PER'),
#     (30, 42, 'MISC'),
#     (44, 48, 'PER')]}),
#  ('Einen Soldaten auf dem Feld opfern, und dafür den AT-AT stärken.',
#   {'entities': [(50, 55, 'ORG')]}),
#  ('Der HSV hat seinen Spielerkader kräftig ausgedünnt.',
#   {'entities': [(4, 7, 'ORG')]}),
#  ('In Österreich galten Luchse 1892 laut der Aussendung schon als ausgerottet.',
#   {'entities': [(3, 13, 'LOC')]}),
#  ('Der Oberstaatsanwalt war für den Amtsgerichtsbezirk Emden zuständig.',
#   {'entities': [(33, 57, 'LOC')]}),
#  ('Total-Chef erwartet bald wieder steigende Ölpreise',
#   {'entities': [(0, 10, 'PER')]}),
#  ('Deutlich wurde Firmenchef Hayek in Sachen intelligenter Uhr.',
#   {'entities': [(26, 31, 'PER')]}),
#  ('Axel Heimken / EPA / picturedesk.com Rock in Vienna 2016: Rammstein sind fix',
#   {'entities': [(0, 12, 'PER'),
#     (15, 41, 'ORG'),
#     (45, 51, 'LOC'),
#     (58, 67, 'ORG')]}),
#  ('Dank dem 2:0-Sieg von Salzburg gegen Austria',
#   {'entities': [(22, 30, 'LOC'), (37, 44, 'ORG')]}),
#  ('Für 126 Minuten schien die schwer erschütterte Fußball-Welt wieder in Ordnung.',
#   {'entities': [(47, 59, 'ORG')]}),
#  ('Otto: Wenn Sie die Entscheidung meinen, dann ja.',
#   {'entities': [(0, 4, 'PER')]}),
#  ('Bei Hertha kommt Ronny für Stocker und bei Wolfsburg Caligiuri für Vieirinha.',
#   {'entities': [(4, 10, 'ORG'),
#     (17, 34, 'PER'),
#     (43, 62, 'ORG'),
#     (67, 76, 'PER')]}),
#  ('Bild: China Daily/Reuters 4 von 8 Vorheriges Bild Nächstes Bild',
#   {'entities': [(6, 17, 'MISC'), (18, 27, 'MISC'), (34, 44, 'MISC')]}),
#  ('Im Laufe einer Kita-Karriere werden alle Kinder mal gewickelt.',
#   {'entities': [(15, 28, 'MISC')]}),
#  ('Neu: "Manufactum - Hightech vs. Handwerk" jetzt in der Gebrauchtboothalle',
#   {'entities': [(6, 16, 'ORG')]}),
#  ('Der CSU-Politiker nannte dies "ein falsches Signal nach draußen".',
#   {'entities': [(4, 17, 'ORG')]}),
#  ('Boko Haram entführt offenbar Hunderte Frauen und Kinder',
#   {'entities': [(0, 10, 'LOC')]}),
#  ('Die Zeit interpretiert nur hinein, dass Erdogan kritisiert wird.',
#   {'entities': [(40, 47, 'PER')]}),
#  ('AB InBev erhöht Übernahmeangebot für SABMiller weitere Nachrichten zu',
#   {'entities': [(0, 8, 'ORG'), (37, 46, 'ORG')]}),
#  ('Reformdezernent Jan Schneider (CDU) will das ändern.',
#   {'entities': [(16, 29, 'PER'), (31, 34, 'ORG')]}),
#  ('In ihrem Statement sind dennoch an Pegida erinnernde Sätze zu hören.',
#   {'entities': [(35, 41, 'ORG')]}),
#  ('Er habe aber entschieden, dass es Zeit sei, als Entrepreneur zu agieren.',
#   {'entities': [(34, 38, 'MISC')]}),
#  ("Wer's noch nicht kennt und des französischen so einigermaßen mächtig ist:",
#   {'entities': [(0, 5, 'PER'), (31, 44, 'MISC')]}),
#  ('Immer wieder hat die Swiss mit renitenten Passagieren zu tun.',
#   {'entities': [(21, 26, 'ORG')]}),
#  ('Herren: „Es tut schon weh, zuzusehen, wie Naddel sich so langsam kaputt macht.',
#   {'entities': [(42, 48, 'PER')]}),
#  ('Aktien New York Verschnaufpause nach der jüngsten Rally',
#   {'entities': [(7, 15, 'ORG')]}),
#  ('Insofern war an der Wall Street vor dem Wochenende Zurückhaltung Trumpf.',
#   {'entities': [(20, 31, 'LOC')]}),
#  ('Wechselhaftes Wetter in Spielberg erwartet',
#   {'entities': [(0, 20, 'PER'), (24, 33, 'LOC')]}),
#  ('Philips spürt Gegenwind - Probleme in US-Werk belasten zusätzlich',
#   {'entities': [(0, 7, 'ORG'), (38, 45, 'ORG')]}),
#  ('Der Opa aus Witten: Arno Boecker und Enkelin Thalia.',
#   {'entities': [(0, 7, 'MISC'),
#     (12, 18, 'LOC'),
#     (20, 32, 'PER'),
#     (37, 51, 'PER')]}),
#  ('Frohes neues Jahr, liebe Leserinnen und Leser!',
#   {'entities': [(0, 17, 'MISC')]}),
#  ('Zwei Jahre verkaufte Markus R. geheime BND-Dokumente an US-Geheimdienste.',
#   {'entities': [(21, 30, 'PER'), (56, 72, 'ORG')]}),
#  ('Sie doch einmal Todesopfer durch Cannabis und Alkohol.',
#   {'entities': [(16, 41, 'MISC')]}),
#  ('Wenngleich 41 an der Zahl, wie in Traupitz, schon außergewöhnlich viele sind.',
#   {'entities': [(34, 42, 'LOC')]}),
#  ('Eribon ist gut informiert, aber er war prüde gegenüber dem Privatleben.',
#   {'entities': [(0, 6, 'PER')]}),
#  ('Auch die Kraftwerkssparte musste bereits erheblich Federn lassen.',
#   {'entities': [(9, 25, 'MISC')]}),
#  ('Er kostet 18,95 Euro bei einem Analog- und 26,95 Euro bei einem ISDN-Anschluss.',
#   {'entities': [(64, 78, 'MISC')]}),
#  ('Jiří Holý: „Man spricht oft von der ‚pragmatischen Generation‘.',
#   {'entities': [(0, 9, 'PER')]}),
#  ('Könnte aber auch daran liegen, dass im Geschäft noch IE 9 installiert ist.',
#   {'entities': [(53, 57, 'MISC')]}),
#  ('Zum Streiken werden natürlich die Vasallen von Verdi vorgeschickt.',
#   {'entities': [(47, 52, 'PER')]}),
#  ('Der Klub hatte den Outfielder 2009 für 800.000 Euro verpflichtet.',
#   {'entities': [(19, 29, 'MISC')]}),
#  ('Sie arbeiteten eng zusammen: Mario Adorf und Helmut Dietl.',
#   {'entities': [(29, 40, 'PER'), (45, 57, 'PER')]}),
#  ('ORF.at im Überblick Bankeinbruch mit Schraubenzieher',
#   {'entities': [(0, 6, 'MISC'), (20, 32, 'MISC')]}),
#  ('Sie sollen im Rahmen des dritten Rettungsprogramms für Griechenland fließen.',
#   {'entities': [(55, 67, 'LOC')]}),
#  ('Sie hatten sich über das Internet kennengelernt.',
#   {'entities': [(25, 33, 'MISC')]}),
#  ('Ohne Führerschein mit Auto gefahren Wörth, Lkrs.',
#   {'entities': [(36, 41, 'LOC'), (43, 47, 'LOC')]}),
#  ('Die SVP unterstützt Silvia Steiner (cvp.) mit einer Inserate-Offensive.',
#   {'entities': [(4, 7, 'ORG'), (20, 34, 'PER')]}),
#  ('Linz: 29°C Ort wählen » Sonntag, 7. Juni 2015, 14:59 Uhr mehr Wetter »',
#   {'entities': [(0, 4, 'LOC'), (9, 10, 'MISC')]}),
#  ('Ein weiteres Todesopfer stammt aus Südtirol.',
#   {'entities': [(35, 43, 'LOC')]}),
#  ('Es geht darum, wer lügt, Hartmann oder Edathy;',
#   {'entities': [(25, 33, 'PER'), (39, 45, 'PER')]}),
#  ('Von Adrian Panholzer, Rahel Schmucki 03.11.2015',
#   {'entities': [(4, 20, 'PER'), (22, 36, 'PER')]}),
#  ('Gai verzettelt sich jedoch im Sechzehner der Dortmunder.',
#   {'entities': [(0, 3, 'PER'), (45, 55, 'MISC')]}),
#  ('Will Nikolaus Schneider, daß solche Verhältnisse in Deutschland Einzug halten?',
#   {'entities': [(0, 23, 'PER'), (52, 63, 'LOC')]}),
#  ('Beresford bedauert die Abwesenheit von Frauen in seinem Club durchaus.',
#   {'entities': [(0, 9, 'PER')]}),
#  ('Lieber Autor, Die NATO hat den DRaht gekappt!',
#   {'entities': [(0, 6, 'PER'), (18, 22, 'ORG'), (31, 36, 'ORG')]}),
#  ('Die fragen oft: Tickt der noch ganz richtig?, sagt David.',
#   {'entities': [(16, 21, 'MISC'), (51, 56, 'PER')]}),
#  ('Die adrivo Sportpresse GmbH sucht in Festanstellung:',
#   {'entities': [(4, 27, 'ORG')]}),
#  ('Die Arbeitslosenquote erreicht somit in Biel eine Höhe von 5.7 Prozent.',
#   {'entities': [(40, 44, 'LOC')]}),
#  ('Wie gründlich waren die Ermittlungen nach dem Feuertod von Florian H. 2013?',
#   {'entities': [(59, 69, 'PER')]}),
#  ('Diese überzeugte den TÜV ebenfalls und ist bereits ab 15.000 Euro erhältlich.',
#   {'entities': [(21, 24, 'ORG')]}),
#  ('Die Boulevardzeitung "Ethnos" titelt: "Die Griechen wählen Europa".',
#   {'entities': [(22, 28, 'PER'), (39, 51, 'MISC'), (59, 65, 'LOC')]}),
#  ('Griechenland: Lassen die Unionsabgeordneten Merkel diesmal im Regen stehen?',
#   {'entities': [(0, 12, 'LOC'), (25, 50, 'MISC')]}),
#  ('Dazu hat das Potsdamer Hasso-Plattner-Institut geraten.',
#   {'entities': [(13, 22, 'LOC'), (23, 46, 'LOC')]}),
#  ('PENNY siegt erneut bei DISQ-Kundenbefragung /',
#   {'entities': [(0, 5, 'ORG'), (23, 45, 'ORG')]}),
#  ('JSVP-Präsident scheitert am Wahlzettel Blick Special Offers Blick-Abo',
#   {'entities': [(0, 14, 'MISC'), (45, 69, 'ORG')]}),
#  ('Wie sonst sollte man es aushalten in Bayern?',
#   {'entities': [(37, 43, 'LOC')]}),
#  ('Bis heute ist das S4 mit 7,9 Millimetern das dünnste Galaxy-S-Modell.',
#   {'entities': [(18, 20, 'LOC'), (53, 68, 'LOC')]}),
#  ('Strom wird 2016 wieder teurer - viele Anbieter erhöhen Düsseldorf.',
#   {'entities': [(55, 65, 'LOC')]}),
#  ('Dieses Konsultationsverfahren dauere noch an.',
#   {'entities': [(7, 29, 'MISC')]}),
#  ('Child of Eden war der grosse Party Spass mit Kincet.',
#   {'entities': [(0, 13, 'MISC'), (45, 51, 'PER')]}),
#  ('Das Angebot habe nicht mithalten können, schreibt Steck.',
#   {'entities': [(50, 55, 'PER')]}),
#  ('Das spart nicht nur Zeit, sondern erhöht auch die Kandidatenreichweite.',
#   {'entities': [(50, 70, 'LOC')]}),
#  ('Sie mal nach Käptn Blaubärs Walversprechen.',
#   {'entities': [(13, 27, 'PER'), (28, 42, 'MISC')]}),
#  ('Alpinist Bruno Hasler nennt den Gipfel einen "Klassiker" unter den Hochtouren.',
#   {'entities': [(9, 21, 'PER')]}),
#  ('Nach Zeugenhinweis Graffiti-Täter gestellt',
#   {'entities': [(5, 33, 'PER')]}),
#  ('Günter Jauch: Stuhlkreis statt Aufklärung',
#   {'entities': [(0, 12, 'PER'), (14, 24, 'PER')]}),
#  ('Sie ein Wochenende an der Lötschberg-Südrampe!',
#   {'entities': [(26, 46, 'ORG')]}),
#  ('Doch ich kann schon seit einigen Seasons nicht mehr richtig drüber lachen.',
#   {'entities': [(33, 40, 'MISC')]}),
#  ('Ein paar schlaflose Nächste habe sie hinter sich, erzählt Gisela Riedel.',
#   {'entities': [(58, 71, 'PER')]}),
#  ('Foto: Evan Agostini/Invision/AP "Ich war die letzten zwei Monate im Spital".',
#   {'entities': [(6, 19, 'PER'), (20, 28, 'ORG'), (29, 31, 'ORG')]}),
#  ('Am Ossiachersee sorgten die Kapriolen für beeindruckende Bilder.',
#   {'entities': [(3, 15, 'LOC')]}),
#  ('Die Hochzeit folgte 2007 in der Kirche Santi Pietro e Paolo in Ascona TI.',
#   {'entities': [(39, 59, 'LOC'), (63, 72, 'LOC')]}),
#  ('Garbine Muguruza in zwei Sätzen mit 5:7 und 3:6.',
#   {'entities': [(0, 16, 'PER')]}),
#  ('Die Uhr ist gegen Spritzwasser geschützt und arbeitet mit Bluetooth 4.0 und LE.',
#   {'entities': [(58, 71, 'MISC'), (76, 78, 'MISC')]}),
#  ('Der Kickstarter-Finanzierungszeitraum dauert noch 29 Tage.',
#   {'entities': [(4, 37, 'LOC')]}),
#  ('Dann kommt der gesamte Mittelstand dran, verhandelt wird dann vor US-Gerichten.',
#   {'entities': [(66, 78, 'MISC')]}),
#  ('Am einfachsten ist die Anreise über Johannesburg.',
#   {'entities': [(36, 48, 'LOC')]}),
#  ('Klassik-Experten vom TÜV geben Tipps Vorbereitung vor der Besichtigung',
#   {'entities': [(21, 24, 'ORG')]}),
#  ('Tipp: das Bild anklicken um den Code neu zu generieren',
#   {'entities': [(0, 4, 'PER')]}),
#  ('Wir brauchen gezielte, zeitlich begrenzte Markteingriffe.',
#   {'entities': [(42, 56, 'LOC')]}),
#  ('Die Familien-Dynastie hat sogar einen Draht in die Bundesliga.',
#   {'entities': [(4, 21, 'LOC'), (51, 61, 'ORG')]}),
#  ('Als UPC Cablecom höhere Tarife verkündete, war der Aufschrei gross.',
#   {'entities': [(4, 16, 'ORG')]}),
#  ('So belohnt "Farmville" seine Spieler: mit bunten, niedlichen Items.',
#   {'entities': [(12, 21, 'MISC')]}),
#  ('Artikel zum Thema Kyrgios muss zahlen – und entschuldigt sich öffentlich',
#   {'entities': [(18, 25, 'PER')]}),
#  ('Til Schweiger ist der Quotenkönig der Deutschen.',
#   {'entities': [(0, 13, 'PER'), (22, 47, 'ORG')]}),
#  ('Joko Winterscheidt filmte seinen Ayahuasca-Trip fürs Fernsehen.',
#   {'entities': [(0, 18, 'PER'), (33, 47, 'MISC')]}),
#  ('Momrntan nutze ich die App Shpock noch am öftesten 4.',
#   {'entities': [(0, 8, 'PER'), (27, 33, 'MISC')]}),
#  ('Dabei sei es mit dem schnellen Griff zu Vitamintabletten nicht getan.',
#   {'entities': [(40, 56, 'MISC')]}),
#  ('Womit Google sein Geld verdient Neuer Algorithmus',
#   {'entities': [(6, 12, 'MISC'), (32, 49, 'MISC')]}),
#  ('Das beweist ein Brief, der Blick.ch exklusiv vorliegt.',
#   {'entities': [(27, 35, 'ORG')]}),
#  ('Auf dem Bankenplatz Bern wird es noch enger Immer mehr Banken sind',
#   {'entities': [(8, 24, 'LOC')]}),
#  ('Der Eindruck über die letzten vier Jahre sei «insgesamt positiv».',
#   {'entities': [(30, 40, 'MISC')]}),
#  ('Fotos von der Nikolaus-Überraschung am 6. Dezember 2013!',
#   {'entities': [(14, 35, 'LOC')]}),
#  ('Der EU-Schwellenwert sollte nicht überschritten werden.',
#   {'entities': [(4, 20, 'ORG')]}),
#  ('Klar, dass Lewandowski den Hebel in der wackeligen Defensive ansetzen muss.',
#   {'entities': [(11, 22, 'PER')]}),
#  ('US-Jobdaten treiben den Dow Richtung Rekordhoch',
#   {'entities': [(0, 11, 'ORG'), (24, 27, 'ORG')]}),
#  ("» Netzer würdigt Heynckes' Lebenswerk und lüftet Geheimnis",
#   {'entities': [(2, 8, 'PER'), (17, 25, 'PER')]}),
#  ('Nur Biden weiss, ob er Präsident werden will.',
#   {'entities': [(0, 9, 'PER')]}),
#  ('Soll auch der Flugplatz Dübendorf für die Fliegerei erhalten bleiben?',
#   {'entities': [(14, 33, 'LOC')]}),
#  ('Wirtschaftskrise "Die Touristen wollen Griechenland beistehen',
#   {'entities': [(39, 51, 'LOC')]}),
#  ('Ähnliches spielte sich im Fall der "Blue Sky M" ab.',
#   {'entities': [(36, 46, 'MISC')]}),
#  ('Einzig verbliebener Rivale Rabat nicht einsatzbereit',
#   {'entities': [(27, 32, 'LOC')]}),
#  ('Vodafone zufolge verlässt das Schlüsselmaterial zu keinem Zeitpunkt das Gerät.',
#   {'entities': [(0, 8, 'ORG')]}),
#  ('Flüchtlingskrise: Braucht Europa einen Verteilschlüssel?',
#   {'entities': [(26, 32, 'LOC')]}),
#  ('In der Hanfbotschaft kann sich jeder selbst ein Bild machen.',
#   {'entities': [(7, 20, 'MISC')]}),
#  ('Logan ist ein Selfmade-Geschäftsmann aus der Parfümindustrie.',
#   {'entities': [(0, 5, 'LOC')]}),
#  ('Der britische Grand Prix anno 2010 verkommt zur Solo-Show des Jorge Lorenzo.',
#   {'entities': [(4, 13, 'MISC'), (14, 34, 'MISC'), (62, 75, 'PER')]}),
#  ('Palästinenser betrauern den Tod der Brandopfer.',
#   {'entities': [(0, 13, 'ORG')]}),
#  ('Das Gleiche gilt für den Baselbieter Thomas de Courten.',
#   {'entities': [(25, 36, 'LOC'), (37, 54, 'PER')]}),
#  ('ZDNet für mobile Geräte Themenseiten: Aldi, E-Commerce, NFC',
#   {'entities': [(0, 5, 'MISC'), (38, 42, 'ORG')]}),
#  ('Er soll die Einhaltung der Europäischen Menschenrechtskonvention sicherstellen.',
#   {'entities': [(27, 64, 'MISC')]}),
#  ('magazin online zeigt, wer von dem Privatisierungsstopp bereits betroffen ist.',
#   {'entities': [(34, 54, 'LOC')]}),
#  ('2695708 Wir sind eine streikaffine Schule", hat Florian Bublys ihr gesagt.',
#   {'entities': [(0, 11, 'ORG'), (48, 62, 'PER')]}),
#  ('Die übrigen 269 Fluggäste konnten erst einen Tag später ihre Reise fortsetzen:',
#   {'entities': [(45, 66, 'MISC')]}),
#  ('Das ORF.at Network im Überblick Musik trennt und verbindet',
#   {'entities': [(4, 18, 'ORG')]}),
#  ('Dieser Film war für die große Dame des deutschen TV wohl nicht das Richtige.',
#   {'entities': [(39, 48, 'MISC')]}),
#  ('Das Kreissozialamt vertritt die kreisangehörigen Städte bei Gerichtsverfahren.',
#   {'entities': [(4, 18, 'LOC')]}),
#  ('Das Neuste International Riesenapplaus für Merkel',
#   {'entities': [(4, 38, 'LOC'), (43, 49, 'PER')]}),
#  ('Tweet Vitali Klitschko (44) ist seit Mai 2014 Bürgermeister von Kiew.',
#   {'entities': [(6, 22, 'PER'), (64, 68, 'LOC')]}),
#  ('Debatte: Soll das Volk über die Euro-Rettung abstimmen?',
#   {'entities': [(0, 22, 'MISC'), (32, 44, 'MISC')]}),
#  ('die Konsumfreudigkeit der reichen Russen in Wien, am Kohlmarkt zum Beispiel.',
#   {'entities': [(34, 40, 'LOC'), (44, 48, 'LOC'), (53, 62, 'LOC')]}),
#  ('Rundfunkrat stimmt neuem Vertrag für Anne Will zu 25.09.2015 –',
#   {'entities': [(25, 46, 'MISC')]}),
#  ('Schweizer Nationalbank hebt Euro-Mindestkurs auf',
#   {'entities': [(0, 22, 'ORG'), (28, 44, 'PER')]}),
#  ('Mörgeli schäumt wegen Bundesrat auf Youtube«',
#   {'entities': [(0, 7, 'PER'), (36, 43, 'MISC')]}),
#  ('Der Diskussion um Flüchtlingskontingente mangelt es aber an Ehrlichkeit.',
#   {'entities': [(18, 40, 'PER')]}),
#  ('Das Handelsblatt hatte den Skandal im Mai 2014 aufgedeckt.',
#   {'entities': [(4, 16, 'MISC')]}),
#  ('Tipp: das Bild anklicken um den Code neu zu generieren',
#   {'entities': [(0, 4, 'PER')]}),
#  ('Die A 49 war in Fahrtrichtung Kassel bis ca. 15.50 Uhr gesperrt.',
#   {'entities': [(4, 8, 'LOC'), (30, 36, 'LOC')]}),
#  ('James Bond würde sich mittelscheiteln lassen vor Begeisterung.',
#   {'entities': [(0, 10, 'PER')]}),
#  ('Sehnt sich gleichermaßen nach einem Heimsieg und nach Ruhe am Valznerweiher:',
#   {'entities': [(62, 75, 'LOC')]}),
#  ('Überregulierungen gefährden den Standort und die Branche.',
#   {'entities': [(0, 17, 'LOC')]}),
#  ('AOK-Chef appelliert wegen Masern-Impfung an Eltern',
#   {'entities': [(0, 8, 'ORG')]}),
#  ('Besteht deshalb überhaupt noch Bedarf an einem weiteren Mail-Client für den PC?',
#   {'entities': [(76, 78, 'MISC')]}),
#  ('Und auch Torwart Ralf Fährmann spricht seinen Mitspielern Mut zu:',
#   {'entities': [(17, 30, 'PER')]}),
#  ('POL-KA: (CW)Bad Wildbad - Von Fahrbahn abgekommen und gegen Schuppen geprallt',
#   {'entities': [(0, 6, 'ORG'), (9, 11, 'ORG'), (12, 23, 'LOC')]}),
#  ('Trotzdem geht unser Export nach Russland gegen Null.',
#   {'entities': [(32, 40, 'LOC')]}),
#  ('Miere heute, 06:46 Uhr Ossifriese heute, 09:15 Uhr',
#   {'entities': [(0, 5, 'MISC')]}),
#  ('» Vuelta: Rodriguez erobert Führung bei Schleck-Sieg',
#   {'entities': [(2, 8, 'ORG'), (10, 19, 'PER'), (40, 52, 'MISC')]}),
#  ('Ich bin kein Heuchler und war nie bequem.',
#   {'entities': [(0, 21, 'MISC')]}),
#  ('Der UMP-Kandidat war nur auf den dritten Platz gekommen, er schied aus.',
#   {'entities': [(4, 16, 'MISC')]}),
#  ('Verzögerung der Kursdaten: Deutsche Börse 15 Min.',
#   {'entities': [(27, 41, 'ORG')]}),
#  ('Sie wehrten sich grundsätzlich gegen die Integration ins kosovarische System.',
#   {'entities': [(57, 69, 'MISC')]}),
#  ('Edward Snowden hat die US-Geheimdienstreform als Meilenstein bezeichnet.',
#   {'entities': [(0, 14, 'PER'), (23, 44, 'ORG')]}),
#  ('Der Transportanhänger für die Lieferungen wurde vom Sturm zerstört.',
#   {'entities': [(52, 57, 'MISC')]}),
#  ('Euro-Finanzstaatssekretäre beraten wieder über Griechenland',
#   {'entities': [(0, 26, 'PER'), (47, 59, 'LOC')]}),
#  ('Wenn der neue SBB Tunnel fertiggestellt sei müssten die LKW verladen werden.',
#   {'entities': [(14, 24, 'ORG')]}),
#  ('Die Häftlinge haben eine Petition gegen neue Ausgangszeiten eingereicht.',
#   {'entities': [(45, 59, 'ORG')]}),
#  ('Die Konzentrationslager waren wie Starbucks, es gab sie überall',
#   {'entities': [(34, 43, 'ORG')]}),
#  ('Sie wurden von 120 Soldaten des Bundesheers unterstützt.',
#   {'entities': [(32, 43, 'LOC')]}),
#  ('Foda: "Dafür spielt man Fußball - um Spiele und Titel zu gewinnen."',
#   {'entities': [(0, 4, 'PER')]}),
#  ('Organisierte Sammeltage der Gourmetchuchi Biel',
#   {'entities': [(28, 46, 'ORG')]}),
#  ('Thelen sagt hingegen, Fachärzte hätten ihm von der Investition abgeraten.',
#   {'entities': [(0, 6, 'PER')]}),
#  ('Der Dateibetrachter Atril unterstützt jetzt das ePub-Format.',
#   {'entities': [(4, 25, 'LOC')]}),
#  ('Erst nach einer halben Stunde herrschte im Giuseppe-Meazza-Stadion Aufregung.',
#   {'entities': [(43, 66, 'LOC')]}),
#  ('Unterstützung erhielt Froome vom früheren Toursieger Greg Lemond.',
#   {'entities': [(22, 28, 'PER'), (53, 64, 'PER')]}),
#  ('Mit Eigenmarken macht Decathlon Nike und Adidas Konkurrenz',
#   {'entities': [(22, 36, 'ORG'), (41, 47, 'ORG')]}),
#  ('Sie enthält das Spezial-Tool Windows Unlocker.',
#   {'entities': [(29, 45, 'MISC')]}),
#  ('DAV wie BMF drücken sich hier etwas undifferenziert aus.',
#   {'entities': [(0, 3, 'ORG'), (8, 11, 'ORG')]}),
#  ('Die britische Kolonialbehörde gewährte ihnen jedoch später Asyl.',
#   {'entities': [(4, 13, 'MISC')]}),
#  ('Bereits am Samstagabend kursierten erste Videos davon im Internet.',
#   {'entities': [(41, 47, 'MISC'), (57, 65, 'MISC')]}),
#  ('Auf dem Weg zur Champions League lässt sich Granit Xhaka durch nichts stoppen.',
#   {'entities': [(16, 32, 'MISC'), (51, 56, 'PER')]}),
#  ('Antwort schreiben 1893 war Griechenland insolvent und 1908 ist die erste europ.',
#   {'entities': [(27, 39, 'LOC')]}),
#  ('Das Relegationsrückspiel in Karlsruhe kommt den HSV teuer zu stehen.',
#   {'entities': [(28, 37, 'MISC'), (48, 51, 'ORG')]}),
#  ('Ford kündigt Smartphone-App Sync Connect an Vergrößern',
#   {'entities': [(0, 4, 'ORG'), (28, 40, 'MISC')]}),
#  ('Pilatus wohnt in der Hauptstraße Nummer 67 - Klüsserath wird zu Jerusalem:',
#   {'entities': [(0, 7, 'PER'), (45, 55, 'LOC'), (64, 73, 'LOC')]}),
#  ('Machst du das als Trainer nicht, heißt es, warum spielt Hazard nicht?',
#   {'entities': [(0, 9, 'MISC'), (56, 62, 'ORG')]}),
#  ('Abprüfen lässt sich nur der Lernfortschritt durch Üben und Trainieren.',
#   {'entities': [(0, 8, 'LOC')]}),
#  ('Tag 3: Walters wirre Abrechnung mit Harry Wijnvoord Tag 2:',
#   {'entities': [(0, 5, 'MISC'),
#     (7, 14, 'PER'),
#     (36, 51, 'PER'),
#     (52, 57, 'MISC')]}),
#  ('Das alles passierte in enger Zusammenarbeit mit dem NIDR.',
#   {'entities': [(52, 56, 'ORG')]}),
#  ('Der Titel MCIII mag daher für sein Namenskürzel plus Albumzahl stehen;',
#   {'entities': [(10, 15, 'MISC')]}),
#  ('Das Problem sind die Nutzungsbedingungen der Social Networks:',
#   {'entities': [(45, 60, 'ORG')]}),
#  ('Aber nicht nur die Israel-Kritiker weltweit nahm Lapid aufs Korn.',
#   {'entities': [(19, 34, 'MISC'), (49, 54, 'PER')]}),
#  ('An Instapaper senden Fenninger: "War dem Karriere-Ende doch sehr nahe".',
#   {'entities': [(3, 13, 'LOC'), (21, 30, 'LOC'), (41, 54, 'LOC')]}),
#  ('Mit dem zweiten Reifen habe ich etwas Chattering bekommen.',
#   {'entities': [(38, 48, 'MISC')]}),
#  ('Elf Tage nach dem Fund zweier Leichen in einer alten Käserei in Laupen',
#   {'entities': [(64, 70, 'LOC')]}),
#  ('In der Klubmitteilung hieß es lediglich: "Damit ist eine Entscheidung gefallen.',
#   {'entities': [(7, 21, 'LOC')]}),
#  ('Doch die Verantwortlichen in Brüssel drücken sich.',
#   {'entities': [(29, 36, 'LOC')]}),
#  ('Vor der schwedischen Ostküste liegt ein fremdes U-Boot auf dem Meeresgrund.',
#   {'entities': [(8, 20, 'MISC')]}),
#  ('Rennes in Heimstetten (im Rahmen des Trainingslagers am Tegernsee).',
#   {'entities': [(0, 6, 'LOC'), (10, 21, 'LOC'), (56, 65, 'LOC')]}),
#  ('Das haben die Erwachsenen scheinbar wieder vergessen.',
#   {'entities': [(14, 25, 'MISC')]}),
#  ('1979 ging er in die USA, zu den Fort Lauderdale Strikers.',
#   {'entities': [(20, 23, 'LOC'), (32, 56, 'ORG')]}),
#  ('Ein Vierteljahrhundert hielt Rogerio Ceni dem FC Sao Paulo die Treue.',
#   {'entities': [(29, 41, 'PER'), (46, 58, 'ORG')]}),
#  ('Handball-WM wird live bei Sky zu sehen sein',
#   {'entities': [(0, 11, 'MISC'), (26, 29, 'ORG')]}),
#  ('SWTOR und ESO hatten bessere Quests und das SIND MMOs!',
#   {'entities': [(0, 5, 'ORG'), (10, 13, 'ORG'), (49, 54, 'ORG')]}),
#  ('Einmal im Jahr fährt sie zu den Söhnen, mehr ist finanziell nicht drin.',
#   {'entities': [(0, 14, 'MISC')]}),
#  ('Die Bilanz der Schweizer NHL-Söldner Schweizer Duell in der NHL:',
#   {'entities': [(15, 36, 'MISC'), (60, 63, 'ORG')]}),
#  ('Als Grund nannte eine Sprecherin Krankheitsfälle in der Organisationsgruppe.',
#   {'entities': [(56, 75, 'ORG')]}),
#  ('Der Film wurde gefördert von MBB, FFA, Film- und Medienstiftung NRW sowie DFFF.',
#   {'entities': [(29, 32, 'ORG'),
#     (34, 37, 'ORG'),
#     (39, 67, 'ORG'),
#     (74, 78, 'MISC')]}),
#  ('Auch die Deutsche Telekom hatte ihre Aktionäre geladen.',
#   {'entities': [(9, 25, 'ORG')]}),
#  ('Samstag gegen Bremen können wir den Zähler hier vergolden.“',
#   {'entities': [(14, 20, 'ORG')]}),
#  ('Die Iserlohn Roosters haben Bobby Raymond verpflichtet.',
#   {'entities': [(4, 21, 'ORG'), (28, 41, 'PER')]}),
#  ('Snapseed 2.0 kann kostenlos für iOS (universal) und Android geladen werden.',
#   {'entities': [(0, 12, 'MISC'), (32, 35, 'MISC'), (52, 59, 'MISC')]}),
#  ('Scholz: Ok, man muss kein Prophet sein, um eine Absage vorherzusagen.',
#   {'entities': [(0, 6, 'PER'), (8, 10, 'MISC')]}),
#  ('Sygnis Aktie Bezugsrechtsangebot, Zeichnen bis 7.12.2015 INDEXÄNDERUNG/Dt.',
#   {'entities': [(0, 32, 'ORG'), (57, 70, 'ORG'), (71, 73, 'ORG')]}),
#  ('Der St. Galler ist neben Emeghara der zweite Schweizer in der MLS.',
#   {'entities': [(4, 14, 'LOC'), (45, 54, 'MISC'), (62, 65, 'ORG')]}),
#  ('In letzter Zeit hat er wieder gut zu tun.',
#   {'entities': [(0, 15, 'MISC')]}),
#  ('Wie uns BND und Verfassungsschutz vor Terror schützen',
#   {'entities': [(8, 11, 'ORG'), (16, 33, 'ORG')]}),
#  ('Englands Verband stellt Wahl am Freitag infrage',
#   {'entities': [(0, 16, 'ORG')]}),
#  ('Die Straßenbahnen auf der "MaHü" verkehrten bis in die 1990er Jahre.',
#   {'entities': [(27, 31, 'ORG')]}),
#  ('Gegen Porto machte Guardiola alles richtig.',
#   {'entities': [(6, 11, 'ORG'), (19, 28, 'PER')]}),
#  ('Fortuna ist neun Punkte vom Relegationsplatz drei entfernt, Leipzig elf.',
#   {'entities': [(0, 7, 'ORG'), (60, 67, 'LOC')]}),
#  ('bei den SCL Tigers Aktualisiert am 08.01.2015',
#   {'entities': [(8, 31, 'ORG')]}),
#  ('Wirtschaftlich hat Russland der EU nichts entgegenzusetzen.',
#   {'entities': [(19, 27, 'LOC'), (32, 34, 'ORG')]}),
#  ('Der 59-Jährige verteidigt das Nachwuchsprogramm von Red Bull.',
#   {'entities': [(52, 60, 'ORG')]}),
#  ('CW: Wie gehen Sie an die Märkte an, in denen Sie Dell positionieren wollen?',
#   {'entities': [(0, 2, 'ORG'), (49, 53, 'ORG')]}),
#  ('Ryanair will Bratislava ab März als neue Basis für Europa-Strecken ausbauen.',
#   {'entities': [(0, 7, 'ORG'), (13, 23, 'LOC'), (51, 66, 'ORG')]}),
#  ('Die Formel 1 ist für Mercedes keine teure Bühne.',
#   {'entities': [(4, 12, 'MISC'), (21, 29, 'ORG')]}),
#  ('Schalke gewinnt Spiel und verliert Huntelaar',
#   {'entities': [(0, 7, 'ORG'), (35, 44, 'ORG')]})]

# %%
random.shuffle(out_sentences)
TRAIN_STAT_DATA=out_sentences[:len(out_sentences)//2]
TEST_STAT_DATA=out_sentences[len(out_sentences)//2:]

# %%
print(len(out_sentences))
print(len(TRAIN_STAT_DATA))
print(len(TEST_STAT_DATA))
print("REVISION", len(TRAIN_REVISION_DATA))
TRAIN_DATA = TRAIN_REVISION_DATA + TRAIN_STAT_DATA
print("COMBINED", len(TRAIN_DATA))
# Out:
# 510
# 255
# 255
# REVISION 562
# COMBINED 817

# %%
#spacy 3.0 attempt


ner = nlp.get_pipe("ner")
ner.add_label("LOCALITY")
from spacy.training import Example
from spacy.tokens import Doc


# get the names of the components we want to disable during training
pipe_exceptions = ["ner", "trf_wordpiecer", "trf_tok2vec"]
other_pipes = [pipe for pipe in nlp.pipe_names if pipe not in pipe_exceptions]

# start the training loop, only training NER
epochs = 30
optimizer = nlp.resume_training()
#optimizer = nlp.initialize()
with nlp.disable_pipes(*other_pipes), warnings.catch_warnings():
    warnings.filterwarnings("once", category=UserWarning, module='spacy')
    sizes = compounding(1.0, 4.0, 1.001)
    
    # batch up the examples using spaCy's minibatc
    for epoch in range(epochs):
        random.shuffle(TRAIN_DATA)
        #text = []
        #annots=[]
        examples=[]


        for text,annots in TRAIN_DATA:
            #text.append(t)
            #annots.append(a)
            doc = nlp.make_doc(text)    
            example = Example.from_dict(doc, annots)
            examples.append(example)
        
        losses = {}
        
        nlp.update(examples, sgd=optimizer, drop=0.35, losses=losses)

        print("Losses ({}/{})".format(epoch + 1, epochs), losses)
# Out:
# Losses (1/30) {'ner': 1036.7250943763693}
# Losses (2/30) {'ner': 989.7197784991635}
# Losses (3/30) {'ner': 826.3420708181119}
# Losses (4/30) {'ner': 838.7834664121892}
# Losses (5/30) {'ner': 733.5376520684233}
# Losses (6/30) {'ner': 724.8222034484029}
# Losses (7/30) {'ner': 685.6173731966405}
# Losses (8/30) {'ner': 625.7451128661105}
# Losses (9/30) {'ner': 656.9089558631244}
# Losses (10/30) {'ner': 619.3330717421031}
# Losses (11/30) {'ner': 606.5922888267305}
# Losses (12/30) {'ner': 549.0530150022387}
# Losses (13/30) {'ner': 554.0773956898993}
# Losses (14/30) {'ner': 513.9042212301647}
# Losses (15/30) {'ner': 551.873147565741}
# Losses (16/30) {'ner': 512.5156379520868}
# Losses (17/30) {'ner': 473.285986641853}
# Losses (18/30) {'ner': 449.35281474152}
# Losses (19/30) {'ner': 411.3688000677557}
# Losses (20/30) {'ner': 420.41035345885757}
# Losses (21/30) {'ner': 413.47846204106463}
# Losses (22/30) {'ner': 365.22585047420375}
# Losses (23/30) {'ner': 403.39692376903076}
# Losses (24/30) {'ner': 362.4690711737503}

# %%
spacy.displacy.render(nlp("Ich heisse Christian und war heute in Zürich bei IBM."), style="ent")
spacy.displacy.render(nlp("Wie viele Kühe hat die Gemeinde Bülach?"), style="ent")
spacy.displacy.render(nlp("Wie hoch ist Eigenkapital auf Bezirksebene?"), style="ent")
spacy.displacy.render(nlp("Ich brauche die Daten pro Bezirk"), style="ent")
spacy.displacy.render(nlp("Ich brauche die Daten für den gesamten Kanton."), style="ent")
spacy.displacy.render(nlp("Wie viel Bauinv. EFH 5 Jahre  hat  in Regensdorf  ?"), style="ent")
spacy.displacy.render(nlp("Was ist der Anteil an MIV-Anteil (Modal Split)   auf Bezirksebene ?"), style="ent")
spacy.displacy.render(nlp("Was ist der Anteil an Geb.Vol. Dienstleistungen: Zunahme   in Flaach ?"), style="ent")
spacy.displacy.render(nlp("Welches ist das Schül. Sekundarstufe II   für den gesamten Kanton ?"), style="ent")
spacy.displacy.render(nlp("Welche Gemeinde hat die grösste Bevölkerung?"), style="ent")

# %%
# dictionary to hold our evaluation data
stat_evaluation = {
    "locality": {
        "correct": 0,
        "total": 0,
    }
}

word_evaluation = {
    "locality": {
        "correct": 0,
        "total": 0
    }

}

for stat in TEST_STAT_DATA:
    # extract the sentence and correct stat entities according to our test data
    sentence = stat[0]
    entities = stat[1]["entities"]

    # for each entity, use our updated model to make a prediction on the sentence
    for entity in entities:
        doc = nlp(sentence)
        correct_text = sentence[entity[0]:entity[1]]
        n_worded_stat =  len(correct_text.split())

        # if we find that there's a match for predicted entity and predicted text, increment correct counters
        for ent in doc.ents:
            if ent.label_ == entity[2] and ent.text == correct_text:
                stat_evaluation["locality"]["correct"] += 1
                if n_worded_stat > 0:
                    word_evaluation["locality"]["correct"] += 1

                # this break is important, ensures that we're not double counting on a correct match
                break

        #  increment total counters after each entity loop
        stat_evaluation["locality"]["total"] += 1
        if n_worded_stat > 0:
            word_evaluation["locality"]["total"] += 1

# %%
for key in word_evaluation:
    correct = word_evaluation[key]["correct"]
    total = word_evaluation[key]["total"]

    print(f"{key}: {correct / total * 100:.2f}%")

stat_total_sum = 0
stat_correct_sum = 0

print("---")
for key in stat_evaluation:
    correct = stat_evaluation[key]["correct"]
    total = stat_evaluation[key]["total"]
    
    stat_total_sum += total
    stat_correct_sum += correct

    print(f"{key}: {correct / total * 100:.2f}%")

print(f"\nTotal: {stat_correct_sum/stat_total_sum * 100:.2f}%")

# %%
# dictionary which will be populated with the entities and result information
entity_evaluation = {}

# helper function to udpate the entity_evaluation dictionary
def update_results(entity, metric):
    if entity not in entity_evaluation:
        entity_evaluation[entity] = {"correct": 0, "total": 0}
    
    entity_evaluation[entity][metric] += 1

# same as before, see if entities from test set match what spaCy currently predicts
for data in TEST_REVISION_DATA:
    sentence = data[0]
    entities = data[1]["entities"]

    for entity in entities:
        doc = nlp(sentence)
        correct_text = sentence[entity[0]:entity[1]]

        for ent in doc.ents:
            if ent.label_ == entity[2] and ent.text == correct_text:
                update_results(ent.label_, "correct")
                break

        update_results(entity[2], "total")

# %%
sum_total = 0
sum_correct = 0

for entity in entity_evaluation:
    total = entity_evaluation[entity]["total"]
    correct = entity_evaluation[entity]["correct"]

    sum_total += total
    sum_correct += correct
    
    print("{} | {:.2f}%".format(entity, correct / total * 100))

print()
print("Overall accuracy: {:.2f}%".format(sum_correct / sum_total * 100))

# %%
nlp.meta["name"] = "stat_entity_extractor_v1"
nlp.to_disk("./models/v1")

# %%
TRAIN_STAT_DATA[5]

# %%
doc = nlp(u'Welche Gemeinde hat die grösste Bevölkerung?')

# show universal pos tags
print(' '.join('{word}/{tag}'.format(word=t.orth_, tag=t.pos_) for t in doc))
# output: Ich/PRON bin/AUX ein/DET Berliner/NOUN ./PUNCT

# show German specific pos tags (STTS)
print(' '.join('{word}/{tag}'.format(word=t.orth_, tag=t.tag_) for t in doc))
# output: Ich/PPER bin/VAFIN ein/ART Berliner/NN ./$.

# show dependency arcs
print('\n'.join('{child:<8} <{label:-^7} {head}'.format(child=t.orth_, label=t.dep_, head=t.head.orth_) for t in doc))
# output: (sb: subject, nk: noun kernel, pd: predicate)

#named entities
print("Named Entity Recognition:")
for ent in doc.ents:
    print(ent.text)
print("Noun chunks:")
for chunk in doc.noun_chunks:
    print(chunk.text)
