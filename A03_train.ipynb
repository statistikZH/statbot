# %%
from __future__ import print_function, unicode_literals
import spacy
import warnings
from spacy.util import minibatch, compounding
import de_core_news_lg
import pandas as pd
import numpy as np
from random import sample
import io, csv
import re
import random
import de_core_news_lg
import json
from spacy.training import Example
from spacy.tokens import Doc
nlp = spacy.load('de_core_news_lg')

# %%
# helper function for incrementing the revision counters
def increment_revision_counters(entity_counter, entities):
    for entity in entities:
        label = entity[2]
        if label in entity_counter:
            entity_counter[label] += 1
        else:
            entity_counter[label] = 1

# %%
#out_sentences=open("input/tagged_sentences.csv", "r").readlines()
with open('input/tagged_sentences.json') as json_file:
    out_sentences = json.load(json_file)
print("LENGTH OF DATASET: ",len(out_sentences))
dataset_dict={}

for sent in out_sentences:
    entities = sent[1]["entities"]
    increment_revision_counters(dataset_dict, entities)
#    print(entity[1])
    #helper_dict.append(entity[1]['entities'][0][2])
#out_sentences[:5]
print(dataset_dict)
# Out:
# LENGTH OF DATASET:  1020
# {'DATA': 1010, 'GRAN': 282}

# %%
npr_df = pd.read_csv("external/deu_news_2015_3M-sentences.txt", delimiter = "\t")
npr_df=npr_df.sample(frac=1)
npr_df.head()
# Out:
#                1                                                  ­
# 1207161  1269596  Er führte aus, wie er während seiner Ems-Amtsz...
# 411754    427638  Daher ist fraglich, wie repräsentativ die Erge...
# 1570656  1657722  Im vergangenen August machte sie bereits Gebra...
# 1206548  1268972  Er fordert: "Wettbewerb muss fair sein und bra...
# 1845540  1949795  Mit Thomas Hügli* sprach Dominique Eigenmann. ...

# %%
# create an nlp object as we'll use this to seperate the sentences and identify existing entities
#loaded already above
#nlp = spacy.load('de_core_news_lg')

# %%
revision_texts = []

# convert the articles to spacy objects to better identify the sentences. Disabled unneeded components. # takes ~ 4 minutes
for doc in nlp.pipe(npr_df.iloc[:100000,1], batch_size=30, disable=["tagger", "ner"]):
    for sentence in doc.sents:
        if  40 < len(sentence.text) < 80:
            # some of the sentences had excessive whitespace in between words, so we're trimming that
            revision_texts.append(" ".join(re.split("\s+", sentence.text, flags=re.UNICODE)))

# %%
revisions = []

# Use the existing spaCy model to predict the entities, then append them to revision
for doc in nlp.pipe(revision_texts, batch_size=50, disable=["tagger", "parser"]):
    
    # don't append sentences that have no entities
    if len(doc.ents) > 0:
        revisions.append((doc.text, {"entities": [(e.start_char, e.end_char, e.label_) for e in doc.ents]}))

# %%
# print an example of the revision sentence
print(revisions[0][0])

# print an example of the revision data
print(revisions[0][1])
# Out:
# Bente Kraus aus Berlin musste mit Rang zwölf zufrieden sein.
# {'entities': [(0, 11, 'PER'), (16, 22, 'LOC')]}

# %%
# create arrays to store the revision data
TRAIN_REVISION_DATA = []
TEST_REVISION_DATA = []

# create dictionaries to keep count of the different entities
TRAIN_ENTITY_COUNTER = {}
TEST_ENTITY_COUNTER = {}

# This will help distribute the entities (i.e. we don't want 1000 PERSON entities, but only 80 ORG entities)
REVISION_SENTENCE_SOFT_LIMIT = 100



random.shuffle(revisions)
for revision in revisions:
    # get the entities from the revision sentence
    entities = revision[1]["entities"]

    # simple hack to make sure spaCy entities don't get too one-sided
    should_append_to_train_counter = 0
    for _, _, label in entities:
        if label in TRAIN_ENTITY_COUNTER and TRAIN_ENTITY_COUNTER[label] > REVISION_SENTENCE_SOFT_LIMIT:
            should_append_to_train_counter -= 1
        else:
            should_append_to_train_counter += 1

    # simple switch for deciding whether to append to train data or test data
    if should_append_to_train_counter >= 0:
        TRAIN_REVISION_DATA.append(revision)
        increment_revision_counters(TRAIN_ENTITY_COUNTER, entities)
    else:
        TEST_REVISION_DATA.append(revision)
        increment_revision_counters(TEST_ENTITY_COUNTER, entities)

# %%
TRAIN_ENTITY_COUNTER
# Out:
# {'DATA': 101, 'PER': 114, 'ORG': 117, 'MISC': 116, 'LOC': 145, 'GRAN': 101}

# %%
TEST_ENTITY_COUNTER
# Out:
# {'PER': 7682, 'ORG': 6820, 'MISC': 7621, 'LOC': 7211, 'DATA': 573, 'GRAN': 76}

# %%
TRAIN_REVISION_DATA
# Out:
# [('Warum können die nicht reinschreiben ob man das für 30 oder 60 FPS braucht..',
#   {'entities': [(74, 76, 'DATA')]}),
#  ('Stefan Aust mag es, Einfluss zu haben und Einfluss zu nehmen.',
#   {'entities': [(0, 11, 'PER')]}),
#  ('Angela Merkel - herausragende Momente einer Kanzlerin dpa,',
#   {'entities': [(0, 13, 'PER')]}),
#  ('Titan Aerospace könnte fliegende Internet-Sendestationen bauen.',
#   {'entities': [(0, 15, 'ORG'), (33, 56, 'MISC')]}),
#  ('Persönliche Nachricht Hat der IS versucht, Geert Wilders zu ermorden?',
#   {'entities': [(30, 32, 'ORG'), (43, 56, 'PER')]}),
#  ('Die Ferien sind vorbei“ ist das Dolce far niente eher eine Bürde:',
#   {'entities': [(32, 37, 'MISC')]}),
#  ('Dann ließen die Mächtigen von Hannover 96',
#   {'entities': [(30, 41, 'ORG')]}),
#  (' 1915867 Minetti gilt als Schlüsselzeugin in der Ruby-Affäre.',
#   {'entities': [(26, 41, 'MISC'), (49, 60, 'MISC')]}),
#  ('Sie teilen sich das Fleisch mit den Löwen.',
#   {'entities': [(36, 41, 'ORG')]}),
#  ('Allein an der Elisabeth-Selbert-Straße sind 38 Plätze eingeplant.',
#   {'entities': [(14, 38, 'LOC')]}),
#  ('Annaburg ist zudem im Kreispokal gefordert.',
#   {'entities': [(0, 8, 'LOC'), (22, 32, 'MISC')]}),
#  ('Der PW-artige Kompaktwagen im Offroad-Look verkauft sich bestens.',
#   {'entities': [(30, 42, 'LOC')]}),
#  ('Zu fragen wäre auch, warum die Jihadisten zuhauf in Belgien hocken.',
#   {'entities': [(52, 59, 'LOC')]}),
#  ('Was ist der geheime Reiz, den die islamischen Kämpfer ausüben?',
#   {'entities': [(34, 45, 'MISC')]}),
#  ('Naja egal, dei Russen werden den IS innerhalb 4 Wochen Besiegt haben.',
#   {'entities': [(15, 21, 'MISC'), (33, 35, 'ORG')]}),
#  ('Ein Veteran sammelt für den Donbass Beliebt:',
#   {'entities': [(28, 43, 'ORG')]}),
#  ('Serie: Chefsache "Wer schläft, ist nicht faul"',
#   {'entities': [(7, 16, 'MISC')]}),
#  ('Den Preis wollte auch Azalea haben, die zwölfmal nominiert war.',
#   {'entities': [(22, 28, 'PER')]}),
#  ('Offenbar wurde der Atletico-Stürmer auch noch gebissen.',
#   {'entities': [(19, 35, 'PER')]}),
#  ('Haraguchi drückt den Ball aus kürzester Distanz über die Linie.',
#   {'entities': [(0, 9, 'PER')]}),
#  ('Das Blut ist nicht herausgespritzt wie in schlechten Hollywood-Filmen.',
#   {'entities': [(0, 8, 'MISC'), (53, 69, 'MISC')]}),
#  ('In diesem Ton geht es munter weiter in den Holstenhallen.',
#   {'entities': [(43, 56, 'LOC')]}),
#  ('«Uns ist Bundesliga und Europa League wichtig.',
#   {'entities': [(9, 19, 'ORG'), (24, 37, 'ORG')]}),
#  ('Dabei zeigten sich erneut Schwächen in Valencias Abwehr.',
#   {'entities': [(39, 48, 'LOC')]}),
#  ('Vielleicht ein Hinweis, wohin die Reise für den FC Wil gehen könnte.»',
#   {'entities': [(48, 54, 'ORG')]}),
#  ('2086840 Olympia ist schon weg und Bundesliga wollen die Vereine selbst machen.',
#   {'entities': [(8, 15, 'LOC'), (34, 44, 'ORG')]}),
#  ('Der Ferrari-Kontrakt von Sebastian Vettel läuft bis einschließlich der Saison',
#   {'entities': [(4, 20, 'MISC'), (25, 41, 'PER')]}),
#  ('Der Kanadier greift jedes Tor an, ist aggressiver als Brown zuvor.',
#   {'entities': [(4, 12, 'LOC'), (54, 59, 'PER')]}),
#  ('Cyndi Lauper geht mit gutem Beispiel voran:',
#   {'entities': [(0, 12, 'PER')]}),
#  ('Er ist Gemeindepräsident von Innertkirchen und Verwaltungsrat der KWO.',
#   {'entities': [(66, 69, 'ORG')]}),
#  ('Vor Fukushima wollte er unbefristet längere Laufzeiten für Atomkraftwerke.',
#   {'entities': [(4, 13, 'LOC')]}),
#  ('Bei der Valora-Gruppe ist schon seit November 2014 Roberto Fedele neuer CIO.',
#   {'entities': [(8, 21, 'LOC'), (51, 65, 'PER')]}),
#  ('Man darf den Reiz der Schweizer Liga nicht vergessen!»',
#   {'entities': [(22, 36, 'ORG')]}),
#  ("Formel 1: Motor an, Ampel aus, los geht's: Alles Wissenswerte über die Rennen.",
#   {'entities': [(0, 8, 'ORG')]}),
#  ('Korruptionsskandal: Fifa suspendiert Blatter und Platini für 90 Tage REUTERS',
#   {'entities': [(20, 24, 'ORG'), (37, 44, 'PER'), (49, 56, 'PER')]}),
#  ('In den 120 Jets der Swiss ist ab Juni ein Partime Sondermodell erhältlich.',
#   {'entities': [(20, 25, 'ORG')]}),
#  ('Den Mangel verwaltet Eskom, der staatliche Stromkonzern.',
#   {'entities': [(21, 26, 'ORG')]}),
#  ('S&P stuft Banco Santander und BBVA hoch, Ausblick stabil weitere Nachrichten zu',
#   {'entities': [(0, 3, 'ORG'), (10, 25, 'ORG'), (30, 34, 'ORG')]}),
#  ('Ganz normal, meint Principato, der Entomologe aus Perugia.',
#   {'entities': [(19, 29, 'PER'), (50, 57, 'LOC')]}),
#  ('LKW-Maut Dobrindt sagt mehr Geld für marode Brücken zu Marode',
#   {'entities': [(0, 17, 'PER'), (55, 61, 'LOC')]}),
#  ('MamablogKinder lernen bereits im Vorschulalter schwimmen.',
#   {'entities': [(0, 14, 'ORG')]}),
#  ('Der Breitenrainplatz ist das Kernstück des Grossprojektes.',
#   {'entities': [(4, 20, 'LOC')]}),
#  ('Am Freitagabend besiegte sie die Schweiz mit 5:2 (3:0).',
#   {'entities': [(33, 40, 'LOC')]}),
#  ('Balancing: Gegner lassen mehr Bier & Gold fallen.',
#   {'entities': [(0, 9, 'PER')]}),
#  ('In den Alpen gab es in den letzten Tagen den meisten Schneefall.',
#   {'entities': [(7, 12, 'LOC')]}),
#  ('Frau Merkel hat eine spannende Biographie.',
#   {'entities': [(5, 11, 'PER')]}),
#  ('Romain Grosjean: Wir können uns gut schlagen.',
#   {'entities': [(0, 15, 'PER')]}),
#  ('Pro Minute in der Schwitzkammer verlieren Menschen 20 bis 30 Gramm Schweiß.',
#   {'entities': [(0, 10, 'ORG')]}),
#  ('Und diesbezüglich hat Arndt wahre Wunder vollbracht.',
#   {'entities': [(22, 27, 'PER')]}),
#  ('Verbaut ist ein Qualcomm-Snapdragon-Prozessor mit 1,4 Gigahertz.',
#   {'entities': [(16, 45, 'MISC')]}),
#  ('Aber nicht, um dort Ferrari zu besuchen, wie mich viele schon gefragt haben.',
#   {'entities': [(20, 27, 'ORG')]}),
#  ('um 10:36 von Mathias Küng Wissen was in der Region läuft?',
#   {'entities': [(13, 25, 'PER'), (44, 50, 'GRAN')]}),
#  (' 2459985 Unser Mann für Hamburg" stand da drauf.',
#   {'entities': [(24, 31, 'LOC')]}),
#  ('Und die kann der Sportverein nicht bezahlen, wie Ewald Matejka sagt: "',
#   {'entities': [(49, 62, 'PER')]}),
#  ('Ansonsten sollten Unternehmen von einem Projektvorgehen mit Scrum absehen.',
#   {'entities': [(60, 65, 'MISC')]}),
#  ('Wenigstens die Gleise nach Markkleeberg sollen erhalten bleiben',
#   {'entities': [(0, 10, 'LOC'), (27, 39, 'LOC')]}),
#  ('Ägypten-Experte der Stiftung Wissenschaft und Politik',
#   {'entities': [(20, 53, 'ORG')]}),
#  ('Der Herbstmeister startet mit einem 2:0-Sieg in Wr.',
#   {'entities': [(48, 50, 'LOC')]}),
#  ('Am Mittwoch kam er in Berlin an, wo die beiden leben.',
#   {'entities': [(22, 28, 'LOC')]}),
#  ('Ein Wasserrohrbruch setzte Wien-Floridsdorf unter Wasser.',
#   {'entities': [(27, 43, 'LOC')]}),
#  ('Dabei lässt sich die eigene Musiksammlung in…',
#   {'entities': [(44, 45, 'LOC')]}),
#  ('Demi Lovato hat ihren Fans versichert, dass sie wohlauf ist.',
#   {'entities': [(0, 11, 'PER')]}),
#  ('Liga sagt Vaduz gegen Sion ab 19. Spieltag:',
#   {'entities': [(10, 15, 'LOC'), (22, 26, 'ORG')]}),
#  ('Als Dividendenperle gilt hierzulande auch die Aktie von Valora.',
#   {'entities': [(56, 62, 'ORG')]}),
#  ('Zum Unglück von Bayern und dem Rest der Republik.',
#   {'entities': [(16, 22, 'LOC'), (40, 48, 'LOC')]}),
#  ('Dabei bräuchte Griechenland so dringend einen Modernisierungsschub.',
#   {'entities': [(15, 27, 'LOC')]}),
#  ('KURIER/Karl Schöndorfer Heinz Bachheimer (rechts) ist tot',
#   {'entities': [(0, 6, 'ORG'), (7, 23, 'PER'), (24, 40, 'PER')]}),
#  ('Laut den türkischen Behörden sind die Ermittlungen noch nicht abgeschlossen.',
#   {'entities': [(9, 19, 'MISC')]}),
#  ('Bei einer Parade gerät eine Figur von Fernsehheld Barney außer Kontrolle.',
#   {'entities': [(38, 56, 'PER')]}),
#  ('Umso eindringlicher warnt Bachmann bei Facebook davor, nach Dresden zu kommen.',
#   {'entities': [(26, 34, 'PER'), (39, 47, 'MISC'), (60, 67, 'LOC')]}),
#  ('Deutschland habe in dieser Frage eine "Vielzahl von Verbündeten".',
#   {'entities': [(0, 11, 'LOC')]}),
#  ('Eine Rennsimulation ist Bradl am Freitag nicht gefahren.',
#   {'entities': [(24, 29, 'PER')]}),
#  ('Er hatte ein Stück Draht vom 1989 abgebauten Eisernen Vorhang mit.',
#   {'entities': [(45, 61, 'MISC')]}),
#  ('Die Kursanstiege im Nikkei wurden allerdings durch Gewinnmitnahmen begrenzt.',
#   {'entities': [(20, 26, 'ORG')]}),
#  ('Krawalle zwischen Flüchtlingen und Polizei auf Lesbos',
#   {'entities': [(47, 53, 'LOC')]}),
#  ('Das Thema spaltet die Koalition von SPD und CDU.',
#   {'entities': [(36, 39, 'ORG'), (44, 47, 'ORG')]}),
#  ('Der dumme Fan ist nut noch Füllmenge und zahlt den ganzen Mist!',
#   {'entities': [(0, 13, 'MISC')]}),
#  ('Dann muss ich leider sagen hast du Crowfunding nicht verstanden.',
#   {'entities': [(35, 46, 'MISC')]}),
#  ('Die SCL Tigers kämpfen in der NLA weiterhin unglücklich.',
#   {'entities': [(4, 14, 'ORG'), (30, 33, 'ORG')]}),
#  ('Das klingt erst einmal abstrakt, aber Andres hat anschauliche Beispiele.',
#   {'entities': [(38, 44, 'PER')]}),
#  ('Renegade X in meine Sammlung aufnehmen in meine Wunschliste aufnehmen',
#   {'entities': [(0, 10, 'MISC')]}),
#  ('Auf Tore muss in Düsseldorf deshalb also nicht verzichtet werden.',
#   {'entities': [(17, 27, 'LOC')]}),
#  ('Das Risiko, dass die Mutter bei der Geburt stirbt, steige um das Dreifache.',
#   {'entities': [(65, 75, 'DATA')]}),
#  ('Der Herr aus dem obigen Bericht ist beileibe kein Einzelfall.',
#   {'entities': [(0, 8, 'MISC')]}),
#  ('Die Schweizer sind so reich wie noch nie.',
#   {'entities': [(4, 13, 'MISC')]}),
#  ('mehr „Spiegel”: Milliarden-Rechenfehler im Verteidigungsministerium Berlin.',
#   {'entities': [(6, 13, 'ORG'), (16, 39, 'ORG'), (43, 74, 'ORG')]}),
#  ('Der Bulli ist Teil des kollektiven deutschen Gedächtnisses.',
#   {'entities': [(4, 9, 'ORG'), (35, 44, 'MISC')]}),
#  ('Doch dann trennt sich Karin plötzlich von Rolf, denn ihr wird alles zu eng.',
#   {'entities': [(22, 27, 'PER'), (42, 46, 'PER')]}),
#  ('Börsenseminare – speziell für Privatanleger.',
#   {'entities': [(0, 14, 'PER')]}),
#  ('Ich war auch nach den letzten Wochen richtig motiviert", sagte Geisenberger.',
#   {'entities': [(63, 75, 'PER')]}),
#  ('In der Küche im Parterre dieses Hauses fand Simon S. seine toten Eltern.',
#   {'entities': [(44, 52, 'PER')]}),
#  ('Und dann schauen sie sich mal den alten "The Mummy" mit Boris Karloff an.',
#   {'entities': [(41, 50, 'ORG'), (56, 69, 'PER')]}),
#  ('Der westafrikanische Staat ist am meisten von der Seuche betroffen.',
#   {'entities': [(4, 20, 'MISC')]}),
#  ('Studie: Englische Spieler haben schlechte Zähne',
#   {'entities': [(8, 17, 'MISC')]}),
#  ('Das russische Militär fliegt seit vergangenem Mittwoch Luftangriffe in Syrien.',
#   {'entities': [(4, 13, 'MISC'), (71, 77, 'LOC')]}),
#  ('Es ist für mich sehr positiv, dass ich bei Citroen weitermachen darf.',
#   {'entities': [(43, 50, 'ORG')]}),
#  ('Vodafone: VoLTE mit iPhone 6 und 6 Plus jetzt möglich',
#   {'entities': [(0, 8, 'ORG'), (10, 15, 'MISC'), (20, 28, 'MISC')]}),
#  ('ONLINE: Sie lassen Ihre Fotos entwickeln?', {'entities': [(0, 6, 'ORG')]}),
#  ('Abschließend fuhren die Golden State Warriors ihren elften Sieg in Folge ein.',
#   {'entities': [(24, 45, 'ORG')]}),
#  ('HANA: Ah ja, die Melodie haben hier einige Schauspieler auf dem Handy.',
#   {'entities': [(0, 4, 'MISC'), (6, 8, 'MISC')]}),
#  ('Damit sind wir ganz sicher kein Schlusslicht, sagte Flasbarth.',
#   {'entities': [(52, 61, 'PER')]}),
#  ('Dort beträgt die Kaufkraft des Euro nur etwa 57 Cent.',
#   {'entities': [(31, 35, 'MISC')]}),
#  ('Goldman Sachs bleibt Dibelius allerdings erhalten.',
#   {'entities': [(0, 13, 'PER'), (21, 29, 'PER')]}),
#  ('Geschminkt wurde Conchita für das Shooting wie ein Indi-Rockstar.',
#   {'entities': [(0, 10, 'PER'), (17, 25, 'PER'), (51, 65, 'DATA')]}),
#  ('Lara Gut motzt über die WM-Organisation «',
#   {'entities': [(0, 8, 'PER'), (24, 39, 'MISC')]}),
#  ('Ein White Paper, ein Film und eine Website geben zusätzliche Energietipps.',
#   {'entities': [(4, 15, 'MISC')]}),
#  ('Die Kriminalpolizei Erding hat die Sachbearbeitung übernommen.',
#   {'entities': [(20, 26, 'LOC')]}),
#  ('Wie Flüchtlinge in Schweden in einem 20-Seelen-Dorf leben',
#   {'entities': [(19, 27, 'LOC')]}),
#  ('Das finden wir weniger gut am HP Color Laserjet Pro MFP M277dw',
#   {'entities': [(30, 38, 'ORG')]}),
#  ('Marc Gabriel, Aktienanalyst des Bankhauses Lampe, empfahl die Aktie zu kaufen.',
#   {'entities': [(0, 12, 'PER'), (32, 48, 'ORG')]}),
#  ('Dünne Schleierwolken stören den sonnigen Wettercharakter nur zeitweise.',
#   {'entities': [(0, 20, 'MISC'), (41, 56, 'LOC')]}),
#  ('Eine Kritik der Sendung lesen Sie auf welt.de.',
#   {'entities': [(38, 45, 'MISC')]}),
#  ('Alpenglühen mit Stars bei der Formula Snow',
#   {'entities': [(30, 42, 'MISC')]}),
#  ('Die Zeit sei die anstrengendste und belastendste Zeit für die Mitarbeiter.',
#   {'entities': [(4, 8, 'MISC'), (49, 53, 'MISC')]}),
#  ('Indes rechnet sich der Außenseiter durchaus Chancen aus.',
#   {'entities': [(0, 5, 'ORG')]}),
#  ('ORF.at Frau bei Frontalcrash ums Leben gekommen',
#   {'entities': [(0, 6, 'MISC'), (16, 28, 'ORG')]}),
#  ('Wissenswertes über iPhone, iPad und die Android-Alternativen.',
#   {'entities': [(19, 25, 'MISC'), (27, 31, 'MISC'), (40, 60, 'ORG')]}),
#  ('260.000 sind lt. UN abgeschlachtet b.z.w. ermordet worden.',
#   {'entities': [(17, 19, 'ORG')]}),
#  ('Steinegger wird primär für die Defensive zuständig sein.',
#   {'entities': [(0, 10, 'PER')]}),
#  ('Die Stimmen der Schweizer am Weltklasse Zürich',
#   {'entities': [(16, 25, 'MISC'), (29, 46, 'ORG')]}),
#  ('Eine Task Force begann mit der Fehlersuche.',
#   {'entities': [(5, 15, 'ORG')]}),
#  ('Der FC Schalke setzt seine durchwachsene Saison fort:',
#   {'entities': [(4, 14, 'ORG')]}),
#  ('Samsung-Handys sollen also endlich sexy werden.',
#   {'entities': [(0, 14, 'PER')]}),
#  ('Meinen Respekt hat sie jedenfalls - obwohl es ja nur die Einliegerwohnung ist..',
#   {'entities': [(77, 79, 'LOC')]}),
#  ('Lenovo/Motorola kommt auf Platz fünf mit 8,3 Prozent.',
#   {'entities': [(0, 6, 'ORG'), (7, 15, 'ORG')]}),
#  ('Es ist der erste Auftritt der Fürstenkinder jenseits der Palastmauern.',
#   {'entities': [(30, 43, 'MISC'), (57, 69, 'LOC')]}),
#  ('Das ist kein Geheimnis, das gilt auch für den VfB Eichstätt und seine Gegner.',
#   {'entities': [(46, 59, 'ORG')]}),
#  ('Mehr als jede fünfte Stimme (21,1 Prozent) ging an die Rechtspopulisten.',
#   {'entities': [(0, 4, 'PER')]}),
#  ('Mönchengladbach Spaziergänger findet Messer in Tatort-Nähe Fotos:',
#   {'entities': [(0, 15, 'LOC'), (47, 58, 'MISC')]}),
#  ('PC Fritz: Handel mit gefälschter Software (Bild: PC Fritz/Screenshot: Golem.',
#   {'entities': [(0, 8, 'MISC'), (49, 57, 'MISC'), (70, 75, 'MISC')]}),
#  ('Sandhausen: Vertrag des Angreifers läuft aus Jovanovics Bewerbungsschreiben',
#   {'entities': [(0, 10, 'LOC'), (12, 34, 'MISC'), (45, 55, 'PER')]}),
#  ('Nur aus den USA, Russland und Frankreich kamen mehr Gäste nach Israel.',
#   {'entities': [(12, 15, 'LOC'),
#     (17, 25, 'LOC'),
#     (30, 40, 'LOC'),
#     (63, 69, 'LOC')]}),
#  ('Sergio Ramos wird Real Madrid wohl im Sommer verlassen.',
#   {'entities': [(0, 12, 'PER'), (18, 29, 'ORG')]}),
#  ('Immer wieder geht der Belgier auf die Hamburger Abwehrspieler drauf.',
#   {'entities': [(22, 29, 'LOC'), (38, 47, 'MISC')]}),
#  ('5. Wir brauchen dringend eine Männerquote auf Sachbearbeiterebene',
#   {'entities': [(46, 65, 'LOC')]}),
#  ('Baumgartner bietet ab sofort Weißbierlinie an SCHÄRDING.',
#   {'entities': [(0, 11, 'PER'), (46, 56, 'DATA')]}),
#  ('Den Bloedsinn wollen nicht alle mitmachen - wer kann es ihnen veruebeln?',
#   {'entities': [(4, 13, 'LOC')]}),
#  ('Die Fahnder waren ihnen vom Raum Backnang aus gefolgt.',
#   {'entities': [(33, 41, 'LOC')]}),
#  ('Bis März 2015 waren chinesische Kampfjets nie dorthin geflogen.“',
#   {'entities': [(20, 31, 'MISC')]}),
#  ('Er versucht ja schon die ganze Zeit, unter seine Haut zu kriechen.',
#   {'entities': [(31, 35, 'MISC')]}),
#  ('Produktion und Verkauf am selben Ort (Bild: Werner Pluta/Golem.',
#   {'entities': [(44, 56, 'PER'), (57, 62, 'MISC')]}),
#  ('Youtube Music ist vorerst nur in den USA verfügbar.',
#   {'entities': [(0, 13, 'ORG'), (37, 40, 'LOC')]}),
#  ('Kiplagat nahm seine Aufgabe relativ locker.',
#   {'entities': [(0, 8, 'PER')]}),
#  ('Hartmann sagt vor dem Ausschuss die Unwahrheit;',
#   {'entities': [(0, 8, 'PER')]}),
#  ('Was wiederum Soziallandesrätin Gertraud Jahn (SP) erzürnte.',
#   {'entities': [(13, 30, 'PER'), (31, 44, 'PER'), (46, 48, 'ORG')]}),
#  ('Das Haus war bombardiert worden, sagte Rudolf Pfeifer.',
#   {'entities': [(39, 53, 'PER')]}),
#  ('Mit HyperCam 4 wird das Abfilmen Ihres Bildschirms zum Kinderspiel.',
#   {'entities': [(4, 14, 'MISC'), (24, 67, 'DATA')]}),
#  ('Weltfrieden ist wohl etwas viel verlangt.', {'entities': [(0, 11, 'PER')]}),
#  (' 2675572 Wird es hier auf 4P einen Test zum Titel geben?',
#   {'entities': [(26, 28, 'LOC')]}),
#  ('Auch für Games soll die Plattform attraktiver werden.',
#   {'entities': [(9, 14, 'MISC')]}),
#  ('Der von Pegida selbsterklärte "Volkszorn" kann sich jederzeit entladen.',
#   {'entities': [(8, 14, 'ORG')]}),
#  ('Im breiten Markt ermässigen sich Sulzer um 1,6 Prozent.',
#   {'entities': [(33, 39, 'PER')]}),
#  ('Ein Krieg, der weit weg von ihrer Haustüre und auf Kosten Europas ist.',
#   {'entities': [(58, 65, 'LOC')]}),
#  ('Geht jetzt für Dynamo Dresden auf Torejagd:',
#   {'entities': [(15, 29, 'ORG')]}),
#  ('Der FC Bayern München hat sich verändert.', {'entities': [(4, 21, 'ORG')]}),
#  ('Bis zu seinem Ausscheiden habe es nur die Swap-Verluste gegeben.',
#   {'entities': [(42, 55, 'MISC')]}),
#  ('Ein Dortmunder schießt Deutschland ins EM-Finale',
#   {'entities': [(4, 14, 'MISC'), (23, 34, 'LOC'), (39, 48, 'MISC')]}),
#  ('Die Tiefsee ist ein äusserst empfindlicher Lebensraum – der befischt wird.',
#   {'entities': [(4, 11, 'LOC')]}),
#  ('Befinden sich auf einem guten Weg: Bender (re.) und Bellarabi (li.',
#   {'entities': [(35, 41, 'PER'), (52, 61, 'PER')]}),
#  ('Eine Panne kommt immer zur falschen Zeit.',
#   {'entities': [(36, 40, 'MISC')]}),
#  ('Top-News Indirekt auf Dividendenperlen setzen',
#   {'entities': [(0, 17, 'PER')]}),
#  ('Noch ist nicht klar, wie genau die Omega-3-Fettsäuren wirken.',
#   {'entities': [(35, 53, 'MISC')]}),
#  ('Auch der Nahverkehr um den Bahnhof kam nach 20 Uhr für Stunden zum Erliegen.',
#   {'entities': [(27, 34, 'LOC')]}),
#  ('Im März folgen die nächsten Gratis-Spiele.',
#   {'entities': [(28, 41, 'MISC')]}),
#  ('Bislang kann Samsung noch keine Internet-of-Things-Geräte (IoT) präsentieren.',
#   {'entities': [(13, 20, 'ORG'), (32, 57, 'MISC'), (59, 62, 'MISC')]}),
#  ('Es liegt an Gruppen, Vereinen und Einzelnen, den Hass der anderen aufzufangen.',
#   {'entities': [(49, 53, 'PER')]}),
#  ('Hossein Hamedani hat die syrische Armee beim Kampf gegen den IS beraten.',
#   {'entities': [(0, 16, 'PER'), (25, 39, 'ORG'), (61, 63, 'ORG')]}),
#  ('Mit der Kamera in der ungarischen Stadt Bicske',
#   {'entities': [(22, 33, 'MISC'), (34, 39, 'LOC'), (40, 46, 'LOC')]}),
#  ('Robohon kann auch zu Musik tanzen und laufen.',
#   {'entities': [(0, 7, 'LOC')]}),
#  ('Das hatte auch schon Innenminister Thomas de Maizière gefordert.',
#   {'entities': [(35, 53, 'PER')]}),
#  ('Eine Teilung gibt es auch in Calama, aber eine ökonomische.',
#   {'entities': [(5, 12, 'MISC'), (29, 35, 'LOC')]}),
#  ('In Großbritannien werden gerade grundsätzliche Fragen ausgehandelt:',
#   {'entities': [(3, 17, 'LOC')]}),
#  ('Der neue Trading Desk der Börse Stuttgart.',
#   {'entities': [(32, 41, 'ORG')]}),
#  ('In drei Finals keinen Titel gewonnen zu haben, ärgerte ihn.',
#   {'entities': [(8, 14, 'MISC')]}),
#  ('Das NM-i155x Kit ist abwärtskompatibel zu den meisten Noctua Kühlern seit 2005.',
#   {'entities': [(4, 16, 'MISC'), (54, 68, 'PER')]}),
#  ('Vielmehr sieht es nun nach dem zweiten Gesamtsieg für Al-Attyiah aus.',
#   {'entities': [(54, 64, 'PER')]}),
#  ('Auch Chefdirigent Meister, dessen Vertrag bis 2018 verlängert wurde.',
#   {'entities': [(34, 50, 'MISC')]}),
#  ('Wir schauen uns das Profil noch immer an, sagte FBI-Mann David Bowdich.',
#   {'entities': [(48, 56, 'ORG'), (57, 70, 'PER')]}),
#  ('Belgien bleibt aber drei Punkte hinter Leader Wales.',
#   {'entities': [(0, 7, 'LOC'), (46, 51, 'ORG')]}),
#  ('Und so kann noch etwas passieren, wenn sich Russland noch erholt.',
#   {'entities': [(44, 52, 'LOC')]}),
#  ('Ilicevic laboriert an Adduktorenbeschwerden.',
#   {'entities': [(0, 8, 'PER'), (22, 43, 'PER')]}),
#  ('Der Titel für PC und Mac soll Anfang 2016 erscheinen;',
#   {'entities': [(14, 16, 'MISC'), (21, 24, 'MISC')]}),
#  ('DGAP-News: Halloren Schokoladenfabrik AG:',
#   {'entities': [(0, 9, 'ORG'), (11, 19, 'LOC')]}),
#  ('Maxime Martin erlebte in Moskau ein perfektes Wochenende.',
#   {'entities': [(0, 13, 'PER'), (25, 31, 'LOC')]}),
#  ('"Sagtest du nicht, der chinesische Rechtsstaat sei perfekt?',
#   {'entities': [(1, 11, 'ORG'), (23, 34, 'MISC')]}),
#  ('Aktuelle DSL-Angebote, DSL-Technik und mehr:',
#   {'entities': [(9, 21, 'MISC'), (23, 34, 'MISC')]}),
#  ('Laut Renn gibt es drei Gründe für diese unverhältnismäßig große Angst.',
#   {'entities': [(5, 9, 'PER')]}),
#  ('Das ist ein Roma-Wort und bedeutet Traum.',
#   {'entities': [(12, 40, 'DATA')]}),
#  ('Aktuelle Beiträge aus dem Polizei-Ressort Fassaden der Hauptstadt Leserbilder:',
#   {'entities': [(26, 41, 'LOC'), (66, 77, 'LOC')]}),
#  ('So gehts: Ihr Video schicken Sie per Wetransfer-Upload (wetransfer.',
#   {'entities': [(37, 54, 'MISC')]}),
#  ('Rückversicherung AG: Neues 26-Wochenhoch (96.91 Euro, Long)',
#   {'entities': [(0, 19, 'ORG'), (54, 58, 'ORG')]}),
#  ('Jaunt will die Kamera ab August 2015 anbieten.',
#   {'entities': [(0, 5, 'PER')]}),
#  ('Der Nikkei 225 steigt in Landeswährung massiv, verliert aber in Fremdwährung.',
#   {'entities': [(4, 14, 'LOC')]}),
#  ('Dies berichtet die Technik-Website Anandtech.',
#   {'entities': [(19, 44, 'MISC')]}),
#  ('Zum Beispiel hatten Rickli und Gregor einen Glacestand an der Zumikoner Chilbi.',
#   {'entities': [(20, 26, 'PER'), (31, 37, 'PER'), (62, 78, 'DATA')]}),
#  ('Ganz knapp landet Wawrinkas Schlag neben der Linie.',
#   {'entities': [(18, 27, 'PER')]}),
#  ('DFB prüft laut Medienbericht Strafanzeige gegen Zwanziger',
#   {'entities': [(0, 3, 'ORG')]}),
#  ('Zitat von metacortexxDer wahre Grund sind doch einfach die Zulieferer.',
#   {'entities': [(10, 24, 'MISC')]}),
#  ('Rosetta war zehn Jahre zu dem Kometen 67P/Tschurjumow-Gerasimenko unterwegs.',
#   {'entities': [(0, 7, 'MISC'), (38, 41, 'MISC'), (42, 65, 'PER')]}),
#  ('ECLISO für eine effiziente Informationsverwaltung.',
#   {'entities': [(0, 6, 'ORG')]}),
#  ('Nicht alle Kinder ziehen sich zurück, so wie Mara.',
#   {'entities': [(45, 49, 'PER')]}),
#  ('Die kleinsten Krümel finden sich in abgelegenen Gebieten nahe dem Nordpol.',
#   {'entities': [(66, 73, 'LOC')]}),
#  ('Die Baustelle auf dem Hernalser Gürtel soll bis zum Ende der Woche fertig sein.',
#   {'entities': [(22, 38, 'LOC')]}),
#  ('Menschliches Leben ist keine Verhandlungsmasse.',
#   {'entities': [(0, 18, 'MISC')]}),
#  ('Im Gegensatz zum Blutbad in der Redaktion des französischen Satiremagazins «',
#   {'entities': [(46, 59, 'MISC')]}),
#  ('Peking nimmt Journalisten und Aufseher wegen Börsencrash fest',
#   {'entities': [(0, 6, 'LOC'), (45, 56, 'ORG')]}),
#  ('Facts 2.0: Das Newsnetzwerk taz.de - Deutschland',
#   {'entities': [(0, 9, 'MISC'), (15, 34, 'ORG'), (37, 48, 'LOC')]}),
#  ('Das geht aus einem Bericht des englischen Fachmagazins "Autosport" hervor.',
#   {'entities': [(31, 41, 'MISC')]}),
#  ('Mehr Gewicht will er der Sicherheitspolitik geben.',
#   {'entities': [(0, 12, 'MISC')]}),
#  ('Auch Mitterndorf ist weiterhin im Gespräch.',
#   {'entities': [(5, 16, 'LOC')]}),
#  ('«Beeindruckend ruhig» sei das alles vonstatten gegangen.',
#   {'entities': [(1, 14, 'LOC')]}),
#  ('Ulas S. (25) wurde zu 26 Monaten teilbedingt verurteilt.',
#   {'entities': [(0, 7, 'PER')]}),
#  ('DeinBus.de lädt zur Taufe eines Fernbusses auf den Namen Claus Weselsky.',
#   {'entities': [(0, 10, 'PER'), (57, 71, 'PER')]}),
#  ('Die Gang Sondame posiert auf der Zürcher Langstrasse.',
#   {'entities': [(33, 52, 'LOC')]}),
#  ('Der Goldpreis war in dieser Zeit um 1,7% gefallen.',
#   {'entities': [(28, 32, 'MISC')]}),
#  ('Hirscher feierte den insgesamt 34. Weltcupsieg, den 16. in einem Riesenslalom.',
#   {'entities': [(0, 8, 'PER')]}),
#  ('Cisco woll damit, das Angebot im Bereich Daten und Datenanalyse ausbauen.',
#   {'entities': [(0, 5, 'ORG')]}),
#  ('Brenntag übernimmt spanischen Chemiedistributeur',
#   {'entities': [(19, 29, 'MISC')]}),
#  ('Das Rückspiel findet am 21. April in München statt.',
#   {'entities': [(37, 44, 'LOC')]}),
#  ('Company of Heroes 2: Master Collection-Trailer',
#   {'entities': [(0, 19, 'ORG')]}),
#  ('Es hat immer Spaß gemacht, mit Frank zusammenzuarbeiten.“',
#   {'entities': [(31, 36, 'PER')]}),
#  ('Sie will Schwarz-Rot-Gold nicht Pegida überlassen.',
#   {'entities': [(9, 25, 'ORG'), (32, 38, 'ORG')]}),
#  ('Den Bio-Burger werde es zunächst aber nur für acht Wochen geben.',
#   {'entities': [(4, 14, 'LOC')]}),
#  ('Ausländerbeirat Dresden: Anfeindungen nehmen seit Pegida zu',
#   {'entities': [(16, 23, 'LOC'), (50, 56, 'ORG')]}),
#  ('Samake führte aus, er sei sich sicher, dass es nur zwei Angreifer gegeben habe.',
#   {'entities': [(0, 6, 'PER')]}),
#  ('Katja zeigt die Scorpions, wie sie wirklich sind.',
#   {'entities': [(0, 5, 'PER'), (16, 25, 'ORG')]}),
#  ('Serie: Arbeitsrechtskolumne Kann ein Job einfach so wegfallen?',
#   {'entities': [(7, 27, 'PER')]}),
#  ('Ist doch alles abgesprochen zwischen der EZB, Bruessel und dem Gerichtshof!',
#   {'entities': [(0, 14, 'MISC'),
#     (41, 44, 'ORG'),
#     (46, 54, 'ORG'),
#     (63, 75, 'ORG')]}),
#  ('Da sage noch einer, die Bayern nehmen auf jeden Fall die Schale mit.',
#   {'entities': [(24, 30, 'LOC')]}),
#  ('Enttäuscht zeigten sich die Investoren dagegen von den Ergebnissen von Kellog.',
#   {'entities': [(71, 77, 'PER')]}),
#  ('Da ist die NATO voll in seinem Revier - wehrlose überfallen.',
#   {'entities': [(11, 15, 'ORG')]}),
#  ('Die FDP hat nie ein Hehl daraus gemacht, dass das ihre Politik ist.',
#   {'entities': [(4, 7, 'ORG')]}),
#  ('Nur Channel Chronik durchsuchen Aussendersuche',
#   {'entities': [(4, 11, 'ORG'), (32, 46, 'DATA')]}),
#  ('Selbstfahrender Lkw von Daimler auf Testfahrt',
#   {'entities': [(24, 31, 'ORG')]}),
#  ('Fuck ist eine grosse Nummer im kanadischen College-Basketball.',
#   {'entities': [(31, 42, 'MISC'), (43, 61, 'LOC')]}),
#  ('Der neue Polizeipräsident Ralf Martin Meyer wurde in sein Amt eingeführt.',
#   {'entities': [(26, 43, 'PER')]}),
#  ('Nach Rekordkälte im US-Osten droht gefährliches Eis',
#   {'entities': [(20, 28, 'ORG')]}),
#  ('Auch Zinnbauers Zukunft ist völlig unklar.',
#   {'entities': [(5, 15, 'PER')]}),
#  ('Heute trainiert er einen andern Zweitligisten, den EHC Bassersdorf.',
#   {'entities': [(32, 45, 'ORG'), (51, 66, 'ORG')]}),
#  ('Tipp: das Bild anklicken um den Code neu zu generieren',
#   {'entities': [(0, 4, 'PER')]}),
#  ('Wer die Zeit der Tulpenblüte voll auskosten will, fährt in die Niederlande:',
#   {'entities': [(8, 12, 'MISC'), (17, 28, 'LOC'), (63, 74, 'LOC')]}),
#  ('Gemarkung Rottenburg: Verkehrsunfall BAB 81 mit mehreren Verletzten',
#   {'entities': [(0, 9, 'GRAN'), (10, 20, 'LOC')]}),
#  ('Der Europäische Gerichtshof hat jetzt entschieden.',
#   {'entities': [(4, 27, 'ORG')]}),
#  ('Das hat sich heute Saskia Veenenbos für uns angesehen.',
#   {'entities': [(19, 35, 'PER')]}),
#  ('Ich würde mich gerne noch weiter in die Materie DTM hineinarbeiten',
#   {'entities': [(48, 51, 'MISC')]}),
#  ('Zuvor hatte die «Hannoversche Allgemeine Zeitung» (HAZ) darüber berichtet.',
#   {'entities': [(17, 48, 'ORG'), (51, 54, 'ORG')]}),
#  ('Oder gehöhren die zum Staats Fernsehen so wie dieser Manta Manta Prolet?',
#   {'entities': [(22, 38, 'ORG'), (53, 72, 'MISC')]}),
#  ('Die Niedersachsen kassierten die vierte Pleite in Serie.',
#   {'entities': [(4, 17, 'LOC')]}),
#  ('Außerdem steckt noch viel mehr in der Süßholzwurzel:',
#   {'entities': [(38, 51, 'LOC')]}),
#  ('Neu: der Faktor-Zertifikate-Finder der Börse Stuttgart.',
#   {'entities': [(0, 3, 'MISC'), (9, 34, 'MISC'), (39, 54, 'ORG')]}),
#  ('Anbieter und Marktplätze für Machine Learning',
#   {'entities': [(29, 45, 'ORG')]}),
#  ('Er führte Deutschland durch eine wirtschaftliche Stabilisierung.',
#   {'entities': [(10, 21, 'LOC')]}),
#  ('Mit dem Kopf gelingt ihm das 2:0 im Test gegen die Niederlande – Endstand',
#   {'entities': [(51, 62, 'LOC')]}),
#  ('Maximilian hatte ohnehin kein Übergewicht.',
#   {'entities': [(0, 10, 'PER')]}),
#  ('Derzeit lehnt noch die große Mehrheit Bankgeschäfte über Amazon oder Google ab.',
#   {'entities': [(57, 63, 'ORG'), (69, 75, 'MISC')]}),
#  ('des Olli Dittrich Panorama Verstehen Sie Spaß?',
#   {'entities': [(4, 17, 'PER')]}),
#  ('Bester Schweizer auf der vierten Etappe ist Silvan Dillier.',
#   {'entities': [(7, 16, 'MISC'), (44, 58, 'PER')]}),
#  ('ÖSTERREICH führte einen VERTEIDIGUNGSKRIEG, an allen Fronten.',
#   {'entities': [(0, 10, 'ORG'), (24, 42, 'ORG')]}),
#  ('Vor wenigen Tagen hatte Fenniger dem Verband mit ihrem Rücktritt gedroht:',
#   {'entities': [(24, 32, 'PER')]}),
#  ('Hecken tritt dafür ein, für die alte 116b-Regelung eine Befristung vorzusehen.',
#   {'entities': [(0, 6, 'PER')]}),
#  ('A380 auf eine Fehleinschätzung des Konzerns zurück.',
#   {'entities': [(0, 4, 'MISC')]}),
#  ('Mehr Produzentin über James Bond"Vielleicht wird er für immer leben"',
#   {'entities': [(0, 4, 'PER'), (22, 32, 'PER')]}),
#  ('Oder wie es Westerwelles behandelnder Arzt Michael Hallek bei Jauch gesagt hat:',
#   {'entities': [(12, 24, 'PER'), (43, 57, 'PER'), (62, 67, 'PER')]}),
#  ('Seit Sonntagabend wurde in Arnsberg der 76 Jahre alte Theodor M. vermisst.',
#   {'entities': [(27, 35, 'LOC'), (54, 64, 'PER')]}),
#  ('Prügelgatte: Siebenjähriger schützte Mutter',
#   {'entities': [(0, 11, 'PER')]}),
#  ('Hinweise nimmt die Kriminalpolizei in Dillenburg unter Tel.:',
#   {'entities': [(38, 48, 'LOC')]}),
#  ('Wer testet in Jerez Testauftakt in Spanien',
#   {'entities': [(14, 31, 'LOC'), (35, 42, 'LOC')]}),
#  ('Der CAS hat den Einspruch des UEFA-Chefs am Freitag abgelehnt.',
#   {'entities': [(4, 7, 'MISC'), (30, 40, 'ORG')]}),
#  ('Anna fuhr nicht zurück ins Teamhotel, sondern blieb bei ihrem Liebsten.',
#   {'entities': [(0, 4, 'PER'), (27, 36, 'ORG')]}),
#  ('Die Elite trifft sich in den Schweizer Alpen',
#   {'entities': [(29, 44, 'DATA')]}),
#  ('Im Zentrum von Solu soll die Cloud stehen – das Datenzentrum liegt in Finnland.',
#   {'entities': [(3, 10, 'ORG'), (15, 19, 'ORG'), (70, 78, 'LOC')]}),
#  ('Aktuelle Beiträge aus dem Politik-Ressort',
#   {'entities': [(26, 41, 'LOC')]}),
#  ('Die EU-Kommission prognostizierte Griechenland 2,9 Prozent Wirtschaftswachstum.',
#   {'entities': [(4, 17, 'ORG'), (34, 46, 'LOC')]}),
#  ('Wie sich diese 24 Mrd. in Deutschland verteilen, ist ganz unterschiedlich.',
#   {'entities': [(26, 37, 'LOC')]}),
#  ("Ched Evans' Videostellungnahme nach seiner Freilassung aus dem Gefängnis.",
#   {'entities': [(0, 10, 'PER')]}),
#  ('Er sagte dem britischen "Guardian": „Es war ein Gemetzel.',
#   {'entities': [(13, 23, 'MISC'), (25, 33, 'ORG')]}),
#  ('Die Buchung: Reisebüro, Katalog, Internet oder Smartphone?',
#   {'entities': [(33, 41, 'MISC')]}),
#  ('So wird es für die Wii U eine angepasste Version von Super Mario 64 geben.',
#   {'entities': [(19, 24, 'MISC'), (53, 67, 'MISC')]}),
#  ('Doch keine 90 Minuten später ist Rosberg bereits wieder auf der Strecke.',
#   {'entities': [(33, 40, 'PER')]}),
#  ('Ihre Mobilität organisiert sie über das Internet.',
#   {'entities': [(40, 48, 'MISC')]}),
#  ('Der Ex-Boss der Kölner Hells Angels gilt jedoch als schwerkriminell.',
#   {'entities': [(4, 11, 'MISC'), (16, 35, 'ORG')]}),
#  ('Kluge Köpfe - innovative Ideen: Europäischer Erfinderpreis',
#   {'entities': [(0, 5, 'PER'), (32, 44, 'MISC')]}),
#  ('Es gibt indes durchaus eine gewisse Souplesse in der Gestaltung.',
#   {'entities': [(36, 64, 'DATA')]}),
#  ('Aber: heute soll es gegen die Linzer endlich einen Sieg geben.',
#   {'entities': [(30, 36, 'LOC')]}),
#  ('Auf das 4:0 im Clásico folgte gestern ein 6:1 über Italiens Vize- Meister.',
#   {'entities': [(51, 59, 'LOC')]}),
#  ('Und, so hoffte man, auch die nervösen Bankkunden in Griechenland.',
#   {'entities': [(52, 64, 'LOC')]}),
#  ('Daher stecken Haitianer auch 13 Nadeln in den Korken des Verursachers.',
#   {'entities': [(14, 23, 'LOC')]}),
#  ('Das in Birsfelden gefundene Kokain werde vernichtet, sagt Buschauer.',
#   {'entities': [(7, 17, 'LOC'), (58, 67, 'PER')]}),
#  ('197 Kamow-Hubschrauber Französische Rafales oder russische Sukhoi-Jets?',
#   {'entities': [(23, 43, 'DATA'), (49, 58, 'MISC')]}),
#  ('Aspach-Großaspach: Polizei fahndet nach Exhibitionist',
#   {'entities': [(0, 17, 'ORG'), (40, 53, 'LOC')]}),
#  ('Der grösste Arbeitgeber in Tunesien ist der Staat.',
#   {'entities': [(27, 35, 'LOC')]}),
#  ('Und seit Jahren sterben Menschen im Mittelmeer.',
#   {'entities': [(36, 46, 'LOC')]}),
#  ('An Junghof- und Goethestraße bildet die Polizei Kessel.',
#   {'entities': [(3, 11, 'LOC')]}),
#  ('In der Mulde, die brannte, wird Haushaltkehricht gesammelt und gepresst.',
#   {'entities': [(7, 12, 'LOC'), (32, 48, 'MISC')]}),
#  ('Die Welt: Was wäre denn ein idealer Tag zum Aufhören?',
#   {'entities': [(44, 53, 'DATA')]}),
#  ('Sie wies die schlechteste Reaktions-Zeit ihres Feldes auf.',
#   {'entities': [(26, 53, 'DATA')]}),
#  ('Zur Bilderserie » Damit ist das Ego-Googlen noch nicht zu Ende.',
#   {'entities': [(32, 63, 'DATA')]}),
#  (' 377676 Brent verzeichnete bei 56,4 USD je Barrel ein 3-Monatstief.',
#   {'entities': [(54, 67, 'DATA')]}),
#  ('«Damit kann sich das Schweizer Bäckerhandwerk auszeichnen.»',
#   {'entities': [(21, 59, 'DATA')]}),
#  ('Die beiden Clubs aus den separatistischen Regionen',
#   {'entities': [(42, 50, 'DATA')]}),
#  ('Einige Deutsche nutzen digitale Radio\xadtechnologien, um darüber Radio zu hören.',
#   {'entities': [(7, 15, 'MISC'), (23, 50, 'DATA')]}),
#  ('Mit einer Handkreissäge geht es ans Grobere:',
#   {'entities': [(36, 44, 'DATA')]}),
#  ('Anders das Viererfeld, welches dem Kanton gehört.',
#   {'entities': [(11, 34, 'DATA'), (35, 41, 'LOC')]}),
#  ('Mit Leuten wie mir waere Oesterreich Bankrott.',
#   {'entities': [(25, 46, 'DATA')]}),
#  ('Der Autozulieferer und Rüstungskonzern verfüge über ein dickes..',
#   {'entities': [(62, 64, 'DATA')]}),
#  ('Neun Menschen sterben bei Kampf um besetztes Rathaus Mexiko:',
#   {'entities': [(45, 52, 'GRAN'), (53, 59, 'LOC')]}),
#  ('Die Nutzung von dateisenden.de basiert auf einem Prepaid-Modell.',
#   {'entities': [(49, 64, 'DATA')]}),
#  ('Der Ferlacher Ingo Appé (SPÖ) wurde mit 65,68 Prozent Gemeindechef bestätigt.',
#   {'entities': [(4, 23, 'DATA'), (25, 28, 'ORG')]}),
#  ('Initiator der Aktion ist die Islamische Gemeinschaft Millî Görüs;',
#   {'entities': [(29, 64, 'DATA')]}),
#  ('Dabei berufen sie sich auf das Bundesverfassungsgerichtsurteil aus dem Jahr',
#   {'entities': [(31, 75, 'DATA')]}),
#  ('Weiter geht die Suche nach der Ersatzdroge..',
#   {'entities': [(31, 42, 'GRAN')]}),
#  ('Oka Nikolov etwa hat diese Ausdauerprogramme gehasst.',
#   {'entities': [(0, 11, 'PER'), (27, 53, 'DATA')]}),
#  ('Wer das MMO von Funcom kennt, wird Schauplätze und Charaktere wieder erkennen.',
#   {'entities': [(8, 22, 'DATA')]}),
#  ('Erscheinen soll das bislang siebte Addon für das Free2Play-Spiel im Sommer.',
#   {'entities': [(49, 75, 'DATA')]}),
#  ('Prügeleien, Freude, Leid - ein Energiepunkt im bayerischen Kosmos.',
#   {'entities': [(31, 66, 'DATA')]}),
#  ('Das bedeutet die nordafrikanischen Staaten müssen mit ins Boot.',
#   {'entities': [(17, 42, 'DATA')]}),
#  ('Petrobras-Chefin Maria das Graças Foster trat bereits zurück.',
#   {'entities': [(0, 22, 'PER'), (27, 40, 'DATA')]}),
#  ('Für die gibt es nur A oder B und nichts dazwischen.',
#   {'entities': [(20, 21, 'LOC'), (27, 51, 'DATA')]}),
#  ('Man befürchtete, dieser könnte das Haus als Asylbewerberheim verwenden wollen.',
#   {'entities': [(35, 39, 'DATA')]}),
#  ('Das könnte Sie auch interessieren Schummel- Alarm!',
#   {'entities': [(34, 50, 'DATA')]}),
#  ('Eine interessante Station ist das Städtchen Medora in Norddakota.',
#   {'entities': [(34, 43, 'GRAN')]}),
#  ('Es ist schwierig, sich nicht zu beschweren, es ist eine Management-Übung.',
#   {'entities': [(56, 73, 'DATA')]}),
#  ('Wollen wir ein Strassenbild wie zB. in der Türkei?',
#   {'entities': [(43, 49, 'GRAN')]}),
#  ('Derzeit ist ein Spin-off-Projekt geplant;',
#   {'entities': [(16, 41, 'DATA')]}),
#  ('FOCUS-Leserdebatte: Welche Reformen braucht die katholische Kirche?',
#   {'entities': [(0, 18, 'MISC'), (48, 67, 'DATA')]}),
#  ('An einem Pausenkiosk wird ein gesunder Znüni zu kleinem Preis angeboten.',
#   {'entities': [(39, 72, 'DATA')]}),
#  ('Wir sind kein Dritte-Welt-Land mit Touristengettos.',
#   {'entities': [(14, 50, 'DATA')]}),
#  ('Die vier Nachwuchsbauern Lars, Maria, Kajal und Svenja stossen miteinander an.',
#   {'entities': [(9, 29, 'DATA'), (48, 54, 'PER')]}),
#  ('Tankstellen oder Testflotten sucht man hier noch vergebens.',
#   {'entities': [(17, 59, 'DATA')]}),
#  ('Jetzt bangt Thyssen-Krupp um einen Rekordauftrag.',
#   {'entities': [(12, 25, 'ORG'), (35, 49, 'DATA')]}),
#  ('Das Problem ist der Mangel an Sozialwohnungen.',
#   {'entities': [(30, 46, 'DATA')]}),
#  ('Für Männer sei die Stadt Duma wie ein Gefängnis gewesen, berichtet Amal.',
#   {'entities': [(19, 24, 'GRAN'), (67, 71, 'PER')]}),
#  ('Wo ist denn die Konkurrenz der Weltsysteme, wo die saubere Grenzziehung?',
#   {'entities': [(59, 72, 'DATA')]}),
#  ('Feuerwehreinsatz am Wasserwerk Trier-Irsch (Trier)',
#   {'entities': [(20, 30, 'GRAN'), (44, 49, 'LOC')]}),
#  ('Der Anteil von Kniegelenksschäden insgesamt liegt bei etwa 18 Prozent;',
#   {'entities': [(15, 43, 'DATA')]}),
#  ('Für den User sieht miniPay aus wie eine normale SEPA-Lastschrift.',
#   {'entities': [(19, 26, 'PER'), (48, 65, 'DATA')]}),
#  ('Die weiteren Ermittlungen hat das Verkehrskommissariat Heidelberg übernommen.',
#   {'entities': [(34, 65, 'DATA')]}),
#  ('3 «Eine heikle Grat-Wanderung» Jetzt spricht Frank über Magersucht im..',
#   {'entities': [(15, 71, 'DATA')]}),
#  ('Einst wurde das Traditionsteam aus Grove von Michelin ausgestattet.',
#   {'entities': [(16, 40, 'DATA'), (45, 53, 'ORG')]}),
#  ('An Instapaper senden Neuerlicher Abbruch der Gemeindesitzung.',
#   {'entities': [(3, 13, 'MISC'), (21, 60, 'DATA')]}),
#  ('Dabei ist diese Fan-Animation alles andere als ein Lego-Stein unterm Fuß.',
#   {'entities': [(16, 73, 'DATA')]}),
#  ('Nur Channel Wirtschaft durchsuchen Aussendersuche',
#   {'entities': [(4, 11, 'ORG'), (35, 49, 'DATA')]}),
#  ('Zuerst war es die spanischsprachige Fernsehanstalt Univision.',
#   {'entities': [(18, 60, 'DATA')]}),
#  ('Die Tschechen statten das Radrennen mit insgesamt 250 Fahrzeugen aus.',
#   {'entities': [(4, 13, 'LOC'), (26, 69, 'DATA')]}),
#  ('Sie ist die älteste im Stadtgebiet Niederkassel;',
#   {'entities': [(23, 34, 'GRAN'), (35, 47, 'LOC')]}),
#  ('Der Jurist nahm zwei Mal erfolglos Anlauf auf das Weiße Haus.',
#   {'entities': [(50, 60, 'DATA')]}),
#  ('Tesla-Fahrer freuen sich inzwischen über ein wachsendes Netz an Superchargern.',
#   {'entities': [(0, 12, 'LOC'), (64, 78, 'DATA')]}),
#  ('Am Ende steht dann ein Zukunftsbild für die Stadt Frankfurt im Jahre',
#   {'entities': [(44, 49, 'GRAN'), (50, 59, 'LOC')]}),
#  ('Bis Ende Juli hängen in der Diözese Sankt Pölten 120 Großplakate.',
#   {'entities': [(28, 35, 'GRAN')]}),
#  ('Generell viele aus meinem Bekanntenkreis sagen Fußzeh.',
#   {'entities': [(47, 54, 'DATA')]}),
#  ('Es war eine Gala-Vorstellung gewesen in einer hoch aufgeladenen Begegnung.',
#   {'entities': [(12, 74, 'DATA')]}),
#  ('Da läuft nichts!, mächte ein Gäste-Fan seinem Ärger Luft.',
#   {'entities': [(29, 56, 'DATA')]}),
#  ('Ich möchte \xaderfolgreich Fussball spielen, \xadTitel gewinnen und, und, und.',
#   {'entities': [(11, 72, 'DATA')]}),
#  ('Bahai: Warum sollten wir Trennungslinien ziehen (2) Foto:',
#   {'entities': [(0, 5, 'MISC'), (25, 47, 'DATA')]}),
#  ('Die Geldscheine werden auf reinem Baumwollfaserpapier gedruckt.',
#   {'entities': [(34, 63, 'DATA')]}),
#  ('USA melden Tod eines weiteren Al-Kaida-Führers',
#   {'entities': [(0, 3, 'LOC'), (30, 46, 'DATA')]}),
#  ('Die «Grenchen» ist eine Allzweck-Lokomotive.',
#   {'entities': [(5, 13, 'LOC'), (24, 44, 'DATA')]}),
#  ('Ich kann alles, was ein Hörender auch kann.»',
#   {'entities': [(24, 44, 'DATA')]}),
#  ('Essensausgabe in der Landeserstaufnahmestelle Ellwangen',
#   {'entities': [(21, 45, 'GRAN'), (46, 55, 'LOC')]}),
#  ('Die Musikbranche zeigt, wie man das Gros der Inhalte global verfügbar macht.',
#   {'entities': [(36, 76, 'DATA')]}),
#  ('Dementsprechend gibt es da auch viel Rede- und Diskussionsbedarf.',
#   {'entities': [(37, 65, 'DATA')]}),
#  ('1,46 Alligator frisst Schildkröte - am Golfplatz',
#   {'entities': [(39, 48, 'GRAN')]}),
#  ('Eine bestimmte Substanz regt das Wachstum der Haare wieder an.',
#   {'entities': [(33, 62, 'DATA')]}),
#  ('Informationen zu VFS Global ShailyV@vfsglobal.com',
#   {'entities': [(17, 27, 'DATA')]}),
#  (' 2698164 Wir sollten Asylkriterien kritischer hinterfragen.',
#   {'entities': [(21, 59, 'DATA')]}),
#  ('Dazu kommen ein USB-3.0- und ein HDMI-Anschluss.',
#   {'entities': [(33, 48, 'DATA')]}),
#  ('Hinzu kam am Mittwoch das Cup-Out gegen Basel.',
#   {'entities': [(26, 45, 'DATA')]}),
#  ('Paul Walker war der Held vieler Sportwagenfans.',
#   {'entities': [(0, 11, 'PER'), (32, 47, 'DATA')]}),
#  ('Trotz der zum Teil merklichen Kursabschläge gebe es kaum Käufer.',
#   {'entities': [(30, 64, 'DATA')]}),
#  ('Motorsport-Total.com @Twitter Zwitschern mit viel PS!',
#   {'entities': [(0, 20, 'ORG'), (50, 53, 'DATA')]}),
#  ('Ein Attentat kann das Reisegeschäft beenden:',
#   {'entities': [(4, 12, 'MISC'), (22, 44, 'DATA')]}),
#  ('Hier bei uns in Sachsen sieht man sehr viel HH BZW 88 auf Nummernschildern!',
#   {'entities': [(16, 23, 'LOC'), (44, 50, 'DATA')]}),
#  ('Gleich mehrfach haben Nutzer das Meme Shut up and take my money gepostet.',
#   {'entities': [(33, 73, 'DATA')]}),
#  ('Patienten haben Recht auf beste Versorgung',
#   {'entities': [(32, 42, 'DATA')]}),
#  ('Nach aktuellem Planungsstand soll Campus 2 2016 eingeweiht werden.',
#   {'entities': [(34, 47, 'DATA')]}),
#  ('Doch das Steinzeitmädchen ist 5600 Jahre alt.',
#   {'entities': [(9, 40, 'DATA')]}),
#  ('1435050 Für das amerikanische Social Media-Unternehmen',
#   {'entities': [(16, 54, 'DATA')]}),
#  ('Die haben sich überlegt was braucht man für ein Vernisage in einem Schloss.',
#   {'entities': [(48, 74, 'DATA')]}),
#  ('Bei den neuen Motorentechnologien gehe es um mehr als absolute Leistung.',
#   {'entities': [(14, 72, 'DATA')]}),
#  ('Ratschiller: Die westliche Kultur verstehe das Bilderverbot im Islam nicht.',
#   {'entities': [(0, 11, 'PER'), (47, 75, 'DATA')]}),
#  ('Nach Renovation erstrahlt das Aquarena fun im Bad Schinznach in neuem Glanz.',
#   {'entities': [(30, 45, 'DATA'), (46, 60, 'LOC')]}),
#  ('Die Silhouette der Stadt Schrobenhausen bietet ihr meist ein lohnendes Motiv.',
#   {'entities': [(19, 24, 'GRAN'), (25, 39, 'LOC')]}),
#  ('Weltweit gibt es etwa 900 Millionen aktive Gmail-User.',
#   {'entities': [(43, 54, 'DATA')]}),
#  ('Der verunglückte Schweizer war in der Region wohnhaft.',
#   {'entities': [(17, 26, 'MISC'), (38, 44, 'GRAN')]}),
#  ('Da könnte ich einen Schreikrampf bekommen!',
#   {'entities': [(20, 42, 'DATA')]}),
#  ('Diese EU-Staaten haben am meisten Schulden',
#   {'entities': [(6, 16, 'LOC'), (34, 42, 'DATA')]}),
#  ('Die erste beschauliche Amazon-Zentrale in Seattle.',
#   {'entities': [(23, 41, 'DATA'), (42, 49, 'LOC')]}),
#  ('Welche Erwartungen habt ihr an Bloodborne?',
#   {'entities': [(31, 42, 'DATA')]}),
#  ('Weitere Artikel zum Thema Österreichische Maturanten in Split schwer verletzt',
#   {'entities': [(26, 52, 'DATA'), (56, 61, 'LOC')]}),
#  ('5.1 Analog so nur ein befriedigender Testeindruck.',
#   {'entities': [(37, 50, 'DATA')]}),
#  ('«Die Bewilligung muss funktionieren wie am Billettschalter.',
#   {'entities': [(43, 59, 'DATA')]}),
#  ('Das weltweite Einzelhandelsnetz umfasste 2014 über 400 exklusive Boutiquen.',
#   {'entities': [(14, 54, 'DATA')]}),
#  ('Dass die Anträge trotzdem gestellt wurden, wirkt wie ein Verzweiflungsakt.',
#   {'entities': [(57, 74, 'DATA')]}),
#  ('Zentrum des Angriffs war das Riu-Hotel "Imperial Marhaba".',
#   {'entities': [(0, 7, 'ORG'), (29, 56, 'DATA')]}),
#  ('Die Helikopter-Sparte wuchs um 4 Prozent, das Raumfahrt-Segment um 2 Prozent.',
#   {'entities': [(4, 21, 'MISC'), (46, 77, 'DATA')]}),
#  ('Außer Lenovo (Festplatte) haben alle Modelle eine SSD.',
#   {'entities': [(6, 12, 'ORG'), (50, 54, 'DATA')]}),
#  ('„Das Lachen nimmt vom Kind zum Erwachsenen zum Alten ab.',
#   {'entities': [(31, 56, 'DATA')]}),
#  ('Fotos von Gemeinde Würflach zur Verfügung gestellt.',
#   {'entities': [(10, 18, 'GRAN'), (19, 27, 'LOC')]}),
#  ('Mittlerweile gibt es eine Dependance in Hitzhusen (Kreis Segeberg).',
#   {'entities': [(40, 49, 'LOC'), (51, 56, 'GRAN')]}),
#  ('Nachrichten - Görlitzer-Anzeiger ▪ Landkreis Görlitz:',
#   {'entities': [(14, 32, 'LOC'), (35, 44, 'GRAN')]}),
#  ('Seit dem 9. Januar sind die Kämpfe in der Region Donezk intensiver geworden.',
#   {'entities': [(42, 48, 'GRAN'), (49, 55, 'LOC')]}),
#  ('Auch die Region Stuttgart steuert auf ein gutes Ergebnis zu.',
#   {'entities': [(9, 15, 'GRAN'), (16, 25, 'LOC')]}),
#  ('Die Nachricht traf die Gemeinde Berneck aus heiterem Himmel.',
#   {'entities': [(23, 31, 'GRAN'), (32, 39, 'LOC')]}),
#  ('Am Flughafen Dallas-Fort Worth wurden rund hundert Flüge abgesagt.',
#   {'entities': [(3, 12, 'GRAN')]}),
#  ('Auf Facebook posten 6 @Schneider genau der Kanton BL macht das absolut richtig!',
#   {'entities': [(4, 12, 'MISC'), (43, 49, 'GRAN')]}),
#  ('Er kennt die finanziellen Engpässe der Kommunen.',
#   {'entities': [(39, 47, 'GRAN')]}),
#  ('Alle Verletzten wurden ins LKH Deutschlandsberg gebracht.',
#   {'entities': [(27, 30, 'GRAN'), (31, 47, 'LOC')]}),
#  ('Im Bezirk Schärding rangiere Riedau mit 11,3 Prozent an der Spitze.',
#   {'entities': [(3, 9, 'GRAN')]}),
#  ('Nun haben sich der Bund, der Kanton Bern und die Stadt Thun geeinigt.',
#   {'entities': [(19, 23, 'LOC'),
#     (29, 35, 'GRAN'),
#     (49, 54, 'GRAN'),
#     (55, 59, 'LOC')]}),
#  ('Wo findet man die Kiwara-Savanne, wie weit ist es bis zum nächsten Spielplatz?',
#   {'entities': [(18, 32, 'MISC'), (67, 77, 'GRAN')]}),
#  ('Beide Frauen wurden vom Roten Kreuz ins LKH Weiz eingeliefert.',
#   {'entities': [(24, 35, 'ORG'), (40, 43, 'GRAN')]}),
#  ('Hier schließt sich der Kreis und Erzähler',
#   {'entities': [(23, 28, 'GRAN')]}),
#  ('Über die Gesundheitsregionplus Landkreis Garmisch-Partenkirchen:',
#   {'entities': [(31, 40, 'GRAN')]}),
#  ('Hier finden Sie professionelle Hilfe in Ihrer Stadt!',
#   {'entities': [(46, 51, 'GRAN')]}),
#  ('In München verkehren die S-Bahnen 2, 3 und 4 im 20-Minutentakt.',
#   {'entities': [(3, 10, 'LOC'), (25, 33, 'GRAN')]}),
#  ('Haben Sie mal wieder Lust auf einen Museumsbesuch?',
#   {'entities': [(36, 49, 'GRAN')]}),
#  ('Dafür habe er sogar mit einem Veto im Kreis der Minister gedroht.',
#   {'entities': [(38, 43, 'GRAN')]}),
#  ('Derzeit führt das Gymnasium Thun drei Quartaklassen.',
#   {'entities': [(18, 27, 'GRAN')]}),
#  ('Stadt Bonn schließt sich Bürgerbegehren an',
#   {'entities': [(0, 5, 'GRAN'), (6, 10, 'LOC')]}),
#  ('Zum ersten Mal geküsst haben sie sich dann am nächsten Tag am Bahnhof Bern.',
#   {'entities': [(62, 69, 'GRAN')]}),
#  ('Münchner Polizei - Bitte keine Hilfsgüter mehr zum Bahnhof',
#   {'entities': [(0, 16, 'ORG'), (51, 58, 'GRAN')]}),
#  ('Das Bild zeigt die Ortschaft Kafruma in der Provinz Idlib.',
#   {'entities': [(19, 28, 'GRAN'), (29, 36, 'LOC'), (44, 51, 'GRAN')]}),
#  ('Überraschend positive Arbeitsmarktzahlen aus den USA Washington.',
#   {'entities': [(49, 52, 'GRAN'), (53, 63, 'LOC')]}),
#  ('Jetzt hoffen Kommunen auf Hilfe durch die Bundeswehr.',
#   {'entities': [(13, 21, 'GRAN'), (42, 52, 'ORG')]}),
#  ('Sind diese Bayern das neue magische Dreieck?',
#   {'entities': [(11, 17, 'LOC'), (36, 43, 'GRAN')]}),
#  ('Allerdings wird das Geld nur an Gemeinden und Landkreise verteilt.',
#   {'entities': [(32, 41, 'GRAN')]}),
#  ('Wir informieren Sie aus der ganzen Region.',
#   {'entities': [(35, 41, 'GRAN')]}),
#  ('2014 machte niemand von diesem Angebot der Gemeinde Sumiswald Gebrauch.',
#   {'entities': [(43, 51, 'GRAN')]}),
#  ('In vielen Gemeinden übernehmen sie auch in der Messe eine tragende Rolle.',
#   {'entities': [(10, 19, 'GRAN')]}),
#  ('Der Landkreis Roth ist zwar grundsätzlich an einem Sportbad interessiert.',
#   {'entities': [(4, 13, 'GRAN')]}),
#  ('Doch gibt es einen Ausweg aus diesem Teufelskreis?',
#   {'entities': [(37, 49, 'GRAN')]}),
#  ('Wir sehen uns morgen auf der Strecke!", legte Smith nach.',
#   {'entities': [(29, 36, 'GRAN'), (46, 51, 'PER')]}),
#  ('Der Ärztemangel wirkt sich auch auf die Notdienste im Bezirk Braunau aus.',
#   {'entities': [(54, 60, 'GRAN')]}),
#  ('Aber sie wissen, dass sie in unseren Gemeinden keinen Platz haben.',
#   {'entities': [(37, 46, 'GRAN')]}),
#  ('Der US-Bundesstaat Kalifornien kämpft derzeit mit ganz anderen Problemen:',
#   {'entities': [(4, 18, 'GRAN'), (19, 30, 'LOC')]}),
#  ('Pele mit Prostataproblemen im Krankenhaus',
#   {'entities': [(0, 4, 'PER'), (30, 41, 'GRAN')]}),
#  ('Durch die Klasse lassen dich diese Vereine im Kreis laufen“, sagt Gucher.',
#   {'entities': [(46, 51, 'GRAN'), (66, 72, 'PER')]}),
#  ('In der Diözese Agrigent liegt auch die Insel Lampedusa.',
#   {'entities': [(7, 14, 'GRAN'), (39, 44, 'GRAN'), (45, 54, 'LOC')]}),
#  ('Auf der Insel Sumatra wurden Rodungsbrände entfacht.',
#   {'entities': [(8, 13, 'GRAN'), (14, 21, 'LOC')]}),
#  ('Fürstliche Patentante für Orchideenschau im Stift Thermografie.',
#   {'entities': [(26, 40, 'MISC'), (44, 49, 'GRAN')]}),
#  ('18.05.2015 – 10:16 Stade (ots) - 1. Einbrüche am Wochenende im Landkreis',
#   {'entities': [(19, 24, 'LOC'), (63, 72, 'GRAN')]}),
#  ('Essentiell ist die Schaffung von Wohnraum durch die Stadt Wien.',
#   {'entities': [(52, 57, 'GRAN'), (58, 62, 'LOC')]}),
#  ('Dann nimm doch einen Last-Minute-Flug in eine dieser Städte!',
#   {'entities': [(53, 59, 'GRAN')]}),
#  ('Die Verunglückten kommen aus den Gemeinden Schkopau und Kabelsketal.',
#   {'entities': [(33, 42, 'GRAN')]}),
#  ('Ueli Maurer wohnt mit seiner Familie im Hinwiler Weiler Wernetshausen.',
#   {'entities': [(0, 11, 'PER'), (40, 48, 'GRAN')]}),
#  ('Der Landkreis Pfaffenhofen hat die erforderlichen Mittel bereits zugesichert.',
#   {'entities': [(4, 13, 'GRAN')]}),
#  ('Eingang zum Kloster Ettal im Landkreis Garmisch-Partenkirchen.',
#   {'entities': [(12, 25, 'LOC'), (29, 38, 'GRAN')]}),
#  ('Was geschah am 14. Dezember in der Feuerbergstraße?',
#   {'entities': [(35, 50, 'GRAN')]}),
#  ('Etwa die zahlreichen bewaffneten Ausländer in diesem Gebiet?',
#   {'entities': [(53, 59, 'GRAN')]}),
#  ('Heute hat das Bezirksgericht Zürich sein Urteil gefällt.',
#   {'entities': [(14, 28, 'GRAN'), (29, 35, 'LOC')]}),
#  ('Vor einem Jahr fragte der Senat die Bürger..',
#   {'entities': [(36, 42, 'GRAN')]}),
#  ('Die Gemeinde der Big-Wave-Surfer überwintert nun auch in Nazaré.',
#   {'entities': [(4, 12, 'GRAN'), (57, 63, 'LOC')]}),
#  ('Das heisst, das Asylrecht geht von der nationalen auf die Gemeinschaftsebene?',
#   {'entities': [(58, 76, 'GRAN')]}),
#  ('Nur, was wiegt eine Foto im Vergleich zu einem handfesten Schloss?',
#   {'entities': [(58, 65, 'GRAN')]}),
#  ('Das beliebteste Winter-Hotel: das Wasserwerk Tegel.',
#   {'entities': [(16, 28, 'ORG'), (34, 44, 'GRAN')]}),
#  ('Die dritte Bluttat im Kanton Aargau in diesem Jahr:',
#   {'entities': [(22, 28, 'GRAN')]}),
#  ('Heute Nachmittag stürzte im Gebiet Alvier ein 68-Jähriger Wanderer in den Tod.',
#   {'entities': [(28, 34, 'GRAN'), (35, 41, 'LOC')]}),
#  ('Seit Beginn des Jahres 2015 gibt es nur mehr 285 anstelle von 539 Gemeinden.',
#   {'entities': [(16, 27, 'MISC'), (66, 75, 'GRAN')]}),
#  ('Die Frau wurde ins Kantonsspital Graubünden nach Chur geflogen.',
#   {'entities': [(19, 32, 'GRAN'), (49, 53, 'LOC')]}),
#  ('Impressionen der Dschungelnacht im Zoo Leipzig hier!',
#   {'entities': [(35, 38, 'GRAN')]}),
#  ('Der Kirchengemeindeverband Sil… mehr alle Fotoserien und Videos …',
#   {'entities': [(4, 26, 'GRAN'), (57, 65, 'MISC')]}),
#  ('In Goldau im Kanton Schwyz traf ein herumfliegendes Blech einen Arbeiter.',
#   {'entities': [(3, 9, 'LOC'), (13, 19, 'GRAN')]}),
#  ('09:19 Erkennen Sie diese neun Nationalhymnen?',
#   {'entities': [(30, 44, 'GRAN')]}),
#  ('Die letzten Stunden der Gemeinde Sternenberg Video',
#   {'entities': [(24, 32, 'GRAN')]}),
#  (' 95824 Alle Verletzten wurden ins Krankenhaus Kufstein gebracht.',
#   {'entities': [(34, 45, 'GRAN'), (46, 54, 'LOC')]}),
#  ('Das griechische statistische Amt Elstat soll rechtlich voll unabhängig werden.',
#   {'entities': [(4, 15, 'MISC'), (29, 32, 'GRAN')]}),
#  ('Wenn man es weglegt, ist klar: ab auf die Kyburg!',
#   {'entities': [(42, 48, 'GRAN')]}),
#  ('Er selbst gibt aber zu, dass er für die Gemeinde online zu wenig aktiv ist.',
#   {'entities': [(40, 48, 'GRAN')]}),
#  ('Babys aus der Region Nachrichten aus Ihrer Region',
#   {'entities': [(14, 20, 'GRAN'), (43, 49, 'GRAN')]}),
#  ('Ihr neuer Wohnsitz im Kanton Schwyz dürfte da einiges an Abgaben sparen.',
#   {'entities': [(22, 28, 'GRAN')]}),
#  ('Der MSV war und ist der größte Werbeträger der Stadt DU.',
#   {'entities': [(4, 7, 'ORG'), (47, 52, 'GRAN')]}),
#  ('Wie wichtig ist ein gutes Verhältnis zwischen Deutschland und den USA?',
#   {'entities': [(46, 57, 'LOC'), (66, 69, 'GRAN')]}),
#  ('Derzeit laufen dazu Verhandlungen mit Ländern und Gemeinden.',
#   {'entities': [(50, 59, 'GRAN')]}),
#  ('Wegen letzteren hat er jetzt zusätzlichen Ärger: mit seiner Gemeinde.',
#   {'entities': [(60, 68, 'GRAN')]}),
#  ('2.) Probieren Sie alle Köstlichkeiten des Landes!',
#   {'entities': [(42, 48, 'GRAN')]}),
#  ('Und das wäre dann die Raumplanungsabteilung des Landes Salzburg.',
#   {'entities': [(48, 54, 'GRAN')]}),
#  ('Kein Wunder fahren die Russem im Ärmelkanal Protestmanöver.',
#   {'entities': [(33, 43, 'GRAN')]}),
#  ('Von Kino bis Festival Finden Sie hier die schönsten Events in unserer Region.',
#   {'entities': [(70, 76, 'GRAN')]}),
#  ('Leider leiden wir unter der schlechtesten Regierung der 2ten Republik!',
#   {'entities': [(61, 69, 'GRAN')]})]

# %%
random.shuffle(out_sentences)
TRAIN_STAT_DATA=out_sentences[:len(out_sentences)//2]
TEST_STAT_DATA=out_sentences[len(out_sentences)//2:]

# %%
print(len(out_sentences))
print(len(TRAIN_STAT_DATA))
print(len(TEST_STAT_DATA))
print("REVISION", len(TRAIN_REVISION_DATA))
TRAIN_DATA = TRAIN_REVISION_DATA + TRAIN_STAT_DATA
print("COMBINED", len(TRAIN_DATA))
# Out:
# 1020
# 510
# 510
# REVISION 479
# COMBINED 989

# %%
ner = nlp.get_pipe("ner")
ner.add_label("GRAN")
ner.add_label("DATA")



# get the names of the components we want to disable during training
pipe_exceptions = ["ner", "trf_wordpiecer", "trf_tok2vec"]
other_pipes = [pipe for pipe in nlp.pipe_names if pipe not in pipe_exceptions]

# start the training loop, only training NER
epochs = 30
optimizer = nlp.resume_training()
#optimizer = nlp.initialize()
with nlp.disable_pipes(*other_pipes), warnings.catch_warnings():
    warnings.filterwarnings("once", category=UserWarning, module='spacy')
    sizes = compounding(1.0, 4.0, 1.001)
    
    # batch up the examples using spaCy's minibatc
    for epoch in range(epochs):
        random.shuffle(TRAIN_DATA)
        #text = []
        #annots=[]
        examples=[]


        for text,annots in TRAIN_DATA:
            #text.append(t)
            #annots.append(a)
            doc = nlp.make_doc(text)    
            example = Example.from_dict(doc, annots)
            examples.append(example)
        
        losses = {}
        
        nlp.update(examples, sgd=optimizer, drop=0.35, losses=losses)

        print("Losses ({}/{})".format(epoch + 1, epochs), losses)
# Out:
# Losses (1/30) {'ner': 603.6519041378497}
# Losses (2/30) {'ner': 521.958930143036}
# Losses (3/30) {'ner': 528.4129105627999}
# Losses (4/30) {'ner': 497.753090302857}
# Losses (5/30) {'ner': 532.9863592055688}
# Losses (6/30) {'ner': 509.5232007509852}
# Losses (7/30) {'ner': 491.3220482238376}
# Losses (8/30) {'ner': 447.5450727470882}
# Losses (9/30) {'ner': 454.8763724614837}
# Losses (10/30) {'ner': 424.7050009609724}
# Losses (11/30) {'ner': 462.0955569751394}
# Losses (12/30) {'ner': 463.85766683346446}
# Losses (13/30) {'ner': 379.27706512248824}
# Losses (14/30) {'ner': 333.7394603521992}
# Losses (15/30) {'ner': 346.1249449538723}
# Losses (16/30) {'ner': 317.42312924982207}
# Losses (17/30) {'ner': 341.20657504827284}
# Losses (18/30) {'ner': 318.87029372153853}
# Losses (19/30) {'ner': 312.57004010324545}
# Losses (20/30) {'ner': 285.87410267170617}
# Losses (21/30) {'ner': 306.41960576960395}
# Losses (22/30) {'ner': 253.47754865200034}
# Losses (23/30) {'ner': 246.98746294407502}
# Losses (24/30) {'ner': 258.7824386351765}
# Losses (25/30) {'ner': 224.70122360011248}
# Losses (26/30) {'ner': 226.89019361999303}
# Losses (27/30) {'ner': 230.98573921469801}
# Losses (28/30) {'ner': 256.76409862806236}
# Losses (29/30) {'ner': 258.3375145509551}
# Losses (30/30) {'ner': 193.6468549201703}

# %%
statbot_colors = {"GRAN": "linear-gradient(90deg, #aa9cfc, #fc9ce7)",
                  "DATA": "linear-gradient(90deg, #ffff00, #ff8c00)"}
statbot_options = {"ents": ["PER","LOC","ORG","MISC","GRAN","DATA"], "colors": statbot_colors}
spacy.displacy.render(nlp("Ich heisse Christian und war heute in Zürich bei IBM im Internet."), style="ent",options=statbot_options)
spacy.displacy.render(nlp("Wie viele Kühe hat die Gemeinde Bülach?"), style="ent",options=statbot_options)
spacy.displacy.render(nlp("Wie hoch ist Eigenkapital auf Bezirksebene?"), style="ent",options=statbot_options)
spacy.displacy.render(nlp("Ich brauche die Daten pro Bezirk"), style="ent",options=statbot_options)
spacy.displacy.render(nlp("Ich brauche die Daten für den gesamten Kanton."), style="ent",options=statbot_options)
spacy.displacy.render(nlp("Wie viel Bauinv. EFH 5 Jahre  hat  in Regensdorf  ?"), style="ent",options=statbot_options)
spacy.displacy.render(nlp("Was ist der Anteil an MIV-Anteil (Modal Split)   auf Bezirksebene ?"), style="ent",options=statbot_options)
spacy.displacy.render(nlp("Was ist der Anteil an Geb.Vol. Dienstleistungen: Zunahme   in Flaach ?"), style="ent",options=statbot_options)
spacy.displacy.render(nlp("Welches ist das Schül. Sekundarstufe II   für den gesamten Kanton ?"), style="ent",options=statbot_options)
spacy.displacy.render(nlp("Welche Gemeinde hat die grösste Bevölkerung?"), style="ent",options=statbot_options)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Ich heisse
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Christian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  und war heute in
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Zürich
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  bei
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     IBM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  im
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Internet
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# .</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Wie viele
# <mark class="entity" style="background: linear-gradient(90deg, #ffff00, #ff8c00); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kühe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATA</span>
# </mark>
#  hat die
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gemeinde
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GRAN</span>
# </mark>
#  Bülach?</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Wie hoch ist Eigenkapital auf
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bezirksebene
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GRAN</span>
# </mark>
# ?</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Ich brauche die Daten pro
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bezirk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GRAN</span>
# </mark>
# </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Ich brauche die Daten für den gesamten
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kanton
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GRAN</span>
# </mark>
# .</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Wie viel
# <mark class="entity" style="background: linear-gradient(90deg, #ffff00, #ff8c00); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bauinv.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATA</span>
# </mark>
#  EFH 5 Jahre  hat  in Regensdorf  ?</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Was ist der Anteil an
# <mark class="entity" style="background: linear-gradient(90deg, #ffff00, #ff8c00); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MIV-Anteil (Modal Split
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATA</span>
# </mark>
# )   auf
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bezirksebene
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GRAN</span>
# </mark>
#  ?</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Was ist der Anteil an
# <mark class="entity" style="background: linear-gradient(90deg, #ffff00, #ff8c00); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Geb.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATA</span>
# </mark>
# Vol. Dienstleistungen: Zunahme   in Flaach ?</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Welches ist das
# <mark class="entity" style="background: linear-gradient(90deg, #ffff00, #ff8c00); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Schül.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATA</span>
# </mark>
#  Sekundarstufe II   für den gesamten
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kanton
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GRAN</span>
# </mark>
#  ?</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Welche
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gemeinde
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GRAN</span>
# </mark>
#  hat die grösste Bevölkerung?</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Die Buchung: Reisebüro, Katalog,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Internet
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  oder Smartphone?</div></span>

# %%
# dictionary to hold our evaluation data
stat_evaluation = {
    "GRAN": {
        "correct": 0,
        "total": 0,
    },
    "DATA": {
        "correct": 0,
        "total": 0,
    }
}

word_evaluation = {
    "GRAN": {
        "correct": 0,
        "total": 0
    },
    "DATA": {
        "correct": 0,
        "total": 0,
    }

}


for stat in TEST_STAT_DATA:
    # extract the sentence and correct stat entities according to our test data
    sentence = stat[0]
    entities = stat[1]["entities"]

    # for each entity, use our updated model to make a prediction on the sentence
    for entity in entities:
        doc = nlp(sentence)
        correct_text = sentence[entity[0]:entity[1]]
        n_worded_stat =  len(correct_text.split())
        print(n_worded_stat)

        # if we find that there's a match for predicted entity and predicted text, increment correct counters
        for ent in doc.ents:
            print("ENT_LABEL",ent.label_)
            print("ENTITY2",entity[2])
            print("ENT_TEXT",ent.text)
            print("CORRECT:TEXT",correct_text)
            if ent.label_ == entity[2] and ent.text == correct_text:
                
                stat_evaluation[entity[2]]["correct"] += 1
                if n_worded_stat > 0:
                    word_evaluation[entity[2]]["correct"] += 1

                # this break is important, ensures that we're not double counting on a correct match
                break

        #  increment total counters after each entity loop
        stat_evaluation[entity[2]]["total"] += 1
        if n_worded_stat > 0:
            word_evaluation[entity[2]]["total"] += 1
# Out:
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil Gewaesserflaeche
# CORRECT:TEXT Anteil Gewaesserflaeche
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Wahlbeteiligung Nationalrat
# CORRECT:TEXT Wahlbeteiligung Nationalrat
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT VZÄ im Sekundaersektor
# CORRECT:TEXT VZÄ im Sekundaersektor
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Hotels
# CORRECT:TEXT Kanton
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Kanton
# CORRECT:TEXT Kanton
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Hotels
# CORRECT:TEXT Hotels
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Steuerb.
# CORRECT:TEXT Kanton
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Kanton
# CORRECT:TEXT Kanton
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerb.
# CORRECT:TEXT Steuerb. Einkommen natuerl. Pers. 25%Quantil
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Kanton
# CORRECT:TEXT Steuerb. Einkommen natuerl. Pers. 25%Quantil
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bauinvestitionen
# CORRECT:TEXT Region
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Region
# CORRECT:TEXT Region
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinvestitionen
# CORRECT:TEXT Bauinvestitionen
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Leerwohnungsquote
# CORRECT:TEXT Bezirk
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirk
# CORRECT:TEXT Bezirk
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Leerwohnungsquote
# CORRECT:TEXT Leerwohnungsquote
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Oberstufe
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Neuerstellte MFHWohnungen
# CORRECT:TEXT Gemeinden
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Gemeinden
# CORRECT:TEXT Gemeinden
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Neuerstellte MFHWohnungen
# CORRECT:TEXT Neuerstellte MFHWohnungen
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Apotheken
# CORRECT:TEXT Kanton
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Kanton
# CORRECT:TEXT Kanton
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Apotheken
# CORRECT:TEXT Apotheken
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil GK C
# CORRECT:TEXT Anteil GK C
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bauinv.
# CORRECT:TEXT Gemeinden
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Gemeinden
# CORRECT:TEXT Gemeinden
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. ÖV, Kommunik. 5 Jahre
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Gemeinden
# CORRECT:TEXT Bauinv. ÖV, Kommunik. 5 Jahre
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Aerzte
# CORRECT:TEXT Bezirk
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirk
# CORRECT:TEXT Bezirk
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Aerzte
# CORRECT:TEXT Aerzte
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Mikrobetriebe
# CORRECT:TEXT Mikrobetriebe 09 VZÄ
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Personenwagen pro 1000 Einwohner
# CORRECT:TEXT Personenwagen pro 1000 Einwohner
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Weg zur naechsten Haltestelle
# CORRECT:TEXT Weg zur naechsten Haltestelle
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Hotelbetten
# CORRECT:TEXT Bezirke
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirke
# CORRECT:TEXT Bezirke
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Hotelbetten
# CORRECT:TEXT Hotelbetten
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Beschaeftigte im Sekundaersektor
# CORRECT:TEXT Beschaeftigte im Sekundaersektor
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT 15Jahresverbrauch
# CORRECT:TEXT Region
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Region
# CORRECT:TEXT Region
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT 15Jahresverbrauch
# CORRECT:TEXT 15Jahresverbrauch
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerertrag allgemeine Gemeindesteuern
# CORRECT:TEXT Steuerertrag allgemeine Gemeindesteuern
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerungsdichte
# CORRECT:TEXT Bevoelkerungsdichte
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Beschaeftigte im Primaersektor
# CORRECT:TEXT Beschaeftigte im Primaersektor
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Steuerb.
# CORRECT:TEXT Gemeinde
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Gemeinde
# CORRECT:TEXT Gemeinde
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerb.
# CORRECT:TEXT Steuerb. Vermoegen natuerl. Pers. 75%Quantil
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Gemeinde
# CORRECT:TEXT Steuerb. Vermoegen natuerl. Pers. 75%Quantil
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Personenwagen
# CORRECT:TEXT Gemeinden
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Gemeinden
# CORRECT:TEXT Gemeinden
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Personenwagen
# CORRECT:TEXT Personenwagen
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil GK C
# CORRECT:TEXT Anteil GK C
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT ÖVWege Quell, Ziel und Binnenverkehr
# CORRECT:TEXT Kanton
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Kanton
# CORRECT:TEXT Kanton
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT ÖVWege Quell, Ziel und Binnenverkehr
# CORRECT:TEXT ÖVWege Quell, Ziel und Binnenverkehr
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Nettoaufwand Finanzen und Steuern
# CORRECT:TEXT Bezirk
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirk
# CORRECT:TEXT Bezirk
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand Finanzen und Steuern
# CORRECT:TEXT Nettoaufwand Finanzen und Steuern
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. Landwirtschaft 5 Jahre
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung:
# CORRECT:TEXT Bevoelkerung: Frauen
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Steuerertrag Politische/
# CORRECT:TEXT Bezirk
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirk
# CORRECT:TEXT Bezirk
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerertrag Politische/
# CORRECT:TEXT Steuerertrag Politische/Schulgemeinde
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Bezirk
# CORRECT:TEXT Steuerertrag Politische/Schulgemeinde
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Bezirk
# CORRECT:TEXT Steuerertrag Politische/Schulgemeinde
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Mikrobetriebe
# CORRECT:TEXT Mikrobetriebe 09 VZÄ
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Fremdkapital
# CORRECT:TEXT Fremdkapital
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Reformierte Kirchensteuerpflichtige
# CORRECT:TEXT Reformierte Kirchensteuerpflichtige
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT VZÄ im Primaersektor
# CORRECT:TEXT VZÄ im Primaersektor
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Altersquotient
# CORRECT:TEXT Altersquotient
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT NRW Waehleranteil AL
# CORRECT:TEXT Kanton
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Kanton
# CORRECT:TEXT Kanton
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT NRW Waehleranteil AL
# CORRECT:TEXT NRW Waehleranteil AL
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bevoelkerung:
# CORRECT:TEXT Kanton
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Kanton
# CORRECT:TEXT Kanton
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung:
# CORRECT:TEXT Bevoelkerung: Anteil 4064Jaehrige
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Kanton
# CORRECT:TEXT Bevoelkerung: Anteil 4064Jaehrige
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bezirksebene
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirksebene
# CORRECT:TEXT Bezirksebene
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. Dienstl. 5 Jahre
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Bezirksebene
# CORRECT:TEXT Bauinv. Dienstl. 5 Jahre
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauzonen
# CORRECT:TEXT Bauzonen
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung
# CORRECT:TEXT Bevoelkerung
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Sekundarstufe I
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Beschaeftigte im Tertiaersektor
# CORRECT:TEXT Bezirk
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirk
# CORRECT:TEXT Bezirk
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Beschaeftigte im Tertiaersektor
# CORRECT:TEXT Beschaeftigte im Tertiaersektor
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Wohnungen:
# CORRECT:TEXT Wohnungen: Anteil Eigentumsobjekte
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bauzonen ueberbaut
# CORRECT:TEXT Bezirk
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirk
# CORRECT:TEXT Bezirk
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauzonen ueberbaut
# CORRECT:TEXT Bauzonen ueberbaut
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung: Heimat
# CORRECT:TEXT Bevoelkerung: Heimat Schweiz
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerkraft pro Kopf
# CORRECT:TEXT Steuerkraft pro Kopf
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Mittelschule
# 3
# ENT_LABEL MISC
# ENTITY2 DATA
# ENT_TEXT Bevoelkerungszunahme
# CORRECT:TEXT Bevoelkerungszunahme 5 Jahre
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Schuel.
# CORRECT:TEXT Bezirk
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirk
# CORRECT:TEXT Bezirk
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Berufsschule
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Bezirk
# CORRECT:TEXT Schuel. Berufsschule
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Restaurants pro 1000 Einwohner
# CORRECT:TEXT Restaurants pro 1000 Einwohner
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Wanderungsbilanz
# CORRECT:TEXT Gemeinden
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Gemeinden
# CORRECT:TEXT Gemeinden
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Wanderungsbilanz
# CORRECT:TEXT Wanderungsbilanz
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Erwerb des Schweizer Buergerrechts
# CORRECT:TEXT Erwerb des Schweizer Buergerrechts
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT VZÄ im Sekundaersektor
# CORRECT:TEXT VZÄ im Sekundaersektor
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Berufsschule
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerkraft berichtigt pro Kopf
# CORRECT:TEXT Steuerkraft berichtigt pro Kopf
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerb.
# CORRECT:TEXT Steuerb. Vermoegen natuerl. Pers. 25%Quantil
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Kindergarten
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. Wohnen
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand oeffentliche Ordnung und Sicherheit
# CORRECT:TEXT Nettoaufwand oeffentliche Ordnung und Sicherheit
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. Wohnen
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand Volkswirtschaft
# CORRECT:TEXT Nettoaufwand Volkswirtschaft
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kapitaldienstanteil
# CORRECT:TEXT Kapitaldienstanteil
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bevoelkerung:
# CORRECT:TEXT Kanton
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Kanton
# CORRECT:TEXT Kanton
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung:
# CORRECT:TEXT Bevoelkerung: Anteil 2039Jaehrige
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Kanton
# CORRECT:TEXT Bevoelkerung: Anteil 2039Jaehrige
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung:
# CORRECT:TEXT Bevoelkerung: Maenner
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. EFH 5 Jahre
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geb.
# CORRECT:TEXT Geb.Vol. Dienstleistungen: Zunahme
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Arbeitslosenanteil an Bevoelkerung 1564 Jahre
# CORRECT:TEXT Arbeitslosenanteil an Bevoelkerung 1564 Jahre
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Aerzte
# CORRECT:TEXT Aerzte
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerb.
# CORRECT:TEXT Steuerb. Einkommen natuerl. Pers. 25%Quantil
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Arbeitsstaetten im Sekundaersektor
# CORRECT:TEXT Arbeitsstaetten im Sekundaersektor
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Arbeitslose
# CORRECT:TEXT Bezirksebene
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirksebene
# CORRECT:TEXT Bezirksebene
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Arbeitslose
# CORRECT:TEXT Arbeitslose
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerb.
# CORRECT:TEXT Steuerb. Einkommen natuerl. Pers. Durchschn.
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Kindergarten
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Scheidungen
# CORRECT:TEXT Scheidungen
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Finanzvermoegen
# CORRECT:TEXT Finanzvermoegen
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT ÖVAnteil Modal Split
# CORRECT:TEXT ÖVAnteil Modal Split
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Total VZÄ
# CORRECT:TEXT Bezirke
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirke
# CORRECT:TEXT Bezirke
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Total VZÄ
# CORRECT:TEXT Total VZÄ
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Apotheken
# CORRECT:TEXT Apotheken
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT 5Personenhaushalte
# CORRECT:TEXT 5Personenhaushalte
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kehrichtmengen
# CORRECT:TEXT Kehrichtmengen
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT 15Jahresverbrauch
# CORRECT:TEXT 15Jahresverbrauch
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Altpapiermengen
# CORRECT:TEXT Altpapiermengen
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Nettoaufwand oeffentliche Ordnung und Sicherheit
# CORRECT:TEXT Gemeinde
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Gemeinde
# CORRECT:TEXT Gemeinde
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand oeffentliche Ordnung und Sicherheit
# CORRECT:TEXT Nettoaufwand oeffentliche Ordnung und Sicherheit
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand Verkehr und Nachrichtenuebermittlung
# CORRECT:TEXT Nettoaufwand Verkehr und Nachrichtenuebermittlung
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Durchschnittliche
# CORRECT:TEXT Durchschnittliche Haushaltsgroesse
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauzonen ueberbaut
# CORRECT:TEXT Bauzonen ueberbaut
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Arbeitsstaetten im Tertiaersektor
# CORRECT:TEXT Arbeitsstaetten im Tertiaersektor
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Finanzvermoegen
# CORRECT:TEXT Finanzvermoegen
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil 2Personenhaushalte
# CORRECT:TEXT Anteil 2Personenhaushalte
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geburtenrate
# CORRECT:TEXT Geburtenrate
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerb.
# CORRECT:TEXT Steuerb. Einkommen natuerl. Pers. 25%Quantil
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Wasserverbrauch pro Tag und Kopf
# CORRECT:TEXT Wasserverbrauch pro Tag und Kopf
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bezirksebene
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirksebene
# CORRECT:TEXT Bezirksebene
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. Dienstl. 5 Jahre
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Bezirksebene
# CORRECT:TEXT Bauinv. Dienstl. 5 Jahre
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT 3Personenhaushalte
# CORRECT:TEXT 3Personenhaushalte
# 6
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Ordentlich und an der Quelle Besteuerte
# CORRECT:TEXT Ordentlich und an der Quelle Besteuerte
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Ø Eigenkapital steuerpfl.
# CORRECT:TEXT Ø Eigenkapital steuerpfl. jur. Pers.
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Privathaushalte Total
# CORRECT:TEXT Privathaushalte Total
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerertrag von juristischen Personen
# CORRECT:TEXT Steuerertrag von juristischen Personen
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Ausserhalb des Kt.
# CORRECT:TEXT Gemeinden
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Gemeinden
# CORRECT:TEXT Gemeinden
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Ausserhalb des Kt.
# CORRECT:TEXT Ausserhalb des Kt. wohnhaft Besteuerte
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Gemeinden
# CORRECT:TEXT Ausserhalb des Kt. wohnhaft Besteuerte
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT MIVWege Quell, Ziel und Binnenverkehr
# CORRECT:TEXT Gemeindeebene
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Gemeindeebene
# CORRECT:TEXT Gemeindeebene
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT MIVWege Quell, Ziel und Binnenverkehr
# CORRECT:TEXT MIVWege Quell, Ziel und Binnenverkehr
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bauzonen ueberbaut
# CORRECT:TEXT Bezirk
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirk
# CORRECT:TEXT Bezirk
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauzonen ueberbaut
# CORRECT:TEXT Bauzonen ueberbaut
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Total Quellensteuerpflichtige
# CORRECT:TEXT Bezirksebene
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirksebene
# CORRECT:TEXT Bezirksebene
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Total Quellensteuerpflichtige
# CORRECT:TEXT Total Quellensteuerpflichtige
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Anteil jur. Pers.
# CORRECT:TEXT Region
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Region
# CORRECT:TEXT Region
# 6
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil jur. Pers.
# CORRECT:TEXT Anteil jur. Pers. an allg. Gemeindesteuern
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Region
# CORRECT:TEXT Anteil jur. Pers. an allg. Gemeindesteuern
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Selbstfinanzierung
# CORRECT:TEXT Bezirk
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirk
# CORRECT:TEXT Bezirk
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Selbstfinanzierung
# CORRECT:TEXT Selbstfinanzierung
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Ø Reingewinn steuerpfl.
# CORRECT:TEXT Ø Reingewinn steuerpfl. jur. Pers.
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geb.Vol.
# CORRECT:TEXT Geb.Vol. Landwirtschaft: Zunahme
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettovermoegen
# CORRECT:TEXT Nettovermoegen
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Beschaeftigte im Primaersektor
# CORRECT:TEXT Beschaeftigte im Primaersektor
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Steuerkraft
# CORRECT:TEXT Region
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Region
# CORRECT:TEXT Region
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerkraft
# CORRECT:TEXT Steuerkraft
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Ø Eigenkapital steuerpfl.
# CORRECT:TEXT Ø Eigenkapital steuerpfl. jur. Pers.
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geburtenrate 5J.mittel
# CORRECT:TEXT Geburtenrate 5J.mittel
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schweine
# CORRECT:TEXT Schweine
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Geb.
# CORRECT:TEXT Kanton
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Kanton
# CORRECT:TEXT Kanton
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geb.
# CORRECT:TEXT Geb.Vol. Dienstleistungen: Anteil
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Kanton
# CORRECT:TEXT Geb.Vol. Dienstleistungen: Anteil
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Neuerstellte
# CORRECT:TEXT Neuerstellte Wohnungen
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Total Arbeitsstaetten
# CORRECT:TEXT Gemeindeebene
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Gemeindeebene
# CORRECT:TEXT Gemeindeebene
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Total Arbeitsstaetten
# CORRECT:TEXT Total Arbeitsstaetten
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT VZÄ im Primaersektor
# CORRECT:TEXT VZÄ im Primaersektor
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Restaurants
# CORRECT:TEXT Restaurants
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Anteil unproduktive Flaeche
# CORRECT:TEXT Gemeinde
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Gemeinde
# CORRECT:TEXT Gemeinde
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil unproduktive Flaeche
# CORRECT:TEXT Anteil unproduktive Flaeche
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Hauptberufliche
# CORRECT:TEXT Hauptberufliche Landwirtschaftsbetriebe
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT NRW Waehleranteil
# CORRECT:TEXT Kanton
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Kanton
# CORRECT:TEXT Kanton
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT NRW Waehleranteil
# CORRECT:TEXT NRW Waehleranteil EDU
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Kanton
# CORRECT:TEXT NRW Waehleranteil EDU
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand Kultur, Sport und Freizeit
# CORRECT:TEXT Nettoaufwand Kultur, Sport und Freizeit
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Landwirtschaftliche Nutzflaeche
# CORRECT:TEXT Landwirtschaftliche Nutzflaeche
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettovermoegen
# CORRECT:TEXT Nettovermoegen
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Geb.
# CORRECT:TEXT Kanton
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Kanton
# CORRECT:TEXT Kanton
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geb.
# CORRECT:TEXT Geb.Vol. Infrastruktur: Anteil
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Kanton
# CORRECT:TEXT Geb.Vol. Infrastruktur: Anteil
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauzonen nicht ueberbaut
# CORRECT:TEXT Bauzonen nicht ueberbaut
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bevoelkerung: katholisch
# CORRECT:TEXT Region
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Region
# CORRECT:TEXT Region
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung: katholisch
# CORRECT:TEXT Bevoelkerung: katholisch
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerertrag von juristischen Personen
# CORRECT:TEXT Steuerertrag von juristischen Personen
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Total
# CORRECT:TEXT Total Kirchensteuerpflichtige
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT KRW Waehleranteil EDU
# CORRECT:TEXT KRW Waehleranteil EDU
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Reingewinn juristische Personen
# CORRECT:TEXT Kanton
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Kanton
# CORRECT:TEXT Kanton
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Reingewinn juristische Personen
# CORRECT:TEXT Reingewinn juristische Personen
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerkraft berichtigt pro Kopf
# CORRECT:TEXT Steuerkraft berichtigt pro Kopf
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT 1Personenhaushalte
# CORRECT:TEXT 1Personenhaushalte
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kleine Betriebe 1049 VZÄ
# CORRECT:TEXT Kleine Betriebe 1049 VZÄ
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geb.Vol.
# CORRECT:TEXT Geb.Vol. Wohnen: Zunahme
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung:
# CORRECT:TEXT Bevoelkerung: Frauen
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Hotelbetten pro Hotel
# CORRECT:TEXT Hotelbetten pro Hotel
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerb.
# CORRECT:TEXT Steuerb. Vermoegen natuerl. Pers. Median
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Sozialhilfequote
# CORRECT:TEXT Sozialhilfequote
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Hotelbetten
# CORRECT:TEXT Hotelbetten
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Beschaeftigte im Tertiaersektor
# CORRECT:TEXT Beschaeftigte im Tertiaersektor
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bevoelkerung:
# CORRECT:TEXT Gemeinde
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Gemeinde
# CORRECT:TEXT Gemeinde
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung:
# CORRECT:TEXT Bevoelkerung: Anteil 6579Jaehrige
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Gemeinde
# CORRECT:TEXT Bevoelkerung: Anteil 6579Jaehrige
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Neuzulassungen  Elektromotor
# CORRECT:TEXT Neuzulassungen  Elektromotor
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Mikrobetriebe 09 VZÄ
# CORRECT:TEXT Bezirk
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirk
# CORRECT:TEXT Bezirk
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Mikrobetriebe 09 VZÄ
# CORRECT:TEXT Mikrobetriebe 09 VZÄ
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Total
# CORRECT:TEXT Total Arbeitsstaetten
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. ÖV, Kommunik. 5 Jahre
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerbares Einkommen natuerliche Pers.
# CORRECT:TEXT Steuerbares Einkommen natuerliche Pers.
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Ø Reingewinn steuerpfl.
# CORRECT:TEXT Ø Reingewinn steuerpfl. jur. Pers.
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Mittlere Betriebe 50249 VZÄ
# CORRECT:TEXT Mittlere Betriebe 50249 VZÄ
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Verkaeufe von unbebautem Land
# CORRECT:TEXT Verkaeufe von unbebautem Land
# 6
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nur an der Quelle besteuerte Quellensteuerpfl.
# CORRECT:TEXT Nur an der Quelle besteuerte Quellensteuerpfl.
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Primarschule
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Nettovermoegen
# CORRECT:TEXT Gemeinden
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Gemeinden
# CORRECT:TEXT Gemeinden
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettovermoegen
# CORRECT:TEXT Nettovermoegen
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Privathaushalte Total
# CORRECT:TEXT Privathaushalte Total
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Wahlbeteiligung Kantonsrat
# CORRECT:TEXT Wahlbeteiligung Kantonsrat
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT KRW Waehleranteil
# CORRECT:TEXT Kanton
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Kanton
# CORRECT:TEXT Kanton
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT KRW Waehleranteil
# CORRECT:TEXT KRW Waehleranteil EVP
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Kanton
# CORRECT:TEXT KRW Waehleranteil EVP
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Total ordentlich Besteuerte
# CORRECT:TEXT Total ordentlich Besteuerte
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Auslaenderanteil
# CORRECT:TEXT Auslaenderanteil
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT 6 und mehr Personenhaushalte
# CORRECT:TEXT 6 und mehr Personenhaushalte
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bestand Dieselmotor
# CORRECT:TEXT Bestand Dieselmotor
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. Dienstl. 5 Jahre
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerertrag von natuerlichen Personen
# CORRECT:TEXT Steuerertrag von natuerlichen Personen
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerertrag
# CORRECT:TEXT Steuerertrag Politische/Schulgemeinde
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Schulgemeinde
# CORRECT:TEXT Steuerertrag Politische/Schulgemeinde
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT EFHBestand
# CORRECT:TEXT EFHBestand
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung: uebrige/andere/ohne Konfession
# CORRECT:TEXT Bevoelkerung: uebrige/andere/ohne Konfession
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Neuzulassungen  Hybridantrieb
# CORRECT:TEXT Neuzulassungen  Hybridantrieb
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerertrag
# CORRECT:TEXT Steuerertrag Kirchgemeinden
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. Strassen, PP 5 Jahre
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Fremdkapital
# CORRECT:TEXT Region
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Region
# CORRECT:TEXT Region
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Fremdkapital
# CORRECT:TEXT Fremdkapital
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Total Beschaeftigte
# CORRECT:TEXT Total Beschaeftigte
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gemeindebeitrag an ZVV
# CORRECT:TEXT Gemeinden
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Gemeinden
# CORRECT:TEXT Gemeinden
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeindebeitrag an ZVV
# CORRECT:TEXT Gemeindebeitrag an ZVV
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Motorraeder pro 1000 Einwohner
# CORRECT:TEXT Motorraeder pro 1000 Einwohner
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kuehe
# CORRECT:TEXT Kuehe
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. Industr./Lager 5 Jahre
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT 2Personenhaushalte
# CORRECT:TEXT 2Personenhaushalte
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerb.
# CORRECT:TEXT Steuerb. Vermoegen natuerl. Pers. Durchschn.
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauzonen nicht ueberbaut
# CORRECT:TEXT Bauzonen nicht ueberbaut
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Jugendquotient
# CORRECT:TEXT Jugendquotient
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil EFH am Wohnungsbestand
# CORRECT:TEXT Anteil EFH am Wohnungsbestand
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Restaurants pro 1000 Einwohner
# CORRECT:TEXT Restaurants pro 1000 Einwohner
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerertrag
# CORRECT:TEXT Steuerertrag Politische/Schulgemeinde
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Schulgemeinde
# CORRECT:TEXT Steuerertrag Politische/Schulgemeinde
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT KRW Waehleranteil FDP
# CORRECT:TEXT Bezirksebene
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirksebene
# CORRECT:TEXT Bezirksebene
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT KRW Waehleranteil FDP
# CORRECT:TEXT KRW Waehleranteil FDP
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kapitaldienstanteil
# CORRECT:TEXT Kapitaldienstanteil
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Privathaushalte
# CORRECT:TEXT Privathaushalte Total
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Wegzuege
# CORRECT:TEXT Wegzuege
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Nettoaufwand oeffentliche Ordnung und Sicherheit
# CORRECT:TEXT Bezirksebene
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirksebene
# CORRECT:TEXT Bezirksebene
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand oeffentliche Ordnung und Sicherheit
# CORRECT:TEXT Nettoaufwand oeffentliche Ordnung und Sicherheit
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Investitionsanteil
# CORRECT:TEXT Bezirk
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirk
# CORRECT:TEXT Bezirk
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Investitionsanteil
# CORRECT:TEXT Investitionsanteil
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Neuerstellte MFHWohnungen
# CORRECT:TEXT Kanton
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Kanton
# CORRECT:TEXT Kanton
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Neuerstellte MFHWohnungen
# CORRECT:TEXT Neuerstellte MFHWohnungen
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Hoehe
# CORRECT:TEXT Bezirke
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirke
# CORRECT:TEXT Bezirke
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Hoehe
# CORRECT:TEXT Hoehe
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Unfaelle
# CORRECT:TEXT Gemeindeebene
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Gemeindeebene
# CORRECT:TEXT Gemeindeebene
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Unfaelle
# CORRECT:TEXT Unfaelle
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Neuzulassungen  Dieselmotor
# CORRECT:TEXT Neuzulassungen  Dieselmotor
# 2
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Anteil GK F
# CORRECT:TEXT Kanton
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Kanton
# CORRECT:TEXT Kanton
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil GK F
# CORRECT:TEXT Anteil GK F
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bestand Benzinmotor
# CORRECT:TEXT Kanton
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Kanton
# CORRECT:TEXT Kanton
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bestand Benzinmotor
# CORRECT:TEXT Bestand Benzinmotor
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT 3Personenhaushalte
# CORRECT:TEXT Bezirke
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirke
# CORRECT:TEXT Bezirke
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT 3Personenhaushalte
# CORRECT:TEXT 3Personenhaushalte
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Rinderviehbestand
# CORRECT:TEXT Rinderviehbestand
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Tertiaerstufe
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Heiraten
# CORRECT:TEXT Heiraten
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoinvestitionen
# CORRECT:TEXT Nettoinvestitionen
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geb.
# CORRECT:TEXT Geb.Vol. Wohnen: Zunahme
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT MIVAnteil Modal Split
# CORRECT:TEXT Gemeinde
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Gemeinde
# CORRECT:TEXT Gemeinde
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT MIVAnteil Modal Split
# CORRECT:TEXT MIVAnteil Modal Split
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand Volkswirtschaft
# CORRECT:TEXT Nettoaufwand Volkswirtschaft
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT MIVWege Quell, Ziel und Binnenverkehr
# CORRECT:TEXT Gemeinde
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Gemeinde
# CORRECT:TEXT Gemeinde
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT MIVWege Quell, Ziel und Binnenverkehr
# CORRECT:TEXT MIVWege Quell, Ziel und Binnenverkehr
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT PWNeuzulassungen pro 1000 Einw.
# CORRECT:TEXT PWNeuzulassungen pro 1000 Einw.
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Arbeitsstaetten im Tertiaersektor
# CORRECT:TEXT Arbeitsstaetten im Tertiaersektor
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bestand Dieselmotor
# CORRECT:TEXT Bestand Dieselmotor
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil Landwirtschaftsflaeche
# CORRECT:TEXT Anteil Landwirtschaftsflaeche
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Sterbefaelle
# CORRECT:TEXT Sterbefaelle
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Sterberate
# CORRECT:TEXT Sterberate 5J.mittel
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil 5 Zi.
# CORRECT:TEXT Anteil 5 Zi.Wohnungen
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Investitionsanteil
# CORRECT:TEXT Investitionsanteil
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauzonen ueberbaut
# CORRECT:TEXT Bauzonen ueberbaut
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Steuerb.
# CORRECT:TEXT Bezirk
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirk
# CORRECT:TEXT Bezirk
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerb.
# CORRECT:TEXT Steuerb. Einkommen natuerl. Pers. 25%Quantil
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Bezirk
# CORRECT:TEXT Steuerb. Einkommen natuerl. Pers. 25%Quantil
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Anteil 6 und mehr Personenhaushalte
# CORRECT:TEXT Bezirksebene
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirksebene
# CORRECT:TEXT Bezirksebene
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil 6 und mehr Personenhaushalte
# CORRECT:TEXT Anteil 6 und mehr Personenhaushalte
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Baulandpreis Median
# CORRECT:TEXT Baulandpreis Median
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung:
# CORRECT:TEXT Bevoelkerung: Frauenanteil
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Steuerertrag Politische/
# CORRECT:TEXT Bezirk
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirk
# CORRECT:TEXT Bezirk
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerertrag Politische/
# CORRECT:TEXT Steuerertrag Politische/Schulgemeinde
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Bezirk
# CORRECT:TEXT Steuerertrag Politische/Schulgemeinde
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Wanderungsbilanz
# CORRECT:TEXT Wanderungsbilanz
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Baulandpreis
# CORRECT:TEXT Baulandpreis Median
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Anteil Waldflaeche
# CORRECT:TEXT Kanton
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Kanton
# CORRECT:TEXT Kanton
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil Waldflaeche
# CORRECT:TEXT Anteil Waldflaeche
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT KRW Waehleranteil EDU
# CORRECT:TEXT Bezirk
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirk
# CORRECT:TEXT Bezirk
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT KRW Waehleranteil EDU
# CORRECT:TEXT KRW Waehleranteil EDU
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT KRW Waehleranteil AL
# CORRECT:TEXT KRW Waehleranteil AL
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Schuel.
# CORRECT:TEXT Bezirksebene
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirksebene
# CORRECT:TEXT Bezirksebene
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Primarschule
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Bezirksebene
# CORRECT:TEXT Schuel. Primarschule
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. Ver/Entsorg. 5 Jahre
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerb.
# CORRECT:TEXT Steuerb. Vermoegen natuerl. Pers. 25%Quantil
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Schuel.
# CORRECT:TEXT Gemeinde
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Gemeinde
# CORRECT:TEXT Gemeinde
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Kindergarten
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Gemeinde
# CORRECT:TEXT Schuel. Kindergarten
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT EFHBestand
# CORRECT:TEXT Bezirksebene
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirksebene
# CORRECT:TEXT Bezirksebene
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT EFHBestand
# CORRECT:TEXT EFHBestand
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Aerzte
# CORRECT:TEXT Aerzte
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Heiraten
# CORRECT:TEXT Heiraten
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geb.Vol.
# CORRECT:TEXT Geb.Vol. Landwirtschaft: Anteil
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geb.
# CORRECT:TEXT Geb.Vol. Industrie/Lager: Zunahme
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT KRW Waehleranteil CVP
# CORRECT:TEXT KRW Waehleranteil CVP
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Personalsteuerpflichtige
# CORRECT:TEXT Gemeinde
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Gemeinde
# CORRECT:TEXT Gemeinde
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Personalsteuerpflichtige
# CORRECT:TEXT Personalsteuerpflichtige
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Zinsbelastungsanteil
# CORRECT:TEXT Kanton
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Kanton
# CORRECT:TEXT Kanton
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Zinsbelastungsanteil
# CORRECT:TEXT Zinsbelastungsanteil
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Personenwagen
# CORRECT:TEXT Personenwagen
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerertrag allgemeine Gemeindesteuern
# CORRECT:TEXT Steuerertrag allgemeine Gemeindesteuern
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Nettoaufwand Verkehr und Nachrichtenuebermittlung
# CORRECT:TEXT Bezirksebene
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirksebene
# CORRECT:TEXT Bezirksebene
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand Verkehr und Nachrichtenuebermittlung
# CORRECT:TEXT Nettoaufwand Verkehr und Nachrichtenuebermittlung
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil ohne GK
# CORRECT:TEXT Anteil ohne GK
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Steuerbares Vermoegen natuerliche Pers.
# CORRECT:TEXT Bezirk
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirk
# CORRECT:TEXT Bezirk
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerbares Vermoegen natuerliche Pers.
# CORRECT:TEXT Steuerbares Vermoegen natuerliche Pers.
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Reformierte Kirchensteuerpflichtige
# CORRECT:TEXT Reformierte Kirchensteuerpflichtige
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Primarschule
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil Landwirtschaftsflaeche
# CORRECT:TEXT Anteil Landwirtschaftsflaeche
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kleine Betriebe
# CORRECT:TEXT Kleine Betriebe 1049 VZÄ
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT KRW Waehleranteil SP
# CORRECT:TEXT Bezirk
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirk
# CORRECT:TEXT Bezirk
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT KRW Waehleranteil SP
# CORRECT:TEXT KRW Waehleranteil SP
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Apotheken
# CORRECT:TEXT Apotheken
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT 4Personenhaushalte
# CORRECT:TEXT Kanton
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Kanton
# CORRECT:TEXT Kanton
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT 4Personenhaushalte
# CORRECT:TEXT 4Personenhaushalte
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Wanderungsbilanz
# CORRECT:TEXT Wanderungsbilanz
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Berufsschule
# 3
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Zahnaerzte
# CORRECT:TEXT Zahnaerzte
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bevoelkerung
# CORRECT:TEXT Bezirk
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirk
# CORRECT:TEXT Bezirk
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung
# CORRECT:TEXT Bevoelkerung
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT 4Personenhaushalte
# CORRECT:TEXT 4Personenhaushalte
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung: reformiert
# CORRECT:TEXT Bevoelkerung: reformiert
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Total
# CORRECT:TEXT Total Quellensteuerpflichtige
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Geb.
# CORRECT:TEXT Bezirk
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirk
# CORRECT:TEXT Bezirk
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geb.
# CORRECT:TEXT Geb.Vol. Infrastruktur: Anteil
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Bezirk
# CORRECT:TEXT Geb.Vol. Infrastruktur: Anteil
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Mittelschule
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Verkaeufe von unbebautem Land
# CORRECT:TEXT Verkaeufe von unbebautem Land
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Nettoaufwand Finanzen und Steuern
# CORRECT:TEXT Bezirksebene
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirksebene
# CORRECT:TEXT Bezirksebene
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand Finanzen und Steuern
# CORRECT:TEXT Nettoaufwand Finanzen und Steuern
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Sterbefaelle
# CORRECT:TEXT Sterbefaelle
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand Volkswirtschaft
# CORRECT:TEXT Nettoaufwand Volkswirtschaft
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Eigenkapital steuerpfl.
# CORRECT:TEXT Eigenkapital steuerpfl. jur. Pers.
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bestand Hybridantrieb
# CORRECT:TEXT Bestand Hybridantrieb
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerkraft pro Kopf
# CORRECT:TEXT Steuerkraft pro Kopf
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Restaurants
# CORRECT:TEXT Bezirke
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirke
# CORRECT:TEXT Bezirke
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Restaurants
# CORRECT:TEXT Restaurants
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerb.
# CORRECT:TEXT Steuerb. Vermoegen natuerl. Pers. 75%Quantil
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Ø Reingewinn steuerpfl.
# CORRECT:TEXT Ø Reingewinn steuerpfl. jur. Pers.
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Erwerb des Schweizer Buergerrechts
# CORRECT:TEXT Erwerb des Schweizer Buergerrechts
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT NRW
# CORRECT:TEXT Bezirk
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirk
# CORRECT:TEXT Bezirk
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT NRW
# CORRECT:TEXT NRW Waehleranteil CVP
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Bezirk
# CORRECT:TEXT NRW Waehleranteil CVP
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT EFHBestand
# CORRECT:TEXT EFHBestand
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerertrag Total
# CORRECT:TEXT Steuerertrag Total
# 6
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerkraft ber. arith.
# CORRECT:TEXT Steuerkraft ber. arith. Mittel 3 Jahre
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerungszunahme 5 Jahre
# CORRECT:TEXT Bevoelkerungszunahme 5 Jahre
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Baulandpreis Modell Median
# CORRECT:TEXT Baulandpreis Modell Median
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bestand anderer Antrieb
# CORRECT:TEXT Bestand anderer Antrieb
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. ÖV, Kommunik. 5 Jahre
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauzonen nicht ueberbaut
# CORRECT:TEXT Bauzonen nicht ueberbaut
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT KRW Waehleranteil FDP
# CORRECT:TEXT KRW Waehleranteil FDP
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Verpackungsglasmengen
# CORRECT:TEXT Verpackungsglasmengen
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT 15Jahresverbrauch
# CORRECT:TEXT Kanton
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Kanton
# CORRECT:TEXT Kanton
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT 15Jahresverbrauch
# CORRECT:TEXT 15Jahresverbrauch
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Leerwohnungen
# CORRECT:TEXT Leerwohnungen Total
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Verkaeufe von unbebautem Land
# CORRECT:TEXT Verkaeufe von unbebautem Land
# 1
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirk
# CORRECT:TEXT Bezirk
# 2
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Bezirk
# CORRECT:TEXT Verkaeufe Stockwerkeigentum
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT 5Personenhaushalte
# CORRECT:TEXT 5Personenhaushalte
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Landwirtschaftliche Nutzflaeche
# CORRECT:TEXT Landwirtschaftliche Nutzflaeche
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Geburtenueberschuss
# CORRECT:TEXT Gemeinde
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Gemeinde
# CORRECT:TEXT Gemeinde
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geburtenueberschuss
# CORRECT:TEXT Geburtenueberschuss 5J.mittel
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Gemeinde
# CORRECT:TEXT Geburtenueberschuss 5J.mittel
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geb.
# CORRECT:TEXT Geb.Vol. Industrie/Lager: Anteil
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Hotelbetten
# CORRECT:TEXT Hotelbetten
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Arbeitsstaetten im Primaersektor
# CORRECT:TEXT Arbeitsstaetten im Primaersektor
# 6
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Ordentlich und an der Quelle
# CORRECT:TEXT Ordentlich und an der Quelle Besteuerte
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT MotorradNeuzulasssungen pro 1000 Einw.
# CORRECT:TEXT MotorradNeuzulasssungen pro 1000 Einw.
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Fremdkapital
# CORRECT:TEXT Fremdkapital
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Baulandpreis
# CORRECT:TEXT Baulandpreis Modell Median
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung: uebrige/andere/ohne Konfession
# CORRECT:TEXT Bevoelkerung: uebrige/andere/ohne Konfession
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schweine
# CORRECT:TEXT Schweine
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Wohnungsbestand
# CORRECT:TEXT Bezirksebene
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirksebene
# CORRECT:TEXT Bezirksebene
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Wohnungsbestand
# CORRECT:TEXT Wohnungsbestand
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerb.
# CORRECT:TEXT Steuerb. Vermoegen natuerl. Pers. Durchschn.
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Zuzuege
# CORRECT:TEXT Zuzuege
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Motorraeder pro 1000 Einwohner
# CORRECT:TEXT Motorraeder pro 1000 Einwohner
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT ÖVWege Quell, Ziel und Binnenverkehr
# CORRECT:TEXT ÖVWege Quell, Ziel und Binnenverkehr
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT KRW Waehleranteil SD
# CORRECT:TEXT KRW Waehleranteil SD
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerb.
# CORRECT:TEXT Steuerb. Vermoegen natuerl. Pers. 25%Quantil
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Landwirtschaftsbetriebe
# CORRECT:TEXT Landwirtschaftsbetriebe
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Beschaeftigte im Sekundaersektor
# CORRECT:TEXT Beschaeftigte im Sekundaersektor
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung: Anteil 80 u.m.
# CORRECT:TEXT Bevoelkerung: Anteil 80 u.m.Jaehrige
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand
# CORRECT:TEXT Nettoaufwand Gesundheit
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Anteil Verkehrsflaeche
# CORRECT:TEXT Bezirksebene
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirksebene
# CORRECT:TEXT Bezirksebene
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil Verkehrsflaeche
# CORRECT:TEXT Anteil Verkehrsflaeche
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Personalsteuerpflichtige
# CORRECT:TEXT Personalsteuerpflichtige
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Neuzulassungen anderer Antrieb
# CORRECT:TEXT Gemeinde
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Gemeinde
# CORRECT:TEXT Gemeinde
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Neuzulassungen anderer Antrieb
# CORRECT:TEXT Neuzulassungen anderer Antrieb
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Steuerpflichtige juristische Personen
# CORRECT:TEXT Region
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Region
# CORRECT:TEXT Region
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerpflichtige juristische Personen
# CORRECT:TEXT Steuerpflichtige juristische Personen
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Motorraeder pro 1000 Einwohner
# CORRECT:TEXT Region
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Region
# CORRECT:TEXT Region
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Motorraeder pro 1000 Einwohner
# CORRECT:TEXT Motorraeder pro 1000 Einwohner
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Personenwagen pro 1000 Einwohner
# CORRECT:TEXT Personenwagen pro 1000 Einwohner
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Jugendquotient
# CORRECT:TEXT Jugendquotient
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Zahnaerzte
# CORRECT:TEXT Zahnaerzte
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT KRW Waehleranteil
# CORRECT:TEXT Kanton
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Kanton
# CORRECT:TEXT Kanton
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT KRW Waehleranteil
# CORRECT:TEXT KRW Waehleranteil BDP
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Kanton
# CORRECT:TEXT KRW Waehleranteil BDP
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT 2Personenhaushalte
# CORRECT:TEXT 2Personenhaushalte
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schafe
# CORRECT:TEXT Schafe
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT VZÄ im Tertiaersektor
# CORRECT:TEXT VZÄ im Tertiaersektor
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil GK D
# CORRECT:TEXT Anteil GK D
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauzonen nicht ueberbaut
# CORRECT:TEXT Bauzonen nicht ueberbaut
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bezirke
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirke
# CORRECT:TEXT Bezirke
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. Industr./Lager 5 Jahre
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Bezirke
# CORRECT:TEXT Bauinv. Industr./Lager 5 Jahre
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Eigenkapital
# CORRECT:TEXT Eigenkapital
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung:
# CORRECT:TEXT Bevoelkerung: Anteil 6579Jaehrige
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Anteil 2Personenhaushalte
# CORRECT:TEXT Region
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Region
# CORRECT:TEXT Region
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil 2Personenhaushalte
# CORRECT:TEXT Anteil 2Personenhaushalte
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Kindergarten
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauzonen ueberbaut
# CORRECT:TEXT Bauzonen ueberbaut
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Motorraeder
# CORRECT:TEXT Motorraeder
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bruttoverschuldungsanteil
# CORRECT:TEXT Bezirke
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirke
# CORRECT:TEXT Bezirke
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bruttoverschuldungsanteil
# CORRECT:TEXT Bruttoverschuldungsanteil
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerb.
# CORRECT:TEXT Steuerb. Einkommen natuerl. Pers. 75%Quantil
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bezirk
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirk
# CORRECT:TEXT Bezirk
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. ÖV, Kommunik. 5 Jahre
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Bezirk
# CORRECT:TEXT Bauinv. ÖV, Kommunik. 5 Jahre
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Heiraten
# CORRECT:TEXT Heiraten
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bruttoverschuldungsanteil
# CORRECT:TEXT Gemeinden
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Gemeinden
# CORRECT:TEXT Gemeinden
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bruttoverschuldungsanteil
# CORRECT:TEXT Bruttoverschuldungsanteil
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Oberstufe
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bezirke
# ...
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Neuerstellte
# CORRECT:TEXT Neuerstellte EFH
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Hotelbetten pro Hotel
# CORRECT:TEXT Hotelbetten pro Hotel
# 6
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Ordentlich und an der Quelle Besteuerte
# CORRECT:TEXT Ordentlich und an der Quelle Besteuerte
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand allgemeine Verwaltung
# CORRECT:TEXT Nettoaufwand allgemeine Verwaltung
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Landwirtschaftsbetriebe
# CORRECT:TEXT Landwirtschaftsbetriebe
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Wohnungsbestand
# CORRECT:TEXT Wohnungsbestand
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Erwerb des Schweizer Buergerrechts
# CORRECT:TEXT Erwerb des Schweizer Buergerrechts
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT MotorradNeuzulassungen
# CORRECT:TEXT MotorradNeuzulassungen
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schafe
# CORRECT:TEXT Schafe
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Apotheken
# CORRECT:TEXT Apotheken
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Steuerkraft ber. arith.
# CORRECT:TEXT Kanton
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Kanton
# CORRECT:TEXT Kanton
# 6
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerkraft ber. arith.
# CORRECT:TEXT Steuerkraft ber. arith. Mittel 3 Jahre
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Kanton
# CORRECT:TEXT Steuerkraft ber. arith. Mittel 3 Jahre
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Landwirtschaftsbetriebe
# CORRECT:TEXT Landwirtschaftsbetriebe
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Scheidungen
# CORRECT:TEXT Bezirksebene
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirksebene
# CORRECT:TEXT Bezirksebene
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Scheidungen
# CORRECT:TEXT Scheidungen
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT NRW Waehleranteil
# CORRECT:TEXT NRW Waehleranteil GLP
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Berufsschule
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT PWNeuzulassungen pro 1000 Einw.
# CORRECT:TEXT PWNeuzulassungen pro 1000 Einw.
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Reformierte Kirchensteuerpflichtige
# CORRECT:TEXT Reformierte Kirchensteuerpflichtige
# 4
# ENT_LABEL MISC
# ENTITY2 DATA
# ENT_TEXT Steuerbares
# CORRECT:TEXT Steuerbares Vermoegen natuerliche Pers.
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT 2Personenhaushalte
# CORRECT:TEXT Bezirke
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirke
# CORRECT:TEXT Bezirke
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT 2Personenhaushalte
# CORRECT:TEXT 2Personenhaushalte
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Anteil GK F
# CORRECT:TEXT Bezirk
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirk
# CORRECT:TEXT Bezirk
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil GK F
# CORRECT:TEXT Anteil GK F
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Neuzulassungen anderer Antrieb
# CORRECT:TEXT Bezirk
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirk
# CORRECT:TEXT Bezirk
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Neuzulassungen anderer Antrieb
# CORRECT:TEXT Neuzulassungen anderer Antrieb
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Anteil Teilzeitbeschaeftigte Landwirtschaft
# CORRECT:TEXT Bezirksebene
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirksebene
# CORRECT:TEXT Bezirksebene
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil Teilzeitbeschaeftigte Landwirtschaft
# CORRECT:TEXT Anteil Teilzeitbeschaeftigte Landwirtschaft
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung:
# CORRECT:TEXT Bevoelkerung: Maenneranteil
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung: reformiert
# CORRECT:TEXT Bevoelkerung: reformiert
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Apotheken
# CORRECT:TEXT Apotheken
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Geburtenrate
# CORRECT:TEXT Gemeindeebene
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Gemeindeebene
# CORRECT:TEXT Gemeindeebene
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geburtenrate
# CORRECT:TEXT Geburtenrate
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT NRW
# CORRECT:TEXT NRW Waehleranteil SP
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Wanderungsbilanz
# CORRECT:TEXT Wanderungsbilanz
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauzonen nicht ueberbaut
# CORRECT:TEXT Bauzonen nicht ueberbaut
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Geburtenrate 5J.mittel
# CORRECT:TEXT Gemeindeebene
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Gemeindeebene
# CORRECT:TEXT Gemeindeebene
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geburtenrate 5J.mittel
# CORRECT:TEXT Geburtenrate 5J.mittel
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Total Quellensteuerpflichtige
# CORRECT:TEXT Total Quellensteuerpflichtige
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT PWNeuzulassungen
# CORRECT:TEXT PWNeuzulassungen
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Personalsteuerpflichtige
# CORRECT:TEXT Personalsteuerpflichtige
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Ø Eigenkapital steuerpfl.
# CORRECT:TEXT Bezirk
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirk
# CORRECT:TEXT Bezirk
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Ø Eigenkapital steuerpfl.
# CORRECT:TEXT Ø Eigenkapital steuerpfl. jur. Pers.
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Bezirk
# CORRECT:TEXT Ø Eigenkapital steuerpfl. jur. Pers.
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT ZLBezuegerquote der Personen ab 65 Jahren
# CORRECT:TEXT Gemeindeebene
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Gemeindeebene
# CORRECT:TEXT Gemeindeebene
# 6
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT ZLBezuegerquote der Personen ab 65 Jahren
# CORRECT:TEXT ZLBezuegerquote der Personen ab 65 Jahren
# 6
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. Spital, Kultur usw. 5 J.
# 6
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Ordentlich und an der Quelle Besteuerte
# CORRECT:TEXT Ordentlich und an der Quelle Besteuerte
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Zinsbelastungsanteil
# CORRECT:TEXT Zinsbelastungsanteil
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schafe
# CORRECT:TEXT Schafe
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Apotheken
# CORRECT:TEXT Apotheken
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT KRW Waehleranteil EVP
# CORRECT:TEXT KRW Waehleranteil EVP
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Verkaeufe von unbebautem Land
# CORRECT:TEXT Verkaeufe von unbebautem Land
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Steuerb.
# CORRECT:TEXT Bezirk
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirk
# CORRECT:TEXT Bezirk
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerb.
# CORRECT:TEXT Steuerb. Einkommen natuerl. Pers. Median
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Bezirk
# CORRECT:TEXT Steuerb. Einkommen natuerl. Pers. Median
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Eigenkapital
# CORRECT:TEXT Eigenkapital
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Beschaeftigte im Primaersektor
# CORRECT:TEXT Kanton
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Kanton
# CORRECT:TEXT Kanton
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Beschaeftigte im Primaersektor
# CORRECT:TEXT Beschaeftigte im Primaersektor
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Sekundarstufe II
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kleine Betriebe
# CORRECT:TEXT Kleine Betriebe 1049 VZÄ
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Mittlere Betriebe
# CORRECT:TEXT Mittlere Betriebe 50249 VZÄ
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Scheidungen
# CORRECT:TEXT Scheidungen
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Total Beschaeftigte
# CORRECT:TEXT Total Beschaeftigte
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Nettoaufwand Umweltschutz und Raumordnung
# CORRECT:TEXT Kanton
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Kanton
# CORRECT:TEXT Kanton
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand Umweltschutz und Raumordnung
# CORRECT:TEXT Nettoaufwand Umweltschutz und Raumordnung
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Selbstfinanzierung
# CORRECT:TEXT Selbstfinanzierung
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT NRW Waehleranteil
# CORRECT:TEXT NRW Waehleranteil SD
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Wasserverbrauch pro Tag und Kopf
# CORRECT:TEXT Wasserverbrauch pro Tag und Kopf
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Steuerb.
# CORRECT:TEXT Region
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Region
# CORRECT:TEXT Region
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerb.
# CORRECT:TEXT Steuerb. Vermoegen natuerl. Pers. Median
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Region
# CORRECT:TEXT Steuerb. Vermoegen natuerl. Pers. Median
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Zuzuege
# CORRECT:TEXT Zuzuege
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Hotelbetten
# CORRECT:TEXT Hotelbetten
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Durchschnittliche Haushaltsgroesse
# CORRECT:TEXT Bezirksebene
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirksebene
# CORRECT:TEXT Bezirksebene
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Durchschnittliche Haushaltsgroesse
# CORRECT:TEXT Durchschnittliche Haushaltsgroesse
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Anteil ohne GK
# CORRECT:TEXT Region
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Region
# CORRECT:TEXT Region
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil ohne GK
# CORRECT:TEXT Anteil ohne GK
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Wanderungsbilanz
# CORRECT:TEXT Wanderungsbilanz
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung
# CORRECT:TEXT Bevoelkerung
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Erwerb des Schweizer Buergerrechts
# CORRECT:TEXT Erwerb des Schweizer Buergerrechts
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Steuerb.
# CORRECT:TEXT Gemeindeebene
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Gemeindeebene
# CORRECT:TEXT Gemeindeebene
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerb.
# CORRECT:TEXT Steuerb. Vermoegen natuerl. Pers. Durchschn.
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Gemeindeebene
# CORRECT:TEXT Steuerb. Vermoegen natuerl. Pers. Durchschn.
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Unfaelle
# CORRECT:TEXT Unfaelle
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bestand Benzinmotor
# CORRECT:TEXT Gemeinde
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Gemeinde
# CORRECT:TEXT Gemeinde
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bestand Benzinmotor
# CORRECT:TEXT Bestand Benzinmotor
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Schuel.
# CORRECT:TEXT Region
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Region
# CORRECT:TEXT Region
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Mittelschule
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Region
# CORRECT:TEXT Schuel. Mittelschule
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Arbeitsstaetten im Sekundaersektor
# CORRECT:TEXT Arbeitsstaetten im Sekundaersektor
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Hauptberufliche Landwirtschaftsbetriebe
# CORRECT:TEXT Hauptberufliche Landwirtschaftsbetriebe
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT NRW Waehleranteil
# CORRECT:TEXT NRW Waehleranteil CVP
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Wegzuege
# CORRECT:TEXT Wegzuege
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geburtenrate 5J.mittel
# CORRECT:TEXT Geburtenrate 5J.mittel
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kehrichtmengen
# CORRECT:TEXT Kehrichtmengen
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geburtenueberschuss 5J.mittel
# CORRECT:TEXT Geburtenueberschuss 5J.mittel
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand Bildung
# CORRECT:TEXT Nettoaufwand Bildung
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand Gesundheit
# CORRECT:TEXT Nettoaufwand Gesundheit
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Zahnaerzte
# CORRECT:TEXT Zahnaerzte
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Verkaeufe Stockwerkeigentum
# CORRECT:TEXT Region
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Region
# CORRECT:TEXT Region
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Verkaeufe Stockwerkeigentum
# CORRECT:TEXT Verkaeufe Stockwerkeigentum
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerungsdichte
# CORRECT:TEXT Bevoelkerungsdichte
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Restaurants
# CORRECT:TEXT Restaurants
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Total geschaffene Stellen, Beschaeftigte
# CORRECT:TEXT Total geschaffene Stellen, Beschaeftigte
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Sterbefaelle
# CORRECT:TEXT Sterbefaelle
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Anteil 5 Zi.
# CORRECT:TEXT Gemeindeebene
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Gemeindeebene
# CORRECT:TEXT Gemeindeebene
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil 5 Zi.
# CORRECT:TEXT Anteil 5 Zi.Wohnungen
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Gemeindeebene
# CORRECT:TEXT Anteil 5 Zi.Wohnungen
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT 5Personenhaushalte
# CORRECT:TEXT 5Personenhaushalte
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Schuel.
# CORRECT:TEXT Gemeinde
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Gemeinde
# CORRECT:TEXT Gemeinde
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Oberstufe
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Gemeinde
# CORRECT:TEXT Schuel. Oberstufe
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Total ordentlich Besteuerte
# CORRECT:TEXT Region
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Region
# CORRECT:TEXT Region
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Total ordentlich Besteuerte
# CORRECT:TEXT Total ordentlich Besteuerte
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung:
# CORRECT:TEXT Bevoelkerung: Durchschnittsalter
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil 3Personenhaushalte
# CORRECT:TEXT Anteil 3Personenhaushalte
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Beschaeftigte im Gastgewerbe: Anteil
# CORRECT:TEXT Beschaeftigte im Gastgewerbe: Anteil
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Wegzuege
# CORRECT:TEXT Wegzuege
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Geb.
# CORRECT:TEXT Bezirk
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirk
# CORRECT:TEXT Bezirk
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geb.
# CORRECT:TEXT Geb.Vol. Nebengebaeude: Anteil
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Bezirk
# CORRECT:TEXT Geb.Vol. Nebengebaeude: Anteil
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geburtenrate
# CORRECT:TEXT Geburtenrate
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerkraft
# CORRECT:TEXT Steuerkraft
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Wegzuege
# CORRECT:TEXT Kanton
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Kanton
# CORRECT:TEXT Kanton
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Wegzuege
# CORRECT:TEXT Wegzuege
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT VZÄ im Tertiaersektor
# CORRECT:TEXT VZÄ im Tertiaersektor
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Hauptberufliche Landwirtschaftsbetriebe
# CORRECT:TEXT Hauptberufliche Landwirtschaftsbetriebe
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Restaurants
# CORRECT:TEXT Restaurants
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT 3Personenhaushalte
# CORRECT:TEXT 3Personenhaushalte
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Beschaeftigte im Gastgewerbe:
# CORRECT:TEXT Beschaeftigte im Gastgewerbe: Anteil
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Geb.
# CORRECT:TEXT Region
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Region
# CORRECT:TEXT Region
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geb.
# CORRECT:TEXT Geb.Vol. Nebengebaeude: Zunahme
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Region
# CORRECT:TEXT Geb.Vol. Nebengebaeude: Zunahme
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Flaeche
# CORRECT:TEXT Gemeinden
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Gemeinden
# CORRECT:TEXT Gemeinden
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Flaeche
# CORRECT:TEXT Flaeche
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Geb.
# CORRECT:TEXT Bezirke
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirke
# CORRECT:TEXT Bezirke
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geb.
# CORRECT:TEXT Geb.Vol. Infrastruktur: Zunahme
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Bezirke
# CORRECT:TEXT Geb.Vol. Infrastruktur: Zunahme
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Arbeitsstaetten im Tertiaersektor
# CORRECT:TEXT Arbeitsstaetten im Tertiaersektor
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Anteil Vollzeitbeschaeftigte Landwirtschaft
# CORRECT:TEXT Bezirk
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirk
# CORRECT:TEXT Bezirk
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil Vollzeitbeschaeftigte Landwirtschaft
# CORRECT:TEXT Anteil Vollzeitbeschaeftigte Landwirtschaft
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Geb.
# CORRECT:TEXT Gemeindeebene
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Gemeindeebene
# CORRECT:TEXT Gemeindeebene
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geb.
# CORRECT:TEXT Geb.Vol. Industrie/Lager: Anteil
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Gemeindeebene
# CORRECT:TEXT Geb.Vol. Industrie/Lager: Anteil
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeindebeitrag an ZVV
# CORRECT:TEXT Gemeindebeitrag an ZVV
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Schuel.
# CORRECT:TEXT Bezirk
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirk
# CORRECT:TEXT Bezirk
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Tertiaerstufe
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Bezirk
# CORRECT:TEXT Schuel. Tertiaerstufe

# %%
for key in word_evaluation:
    correct = word_evaluation[key]["correct"]
    total = word_evaluation[key]["total"]

    print(f"{key}: {correct / total * 100:.2f}%")

stat_total_sum = 0
stat_correct_sum = 0

print("---")
for key in stat_evaluation:
    correct = stat_evaluation[key]["correct"]
    total = stat_evaluation[key]["total"]
    
    stat_total_sum += total
    stat_correct_sum += correct

    print(f"{key}: {correct / total * 100:.2f}%")

print(f"\nTotal: {stat_correct_sum/stat_total_sum * 100:.2f}%")
# Out:
# GRAN: 100.00%
# DATA: 68.50%
# ---
# GRAN: 100.00%
# DATA: 68.50%
#
# Total: 75.38%

# %%
# dictionary which will be populated with the entities and result information
entity_evaluation = {}

# helper function to udpate the entity_evaluation dictionary
def update_results(entity, metric):
    if entity not in entity_evaluation:
        entity_evaluation[entity] = {"correct": 0, "total": 0}
    
    entity_evaluation[entity][metric] += 1

# same as before, see if entities from test set match what spaCy currently predicts
for data in TEST_REVISION_DATA:
    sentence = data[0]
    entities = data[1]["entities"]

    for entity in entities:
        doc = nlp(sentence)
        correct_text = sentence[entity[0]:entity[1]]

        for ent in doc.ents:
            if ent.label_ == entity[2] and ent.text == correct_text:
                update_results(ent.label_, "correct")
                break

        update_results(entity[2], "total")

# %%
sum_total = 0
sum_correct = 0

for entity in entity_evaluation:
    total = entity_evaluation[entity]["total"]
    correct = entity_evaluation[entity]["correct"]

    sum_total += total
    sum_correct += correct
    
    print("{} | {:.2f}%".format(entity, correct / total * 100))

print()
print("Overall accuracy: {:.2f}%".format(sum_correct / sum_total * 100))
# Out:
# MISC | 81.73%
# LOC | 82.25%
# ORG | 88.79%
# PER | 93.97%
#
# Overall accuracy: 85.99%

# %%
nlp.meta["name"] = "stat_entity_extractor_v1"
nlp.to_disk("./models/v1")

# %%
TRAIN_STAT_DATA[5]
# Out:
# ['Ich brauche Schuel. Oberstufe ', {'entities': [[12, 29, 'DATA']]}]

# %%
doc = nlp(u'Welche Gemeinde hat die grösste Bevölkerung und welche hatte im 2019 den höchsten Ausländeranteil?')

# show universal pos tags
print(' '.join('{word}/{tag}'.format(word=t.orth_, tag=t.pos_) for t in doc))
# output: Ich/PRON bin/AUX ein/DET Berliner/NOUN ./PUNCT

# show German specific pos tags (STTS)
print(' '.join('{word}/{tag}'.format(word=t.orth_, tag=t.tag_) for t in doc))
# output: Ich/PPER bin/VAFIN ein/ART Berliner/NN ./$.

# show dependency arcs
print('\n'.join('{child:<8} <{label:-^7} {head}'.format(child=t.orth_, label=t.dep_, head=t.head.orth_) for t in doc))
# output: (sb: subject, nk: noun kernel, pd: predicate)

#named entities
print("Named Entity Recognition:")
for ent in doc.ents:
    print(ent.text)
print("Noun chunks:")
for chunk in doc.noun_chunks:
    print(chunk.text)
# Out:
# Welche/DET Gemeinde/NOUN hat/AUX die/DET grösste/ADJ Bevölkerung/NOUN und/CCONJ welche/PRON hatte/AUX im/ADP 2019/PROPN den/DET höchsten/ADJ Ausländeranteil/NOUN ?/PUNCT
# Welche/PWAT Gemeinde/NN hat/VAFIN die/ART grösste/ADJA Bevölkerung/NN und/KON welche/PDS hatte/VAFIN im/APPRART 2019/CARD den/ART höchsten/ADJA Ausländeranteil/NN ?/$.
# Welche   <--nk--- Gemeinde
# Gemeinde <--sb--- hat
# hat      <-ROOT-- hat
# die      <--nk--- Bevölkerung
# grösste  <--nk--- Bevölkerung
# Bevölkerung <--oa--- hat
# und      <--cd--- Bevölkerung
# welche   <--cj--- und
# hatte    <--cj--- hat
# im       <--mo--- hatte
# 2019     <--nk--- im
# den      <--nk--- Ausländeranteil
# höchsten <--nk--- Ausländeranteil
# Ausländeranteil <--oa--- hatte
# ?        <-punct- hat
# Named Entity Recognition:
# Gemeinde
# Noun chunks:
# Welche Gemeinde
# die grösste Bevölkerung
# welche
# 2019
# den höchsten Ausländeranteil
