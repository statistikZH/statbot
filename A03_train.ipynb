# %%
from __future__ import print_function, unicode_literals
import spacy
import warnings
from spacy.util import minibatch, compounding
import de_core_news_lg
import pandas as pd
import numpy as np
from random import sample
import io, csv
import re
import random
import de_core_news_lg
import json
from spacy.training import Example
from spacy.tokens import Doc
nlp = spacy.load('de_core_news_lg')

# %%
# helper function for incrementing the revision counters
def increment_revision_counters(entity_counter, entities):
    for entity in entities:
        label = entity[2]
        if label in entity_counter:
            entity_counter[label] += 1
        else:
            entity_counter[label] = 1

# %%
#out_sentences=open("input/tagged_sentences.csv", "r").readlines()
with open('input/tagged_sentences.json') as json_file:
    out_sentences = json.load(json_file)
print("LENGTH OF DATASET: ",len(out_sentences))
dataset_dict={}

for sent in out_sentences:
    entities = sent[1]["entities"]
    increment_revision_counters(dataset_dict, entities)
#    print(entity[1])
    #helper_dict.append(entity[1]['entities'][0][2])
#out_sentences[:5]
print(dataset_dict)
# Out:
# LENGTH OF DATASET:  1020
# {'DATA': 1010, 'GRAN': 282}

# %%
npr_df = pd.read_csv("external/deu_news_2015_3M-sentences.txt", delimiter = "\t")
npr_df=npr_df.sample(frac=1)
npr_df.head()
# Out:
#                1                                                  ­
# 44365      46308  Aber mit den anderen muss man natürlich reden“...
# 1144264  1203424  Eine Nutzerin schreibt, niemand sei wütend auf...
# 1567360  1654327  Im Sommer 2014 beim überraschenden Aufstieg de...
# 2450017  2581907  We Care A Lot wurde übrigens für das zweite Al...
# 2635306  2779648  Zu wenig Individualisierung Im Falle der Locks...

# %%
# create an nlp object as we'll use this to seperate the sentences and identify existing entities
#loaded already above
#nlp = spacy.load('de_core_news_lg')

# %%
revision_texts = []

# convert the articles to spacy objects to better identify the sentences. Disabled unneeded components. # takes ~ 4 minutes
for doc in nlp.pipe(npr_df.iloc[:100000,1], batch_size=30, disable=["tagger", "ner"]):
    for sentence in doc.sents:
        if  40 < len(sentence.text) < 80:
            # some of the sentences had excessive whitespace in between words, so we're trimming that
            revision_texts.append(" ".join(re.split("\s+", sentence.text, flags=re.UNICODE)))

# %%
revisions = []

# Use the existing spaCy model to predict the entities, then append them to revision
for doc in nlp.pipe(revision_texts, batch_size=50, disable=["tagger", "parser"]):
    
    # don't append sentences that have no entities
    if len(doc.ents) > 0:
        revisions.append((doc.text, {"entities": [(e.start_char, e.end_char, e.label_) for e in doc.ents]}))

# %%
# print an example of the revision sentence
print(revisions[0][0])

# print an example of the revision data
print(revisions[0][1])
# Out:
# Aber mit den anderen muss man natürlich reden“, sagte Oppermann.
# {'entities': [(54, 63, 'PER')]}

# %%
# create arrays to store the revision data
TRAIN_REVISION_DATA = []
TEST_REVISION_DATA = []

# create dictionaries to keep count of the different entities
TRAIN_ENTITY_COUNTER = {}
TEST_ENTITY_COUNTER = {}

# This will help distribute the entities (i.e. we don't want 1000 PERSON entities, but only 80 ORG entities)
REVISION_SENTENCE_SOFT_LIMIT = 100



random.shuffle(revisions)
for revision in revisions:
    # get the entities from the revision sentence
    entities = revision[1]["entities"]

    # simple hack to make sure spaCy entities don't get too one-sided
    should_append_to_train_counter = 0
    for _, _, label in entities:
        if label in TRAIN_ENTITY_COUNTER and TRAIN_ENTITY_COUNTER[label] > REVISION_SENTENCE_SOFT_LIMIT:
            should_append_to_train_counter -= 1
        else:
            should_append_to_train_counter += 1

    # simple switch for deciding whether to append to train data or test data
    if should_append_to_train_counter >= 0:
        TRAIN_REVISION_DATA.append(revision)
        increment_revision_counters(TRAIN_ENTITY_COUNTER, entities)
    else:
        TEST_REVISION_DATA.append(revision)
        increment_revision_counters(TEST_ENTITY_COUNTER, entities)

# %%
TRAIN_ENTITY_COUNTER
# Out:
# {'LOC': 107, 'MISC': 102, 'PER': 101, 'ORG': 102}

# %%
TEST_ENTITY_COUNTER
# Out:
# {'LOC': 7993, 'MISC': 7495, 'ORG': 5806, 'PER': 7132}

# %%
TRAIN_REVISION_DATA
# Out:
# [('In Ferguson hatte der Behörden\xadrassismus System.',
#   {'entities': [(3, 11, 'LOC'), (22, 47, 'MISC')]}),
#  ('Doch ganz ohne Klischees kommt auch „Barbara“ nicht aus.',
#   {'entities': [(37, 44, 'PER')]}),
#  ('Seit Mittwoch verschwunden: Wo ist der kleine Elias (6)?',
#   {'entities': [(5, 13, 'PER'), (46, 51, 'PER')]}),
#  ('Intel strebt das größte Portfolio für IoT-Komopnenten am Markt an.',
#   {'entities': [(0, 5, 'ORG'), (38, 53, 'MISC')]}),
#  ('Zum großen Handy-Kamera-Test Rechtsschutz\xadversicherung',
#   {'entities': [(11, 54, 'MISC')]}),
#  ('Resultate und Tabelle: Sampdoria Genua - Fiorentina 0:2 (0:1).',
#   {'entities': [(23, 38, 'ORG'), (41, 51, 'ORG')]}),
#  ('Berner Stadtpräsident im freien Fall Aktualisiert um 06:53 7 Kommentare',
#   {'entities': [(0, 6, 'LOC'), (37, 49, 'MISC')]}),
#  ('KRUGFOTO Peter Zeidler ist nicht länger Trainer von Red Bull Salzburg.',
#   {'entities': [(0, 22, 'PER'), (52, 69, 'ORG')]}),
#  ('In den USA sind die Bauausgaben im Juni schwächer als erwartet gestiegen.',
#   {'entities': [(3, 10, 'LOC'), (20, 31, 'LOC')]}),
#  ('Gold geht an Norwegen, Österreich auf Platz 2, dahinter Polen.',
#   {'entities': [(13, 21, 'LOC'), (23, 33, 'LOC'), (56, 61, 'LOC')]}),
#  ('Nach MDR haben einige Flüchtlinge nun Angst vor den Deutschen.',
#   {'entities': [(5, 8, 'ORG'), (52, 61, 'MISC')]}),
#  ('In der Türkei sind zwei Soldaten getötet worden.',
#   {'entities': [(7, 13, 'LOC')]}),
#  ('Diese schlängelt sich zwischen Treuchtlingen und Ingolstadt.',
#   {'entities': [(31, 44, 'LOC'), (49, 59, 'LOC')]}),
#  ('Anschließend pendelte sie zwei Jahre ins Spital nach Ried.',
#   {'entities': [(53, 57, 'LOC')]}),
#  ('Einerseits, weil das Rätseldesign immer dem gleichen Muster folgt.',
#   {'entities': [(21, 33, 'LOC')]}),
#  ('Die Temperatur erinnert an die Badi-Zeit.',
#   {'entities': [(31, 40, 'LOC')]}),
#  ('Die Hürde scheint für ihn vielmehr Zampano Ecclestone selbst zu sein.',
#   {'entities': [(35, 53, 'PER')]}),
#  ('Sygnis Aktie Bezugsrechtsangebot, Zeichnen bis 7.12.2015',
#   {'entities': [(0, 32, 'ORG')]}),
#  ('Der Deutsche Judo-Bund (DJB) trauert um Heiner Metzler.',
#   {'entities': [(4, 22, 'ORG'), (24, 27, 'ORG'), (40, 54, 'PER')]}),
#  ('Die haben genau so viele Rechte in dieser Sache wie Zb.',
#   {'entities': [(52, 54, 'LOC')]}),
#  ('Der Dax hat zum Start in die neue Woche eine Atempause eingelegt.',
#   {'entities': [(4, 7, 'ORG')]}),
#  ('Die HH-Geschäftsleitung arbeitet immer noch an Felix Versetzung.',
#   {'entities': [(4, 23, 'ORG'), (47, 52, 'PER')]}),
#  ('Autobombe explodiert in belebtem Markt in Bagdad',
#   {'entities': [(42, 48, 'LOC')]}),
#  ('Niemand stört, kein Handy klingelt, endlich mal Zeit für nur sich selbst.',
#   {'entities': [(0, 7, 'ORG'), (48, 52, 'MISC')]}),
#  ('QGroup GmbH Sicherheitslücke im Netz des Bundestages?',
#   {'entities': [(41, 52, 'ORG')]}),
#  ('Der Dow-Jones-Index gewann 0,8 Prozent auf 16.740 Punkte.',
#   {'entities': [(4, 19, 'MISC')]}),
#  ('Agawi war 2010 als iSwifter gegründet worden.',
#   {'entities': [(0, 5, 'PER'), (19, 27, 'MISC')]}),
#  ('Aber dann begann sein Engagement für die Wiener Sozialdemokratie.',
#   {'entities': [(41, 64, 'ORG')]}),
#  ('Dammweg in Treptow zu einem schweren Verkehrsunfall gekommen.',
#   {'entities': [(11, 18, 'LOC')]}),
#  ('Alle Angebote anzeigen Prinzessin Charlotte in den Armen von Brüderchen',
#   {'entities': [(34, 43, 'PER'), (61, 71, 'LOC')]}),
#  ('Das neue Mate 8 von Huawei (Bild: Huawei)',
#   {'entities': [(20, 26, 'ORG'), (34, 40, 'ORG')]}),
#  ('Neue türkische Angriffe auf Kurden im Irak',
#   {'entities': [(5, 14, 'MISC'), (28, 34, 'LOC'), (38, 42, 'LOC')]}),
#  ('Auch der Wiederaufbau von Sergios Auto war eine große Herausforderung.',
#   {'entities': [(26, 38, 'ORG')]}),
#  ('Die beiden Österreicher meistern ihre Auftakthürden erfolgreich.',
#   {'entities': [(11, 23, 'LOC')]}),
#  ('Bilder von der "Grünen Woche" in Berlin Kostprobe gefällig?',
#   {'entities': [(15, 28, 'ORG'), (33, 39, 'LOC')]}),
#  ('Promihunde: Bunt, verwöhnt oder ganz normal',
#   {'entities': [(0, 16, 'MISC')]}),
#  ('Das Team muss sich steigern, um es zu schaffen", sagte Pellerud.',
#   {'entities': [(55, 63, 'PER')]}),
#  ('Wal-Mart will Lieferung per Drohne testen', {'entities': [(0, 8, 'ORG')]}),
#  ('Es handelt sich dabei um Brian T. Delaney und Courtenay Taylor.',
#   {'entities': [(25, 41, 'PER'), (46, 62, 'PER')]}),
#  ('Bei der EU-Ausbildungsmission in Mali sind 207 deutsche Soldaten im Einsatz.',
#   {'entities': [(8, 29, 'ORG'), (33, 37, 'LOC'), (47, 55, 'MISC')]}),
#  ('Für die Schalker geht es als hoher Favorit zu',
#   {'entities': [(8, 16, 'ORG')]}),
#  ('Einer davon wird von Luke Mitchell („The Tomorrow People“) verkörpert werden.',
#   {'entities': [(21, 34, 'PER'), (37, 56, 'MISC')]}),
#  ('Der Festakt in der Alten Oper wird zur Stunde des Bundespräsidenten.',
#   {'entities': [(19, 29, 'LOC')]}),
#  ('Nun gibts auch vom Feuerwehrkommando der Stadt Bern ein Update:',
#   {'entities': [(19, 51, 'MISC')]}),
#  ('Der Quelltopf ist ebenfalls dem Untergang geweiht.',
#   {'entities': [(4, 13, 'LOC')]}),
#  ('Unter den Einzelwerten stehen die Aktien von Zynga im Fokus.',
#   {'entities': [(45, 50, 'ORG')]}),
#  ('Lufthansa umfliegt Sinai schon seit Samstag',
#   {'entities': [(0, 24, 'MISC')]}),
#  ('Das Institut hatte die Aktien von "Overweight" auf "Equal-weight" abgestuft.',
#   {'entities': [(35, 45, 'ORG')]}),
#  ('1. Abgeordneter Müller Darf man als Politiker einen Ferrari fahren?',
#   {'entities': [(0, 27, 'ORG'), (52, 59, 'ORG')]}),
#  ('Die SVP ist jedoch generell gegen höhere Steuern.',
#   {'entities': [(4, 7, 'ORG')]}),
#  ('Derzeit haben wir mehr Optionen für ihn als letztes Jahr, sagt Guardiola.',
#   {'entities': [(63, 72, 'PER')]}),
#  ('Auch zwei Spitzen sollen künftig im Ausnahefall möglich sein.',
#   {'entities': [(36, 47, 'LOC')]}),
#  ('Ihre Reaktion zu diesem Thema Wintersport - Biathlon Ihr persönliches BILD.',
#   {'entities': [(70, 74, 'MISC')]}),
#  ('Drei seiner fünf Tore erzielte er auf Vorarbeit des Mittelfeldkämpfers.',
#   {'entities': [(52, 70, 'LOC')]}),
#  ('Die Serverumgebung besteht vor allem aus MobileIron Core und MobileIron Sentry.',
#   {'entities': [(41, 56, 'MISC'), (61, 78, 'MISC')]}),
#  ('" 27. Dezember 2015 08:55 von Roberto Lamprecht',
#   {'entities': [(30, 47, 'PER')]}),
#  ('Die Montoneros waren wie in Deutschland die RAF.',
#   {'entities': [(4, 14, 'PER'), (28, 39, 'LOC'), (44, 47, 'ORG')]}),
#  ("Wie der Betrag von 80'000 Franken zustande kommt, wird nicht erläutert.",
#   {'entities': [(19, 33, 'MISC')]}),
#  ('Falschparker attackierte Opfer mit Faustschlägen im Gesicht und am Oberkörper.',
#   {'entities': [(0, 12, 'PER')]}),
#  ('Weitere Artikel zum Thema Baustellen in Wien:',
#   {'entities': [(40, 44, 'LOC')]}),
#  ('Trina Solar hält die Entscheidung von ITC und DOC für falsch und ungerecht.',
#   {'entities': [(0, 11, 'PER'), (38, 41, 'MISC')]}),
#  ('In diesem Video befassen wir uns mit VMware vSphere und VMware vCenter Suite.',
#   {'entities': [(37, 51, 'MISC'), (56, 76, 'MISC')]}),
#  ('Vier Pflichtspiele in Serie haben die Albatrosse verloren.',
#   {'entities': [(38, 48, 'ORG')]}),
#  ('Die beiden Briten haben bunte Autos auf ihre Stoffe gedruckt.',
#   {'entities': [(11, 17, 'LOC')]}),
#  ('Andererseits liegt das Hässliche ja auch im Auge des Betrachters.',
#   {'entities': [(23, 32, 'LOC')]}),
#  ('Was bitteschön macht Ursula von der Leyen dann in Singapur?',
#   {'entities': [(21, 41, 'PER'), (50, 58, 'LOC')]}),
#  ('Einer der Höhepunkte war der Besuch eines Innovationsparks im ungarischen Fót.',
#   {'entities': [(62, 73, 'MISC'), (74, 77, 'LOC')]}),
#  ('So lief das Rennen für die Mercedes-Stars Hamilton und Rosberg.',
#   {'entities': [(27, 50, 'ORG'), (55, 62, 'LOC')]}),
#  ("38' Hoarau ist in der Sturmspitze wirklich ständig anspielbar.",
#   {'entities': [(4, 10, 'PER')]}),
#  ('Dazu wurde kürzlich in Zürich die Eos Commerce AG gegründet.',
#   {'entities': [(23, 29, 'LOC'), (34, 49, 'ORG')]}),
#  ('Dort laufen aktuelle News, Videos und Screenshots zusammen.',
#   {'entities': [(21, 25, 'MISC'), (27, 33, 'MISC')]}),
#  ('Woran liegt es, dass Rosberg in diesem Jahr so schwer in die Gänge kommt?',
#   {'entities': [(21, 28, 'PER')]}),
#  ('Razzia bei regierungskritischer Zeitung in Türkei',
#   {'entities': [(43, 49, 'LOC')]}),
#  ('Die Durchführung und Abwicklung obliegt dem Justizministerium.',
#   {'entities': [(44, 61, 'ORG')]}),
#  ('Alle Rechte vorbehalten Meinung Merkel und Syrien',
#   {'entities': [(32, 38, 'PER'), (43, 49, 'LOC')]}),
#  ('Das gilt auch für enttäuschende britische Daten.',
#   {'entities': [(32, 41, 'MISC')]}),
#  ('Für Ferdinand Piëch, den damaligen Audi-Vorstand, wurden zudem 2',
#   {'entities': [(4, 19, 'PER')]}),
#  ('Eine Selbstbefreiung des Lagers Buchenwald findet nicht statt;',
#   {'entities': [(25, 42, 'LOC')]}),
#  ('Ungarn bringt mit Bussen Tausende Flüchtlinge nach Österreich.',
#   {'entities': [(0, 6, 'LOC'), (51, 61, 'LOC')]}),
#  ('Bastian Schweinsteiger hat nicht gespielt.',
#   {'entities': [(0, 22, 'PER')]}),
#  ('Bitte beachten Sie unsere AGB, die Datenschutzerklärung und das Impressum.',
#   {'entities': [(26, 29, 'ORG'), (64, 73, 'ORG')]}),
#  ('Zwei Unternehmen verlegen Sitz nach Pinneberg',
#   {'entities': [(36, 45, 'LOC')]}),
#  ('27.04.13 Kultur Nacht der Museen in Jena:',
#   {'entities': [(36, 40, 'LOC')]}),
#  ('Der historische Zeitpunkt dieses Kriegs war nicht gut für die Syrer.',
#   {'entities': [(33, 39, 'MISC'), (62, 67, 'LOC')]}),
#  ('Auch im Burgenland gab es heuer bereits einige Vorfälle.',
#   {'entities': [(8, 18, 'LOC')]}),
#  ('Und sogar der "Nietzche" hat eine Pop-Tradition.',
#   {'entities': [(15, 23, 'LOC'), (34, 47, 'MISC')]}),
#  ('News Apple Retail: iPhone nur noch mit Telekom-Vertrag',
#   {'entities': [(0, 17, 'MISC'), (19, 25, 'MISC'), (39, 54, 'MISC')]}),
#  ('Die Zurich erleidet einen Leistungsabfall', {'entities': [(4, 10, 'LOC')]}),
#  ('Panasonics Lösungen reichen „vom Glas zum Bildschirm“.',
#   {'entities': [(0, 10, 'ORG')]}),
#  ('Hier setzt Löffel-Bösch zu einer Forderung an:',
#   {'entities': [(11, 23, 'MISC')]}),
#  ('So ist beispielsweise das bekannte englische Weihnachtslied „Hark!',
#   {'entities': [(35, 44, 'MISC'), (61, 66, 'MISC')]}),
#  ('Knapp 60 Prozent der helvetischen Exporte gehen in die EU.',
#   {'entities': [(55, 57, 'ORG')]}),
#  ('Zoo Giraffen zählen zu den Lieblingen der jüngsten Besucher.',
#   {'entities': [(0, 12, 'LOC')]}),
#  ('Der Tourismus ist die Haupteinkommensquelle der Kanaren.',
#   {'entities': [(48, 55, 'LOC')]}),
#  ('Objektbasierter Raumklang und HDR-Inhalte sind mitspezifiziert',
#   {'entities': [(0, 25, 'PER')]}),
#  ('In Hellas droht Hängepartie bis Anfang Juni',
#   {'entities': [(3, 9, 'LOC')]}),
#  ('nur mit ihrer Mutter Rascha, ohne den Vater.',
#   {'entities': [(21, 27, 'PER')]}),
#  ('„Wir haben spürbaren Schwung nach Waidhofen gebracht.',
#   {'entities': [(34, 43, 'LOC')]}),
#  ('Rund 30 Unternehmen verwaltet Flöther pro Jahr.',
#   {'entities': [(30, 37, 'ORG')]}),
#  ('Briten sagen dem Sozialstaat den Kampf an', {'entities': [(0, 6, 'LOC')]}),
#  ('Und das ist das Entscheidende", betont Heinzer.',
#   {'entities': [(39, 46, 'PER')]}),
#  ('Warum, erklärt er in unserer Spiele-Kolumne.',
#   {'entities': [(29, 43, 'ORG')]}),
#  ('Observation System», eine digitale Kristallkugel für Verbrechen.',
#   {'entities': [(0, 18, 'MISC')]}),
#  ('Vi står i løbet af få år med en ubalance i dansk økonomi, som er uholdbar.',
#   {'entities': [(0, 56, 'MISC')]}),
#  ('HEK für 4-TByte-HDDs halbiert sich seit Jahresanfang 28. März 2013, 11:03 Uhr',
#   {'entities': [(0, 3, 'ORG')]}),
#  ('Die russische Hauptstadt sei teuer und gefährlich.',
#   {'entities': [(4, 13, 'MISC')]}),
#  ('Dank Hyper-Threading verarbeitet der Vierkern-Chip bis zu 8 Threads parallel.',
#   {'entities': [(37, 50, 'MISC')]}),
#  ('Grass ruft junge Autoren auf, sich einzumischen',
#   {'entities': [(0, 5, 'MISC')]}),
#  ('Grund hierfür war die deutliche Abwertung des Euro gegenüber dem US-Dollar.',
#   {'entities': [(46, 50, 'MISC')]}),
#  ('Winterkorn bleibt im Aufsichtsrat von Audi und Porsche',
#   {'entities': [(0, 10, 'PER'), (38, 42, 'ORG'), (47, 54, 'ORG')]}),
#  ('Nach dem spektakulären ersten Trailer zu Terminator:',
#   {'entities': [(41, 51, 'MISC')]}),
#  ('Georg Seiler: Derzeit ist die Vertragslage für 2017 offen.',
#   {'entities': [(0, 12, 'PER'), (30, 42, 'MISC')]}),
#  ('Es ist die schwierigste Aufgabe bisher für die aufstrebende Hertha.',
#   {'entities': [(60, 66, 'ORG')]}),
#  ('Ein neues US-Gesetz stellt das nun infrage:',
#   {'entities': [(10, 19, 'MISC')]}),
#  ('Der FCB tut sich wirklich schwer, ein vernünftiges Passspiel aufzuziehen.',
#   {'entities': [(4, 7, 'ORG')]}),
#  ('Das Berliner Votum gibt schon die Stimmung in der Partei wieder.',
#   {'entities': [(4, 12, 'MISC'), (50, 56, 'ORG')]}),
#  ('Der C 450 AMG kommt damit gerade einmal ein Viertel so weit.',
#   {'entities': [(4, 9, 'MISC')]}),
#  ('Sie sind hier: Wirtschafts- & Finanzinfo » News »',
#   {'entities': [(15, 40, 'ORG'), (43, 47, 'MISC')]}),
#  ('Gazprom spürt den Niedergang der russischen Wirtschaft.',
#   {'entities': [(0, 7, 'ORG'), (33, 43, 'MISC')]}),
#  ('Unverändert blieben die AfD bei sieben und die FDP bei fünf Prozent.',
#   {'entities': [(24, 27, 'ORG'), (47, 50, 'ORG')]}),
#  ('Auf dem Tablet ist Windows 8.1 vorinstalliert.',
#   {'entities': [(8, 14, 'MISC'), (19, 30, 'MISC')]}),
#  ('Das sollen nun die Leipziger Wissenschaftler ändern.',
#   {'entities': [(19, 28, 'MISC')]}),
#  ('In Griechenland geht man diese gemäss Soguel an, etwa bei der Rentenreform.',
#   {'entities': [(3, 15, 'LOC')]}),
#  ('beim Aufeinandertreffen im DFB-Pokal Finale in Berlin noch mal um alles.',
#   {'entities': [(27, 36, 'MISC'), (47, 53, 'LOC')]}),
#  ('Die Gewerkschaft der Polizei sieht den Vorschlag demnach kritisch.',
#   {'entities': [(4, 28, 'ORG')]}),
#  ('Die Entwicklung von Sportspielen wie Tiger Woods Golf wird eingestellt.',
#   {'entities': [(37, 53, 'MISC')]}),
#  ('Sie kämen aus Bosnien, Spanien, Marokko oder aus Syrien.',
#   {'entities': [(14, 21, 'LOC'),
#     (23, 30, 'LOC'),
#     (32, 39, 'LOC'),
#     (49, 55, 'LOC')]}),
#  ('Das bereinigte EBITDA stieg um 2,8% auf CHF 638 Millionen.',
#   {'entities': [(15, 21, 'ORG'), (40, 43, 'MISC')]}),
#  ('Das AMS begründet den Einbruch mit einem Strategiewechsel:',
#   {'entities': [(4, 7, 'ORG')]}),
#  ('Das schöne Leben an sich Lady Edith und die Taschen',
#   {'entities': [(25, 35, 'PER')]}),
#  ('Heute aber sieht es nicht so aus, als müsse Klopp um den Sieg zittern.',
#   {'entities': [(44, 49, 'PER')]}),
#  ('Sie steht im Frühjahr 2017 an, ein halbes Jahr vor der Bundestagswahl.',
#   {'entities': [(55, 69, 'MISC')]}),
#  ('Die Wall Street hat am Mittwoch den dritten Handelstag in Folge zugelegt.',
#   {'entities': [(4, 15, 'LOC')]}),
#  ('London hatte also einen ganz klaren Plan, einen sehr nachhaltigen übrigens.',
#   {'entities': [(0, 6, 'LOC')]}),
#  ('Klamme Trierer dürfen die Saison zu Ende bringen',
#   {'entities': [(0, 14, 'LOC')]}),
#  ('Ich kenne keinen, der dem ZDF noch in irgend einer Weise Glauben schenkt.',
#   {'entities': [(26, 29, 'ORG')]}),
#  ('Techniker der Telekom (Bild: Deutsche Telekom)',
#   {'entities': [(14, 21, 'ORG'), (29, 45, 'ORG')]}),
#  ('„Griechenland machte einen weiteren Schritt zum Austritt aus der Eurozone.',
#   {'entities': [(1, 13, 'LOC'), (65, 73, 'LOC')]}),
#  ('Schlammschlacht um BVB-Trainer Thomas Tuchel',
#   {'entities': [(0, 15, 'MISC'), (31, 44, 'PER')]}),
#  ('Warum sollten sie deutsche Gesetze mehr achten, als die der Transitländer.',
#   {'entities': [(18, 26, 'MISC')]}),
#  ('Löw entschied sich für eine taktische Variante.',
#   {'entities': [(0, 3, 'PER')]}),
#  ('Gegen den Stadtrivalen Tottenham Hotspur gibts ein enttäuschendes 0:0.',
#   {'entities': [(10, 22, 'ORG'), (23, 40, 'ORG')]}),
#  ('“Ich ha\xadbe kei\xadne, aber Re\xadspekt vor al\xadlem.',
#   {'entities': [(24, 32, 'PER')]}),
#  ('Karikaturisten wegen Erdogan-Beleidigung verurteilt',
#   {'entities': [(21, 40, 'MISC')]}),
#  ('41 Aussteller aus Hamburg auf der Hannover Messe.',
#   {'entities': [(18, 25, 'LOC'), (34, 48, 'LOC')]}),
#  ('Dann haben wir die Hektik des Fussballbereichs, da ist vieles Tagesgeschäft.',
#   {'entities': [(30, 46, 'LOC')]}),
#  ('Ein Foto von Ahmed in Handschellen verbreitete sich rasend schnell im Internet.',
#   {'entities': [(13, 18, 'PER'), (70, 78, 'MISC')]}),
#  ('Doch auch Tito Rabat oder Sam Lowes könnten vorne mitmischen.',
#   {'entities': [(10, 20, 'PER'), (26, 35, 'PER')]}),
#  ('"Nach dem Motto: \'Endlich haben wir es den Grünen gezeigt.',
#   {'entities': [(39, 49, 'ORG')]}),
#  ('Sie ist die Redakteurin der MDR-Sendung „Ilse Bähnerts Schnapsidee“.',
#   {'entities': [(28, 39, 'MISC'), (41, 54, 'PER')]}),
#  ('ONLINE: Kann er sein Preisrisiko nicht minimieren?',
#   {'entities': [(0, 6, 'ORG'), (21, 32, 'PER')]}),
#  ('Blatter kann sich auf seine Basis in Asien, Afrika und Ozeanien verlassen.',
#   {'entities': [(0, 7, 'PER'), (37, 42, 'LOC'), (44, 50, 'LOC')]}),
#  ('LIVE: Maikundgebung der SPÖ am Rathausplatz in Wien 1. Mai 2015',
#   {'entities': [(0, 4, 'MISC'),
#     (24, 27, 'ORG'),
#     (31, 43, 'LOC'),
#     (47, 51, 'LOC')]}),
#  ('Newsletter Bestellen weitere Newsletter bestellen',
#   {'entities': [(0, 20, 'ORG')]}),
#  ('Russland erwägt den Einsatz von Soldaten in der Krisenregion.',
#   {'entities': [(0, 8, 'LOC')]}),
#  ('Deutschland droht 2022 eine Monster-Grippewelle!',
#   {'entities': [(0, 11, 'LOC')]}),
#  ('Schwarzmarkt Tickethandel - Ein Dealer packt aus',
#   {'entities': [(0, 25, 'PER'), (28, 44, 'MISC')]}),
#  ('Beim Biergulasch eröffnet er Tukur und dem HR-Redakteur:',
#   {'entities': [(29, 34, 'PER'), (43, 55, 'ORG')]}),
#  ('Mit Booten bewegen sich die Bewohner Paraquays Hauptstadt Asuncion fort.',
#   {'entities': [(37, 46, 'LOC'), (58, 66, 'LOC')]}),
#  ('Die schlimmsten Auswüchse davon waren in Heidenau zu beobachten.',
#   {'entities': [(41, 49, 'LOC')]}),
#  ('Zank & Streit herrscht natürlich auch in anderen Parteien & das nicht zu knapp.',
#   {'entities': [(0, 13, 'MISC')]}),
#  ('Usain Bolt noch ohne Top-Zeit dieses Jahr', {'entities': [(0, 10, 'PER')]}),
#  ('FTTH mit einer Datenübertragungsrate von 200 MBit/',
#   {'entities': [(0, 4, 'MISC')]}),
#  ('Auch wenn der Standort Oberfranken strategische Vorteile bietet.',
#   {'entities': [(23, 34, 'LOC')]}),
#  ('Sauerstoff, Abstand zum Gestirn, Magnetfeld, Rotation, Mond',
#   {'entities': [(55, 59, 'LOC')]}),
#  ('Als er wieder auf ihn losgehen wollte, hatte Dellwo einen Geistesblitz.',
#   {'entities': [(45, 51, 'PER')]}),
#  ('Broken Age in meine Sammlung aufnehmen in meine Wunschliste aufnehmen 47816',
#   {'entities': [(0, 10, 'MISC')]}),
#  ('Die Rettungskräfte konnten nur noch den Tod der beiden feststellen.',
#   {'entities': [(4, 18, 'MISC')]}),
#  ('Die zwei Optionen der EZB beim Staatsanleihenkauf',
#   {'entities': [(22, 25, 'ORG')]}),
#  ('Mit dem Airbus E-Fan 2.0 will er von Dover nach Calais fliegen.',
#   {'entities': [(8, 24, 'MISC'), (37, 42, 'LOC'), (48, 54, 'LOC')]}),
#  ('Dennoch ist es der ZSC, der in Führung geht:',
#   {'entities': [(19, 22, 'ORG')]}),
#  ('Des Weiteren hat LG einen größeren Bildsensor im 1/2,6-Zoll-Format verbaut.',
#   {'entities': [(17, 19, 'ORG')]}),
#  ('In Zusammenarbeit mit Swisscom sind die ersten 15 Hotspots bere.',
#   {'entities': [(22, 30, 'ORG')]}),
#  ('Denn die allein reicht nicht, um YouTube wirklich profitabel zu betreiben.',
#   {'entities': [(33, 40, 'MISC')]}),
#  ('Die Streithähne wurden vom Sicherheitsdienst vom Club verwiesen.',
#   {'entities': [(27, 53, 'ORG')]}),
#  ('Pep Guardiola dürfte froh sein, wenn die Saison endlich vorbei ist.',
#   {'entities': [(0, 13, 'PER')]}),
#  ('Der erste Kontakt war immer über die Couchsurfing-Website.',
#   {'entities': [(37, 57, 'LOC')]}),
#  ('Genau das aber will die Türkei verhindern.',
#   {'entities': [(24, 30, 'LOC')]}),
#  ('Eine Hauptrolle spielten die Akteure im Rathauscenter.',
#   {'entities': [(40, 53, 'MISC')]}),
#  ('Der Joint Terrorism Task Force JTTF des FBI hatte die Operation geleitet.',
#   {'entities': [(4, 35, 'ORG'), (40, 43, 'ORG')]}),
#  ('Auf dem Burgring wurde er von einem Geschäftswagen niedergestoßen.',
#   {'entities': [(8, 16, 'LOC')]}),
#  ('Der Rudi kommt nach Erfurt, er ist hier unser Star..',
#   {'entities': [(20, 26, 'LOC')]}),
#  ('Truecrypt ist ein im Quellcode verfügbares Datenverschlüsselungstool.',
#   {'entities': [(43, 68, 'MISC')]}),
#  ('Dahinter steckt eine neue Prognose des Sozialreferats.',
#   {'entities': [(39, 53, 'MISC')]}),
#  ('Der Aufstieg des FC Ingolstadt ist auch ein Aufstieg für Audi.',
#   {'entities': [(17, 30, 'ORG'), (57, 61, 'ORG')]}),
#  ('Der 29-Jährige will, dass sich der Sport in Jordanien entwickelt:',
#   {'entities': [(44, 53, 'LOC')]}),
#  ('Ihm folgt Verteidigungsminister Sergej Schoigu mit acht Prozent.',
#   {'entities': [(32, 46, 'PER')]}),
#  ('SZ war der Schweizer mit türkischen Wurzeln gefürchtet.',
#   {'entities': [(0, 2, 'MISC'), (11, 20, 'MISC'), (25, 35, 'MISC')]}),
#  ('Wenn Land Rover drauf steht, dann taugt das Auto auch für die Buckelpiste.',
#   {'entities': [(5, 15, 'MISC')]}),
#  ('Er ist auch der Begründer der amerikanischen Grünen.',
#   {'entities': [(30, 51, 'ORG')]}),
#  ('Ermittelt wird wegen des Verdachts auf Anbau von Betäubungsmitteln.',
#   {'entities': [(0, 9, 'MISC')]}),
#  ('Ein außergewöhnlicher Konzertabend („Shalom!',
#   {'entities': [(37, 44, 'ORG')]}),
#  ('Klaus Steinwender - Einsatzleiter des Roten Kreuz',
#   {'entities': [(0, 17, 'PER'), (38, 49, 'ORG')]}),
#  ('Wie ist Ihr Umgang mit Geld: Risikofreudig?',
#   {'entities': [(29, 42, 'MISC')]}),
#  ('ONLINE: Wie zeigt sich die Diskriminierung?',
#   {'entities': [(0, 6, 'ORG')]}),
#  ('Doch viele in der Partei ahnen wohl auch:',
#   {'entities': [(18, 24, 'ORG')]}),
#  ('Griechenlands neuer Präsident ist verheiratet und hat drei Kinder.',
#   {'entities': [(0, 13, 'LOC')]}),
#  ('In Worfelden wird der Gottesdienst um 17 Uhr gefeiert.',
#   {'entities': [(3, 12, 'LOC')]}),
#  ('Die Armee soll auch offensive Fähigkeiten erhalten:',
#   {'entities': [(4, 9, 'ORG')]}),
#  ('Auf dem neusten Foto beisst Töchterchen Alina genüsslich in eine Limette.',
#   {'entities': [(40, 45, 'PER')]}),
#  ('Finstere Reden sind das, die da geschwungen werden.',
#   {'entities': [(0, 14, 'MISC')]}),
#  ('Dagegen rentieren CoCos aus dem Index von Bank of America mit 6,67 Prozent.',
#   {'entities': [(18, 23, 'PER'), (42, 57, 'ORG')]}),
#  ('Von Christa Gebhardt, Bad Tölz Krimi schreiben ist nicht schwer.',
#   {'entities': [(4, 20, 'PER'), (22, 36, 'ORG')]}),
#  ('Werde dann beschimpft, dass ich was gegen H4ler hätte, dies von H4lern!',
#   {'entities': [(42, 47, 'PER')]}),
#  ('Das geht aus einer Pressemitteilung der Sozialdemokraten hervor.',
#   {'entities': [(40, 56, 'ORG')]}),
#  ('Im Sommer 2014 beim überraschenden Aufstieg des SCP.',
#   {'entities': [(48, 51, 'ORG')]}),
#  ('Auf einer Seite lesen Einige Leute halten Rebecca Gomperts für gefährlich.',
#   {'entities': [(42, 58, 'PER')]}),
#  ('Google würde dabei als sogenannter "virtueller Netzbetreiber" auftreten:',
#   {'entities': [(0, 6, 'MISC')]}),
#  ('Ein Gespräch zur WM-Vergabe hätten sie abgelehnt.',
#   {'entities': [(17, 27, 'ORG')]}),
#  ('Die mögliche Aufstellung der Partie Leverkusen -',
#   {'entities': [(36, 46, 'ORG')]}),
#  ('Bezog sich ja auch auf bh9ks hat nichts genützt Re:',
#   {'entities': [(0, 5, 'PER'), (23, 28, 'LOC'), (48, 50, 'PER')]}),
#  ('Bayer 04 habe etwa zehn Millionen Euro geboten.',
#   {'entities': [(0, 8, 'ORG')]}),
#  ('Die nette Familie zieht fort und es kommen neue Menschen.',
#   {'entities': [(0, 17, 'MISC')]}),
#  ('Aktuelle Beiträge aus dem Politik-Ressort',
#   {'entities': [(26, 41, 'MISC')]}),
#  ('Gericht spricht acht Malala-Attentäter frei Aktualisiert am',
#   {'entities': [(0, 7, 'LOC'), (21, 38, 'MISC')]}),
#  ('Es ist ganz egal, wo man in Eisenschmitt auf sein Handy schaut.',
#   {'entities': [(28, 40, 'PER')]}),
#  ('Vor einem Jahr tötete bereits eine Gasexplosion in Harlem acht Menschen.',
#   {'entities': [(51, 57, 'LOC')]}),
#  ('Am Dienstag stellte der Onlinehändler seinen neuen Dash-Button vor.',
#   {'entities': [(51, 62, 'LOC')]}),
#  ('Für die Sängerin Lena Meyer-Landrut ist Nachwuchs derzeit kein Thema.',
#   {'entities': [(17, 35, 'PER')]}),
#  ('Die Griechen haben schon selbst auch einiges zu ihrem Elend beigetragen.',
#   {'entities': [(4, 12, 'MISC')]}),
#  ('08:37 Achtjähriger stürzte aus Sessellift',
#   {'entities': [(31, 41, 'LOC')]}),
#  ('Der FC Basel steht vor einem erneuten Umbruch.',
#   {'entities': [(4, 12, 'ORG')]}),
#  ('Die FDP startete in Zug ihren Wahlkampf, und sie startete opulent.',
#   {'entities': [(4, 7, 'ORG'), (20, 23, 'LOC')]}),
#  ('Auch die deutsche Übersetzung ist noch nicht tadellos - oder vollständig.',
#   {'entities': [(9, 29, 'MISC')]}),
#  ('Auf den zehnten Platz schaffte es Daniel Schwarz von der Commerzbank.',
#   {'entities': [(8, 21, 'LOC'), (34, 48, 'PER'), (57, 68, 'ORG')]}),
#  ('07:25 Uhr: Athen muss Gehälter und Renten für Juni kürzen',
#   {'entities': [(11, 16, 'LOC')]}),
#  ('Es handelt sich um einen Schüler und einen Arbeiter aus Straßburg.',
#   {'entities': [(56, 65, 'LOC')]}),
#  ('Und genau das dürfte der Elfenbeinküste passieren.',
#   {'entities': [(25, 39, 'LOC')]}),
#  ('Portugal bekommt es am Tag davor in Olomouc mit Deutschland zu tun.',
#   {'entities': [(0, 8, 'LOC'),
#     (23, 32, 'MISC'),
#     (36, 43, 'LOC'),
#     (48, 59, 'LOC')]}),
#  ('Alle Angebote anzeigen Empörung über Schmidt-Tweet Politik statt Trauer:',
#   {'entities': [(37, 50, 'PER')]}),
#  ('Wäre Zwanziger nicht, hätte Niersbach am Montag wohl frei.',
#   {'entities': [(5, 14, 'MISC'), (28, 37, 'PER')]}),
#  ('Eine Einführung in die Debatte des Tagesspiegel Politikmonitorings.',
#   {'entities': [(35, 66, 'MISC')]}),
#  ('damit gilt der 60-jährige Franzose als Favorit.',
#   {'entities': [(26, 34, 'LOC')]}),
#  ('Ins gleiche Modell fallen Länder wie Nordkorea, Kuba oder Syrien.',
#   {'entities': [(37, 46, 'LOC'), (48, 52, 'LOC'), (58, 64, 'LOC')]}),
#  ('Der österreichische Dirigent zieht sich zum 86. Geburtstag vom Pult zurück.',
#   {'entities': [(4, 19, 'MISC')]}),
#  ('Gold Fields verbessern sich 4,5% und Harmony 2,1%.',
#   {'entities': [(0, 11, 'LOC'), (37, 44, 'ORG')]}),
#  ('Und mit Lejaby halste sich der Konzern Mega-Probleme auf.',
#   {'entities': [(8, 14, 'PER'), (39, 52, 'ORG')]}),
#  ('So würde die Serie mit amerikanischem Akzent klingen',
#   {'entities': [(23, 37, 'MISC')]}),
#  ('Dieses Wochenende beginnt die Fussball-WM der Frauen.',
#   {'entities': [(30, 52, 'MISC')]}),
#  ('Yip erhält bei den Adlern einen Vertrag bis zum Saisonende.',
#   {'entities': [(0, 3, 'PER'), (19, 25, 'MISC')]}),
#  ('Doch nun ist sein Wechsel zu Juventus Turin perfekt.',
#   {'entities': [(29, 43, 'ORG')]}),
#  ('Start der 5. Staffel "Game of Thrones"- Stars über brutale Dreharbeiten',
#   {'entities': [(22, 45, 'MISC')]}),
#  ('Scorpions, Kidman und Lagerfeld-Puschel DPA Sehen und gesehen werden:',
#   {'entities': [(0, 9, 'ORG'), (11, 17, 'PER'), (22, 49, 'ORG')]}),
#  ('Der KSC verpasste im 21. Auftritt in Bielefeld den sechsten Sieg.',
#   {'entities': [(4, 7, 'ORG'), (37, 46, 'ORG')]}),
#  ('Von den Experten von Motorsport-Total.com » Neue Formel-1-Saison',
#   {'entities': [(21, 41, 'ORG')]}),
#  ('Ein Mitglied der SPD will daher wissen, ob Gysi zu dieser Aussage stehe.',
#   {'entities': [(17, 20, 'ORG'), (43, 47, 'PER')]}),
#  ('Trotz des Erfolgs reichte es Ogier nicht zur vorzeitigen Titelverteidigung.',
#   {'entities': [(29, 34, 'PER')]}),
#  ('Das wäre eine klare Auflage – die nach Angaben von Carsten Spohr nicht bestand.',
#   {'entities': [(51, 64, 'PER')]}),
#  ('Ich wette der Mafiabott "Klemmer" basiert auch auf seiner Figur.',
#   {'entities': [(25, 32, 'PER')]}),
#  ('Der irre Katar-Erfolg: Braucht der Handball neue Regeln?',
#   {'entities': [(9, 21, 'MISC')]}),
#  ('Ein verbaler Aussetzer von Nick Kyrgios im Spiel gegen Franch-Open',
#   {'entities': [(27, 39, 'PER'), (55, 66, 'ORG')]}),
#  ('Hamilton und Rosberg belegen die beiden führenden Positionen.',
#   {'entities': [(0, 8, 'PER'), (13, 20, 'PER')]}),
#  ('Philosoph Rene Girard in Stanford gestorben',
#   {'entities': [(10, 21, 'PER'), (25, 33, 'LOC')]}),
#  ('Aus der Flasche oder dem Hahn ZDF testet:',
#   {'entities': [(30, 33, 'ORG')]}),
#  ('An Instapaper senden Post erhöht Briefporto um 5 bis 10 Prozent.',
#   {'entities': [(3, 13, 'MISC')]}),
#  ('Selbst über die Grenze fahren wollen russische Taxi-Fahrer aber nicht.',
#   {'entities': [(37, 46, 'MISC')]}),
#  ('Das Blutschutzgesetz der Nazis macht die Zukunft der beiden zunichte.',
#   {'entities': [(4, 20, 'MISC')]}),
#  ('Tagesgeld-Vergleich Klicken Sie hier für die aktuellen Konditionen',
#   {'entities': [(0, 19, 'PER')]}),
#  ('Die Finma krempelt ihren Verwaltungsrat vollständig um:',
#   {'entities': [(4, 9, 'ORG')]}),
#  ('Neues Angebot für Balda in Sicht - Italiener wollen 80 Millionen Euro bieten',
#   {'entities': [(18, 23, 'PER'), (35, 44, 'LOC')]}),
#  ('Früher waren sie nur Wuschel, Mimi oder Hansi.',
#   {'entities': [(30, 34, 'PER'), (40, 45, 'PER')]}),
#  ('Amazon France listet den heute erschienene PS4-Hit Bloodborne für den PC.',
#   {'entities': [(0, 13, 'ORG'), (43, 61, 'MISC'), (70, 72, 'MISC')]}),
#  ('Mozilla gibt Flash Player wieder frei - deaktivieren Sie ihn trotzdem',
#   {'entities': [(0, 7, 'MISC'), (13, 25, 'MISC')]}),
#  ('TV-Kolumne: „Die Facebook-Story“: Und plötzlich tut Mark Zuckerberg einem leid',
#   {'entities': [(0, 10, 'PER'), (17, 31, 'MISC'), (52, 67, 'PER')]}),
#  ('Mit weitem Abstand folgt das Audi-Duo Q3 und Q5.',
#   {'entities': [(29, 40, 'MISC'), (45, 48, 'MISC')]}),
#  ('Tipp: das Bild anklicken um den Code neu zu generieren',
#   {'entities': [(0, 4, 'PER')]}),
#  ('Zschäpes Aussage war ursprünglich für vergangenen Mittwoch angekündigt worden.',
#   {'entities': [(0, 8, 'PER')]}),
#  ('«Klar und eindeutig: Nein!», stellte Bucher am Donnerstag klar.',
#   {'entities': [(37, 43, 'PER')]}),
#  ('Steigende Preise für Energie, Korruption, Hass auf die Staatsmacht.',
#   {'entities': [(42, 46, 'PER')]}),
#  ("Schon wieder schlechte Nachrichten gibt es von Del Frisco's:",
#   {'entities': [(47, 59, 'PER')]}),
#  ('Erfolgreicher unterwegs war in Aksel Lund Svindal ein zweiter Rekonvaleszent.',
#   {'entities': [(31, 49, 'PER')]}),
#  ('Darüber hinaus tragen modifizierte Schürzen zum frischeren Auftritt bei.',
#   {'entities': [(35, 43, 'PER')]}),
#  ('Er möchte die Aussage aber nicht als Kritik an Hudac verstanden wissen.',
#   {'entities': [(47, 52, 'PER')]}),
#  ('Der Boss der kolumbianischen Guerillagruppe ist tot.',
#   {'entities': [(13, 43, 'ORG')]}),
#  ('Ein paar hundert Milliönchen mehr machen den Kohl doch nicht fett.',
#   {'entities': [(45, 49, 'PER')]}),
#  ('Einen Kick fürs Selbstbewusstsein gibt es von Ex-Boxer Christian Görisch.',
#   {'entities': [(46, 72, 'PER')]}),
#  ('Doch es fehlen ihm Souveränität und ein richtiges Zentrum.',
#   {'entities': [(50, 57, 'ORG')]}),
#  ('IBM erweitert Smarter Workforce mit Kenexa',
#   {'entities': [(0, 3, 'ORG'), (14, 31, 'MISC')]}),
#  ('In Syrien traf er dann sein großes Idol – den Journalisten Kenji Goto.',
#   {'entities': [(3, 9, 'LOC'), (59, 69, 'PER')]}),
#  ('Cameron machte die Zusage am Freitag bei einem Besuch in Lissabon.',
#   {'entities': [(0, 7, 'PER'), (57, 65, 'LOC')]}),
#  ('Aber: Die Kanzlerin muss dabei sein", forderte Varoufakis.',
#   {'entities': [(10, 19, 'ORG'), (47, 57, 'PER')]}),
#  ('Kenneth Branagh "Ich bin vielleicht einfach ein unbelehrbarer Hippie"',
#   {'entities': [(0, 15, 'PER')]}),
#  ('Patrice Marcelo Vitali vor 5 Stunden Pseudotradionsgetue:',
#   {'entities': [(0, 22, 'PER'), (37, 56, 'PER')]}),
#  ('Pere Guardiola, Bruder des Startrainers, ist dessen Berater im Sinne von Agent.',
#   {'entities': [(0, 14, 'PER'), (16, 39, 'PER')]}),
#  ('„Meine erste Lesung war für mich umwerfend“, erinnert sich Schenk.',
#   {'entities': [(59, 65, 'PER')]}),
#  ('Martin Hüfner, Berater des Vermögensverwalters Assenagon, sieht mehrere Gründe.',
#   {'entities': [(0, 13, 'PER'), (47, 56, 'ORG')]}),
#  ('Ibisevic, die vor der Partie auf einem Nebenplatz trainiert hatten.',
#   {'entities': [(0, 8, 'PER')]}),
#  ('Er stellt damit Äußerungen von Präsident Putin klar.',
#   {'entities': [(41, 46, 'PER')]}),
#  ('Jubilar Xaver Geyer durfte gesund und munter seinen 80. Geburtstag feiern.',
#   {'entities': [(8, 19, 'PER')]}),
#  ('Intern soll Babor inzwischen erklärt habe, die Rede zu bereuen.',
#   {'entities': [(12, 17, 'PER')]}),
#  ('In Berlin entschied Heinevetter den Vergleich lange zu seinen Gunsten.',
#   {'entities': [(3, 9, 'LOC'), (20, 31, 'PER')]})]

# %%
random.shuffle(out_sentences)
TRAIN_STAT_DATA=out_sentences[:len(out_sentences)//2]
TEST_STAT_DATA=out_sentences[len(out_sentences)//2:]

# %%
print(len(out_sentences))
print(len(TRAIN_STAT_DATA))
print(len(TEST_STAT_DATA))
print("REVISION", len(TRAIN_REVISION_DATA))
TRAIN_DATA = TRAIN_REVISION_DATA + TRAIN_STAT_DATA
print("COMBINED", len(TRAIN_DATA))
# Out:
# 1020
# 510
# 510
# REVISION 291
# COMBINED 801

# %%
ner = nlp.get_pipe("ner")
ner.add_label("GRAN")
ner.add_label("DATA")



# get the names of the components we want to disable during training
pipe_exceptions = ["ner", "trf_wordpiecer", "trf_tok2vec"]
other_pipes = [pipe for pipe in nlp.pipe_names if pipe not in pipe_exceptions]

# start the training loop, only training NER
epochs = 30
#optimizer = nlp.resume_training()
#optimizer = nlp.initialize()
with nlp.disable_pipes(*other_pipes), warnings.catch_warnings():
    warnings.filterwarnings("once", category=UserWarning, module='spacy')
    sizes = compounding(1.0, 4.0, 1.001)
    
    # batch up the examples using spaCy's minibatc
    for epoch in range(epochs):
        random.shuffle(TRAIN_DATA)
        #text = []
        #annots=[]
        examples=[]


        for text,annots in TRAIN_DATA:
            #text.append(t)
            #annots.append(a)
            doc = nlp.make_doc(text)    
            example = Example.from_dict(doc, annots)
            examples.append(example)
        
        losses = {}
        
        nlp.update(examples, drop=0.35, losses=losses)#,sgd=optimizer)

        print("Losses ({}/{})".format(epoch + 1, epochs), losses)
# Out:
# Losses (1/30) {'ner': 2385.5419125936055}
# Losses (2/30) {'ner': 2043.9089004172185}
# Losses (3/30) {'ner': 1892.4018475627818}
# Losses (4/30) {'ner': 1668.3351902225502}
# Losses (5/30) {'ner': 1607.4926412801724}
# Losses (6/30) {'ner': 1503.0205603179356}
# Losses (7/30) {'ner': 1471.0794919212785}
# Losses (8/30) {'ner': 1395.5419513410889}
# Losses (9/30) {'ner': 1362.8461099738488}
# Losses (10/30) {'ner': 1290.3212392951245}
# Losses (11/30) {'ner': 1287.6162469459232}
# Losses (12/30) {'ner': 1236.1939815005753}
# Losses (13/30) {'ner': 1200.5868435432203}
# Losses (14/30) {'ner': 1193.479590804316}
# Losses (15/30) {'ner': 1179.2460084240884}
# Losses (16/30) {'ner': 1154.7695163995668}
# Losses (17/30) {'ner': 1118.532352203736}
# Losses (18/30) {'ner': 1080.3043447384553}
# Losses (19/30) {'ner': 1070.3354025850113}
# Losses (20/30) {'ner': 1055.5522190239863}
# Losses (21/30) {'ner': 1000.792888879776}
# Losses (22/30) {'ner': 997.667265408214}
# Losses (23/30) {'ner': 1121.9321248072183}
# Losses (24/30) {'ner': 1222.702941409998}
# Losses (25/30) {'ner': 1260.7421344518661}
# Losses (26/30) {'ner': 1376.371973156929}
# Losses (27/30) {'ner': 1528.6360831690176}
# Losses (28/30) {'ner': 1485.4633742461883}
# Losses (29/30) {'ner': 1425.266089262488}
# Losses (30/30) {'ner': 1427.008161664009}

# %%
statbot_colors = {"GRAN": "linear-gradient(90deg, #aa9cfc, #fc9ce7)",
                  "DATA": "linear-gradient(90deg, #ffff00, #ff8c00)"}
statbot_options = {"ents": ["PER","LOC","ORG","MISC","GRAN","DATA"], "colors": statbot_colors}
spacy.displacy.render(nlp("Ich heisse Christian und war heute in Zürich bei IBM im Internet."), style="ent",options=statbot_options)
spacy.displacy.render(nlp("Wie viele Kühe hat die Gemeinde Bülach?"), style="ent",options=statbot_options)
spacy.displacy.render(nlp("Wie hoch ist Eigenkapital auf Bezirksebene?"), style="ent",options=statbot_options)
spacy.displacy.render(nlp("Ich brauche die Daten pro Bezirk"), style="ent",options=statbot_options)
spacy.displacy.render(nlp("Ich brauche die Daten für den gesamten Kanton."), style="ent",options=statbot_options)
spacy.displacy.render(nlp("Wie viel Bauinv. EFH 5 Jahre  hat  in Regensdorf  ?"), style="ent",options=statbot_options)
spacy.displacy.render(nlp("Was ist der Anteil an MIV-Anteil (Modal Split)   auf Bezirksebene ?"), style="ent",options=statbot_options)
spacy.displacy.render(nlp("Was ist der Anteil an Geb.Vol. Dienstleistungen: Zunahme   in Flaach ?"), style="ent",options=statbot_options)
spacy.displacy.render(nlp("Welches ist das Schül. Sekundarstufe II   für den gesamten Kanton ?"), style="ent",options=statbot_options)
spacy.displacy.render(nlp("Welche Gemeinde hat die grösste Bevölkerung?"), style="ent",options=statbot_options)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Ich heisse
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Christian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  und war heute in
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Zürich
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  bei
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     IBM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  im
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Internet
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# .</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Wie viele Kühe hat die
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gemeinde
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GRAN</span>
# </mark>
#  Bülach?</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Wie hoch ist Eigenkapital auf
# <mark class="entity" style="background: linear-gradient(90deg, #ffff00, #ff8c00); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bezirksebene?
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATA</span>
# </mark>
# </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Ich brauche die Daten pro
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bezirk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GRAN</span>
# </mark>
# </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Ich brauche die Daten für den gesamten
# <mark class="entity" style="background: linear-gradient(90deg, #ffff00, #ff8c00); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kanton.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATA</span>
# </mark>
# </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Wie viel
# <mark class="entity" style="background: linear-gradient(90deg, #ffff00, #ff8c00); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bauinv.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATA</span>
# </mark>
#  EFH 5 Jahre  hat  in Regensdorf  ?</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Was ist der Anteil an MIV-Anteil (Modal Split)   auf
# <mark class="entity" style="background: linear-gradient(90deg, #ffff00, #ff8c00); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bezirksebene ?
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATA</span>
# </mark>
# </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Was ist der Anteil an
# <mark class="entity" style="background: linear-gradient(90deg, #ffff00, #ff8c00); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Geb.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATA</span>
# </mark>
# Vol. Dienstleistungen: Zunahme   in Flaach ?</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Welches ist das Schül. Sekundarstufe II   für den gesamten
# <mark class="entity" style="background: linear-gradient(90deg, #ffff00, #ff8c00); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kanton ?
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATA</span>
# </mark>
# </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Welche
# <mark class="entity" style="background: linear-gradient(90deg, #ffff00, #ff8c00); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gemeinde hat die grösste Bevölkerung
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATA</span>
# </mark>
# ?</div></span>

# %%
# dictionary to hold our evaluation data
stat_evaluation = {
    "GRAN": {
        "correct": 0,
        "total": 0,
    },
    "DATA": {
        "correct": 0,
        "total": 0,
    }
}

word_evaluation = {
    "GRAN": {
        "correct": 0,
        "total": 0
    },
    "DATA": {
        "correct": 0,
        "total": 0,
    }

}


for stat in TEST_STAT_DATA:
    # extract the sentence and correct stat entities according to our test data
    sentence = stat[0]
    entities = stat[1]["entities"]

    # for each entity, use our updated model to make a prediction on the sentence
    for entity in entities:
        doc = nlp(sentence)
        correct_text = sentence[entity[0]:entity[1]]
        n_worded_stat =  len(correct_text.split())
        print(n_worded_stat)

        # if we find that there's a match for predicted entity and predicted text, increment correct counters
        for ent in doc.ents:
            print("ENT_LABEL",ent.label_)
            print("ENTITY2",entity[2])
            print("ENT_TEXT",ent.text)
            print("CORRECT:TEXT",correct_text)
            if ent.label_ == entity[2] and ent.text == correct_text:
                
                stat_evaluation[entity[2]]["correct"] += 1
                if n_worded_stat > 0:
                    word_evaluation[entity[2]]["correct"] += 1

                # this break is important, ensures that we're not double counting on a correct match
                break

        #  increment total counters after each entity loop
        stat_evaluation[entity[2]]["total"] += 1
        if n_worded_stat > 0:
            word_evaluation[entity[2]]["total"] += 1
# Out:
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Tertiaerstufe
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Verkaeufe von unbebautem
# CORRECT:TEXT Verkaeufe von unbebautem Land
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung:
# CORRECT:TEXT Bevoelkerung: Frauen
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Apotheken hat
# CORRECT:TEXT Kanton
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Kanton
# CORRECT:TEXT Kanton
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Apotheken hat
# CORRECT:TEXT Apotheken
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kanton
# CORRECT:TEXT Apotheken
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand Gesundheit
# CORRECT:TEXT Nettoaufwand Gesundheit
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kuehe
# CORRECT:TEXT Kuehe
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Erwerb des Schweizer
# CORRECT:TEXT Erwerb des Schweizer Buergerrechts
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Mittelschule
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Steuerpflichtige juristische Personen
# CORRECT:TEXT Region
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Region Furttal
# CORRECT:TEXT Region
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerpflichtige juristische Personen
# CORRECT:TEXT Steuerpflichtige juristische Personen
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schweizer Buergerrechts  in Moenchaltorf
# CORRECT:TEXT Erwerb des Schweizer Buergerrechts
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Anteil Vollzeitbeschaeftigte
# CORRECT:TEXT Bezirk
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirk Zuerich und
# CORRECT:TEXT Bezirk
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil Vollzeitbeschaeftigte
# CORRECT:TEXT Anteil Vollzeitbeschaeftigte Landwirtschaft
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirk Zuerich und
# CORRECT:TEXT Anteil Vollzeitbeschaeftigte Landwirtschaft
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Restaurants pro 1000
# CORRECT:TEXT Restaurants pro 1000 Einwohner
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerkraft berichtigt pro
# CORRECT:TEXT Steuerkraft berichtigt pro Kopf
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Mittlere Betriebe
# CORRECT:TEXT Mittlere Betriebe 50249 VZÄ
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerb.
# CORRECT:TEXT Steuerb. Vermoegen natuerl. Pers. 75%Quantil
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Anteil Waldflaeche
# CORRECT:TEXT Kanton
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Kanton
# CORRECT:TEXT Kanton
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil Waldflaeche
# CORRECT:TEXT Anteil Waldflaeche
# 3
# ENT_LABEL LOC
# ENTITY2 DATA
# ENT_TEXT NRW
# CORRECT:TEXT NRW Waehleranteil FDP
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Mikrobetriebe 09 VZÄ
# CORRECT:TEXT Bezirk
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirk Uster
# CORRECT:TEXT Bezirk
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Mikrobetriebe 09 VZÄ
# CORRECT:TEXT Mikrobetriebe 09 VZÄ
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinvestitionen hat
# CORRECT:TEXT Bauinvestitionen
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Baulandpreis Modell Median
# CORRECT:TEXT Baulandpreis Modell Median
# 6
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerkraft ber.
# CORRECT:TEXT Steuerkraft ber. arith. Mittel 3 Jahre
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Erwerb des Schweizer
# CORRECT:TEXT Erwerb des Schweizer Buergerrechts
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerertrag
# CORRECT:TEXT Steuerertrag Total
# 3
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Wegzuege
# CORRECT:TEXT Wegzuege
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Beschaeftigte Landwirtschaft
# CORRECT:TEXT Beschaeftigte Landwirtschaft
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT ÖVWege Quell
# CORRECT:TEXT ÖVWege Quell, Ziel und Binnenverkehr
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Arbeitsstaetten im Sekundaersektor
# CORRECT:TEXT Arbeitsstaetten im Sekundaersektor
# 1
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirk ?
# CORRECT:TEXT Bezirk
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirk ?
# CORRECT:TEXT Total geschaffene Stellen, Beschaeftigte
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirke ?
# CORRECT:TEXT Bezirke
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirke ?
# CORRECT:TEXT Geb.Vol. Infrastruktur: Zunahme
# 3
# ENT_LABEL LOC
# ENTITY2 DATA
# ENT_TEXT NRW
# CORRECT:TEXT NRW Waehleranteil EVP
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Oberstufe
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Berufsschule
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT KRW Waehleranteil SP
# CORRECT:TEXT KRW Waehleranteil SP
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand Gesundheit  Urdorf
# CORRECT:TEXT Nettoaufwand Gesundheit
# 1
# ENT_LABEL LOC
# ENTITY2 DATA
# ENT_TEXT Hoehe
# CORRECT:TEXT Hoehe
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Oberstufe
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Beschaeftigte im Gastgewerbe
# CORRECT:TEXT Beschaeftigte im Gastgewerbe: Anteil
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Mittelschule
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Steuerb.
# CORRECT:TEXT Gemeindeebene
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gemeindeebene ?
# CORRECT:TEXT Gemeindeebene
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerb.
# CORRECT:TEXT Steuerb. Vermoegen natuerl. Pers. Durchschn.
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeindeebene ?
# CORRECT:TEXT Steuerb. Vermoegen natuerl. Pers. Durchschn.
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerertrag von juristischen
# CORRECT:TEXT Steuerertrag von juristischen Personen
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Landwirtschaftliche Nutzflaeche
# CORRECT:TEXT Landwirtschaftliche Nutzflaeche
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Verpackungsglasmengen
# CORRECT:TEXT Verpackungsglasmengen
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geb.
# CORRECT:TEXT Geb.Vol. Wohnen: Anteil
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT VZÄ im Sekundaersektor
# CORRECT:TEXT VZÄ im Sekundaersektor
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Mikrobetriebe 09 VZÄ  pro Bezirk
# CORRECT:TEXT Bezirk
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Mikrobetriebe 09 VZÄ  pro Bezirk
# CORRECT:TEXT Mikrobetriebe 09 VZÄ
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand Bildung
# CORRECT:TEXT Nettoaufwand Bildung
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bruttoinvestitionen
# CORRECT:TEXT Bruttoinvestitionen
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Neuerstellte
# CORRECT:TEXT Neuerstellte MFHWohnungen
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bevoelkerung:
# CORRECT:TEXT Kanton
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Kanton ?
# CORRECT:TEXT Kanton
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung:
# CORRECT:TEXT Bevoelkerung: Anteil 2039Jaehrige
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kanton ?
# CORRECT:TEXT Bevoelkerung: Anteil 2039Jaehrige
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Anteil Verkehrsflaeche
# CORRECT:TEXT Gemeinden
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gemeinden ?
# CORRECT:TEXT Gemeinden
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil Verkehrsflaeche
# CORRECT:TEXT Anteil Verkehrsflaeche
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Personalsteuerpflichtige hat
# CORRECT:TEXT Personalsteuerpflichtige
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Beschaeftigte Landwirtschaft hat
# CORRECT:TEXT Gemeindeebene
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gemeindeebene  ?
# CORRECT:TEXT Gemeindeebene
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Beschaeftigte Landwirtschaft hat
# CORRECT:TEXT Beschaeftigte Landwirtschaft
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeindeebene  ?
# CORRECT:TEXT Beschaeftigte Landwirtschaft
# 1
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Baulandpreis
# CORRECT:TEXT Baulandpreis Modell Median
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geb.
# CORRECT:TEXT Geb.Vol. Infrastruktur: Zunahme
# 3
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geb.
# CORRECT:TEXT Geb.Vol. Industrie/Lager: Zunahme
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Finanzvermoegen hat  in
# CORRECT:TEXT Finanzvermoegen
# 2
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Kanton
# CORRECT:TEXT Kanton
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kanton
# CORRECT:TEXT Verkaeufe MFH
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT 4Personenhaushalte
# CORRECT:TEXT 4Personenhaushalte
# 1
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung: Heimat
# CORRECT:TEXT Bevoelkerung: Heimat Schweiz
# 1
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Apotheken
# CORRECT:TEXT Apotheken
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung:
# CORRECT:TEXT Bevoelkerung: Anteil 2039Jaehrige
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bevoelkerung:
# CORRECT:TEXT Gemeindeebene
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gemeindeebene ?
# CORRECT:TEXT Gemeindeebene
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung:
# CORRECT:TEXT Bevoelkerung: Frauen
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeindeebene ?
# CORRECT:TEXT Bevoelkerung: Frauen
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerertrag von juristischen
# CORRECT:TEXT Steuerertrag von juristischen Personen
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. MFH 5 Jahre
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT PWNeuzulassungen
# CORRECT:TEXT PWNeuzulassungen
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirksebene
# CORRECT:TEXT Bezirksebene
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirksebene
# CORRECT:TEXT Reingewinn juristische Personen
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bevoelkerung:
# CORRECT:TEXT Bezirk
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirk Winterthur
# CORRECT:TEXT Bezirk
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung:
# CORRECT:TEXT Bevoelkerung: Anteil 1519Jaehrige
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirk Winterthur
# CORRECT:TEXT Bevoelkerung: Anteil 1519Jaehrige
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeindebeitrag an ZVV
# CORRECT:TEXT Gemeindebeitrag an ZVV
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung:
# CORRECT:TEXT Bevoelkerung: Durchschnittsalter
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung:
# CORRECT:TEXT Bevoelkerung: Heimat Ausland
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. EFH 5 Jahre
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirksebene ?
# CORRECT:TEXT Bezirksebene
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirksebene ?
# CORRECT:TEXT Neuzulassungen Benzinmotor
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. Dienstl. 5 Jahre
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Berufsschule
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Anteil 6 und mehr Personenhaushalte
# CORRECT:TEXT Bezirksebene
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirksebene
# CORRECT:TEXT Bezirksebene
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil 6 und mehr Personenhaushalte
# CORRECT:TEXT Anteil 6 und mehr Personenhaushalte
# 1
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauzonen ueberbaut
# CORRECT:TEXT Bauzonen ueberbaut
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Auslaenderanteil  fuer alle
# CORRECT:TEXT Bezirke
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirke ?
# CORRECT:TEXT Bezirke
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Auslaenderanteil  fuer alle
# CORRECT:TEXT Auslaenderanteil
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirke ?
# CORRECT:TEXT Auslaenderanteil
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bevoelkerungszunahme 1 Jahr
# CORRECT:TEXT Region
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Region Knonaueramt
# CORRECT:TEXT Region
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerungszunahme 1 Jahr
# CORRECT:TEXT Bevoelkerungszunahme 1 Jahr
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Region Knonaueramt
# CORRECT:TEXT Bevoelkerungszunahme 1 Jahr
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Kindergarten
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT KRW Waehleranteil FDP
# CORRECT:TEXT Bezirksebene
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirksebene ?
# CORRECT:TEXT Bezirksebene
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT KRW Waehleranteil FDP
# CORRECT:TEXT KRW Waehleranteil FDP
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerb.
# CORRECT:TEXT Steuerb. Vermoegen natuerl. Pers. 75%Quantil
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerb.
# CORRECT:TEXT Steuerb. Vermoegen natuerl. Pers. Median
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung: Anteil
# CORRECT:TEXT Bevoelkerung: Anteil 80 u.m.Jaehrige
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Verpackungsglasmengen hat
# CORRECT:TEXT Verpackungsglasmengen
# 4
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Anteil unproduktive Flaeche
# CORRECT:TEXT Bezirk
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirk
# CORRECT:TEXT Bezirk
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil unproduktive Flaeche
# CORRECT:TEXT Anteil unproduktive Flaeche
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Verkaeufe Stockwerkeigentum
# CORRECT:TEXT Region
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Region Weinland
# CORRECT:TEXT Region
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Verkaeufe Stockwerkeigentum
# CORRECT:TEXT Verkaeufe Stockwerkeigentum
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Region Weinland
# CORRECT:TEXT Verkaeufe Stockwerkeigentum
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Arbeitslose  auf Bezirksebene
# CORRECT:TEXT Bezirksebene
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Arbeitslose  auf Bezirksebene
# CORRECT:TEXT Arbeitslose
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT 3Personenhaushalte
# CORRECT:TEXT 3Personenhaushalte
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT 4Personenhaushalte hat
# CORRECT:TEXT Bezirksebene
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirksebene
# CORRECT:TEXT Bezirksebene
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT 4Personenhaushalte hat
# CORRECT:TEXT 4Personenhaushalte
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirksebene
# CORRECT:TEXT 4Personenhaushalte
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauzonen ueberbaut pro
# CORRECT:TEXT Bauzonen ueberbaut pro Kopf
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Nettoaufwand Finanzen und Steuern
# CORRECT:TEXT Bezirksebene
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirksebene
# CORRECT:TEXT Bezirksebene
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand Finanzen und Steuern
# CORRECT:TEXT Nettoaufwand Finanzen und Steuern
# 6
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Motorraeder pro 1000
# CORRECT:TEXT Region
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Motorraeder pro 1000
# CORRECT:TEXT Motorraeder pro 1000 Einwohner
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Anteil 1 Zi
# CORRECT:TEXT Bezirksebene
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirksebene
# CORRECT:TEXT Bezirksebene
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil 1 Zi
# CORRECT:TEXT Anteil 1 Zi.Wohnungen
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Bezirksebene
# CORRECT:TEXT Anteil 1 Zi.Wohnungen
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Beschaeftigte im Sekundaersektor
# CORRECT:TEXT Beschaeftigte im Sekundaersektor
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Verkaeufe EFH
# CORRECT:TEXT Bezirksebene
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirksebene ?
# CORRECT:TEXT Bezirksebene
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Verkaeufe EFH
# CORRECT:TEXT Verkaeufe EFH
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Motorraeder pro 1000
# CORRECT:TEXT Motorraeder pro 1000 Einwohner
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kehrichtmengen
# CORRECT:TEXT Kehrichtmengen
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Beschaeftigte im Sekundaersektor
# CORRECT:TEXT Beschaeftigte im Sekundaersektor
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand Volkswirtschaft hat
# CORRECT:TEXT Nettoaufwand Volkswirtschaft
# 4
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Primarschule
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT EFHBestand
# CORRECT:TEXT EFHBestand
# 4
# 1
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geb.
# CORRECT:TEXT Geb.Vol. Industrie/Lager: Anteil
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Neuerstellte Wohnungen
# CORRECT:TEXT Neuerstellte Wohnungen
# 3
# 2
# 6
# ENT_LABEL MISC
# ENTITY2 DATA
# ENT_TEXT ZLBezuegerquote
# CORRECT:TEXT ZLBezuegerquote der Personen ab 65 Jahren
# 6
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Restaurants  fuer alle
# CORRECT:TEXT Bezirke
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirke ?
# CORRECT:TEXT Bezirke
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Restaurants  fuer alle
# CORRECT:TEXT Restaurants
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirke ?
# CORRECT:TEXT Restaurants
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Steuerkraft arith
# CORRECT:TEXT Bezirke
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirke  ?
# CORRECT:TEXT Bezirke
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerkraft arith
# CORRECT:TEXT Steuerkraft arith. Mittel 3 Jahre
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirke  ?
# CORRECT:TEXT Steuerkraft arith. Mittel 3 Jahre
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Neuerstellte Wohnungen
# CORRECT:TEXT Bezirke
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirke ?
# CORRECT:TEXT Bezirke
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Neuerstellte Wohnungen
# CORRECT:TEXT Neuerstellte Wohnungen
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bezirke
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirke ?
# CORRECT:TEXT Bezirke
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. Wohnen
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirke ?
# CORRECT:TEXT Bauinv. Wohnen
# 4
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT MIVWege Quell
# CORRECT:TEXT MIVWege Quell, Ziel und Binnenverkehr
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Wegzuege  fuer den
# CORRECT:TEXT Kanton
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Kanton ?
# CORRECT:TEXT Kanton
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Wegzuege  fuer den
# CORRECT:TEXT Wegzuege
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kanton ?
# CORRECT:TEXT Wegzuege
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT MIVWege Quell
# CORRECT:TEXT Gemeindeebene
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gemeindeebene  ?
# CORRECT:TEXT Gemeindeebene
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT MIVWege Quell
# CORRECT:TEXT MIVWege Quell, Ziel und Binnenverkehr
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeindeebene  ?
# CORRECT:TEXT MIVWege Quell, Ziel und Binnenverkehr
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Personenhaushalte  in
# CORRECT:TEXT Anteil 6 und mehr Personenhaushalte
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. Industr./Lager 5 Jahre
# 3
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT NRW
# CORRECT:TEXT NRW Waehleranteil EDU
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Reformierte Kirchensteuerpflichtige
# CORRECT:TEXT Reformierte Kirchensteuerpflichtige
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Neuzulassungen  Dieselmotor
# CORRECT:TEXT Neuzulassungen  Dieselmotor
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bezirksebene
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirksebene
# CORRECT:TEXT Bezirksebene
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. Strassen, PP 5 Jahre
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirksebene
# CORRECT:TEXT Bauinv. Strassen, PP 5 Jahre
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kleine Betriebe
# CORRECT:TEXT Kleine Betriebe 1049 VZÄ
# 3
# 3
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Neuerstellte Wohnungen
# CORRECT:TEXT Bezirk
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirk Buelach
# CORRECT:TEXT Bezirk
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Neuerstellte Wohnungen
# CORRECT:TEXT Neuerstellte Wohnungen
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Wanderungsbilanz  in
# CORRECT:TEXT Wanderungsbilanz
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Flaeche hat
# CORRECT:TEXT Gemeinden
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gemeinden
# CORRECT:TEXT Gemeinden
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Flaeche hat
# CORRECT:TEXT Flaeche
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeinden
# CORRECT:TEXT Flaeche
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Anteil GK F
# CORRECT:TEXT Kanton
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Kanton ?
# CORRECT:TEXT Kanton
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil GK F
# CORRECT:TEXT Anteil GK F
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT KRW Waehleranteil EVP
# CORRECT:TEXT KRW Waehleranteil EVP
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geburtenueberschuss
# CORRECT:TEXT Geburtenueberschuss 5J.mittel
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinvestitionen
# CORRECT:TEXT Bauinvestitionen
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirke ?
# CORRECT:TEXT Bezirke
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirke ?
# CORRECT:TEXT Total VZÄ
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT KRW Waehleranteil CVP
# CORRECT:TEXT KRW Waehleranteil CVP
# 2
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bevoelkerung: Heimat
# CORRECT:TEXT Gemeinde
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gemeinde ?
# CORRECT:TEXT Gemeinde
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung: Heimat
# CORRECT:TEXT Bevoelkerung: Heimat Ausland
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeinde ?
# CORRECT:TEXT Bevoelkerung: Heimat Ausland
# 1
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Hotelbetten pro 1000
# CORRECT:TEXT Hotelbetten pro 1000 Einwohner
# 3
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand Umweltschutz und Raumordnung
# CORRECT:TEXT Nettoaufwand Umweltschutz und Raumordnung
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Steuerb.
# CORRECT:TEXT Bezirk
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirk Winterthur
# CORRECT:TEXT Bezirk
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerb.
# CORRECT:TEXT Steuerb. Einkommen natuerl. Pers. 75%Quantil
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirk Winterthur
# CORRECT:TEXT Steuerb. Einkommen natuerl. Pers. 75%Quantil
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerfuss juristische Personen
# CORRECT:TEXT Steuerfuss juristische Personen
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT PWNeuzulassungen
# CORRECT:TEXT PWNeuzulassungen
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Wasserverbrauch pro Tag
# CORRECT:TEXT Wasserverbrauch pro Tag und Kopf
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT EFHBestand  auf Bezirksebene
# CORRECT:TEXT Bezirksebene
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT EFHBestand  auf Bezirksebene
# CORRECT:TEXT EFHBestand
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT MotorradNeuzulasssungen pro 1000
# CORRECT:TEXT MotorradNeuzulasssungen pro 1000 Einw.
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirke  ?
# CORRECT:TEXT Bezirke
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirke  ?
# CORRECT:TEXT Scheidungen
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Verkaeufe von unbebautem
# CORRECT:TEXT Verkaeufe von unbebautem Land
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Neuerstellte MFHWohnungen
# CORRECT:TEXT Gemeinden
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gemeinden ?
# CORRECT:TEXT Gemeinden
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Neuerstellte MFHWohnungen
# CORRECT:TEXT Neuerstellte MFHWohnungen
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeinden ?
# CORRECT:TEXT Neuerstellte MFHWohnungen
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand Finanzen und Steuern
# CORRECT:TEXT Nettoaufwand Finanzen und Steuern
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Anteil Siedlungsflaeche
# CORRECT:TEXT Bezirk
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirk
# CORRECT:TEXT Bezirk
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil Siedlungsflaeche
# CORRECT:TEXT Anteil Siedlungsflaeche
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Rinderviehbestand  fuer alle
# CORRECT:TEXT Gemeinden
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gemeinden ?
# CORRECT:TEXT Gemeinden
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Rinderviehbestand  fuer alle
# CORRECT:TEXT Rinderviehbestand
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeinden ?
# CORRECT:TEXT Rinderviehbestand
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Ø Eigenkapital
# CORRECT:TEXT Ø Eigenkapital steuerpfl. jur. Pers.
# 1
# 2
# 3
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kehrichtmengen
# CORRECT:TEXT Kehrichtmengen
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. Landwirtschaft 5 Jahre
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerb.
# CORRECT:TEXT Steuerb. Vermoegen natuerl. Pers. 25%Quantil
# 1
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Anteil 6+
# CORRECT:TEXT Bezirk
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirk Buelach
# CORRECT:TEXT Bezirk
# 1
# 1
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Steuerkraft
# CORRECT:TEXT Steuerkraft
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Schuel.
# CORRECT:TEXT Bezirk
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirk  ?
# CORRECT:TEXT Bezirk
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Berufsschule
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirk  ?
# CORRECT:TEXT Schuel. Berufsschule
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand Volkswirtschaft
# CORRECT:TEXT Nettoaufwand Volkswirtschaft
# 6
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerkraft ber.
# CORRECT:TEXT Steuerkraft ber. arith. Mittel 3 Jahre
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand oeffentliche Ordnung
# CORRECT:TEXT Nettoaufwand oeffentliche Ordnung und Sicherheit
# 1
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Wahlbeteiligung Kantonsrat in Prozent
# CORRECT:TEXT Wahlbeteiligung Kantonsrat
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT NRW Waehleranteil
# CORRECT:TEXT NRW Waehleranteil SD
# 1
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bauinvestitionen hat
# CORRECT:TEXT Bezirk
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirk Hinwil
# CORRECT:TEXT Bezirk
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinvestitionen hat
# CORRECT:TEXT Bauinvestitionen
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirk Hinwil
# CORRECT:TEXT Bauinvestitionen
# 1
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT MotorradNeuzulassungen
# CORRECT:TEXT MotorradNeuzulassungen
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Neuerstellte MFHWohnungen
# CORRECT:TEXT Neuerstellte MFHWohnungen
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Neu gegruendete Unternehmen
# CORRECT:TEXT Gemeinde
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gemeinde  ?
# CORRECT:TEXT Gemeinde
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Neu gegruendete Unternehmen
# CORRECT:TEXT Neu gegruendete Unternehmen Total
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeinde  ?
# CORRECT:TEXT Neu gegruendete Unternehmen Total
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauzonen ueberbaut in
# CORRECT:TEXT Bauzonen ueberbaut
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT MotorradNeuzulasssungen pro 1000
# CORRECT:TEXT MotorradNeuzulasssungen pro 1000 Einw.
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT KRW Waehleranteil SD
# CORRECT:TEXT KRW Waehleranteil SD
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bevoelkerung: katholisch hat
# CORRECT:TEXT Region
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Region Unterland
# CORRECT:TEXT Region
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung: katholisch hat
# CORRECT:TEXT Bevoelkerung: katholisch
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Region Unterland
# CORRECT:TEXT Bevoelkerung: katholisch
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Arbeitsstaetten im Primaersektor
# CORRECT:TEXT Arbeitsstaetten im Primaersektor
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Mittlere Betriebe 50249
# CORRECT:TEXT Region
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Region Unterland
# CORRECT:TEXT Region
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Mittlere Betriebe 50249
# CORRECT:TEXT Mittlere Betriebe 50249 VZÄ
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Region Unterland
# CORRECT:TEXT Mittlere Betriebe 50249 VZÄ
# 2
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. Wohnen
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Wohnungen:
# CORRECT:TEXT Kanton
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Kanton
# CORRECT:TEXT Kanton
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Wohnungen:
# CORRECT:TEXT Wohnungen: Anteil Eigentumsobjekte
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Kanton
# CORRECT:TEXT Wohnungen: Anteil Eigentumsobjekte
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil 2 Zi
# CORRECT:TEXT Anteil 2 Zi.Wohnungen
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bezirksebene
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirksebene
# CORRECT:TEXT Bezirksebene
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. MFH 5 Jahre
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirksebene
# CORRECT:TEXT Bauinv. MFH 5 Jahre
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT PWNeuzulassungen pro 1000
# CORRECT:TEXT PWNeuzulassungen pro 1000 Einw.
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Leerwohnungen
# CORRECT:TEXT Leerwohnungen Total
# 4
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Restaurants hat
# CORRECT:TEXT Restaurants
# 1
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Landwirtschaftsbetriebe
# CORRECT:TEXT Landwirtschaftsbetriebe
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bestand Hybridantrieb in Prozent
# CORRECT:TEXT Bezirksebene
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirksebene
# CORRECT:TEXT Bezirksebene
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bestand Hybridantrieb in Prozent
# CORRECT:TEXT Bestand Hybridantrieb
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Bezirksebene
# CORRECT:TEXT Bestand Hybridantrieb
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Hotelbetten pro Hotel
# CORRECT:TEXT Hotelbetten pro Hotel
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Zuzuege
# CORRECT:TEXT Zuzuege
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Arbeitslose
# CORRECT:TEXT Arbeitslose
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Arbeitsstaetten im Tertiaersektor
# CORRECT:TEXT Arbeitsstaetten im Tertiaersektor
# 1
# ENT_LABEL LOC
# ENTITY2 DATA
# ENT_TEXT Hoehe
# CORRECT:TEXT Hoehe
# 6
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. Spital, Kultur usw. 5 J.
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerungszunahme 1
# CORRECT:TEXT Bevoelkerungszunahme 1 Jahr
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Tertiaerstufe
# 1
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerungszunahme
# CORRECT:TEXT Bevoelkerungszunahme 5 Jahre
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand
# CORRECT:TEXT Nettoaufwand allgemeine Verwaltung
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Verwaltung hat
# CORRECT:TEXT Nettoaufwand allgemeine Verwaltung
# 1
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Steuerbares Vermoegen
# CORRECT:TEXT Kanton
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Kanton
# CORRECT:TEXT Kanton
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerbares Vermoegen
# CORRECT:TEXT Steuerbares Vermoegen natuerliche Pers.
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kanton
# CORRECT:TEXT Steuerbares Vermoegen natuerliche Pers.
# 3
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Schweizer Buergerrechts hat
# CORRECT:TEXT Kanton
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Kanton Zuerich
# CORRECT:TEXT Kanton
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schweizer Buergerrechts hat
# CORRECT:TEXT Erwerb des Schweizer Buergerrechts
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kanton Zuerich
# CORRECT:TEXT Erwerb des Schweizer Buergerrechts
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung:
# CORRECT:TEXT Bevoelkerung: Anteil 6579Jaehrige
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerkraft berichtigt
# CORRECT:TEXT Steuerkraft berichtigt
# 1
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Sekundarstufe II
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil GK C  in
# CORRECT:TEXT Anteil GK C
# 3
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauzonen nicht ueberbaut
# CORRECT:TEXT Bauzonen nicht ueberbaut
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Kanton Zuerich
# CORRECT:TEXT Kanton
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kanton Zuerich
# CORRECT:TEXT Anteil Kirchgemeinden an allg. Gemeindesteuern
# 1
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Geburten
# CORRECT:TEXT Geburten
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung: uebrige
# CORRECT:TEXT Bevoelkerung: uebrige/andere/ohne Konfession
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Motorraeder pro 1000
# CORRECT:TEXT Gemeindeebene
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gemeindeebene ?
# CORRECT:TEXT Gemeindeebene
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Motorraeder pro 1000
# CORRECT:TEXT Motorraeder pro 1000 Einwohner
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeindeebene ?
# CORRECT:TEXT Motorraeder pro 1000 Einwohner
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geb.Vol.
# CORRECT:TEXT Geb.Vol. Landwirtschaft: Anteil
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geburtenrate hat
# CORRECT:TEXT Geburtenrate
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerpflichtige juristische Personen
# CORRECT:TEXT Steuerpflichtige juristische Personen
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauzonen nicht ueberbaut
# CORRECT:TEXT Bauzonen nicht ueberbaut
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Steuerb.
# CORRECT:TEXT Kanton
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Kanton Zuerich
# CORRECT:TEXT Kanton
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerb.
# CORRECT:TEXT Steuerb. Einkommen natuerl. Pers. 25%Quantil
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kanton Zuerich
# CORRECT:TEXT Steuerb. Einkommen natuerl. Pers. 25%Quantil
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung: uebrige
# CORRECT:TEXT Bevoelkerung: uebrige/andere/ohne Konfession
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Wegzuege
# CORRECT:TEXT Wegzuege
# 1
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Reformierte Kirchensteuerpflichtige
# CORRECT:TEXT Reformierte Kirchensteuerpflichtige
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirk ?
# CORRECT:TEXT Bezirk
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirk ?
# CORRECT:TEXT Geb.Vol. Infrastruktur: Anteil
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerb.
# CORRECT:TEXT Steuerb. Einkommen natuerl. Pers. 25%Quantil
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Kindergarten
# 1
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geburtenrate
# CORRECT:TEXT Geburtenrate 5J.mittel
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung: katholisch
# CORRECT:TEXT Bevoelkerung: katholisch
# 1
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung:
# CORRECT:TEXT Bevoelkerung: Maenner
# 1
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Neuzulassungen  Dieselmotor
# CORRECT:TEXT Neuzulassungen  Dieselmotor
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Anteil 6+
# CORRECT:TEXT Bezirksebene
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirksebene
# CORRECT:TEXT Bezirksebene
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Selbstfinanzierung hat
# CORRECT:TEXT Bezirk
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirk  ?
# CORRECT:TEXT Bezirk
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Selbstfinanzierung hat
# CORRECT:TEXT Selbstfinanzierung
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirk  ?
# CORRECT:TEXT Selbstfinanzierung
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. ÖV, Kommunik. 5 Jahre
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Selbstfinanzierung
# CORRECT:TEXT Selbstfinanzierung
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung: Heimat
# CORRECT:TEXT Bevoelkerung: Heimat Ausland
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT PWNeuzulassungen pro 1000
# CORRECT:TEXT PWNeuzulassungen pro 1000 Einw.
# 1
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung
# CORRECT:TEXT Bevoelkerung
# 1
# ENT_LABEL LOC
# ENTITY2 GRAN
# ENT_TEXT Hoehe
# CORRECT:TEXT Gemeinden
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gemeinden
# CORRECT:TEXT Gemeinden
# 1
# ENT_LABEL LOC
# ENTITY2 DATA
# ENT_TEXT Hoehe
# CORRECT:TEXT Hoehe
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeinden
# CORRECT:TEXT Hoehe
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gesamtsteuerfuss ohne Kirchen
# CORRECT:TEXT Gesamtsteuerfuss ohne Kirchen
# 1
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT KRW Waehleranteil
# CORRECT:TEXT KRW Waehleranteil BDP
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. EFH 5 Jahre
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Ø steuerbares Vermoegen
# CORRECT:TEXT Ø steuerbares Vermoegen natuerliche Pers.
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT PWNeuzulassungen pro 1000
# CORRECT:TEXT Bezirk
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirk ?
# CORRECT:TEXT Bezirk
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT PWNeuzulassungen pro 1000
# CORRECT:TEXT PWNeuzulassungen pro 1000 Einw.
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirk ?
# CORRECT:TEXT PWNeuzulassungen pro 1000 Einw.
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand soziale Sicherheit
# CORRECT:TEXT Nettoaufwand soziale Sicherheit
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Steuerertrag von natuerlichen Personen
# CORRECT:TEXT Gemeinden
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gemeinden
# CORRECT:TEXT Gemeinden
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerertrag von natuerlichen Personen
# CORRECT:TEXT Steuerertrag von natuerlichen Personen
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Hotelbetten pro 1000
# CORRECT:TEXT Hotelbetten pro 1000 Einwohner
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Kindergarten
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Durchschnittliche Haushaltsgroesse
# CORRECT:TEXT Bezirksebene
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirksebene ?
# CORRECT:TEXT Bezirksebene
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Durchschnittliche Haushaltsgroesse
# CORRECT:TEXT Durchschnittliche Haushaltsgroesse
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung: Anteil
# CORRECT:TEXT Bevoelkerung: Anteil 80 u.m.Jaehrige
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Motorraeder  fuer den
# CORRECT:TEXT Kanton
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Kanton ?
# CORRECT:TEXT Kanton
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Motorraeder  fuer den
# CORRECT:TEXT Motorraeder
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kanton ?
# CORRECT:TEXT Motorraeder
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand allgemeine Verwaltung
# CORRECT:TEXT Nettoaufwand allgemeine Verwaltung
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirke ?
# CORRECT:TEXT Bezirke
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirke ?
# CORRECT:TEXT 2Personenhaushalte
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand Volkswirtschaft
# CORRECT:TEXT Nettoaufwand Volkswirtschaft
# 3
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauzonen ueberbaut
# CORRECT:TEXT Bauzonen ueberbaut
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Geb.
# CORRECT:TEXT Bezirksebene
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirksebene ?
# CORRECT:TEXT Bezirksebene
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geb.
# CORRECT:TEXT Geb.Vol. Nebengebaeude: Anteil
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirksebene ?
# CORRECT:TEXT Geb.Vol. Nebengebaeude: Anteil
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerkraft berichtigt
# CORRECT:TEXT Steuerkraft berichtigt
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bauinv.
# CORRECT:TEXT Region
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Region Unterland
# CORRECT:TEXT Region
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. Landwirtschaft 5 Jahre
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Region Unterland
# CORRECT:TEXT Bauinv. Landwirtschaft 5 Jahre
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeindebeitrag an ZVV
# CORRECT:TEXT Gemeindebeitrag an ZVV
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT 1Personenhaushalte
# CORRECT:TEXT 1Personenhaushalte
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerertrag
# CORRECT:TEXT Steuerertrag Kirchgemeinden
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Personenhaushalte hat
# CORRECT:TEXT 6 und mehr Personenhaushalte
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Auslaenderanteil in Prozent  in Wallisellen
# CORRECT:TEXT Auslaenderanteil
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil Landwirtschaftsflaeche
# CORRECT:TEXT Anteil Landwirtschaftsflaeche
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Grosse Betriebe 250
# CORRECT:TEXT Bezirk
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirk  ?
# CORRECT:TEXT Bezirk
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Beschaeftigte im Sekundaersektor
# CORRECT:TEXT Beschaeftigte im Sekundaersektor
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Reformierte Kirchensteuerpflichtige
# CORRECT:TEXT Reformierte Kirchensteuerpflichtige
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gemeindeebene ?
# CORRECT:TEXT Gemeindeebene
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeindeebene ?
# CORRECT:TEXT Total Arbeitsstaetten
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil GK D
# CORRECT:TEXT Anteil GK D
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT 3Personenhaushalte hat
# CORRECT:TEXT 3Personenhaushalte
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand soziale Sicherheit
# CORRECT:TEXT Nettoaufwand soziale Sicherheit
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT VZÄ im Tertiaersektor
# CORRECT:TEXT VZÄ im Tertiaersektor
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT MotorradNeuzulassungen
# CORRECT:TEXT MotorradNeuzulassungen
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Restaurants pro 1000
# CORRECT:TEXT Restaurants pro 1000 Einwohner
# 4
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gebaeudevolumen:
# CORRECT:TEXT Bezirk
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirk ?
# CORRECT:TEXT Bezirk
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gebaeudevolumen:
# CORRECT:TEXT Gebaeudevolumen: Zunahme
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirk ?
# CORRECT:TEXT Gebaeudevolumen: Zunahme
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil 4Personenhaushalte
# CORRECT:TEXT Anteil 4Personenhaushalte
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Zuzuege
# CORRECT:TEXT Zuzuege
# 1
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Gemeinde
# CORRECT:TEXT Gemeinde
# 3
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Gemeinde
# CORRECT:TEXT Neuzulassungen anderer Antrieb
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Kanton Zuerich
# CORRECT:TEXT Kanton
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kanton Zuerich
# CORRECT:TEXT Eigenkapital
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Sterbefaelle
# CORRECT:TEXT Sterbefaelle
# 4
# 3
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geburtenrate 5J.mittel
# CORRECT:TEXT Geburtenrate 5J.mittel
# 4
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Neuerstellte EFH  Mettmenstetten
# CORRECT:TEXT Neuerstellte EFH
# 1
# 1
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT KRW Waehleranteil EDU
# CORRECT:TEXT KRW Waehleranteil EDU
# 4
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung:
# CORRECT:TEXT Bevoelkerung: Anteil 014Jaehrige
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kuehe  in
# CORRECT:TEXT Kuehe
# 1
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Mittelschule
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Geb.
# CORRECT:TEXT Gemeindeebene
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gemeindeebene ?
# CORRECT:TEXT Gemeindeebene
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geb.
# CORRECT:TEXT Geb.Vol. Industrie/Lager: Anteil
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeindeebene ?
# CORRECT:TEXT Geb.Vol. Industrie/Lager: Anteil
# 6
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. Spital, Kultur usw. 5 J.
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Zinsbelastungsanteil in Prozent
# CORRECT:TEXT Zinsbelastungsanteil
# 3
# ENT_LABEL MISC
# ENTITY2 DATA
# ENT_TEXT Total
# CORRECT:TEXT Total ordentlich Besteuerte
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Besteuerte hat
# CORRECT:TEXT Total ordentlich Besteuerte
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. Strassen, PP 5 Jahre
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung:
# CORRECT:TEXT Bevoelkerung: Maenneranteil
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand soziale Sicherheit
# CORRECT:TEXT Nettoaufwand soziale Sicherheit
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand Volkswirtschaft
# CORRECT:TEXT Nettoaufwand Volkswirtschaft
# 2
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geburtenueberschuss 5J.mittel
# CORRECT:TEXT Geburtenueberschuss 5J.mittel
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerertrag von natuerlichen Personen
# CORRECT:TEXT Steuerertrag von natuerlichen Personen
# 2
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerertrag Grundsteuern
# CORRECT:TEXT Steuerertrag Grundsteuern
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerertrag von juristischen
# CORRECT:TEXT Steuerertrag von juristischen Personen
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Nettoaufwand oeffentliche Ordnung
# CORRECT:TEXT Bezirksebene
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirksebene ?
# CORRECT:TEXT Bezirksebene
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand oeffentliche Ordnung
# CORRECT:TEXT Nettoaufwand oeffentliche Ordnung und Sicherheit
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirksebene ?
# CORRECT:TEXT Nettoaufwand oeffentliche Ordnung und Sicherheit
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bezirke
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirke  ?
# CORRECT:TEXT Bezirke
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. Industr./Lager 5 Jahre
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirke  ?
# CORRECT:TEXT Bauinv. Industr./Lager 5 Jahre
# 2
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kleine Betriebe
# CORRECT:TEXT Kleine Betriebe 1049 VZÄ
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT ÖVWege Quell, Ziel
# CORRECT:TEXT Kanton
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Kanton
# CORRECT:TEXT Kanton
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT ÖVWege Quell, Ziel
# CORRECT:TEXT ÖVWege Quell, Ziel und Binnenverkehr
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kanton
# CORRECT:TEXT ÖVWege Quell, Ziel und Binnenverkehr
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Personalsteuerpflichtige
# CORRECT:TEXT Personalsteuerpflichtige
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Anteil 3 Zi
# CORRECT:TEXT Kanton
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Kanton
# CORRECT:TEXT Kanton
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil 3 Zi
# CORRECT:TEXT Anteil 3 Zi.Wohnungen
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Kanton
# CORRECT:TEXT Anteil 3 Zi.Wohnungen
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Geb.
# CORRECT:TEXT Bezirke
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirke
# CORRECT:TEXT Bezirke
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geb.
# CORRECT:TEXT Geb.Vol. Dienstleistungen: Anteil
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Bezirke
# CORRECT:TEXT Geb.Vol. Dienstleistungen: Anteil
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Neuzulassungen Benzinmotor in Prozent
# CORRECT:TEXT Neuzulassungen Benzinmotor
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Kanton ?
# CORRECT:TEXT Kanton
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kanton ?
# CORRECT:TEXT Hotels
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezuegerquote der bedarfsabh
# CORRECT:TEXT Bezuegerquote der bedarfsabh. Sozialleistungen
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Arbeitsstaetten im Primaersektor
# CORRECT:TEXT Arbeitsstaetten im Primaersektor
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Schuel.
# CORRECT:TEXT Bezirke
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirke  ?
# CORRECT:TEXT Bezirke
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Kindergarten
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirke  ?
# CORRECT:TEXT Schuel. Kindergarten
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil 1Personenhaushalte
# CORRECT:TEXT Anteil 1Personenhaushalte
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirk Zuerich
# CORRECT:TEXT Bezirk
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirk Zuerich
# CORRECT:TEXT Verkaeufe Stockwerkeigentum
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Sozialhilfequote  Huetten
# CORRECT:TEXT Sozialhilfequote
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. Wohnen
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Oberstufe
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bevoelkerung: reformiert
# CORRECT:TEXT Kanton
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Kanton ?
# CORRECT:TEXT Kanton
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung: reformiert
# CORRECT:TEXT Bevoelkerung: reformiert
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kanton ?
# CORRECT:TEXT Bevoelkerung: reformiert
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bruttoverschuldungsanteil in Prozent  fuer alle
# CORRECT:TEXT Bezirke
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirke
# CORRECT:TEXT Bezirke
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bruttoverschuldungsanteil in Prozent  fuer alle
# CORRECT:TEXT Bruttoverschuldungsanteil
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Bezirke
# CORRECT:TEXT Bruttoverschuldungsanteil
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT MIVAnteil Modal
# CORRECT:TEXT Gemeinde
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Gemeinde
# CORRECT:TEXT Gemeinde
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT MIVAnteil Modal
# CORRECT:TEXT MIVAnteil Modal Split
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Gemeinde
# CORRECT:TEXT MIVAnteil Modal Split
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung: uebrige
# CORRECT:TEXT Bevoelkerung: uebrige/andere/ohne Konfession
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Finanzvermoegen
# CORRECT:TEXT Finanzvermoegen
# 2
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Steuerertrag
# CORRECT:TEXT Steuerertrag Kirchgemeinden
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerungszunahme 1 Jahr in Prozent
# CORRECT:TEXT Bevoelkerungszunahme 1 Jahr
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerungszunahme 5 Jahre
# CORRECT:TEXT Bevoelkerungszunahme 5 Jahre
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Beschaeftigte im Tertiaersektor
# CORRECT:TEXT Beschaeftigte im Tertiaersektor
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. Ver/Entsorg. 5 Jahre
# 3
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Steuerertrag Politische/
# CORRECT:TEXT Bezirk
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirk ?
# CORRECT:TEXT Bezirk
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerertrag Politische/
# CORRECT:TEXT Steuerertrag Politische/Schulgemeinde
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirk ?
# CORRECT:TEXT Steuerertrag Politische/Schulgemeinde
# 1
# 1
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Restaurants
# CORRECT:TEXT Restaurants
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerbares Einkommen natuerliche Pers
# CORRECT:TEXT Steuerbares Einkommen natuerliche Pers.
# 2
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Personalsteuerpflichtige  pro
# CORRECT:TEXT Gemeinde
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gemeinde ?
# CORRECT:TEXT Gemeinde
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Personalsteuerpflichtige  pro
# CORRECT:TEXT Personalsteuerpflichtige
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeinde ?
# CORRECT:TEXT Personalsteuerpflichtige
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerungsdichte
# CORRECT:TEXT Bevoelkerungsdichte
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Sekundarstufe I
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Ø steuerbares Vermoegen
# CORRECT:TEXT Ø steuerbares Vermoegen natuerliche Pers.
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Sekundarstufe II
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Steuerertrag Politische/
# CORRECT:TEXT Bezirk
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirk Winterthur
# ...
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Neuerstellte
# CORRECT:TEXT Gemeindeebene
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gemeindeebene  ?
# CORRECT:TEXT Gemeindeebene
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Neuerstellte
# CORRECT:TEXT Neuerstellte EFH
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeindeebene  ?
# CORRECT:TEXT Neuerstellte EFH
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerkraft arith.
# CORRECT:TEXT Steuerkraft arith. Mittel 3 Jahre
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Altersquotient  in
# CORRECT:TEXT Altersquotient
# 3
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauzonen ueberbaut pro
# CORRECT:TEXT Bauzonen ueberbaut pro Kopf
# 1
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Flaeche
# CORRECT:TEXT Flaeche
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT 2Personenhaushalte
# CORRECT:TEXT 2Personenhaushalte
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Kanton Zuerich
# CORRECT:TEXT Kanton
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kanton Zuerich
# CORRECT:TEXT NRW Waehleranteil EDU
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Sekundarstufe II
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil Pol./Schulgem
# CORRECT:TEXT Anteil Pol./Schulgem. an allg. Gemeindesteuern
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Mittelschule
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Arbeitsstaetten im Tertiaersektor
# CORRECT:TEXT Arbeitsstaetten im Tertiaersektor
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Rinderviehbestand
# CORRECT:TEXT Rinderviehbestand
# 2
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Anteil
# CORRECT:TEXT Anteil Waldflaeche
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Wohnungsbestand  Turbenthal
# CORRECT:TEXT Anteil EFH am Wohnungsbestand
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinvestitionen
# CORRECT:TEXT Bauinvestitionen
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bestand Benzinmotor in Prozent
# CORRECT:TEXT Kanton
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Kanton Zuerich
# CORRECT:TEXT Kanton
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bestand Benzinmotor in Prozent
# CORRECT:TEXT Bestand Benzinmotor
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kanton Zuerich
# CORRECT:TEXT Bestand Benzinmotor
# 2
# 4
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. MFH 5 Jahre
# 1
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Baulandpreis
# CORRECT:TEXT Bezirk
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirk  ?
# CORRECT:TEXT Bezirk
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Baulandpreis
# CORRECT:TEXT Baulandpreis Modell Median
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirk  ?
# CORRECT:TEXT Baulandpreis Modell Median
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Hotelbetten pro Hotel
# CORRECT:TEXT Hotelbetten pro Hotel
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung: reformiert
# CORRECT:TEXT Bevoelkerung: reformiert
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Geburtenueberschuss
# CORRECT:TEXT Gemeinde
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gemeinde  ?
# CORRECT:TEXT Gemeinde
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geburtenueberschuss
# CORRECT:TEXT Geburtenueberschuss 5J.mittel
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeinde  ?
# CORRECT:TEXT Geburtenueberschuss 5J.mittel
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gemeinden
# CORRECT:TEXT Gemeinden
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeinden
# CORRECT:TEXT Personenwagen
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil GK D
# CORRECT:TEXT Anteil GK D
# 4
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geburten hat
# CORRECT:TEXT Geburten
# 2
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Geb.
# CORRECT:TEXT Bezirk
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirk ?
# CORRECT:TEXT Bezirk
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geb.
# CORRECT:TEXT Geb.Vol. Industrie/Lager: Zunahme
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirk ?
# CORRECT:TEXT Geb.Vol. Industrie/Lager: Zunahme
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT KRW Waehleranteil SP
# CORRECT:TEXT Bezirk
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirk ?
# CORRECT:TEXT Bezirk
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT KRW Waehleranteil SP
# CORRECT:TEXT KRW Waehleranteil SP
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauzonen nicht ueberbaut
# CORRECT:TEXT Bauzonen nicht ueberbaut
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT ÖVWege Quell
# CORRECT:TEXT ÖVWege Quell, Ziel und Binnenverkehr
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Steuerb.
# CORRECT:TEXT Bezirk
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirk  ?
# CORRECT:TEXT Bezirk
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerb.
# CORRECT:TEXT Steuerb. Einkommen natuerl. Pers. 75%Quantil
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirk  ?
# CORRECT:TEXT Steuerb. Einkommen natuerl. Pers. 75%Quantil
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinvestitionen
# CORRECT:TEXT Bauinvestitionen
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Baulandpreis Median hat
# CORRECT:TEXT Baulandpreis Median
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geb.
# CORRECT:TEXT Geb.Vol. Dienstleistungen: Zunahme
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerertrag allgemeine Gemeindesteuern
# CORRECT:TEXT Steuerertrag allgemeine Gemeindesteuern
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Baulandpreis Median  fuer alle
# CORRECT:TEXT Gemeinden
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gemeinden ?
# CORRECT:TEXT Gemeinden
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Baulandpreis Median  fuer alle
# CORRECT:TEXT Baulandpreis Median
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeinden ?
# CORRECT:TEXT Baulandpreis Median
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettoaufwand Kultur, Sport
# CORRECT:TEXT Nettoaufwand Kultur, Sport und Freizeit
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Geburtenrate
# CORRECT:TEXT Gemeindeebene
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gemeindeebene ?
# CORRECT:TEXT Gemeindeebene
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geburtenrate
# CORRECT:TEXT Geburtenrate
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeindeebene ?
# CORRECT:TEXT Geburtenrate
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirksebene
# CORRECT:TEXT Bezirksebene
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirksebene
# CORRECT:TEXT Sterberate
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Jugendquotient in Prozent
# CORRECT:TEXT Jugendquotient
# 5
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Selbstfinanzierungsgrad  Dachsen
# CORRECT:TEXT Selbstfinanzierungsgrad
# 4
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT 1Personenhaushalte
# CORRECT:TEXT 1Personenhaushalte
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Neuzulassungen  Elektromotor
# CORRECT:TEXT Neuzulassungen  Elektromotor
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Anteil 5 Zi
# CORRECT:TEXT Gemeindeebene
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Gemeindeebene
# CORRECT:TEXT Gemeindeebene
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil 5 Zi
# CORRECT:TEXT Anteil 5 Zi.Wohnungen
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Gemeindeebene
# CORRECT:TEXT Anteil 5 Zi.Wohnungen
# 1
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Gemeinde
# CORRECT:TEXT Gemeinde
# 1
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Gemeinde
# CORRECT:TEXT Selbstfinanzierungsanteil
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Oberstufe
# 2
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gemeinde ?
# CORRECT:TEXT Gemeinde
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeinde ?
# CORRECT:TEXT Ausserhalb des Kt. wohnhaft Besteuerte
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirksebene ?
# CORRECT:TEXT Bezirksebene
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirksebene ?
# CORRECT:TEXT Sterberate 5J.mittel
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil EFH am Wohnungsbestand
# CORRECT:TEXT Anteil EFH am Wohnungsbestand
# 2
# 1
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bruttoinvestitionen
# CORRECT:TEXT Bruttoinvestitionen
# 1
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Katholische Kirchensteuerpflichtige
# CORRECT:TEXT Katholische Kirchensteuerpflichtige
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Total Arbeitsstaetten hat
# CORRECT:TEXT Bezirk
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirk
# CORRECT:TEXT Bezirk
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Total Arbeitsstaetten hat
# CORRECT:TEXT Total Arbeitsstaetten
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Bezirk
# CORRECT:TEXT Total Arbeitsstaetten
# 2
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Steuerertrag
# CORRECT:TEXT Steuerertrag Kirchgemeinden
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Rinderviehbestand hat
# CORRECT:TEXT Kanton
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Kanton
# CORRECT:TEXT Kanton
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Rinderviehbestand hat
# CORRECT:TEXT Rinderviehbestand
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kanton
# CORRECT:TEXT Rinderviehbestand
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. Ver/Entsorg. 5 Jahre
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Leerwohnungen Total
# CORRECT:TEXT Leerwohnungen Total
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Nettovermoegen  fuer alle
# CORRECT:TEXT Gemeinden
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gemeinden ?
# CORRECT:TEXT Gemeinden
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Nettovermoegen  fuer alle
# CORRECT:TEXT Nettovermoegen
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeinden ?
# CORRECT:TEXT Nettovermoegen
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Oberstufe
# 2
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung: Heimat
# CORRECT:TEXT Bevoelkerung: Heimat Ausland
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Landwirtschaftliche Nutzflaeche
# CORRECT:TEXT Landwirtschaftliche Nutzflaeche
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT ÖVAnteil Modal Split
# CORRECT:TEXT ÖVAnteil Modal Split
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Berufsschule
# 1
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Zuzuege  fuer alle
# CORRECT:TEXT Gemeinden
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gemeinden ?
# CORRECT:TEXT Gemeinden
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Zuzuege  fuer alle
# CORRECT:TEXT Zuzuege
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeinden ?
# CORRECT:TEXT Zuzuege
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung:
# CORRECT:TEXT Bevoelkerung: Frauenanteil
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Geburtenueberschuss 5J.mittel
# CORRECT:TEXT Kanton
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Kanton Zuerich
# CORRECT:TEXT Kanton
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geburtenueberschuss 5J.mittel
# CORRECT:TEXT Geburtenueberschuss 5J.mittel
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kanton Zuerich
# CORRECT:TEXT Geburtenueberschuss 5J.mittel
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Unfaelle hat
# CORRECT:TEXT Region
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Region Pfannenstiel
# CORRECT:TEXT Region
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Unfaelle hat
# CORRECT:TEXT Unfaelle
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Region Pfannenstiel
# CORRECT:TEXT Unfaelle
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bauinv.
# CORRECT:TEXT Gemeinden
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gemeinden
# CORRECT:TEXT Gemeinden
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. ÖV, Kommunik. 5 Jahre
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeinden
# CORRECT:TEXT Bauinv. ÖV, Kommunik. 5 Jahre
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Restaurants pro 1000
# CORRECT:TEXT Restaurants pro 1000 Einwohner
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerungszunahme 1
# CORRECT:TEXT Bevoelkerungszunahme 1 Jahr
# 6
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. Spital, Kultur usw. 5 J.
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Zuzuege
# CORRECT:TEXT Zuzuege
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Schuel.
# CORRECT:TEXT Schuel. Kindergarten
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Wanderungsbilanz hat  fuer alle
# CORRECT:TEXT Gemeinden
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gemeinden
# CORRECT:TEXT Gemeinden
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Wanderungsbilanz hat  fuer alle
# CORRECT:TEXT Wanderungsbilanz
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeinden
# CORRECT:TEXT Wanderungsbilanz
# 1
# 1
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Scheidungen
# CORRECT:TEXT Scheidungen
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung:
# CORRECT:TEXT Bevoelkerung: Anteil 4064Jaehrige
# 1
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Scheidungen
# CORRECT:TEXT Scheidungen
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Altpapiermengen
# CORRECT:TEXT Altpapiermengen
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Total Arbeitsstaetten
# CORRECT:TEXT Total Arbeitsstaetten
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT KRW Waehleranteil GLP
# CORRECT:TEXT KRW Waehleranteil GLP
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Neu gegruendete Unternehmen
# CORRECT:TEXT Neu gegruendete Unternehmen Total
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Anteil Verkehrsflaeche
# CORRECT:TEXT Bezirksebene
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Bezirksebene
# CORRECT:TEXT Bezirksebene
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil Verkehrsflaeche
# CORRECT:TEXT Anteil Verkehrsflaeche
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bauinvestitionen  fuer
# CORRECT:TEXT Bezirke
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirke ?
# CORRECT:TEXT Bezirke
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinvestitionen  fuer
# CORRECT:TEXT Bauinvestitionen
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirke ?
# CORRECT:TEXT Bauinvestitionen
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bevoelkerung:
# CORRECT:TEXT Bevoelkerung: Durchschnittsalter
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geb.Vol.
# CORRECT:TEXT Geb.Vol. Wohnen: Zunahme
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Ø Eigenkapital
# CORRECT:TEXT Ø Eigenkapital steuerpfl. jur. Pers.
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Steuerb.
# CORRECT:TEXT Gemeinden
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gemeinden ?
# CORRECT:TEXT Gemeinden
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerb.
# CORRECT:TEXT Steuerb. Vermoegen natuerl. Pers. 75%Quantil
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeinden ?
# CORRECT:TEXT Steuerb. Vermoegen natuerl. Pers. 75%Quantil
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bruttoinvestitionen hat
# CORRECT:TEXT Gemeindeebene
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gemeindeebene  ?
# CORRECT:TEXT Gemeindeebene
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bruttoinvestitionen hat
# CORRECT:TEXT Bruttoinvestitionen
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeindeebene  ?
# CORRECT:TEXT Bruttoinvestitionen
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauinv.
# CORRECT:TEXT Bauinv. Dienstl. 5 Jahre
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Steuerb.
# CORRECT:TEXT Gemeindeebene
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gemeindeebene ?
# CORRECT:TEXT Gemeindeebene
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerb.
# CORRECT:TEXT Steuerb. Einkommen natuerl. Pers. Durchschn.
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeindeebene ?
# CORRECT:TEXT Steuerb. Einkommen natuerl. Pers. Durchschn.
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Geb.Vol.
# CORRECT:TEXT Gemeindeebene
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Gemeindeebene
# CORRECT:TEXT Gemeindeebene
# 3
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Geb.Vol.
# CORRECT:TEXT Geb.Vol. Wohnen: Anteil
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Gemeindeebene
# CORRECT:TEXT Geb.Vol. Wohnen: Anteil
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bauzonen
# CORRECT:TEXT Bauzonen
# 4
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerkraft berichtigt pro
# CORRECT:TEXT Steuerkraft berichtigt pro Kopf
# 1
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Christkatholische
# CORRECT:TEXT Gemeinde
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Gemeinde  ?
# CORRECT:TEXT Gemeinde
# 2
# ENT_LABEL GRAN
# ENTITY2 DATA
# ENT_TEXT Christkatholische
# CORRECT:TEXT Christkatholische Kirchensteuerpflichtige
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Gemeinde  ?
# CORRECT:TEXT Christkatholische Kirchensteuerpflichtige
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Ø steuerbares Einkommen
# CORRECT:TEXT Bezirksebene
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Bezirksebene
# CORRECT:TEXT Bezirksebene
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Ø steuerbares Einkommen
# CORRECT:TEXT Ø steuerbares Einkommen natuerliche Pers.
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Bezirksebene
# CORRECT:TEXT Ø steuerbares Einkommen natuerliche Pers.
# 1
# 5
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Steuerb.
# CORRECT:TEXT Steuerb. Vermoegen natuerl. Pers. 25%Quantil
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT EFHBestand
# CORRECT:TEXT EFHBestand
# 1
# ENT_LABEL DATA
# ENTITY2 GRAN
# ENT_TEXT Anteil 5Personenhaushalte
# CORRECT:TEXT Kanton
# ENT_LABEL GRAN
# ENTITY2 GRAN
# ENT_TEXT Kanton
# CORRECT:TEXT Kanton
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Anteil 5Personenhaushalte
# CORRECT:TEXT Anteil 5Personenhaushalte
# 2
# 1
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Kehrichtmengen
# CORRECT:TEXT Kehrichtmengen
# 2
# ENT_LABEL DATA
# ENTITY2 DATA
# ENT_TEXT Hauptberufliche Landwirtschaftsbetriebe
# CORRECT:TEXT Hauptberufliche Landwirtschaftsbetriebe

# %%
for key in word_evaluation:
    correct = word_evaluation[key]["correct"]
    total = word_evaluation[key]["total"]

    print(f"{key}: {correct / total * 100:.2f}%")

stat_total_sum = 0
stat_correct_sum = 0

print("---")
for key in stat_evaluation:
    correct = stat_evaluation[key]["correct"]
    total = stat_evaluation[key]["total"]
    
    stat_total_sum += total
    stat_correct_sum += correct

    print(f"{key}: {correct / total * 100:.2f}%")

print(f"\nTotal: {stat_correct_sum/stat_total_sum * 100:.2f}%")
# Out:
# GRAN: 15.56%
# DATA: 22.51%
# ---
# GRAN: 15.56%
# DATA: 22.51%
#
# Total: 21.04%

# %%
# dictionary which will be populated with the entities and result information
entity_evaluation = {}

# helper function to udpate the entity_evaluation dictionary
def update_results(entity, metric):
    if entity not in entity_evaluation:
        entity_evaluation[entity] = {"correct": 0, "total": 0}
    
    entity_evaluation[entity][metric] += 1

# same as before, see if entities from test set match what spaCy currently predicts
for data in TEST_REVISION_DATA:
    sentence = data[0]
    entities = data[1]["entities"]

    for entity in entities:
        doc = nlp(sentence)
        correct_text = sentence[entity[0]:entity[1]]

        for ent in doc.ents:
            if ent.label_ == entity[2] and ent.text == correct_text:
                update_results(ent.label_, "correct")
                break

        update_results(entity[2], "total")

# %%
sum_total = 0
sum_correct = 0

for entity in entity_evaluation:
    total = entity_evaluation[entity]["total"]
    correct = entity_evaluation[entity]["correct"]

    sum_total += total
    sum_correct += correct
    
    print("{} | {:.2f}%".format(entity, correct / total * 100))

print()
print("Overall accuracy: {:.2f}%".format(sum_correct / sum_total * 100))

# %%
nlp.meta["name"] = "stat_entity_extractor_v1"
nlp.to_disk("./models/v1")

# %%
TRAIN_STAT_DATA[5]

# %%
doc = nlp(u'Welche Gemeinde hat die grösste Bevölkerung und welche hatte im 2019 den höchsten Ausländeranteil?')

# show universal pos tags
print(' '.join('{word}/{tag}'.format(word=t.orth_, tag=t.pos_) for t in doc))
# output: Ich/PRON bin/AUX ein/DET Berliner/NOUN ./PUNCT

# show German specific pos tags (STTS)
print(' '.join('{word}/{tag}'.format(word=t.orth_, tag=t.tag_) for t in doc))
# output: Ich/PPER bin/VAFIN ein/ART Berliner/NN ./$.

# show dependency arcs
print('\n'.join('{child:<8} <{label:-^7} {head}'.format(child=t.orth_, label=t.dep_, head=t.head.orth_) for t in doc))
# output: (sb: subject, nk: noun kernel, pd: predicate)

#named entities
print("Named Entity Recognition:")
for ent in doc.ents:
    print(ent.text)
print("Noun chunks:")
for chunk in doc.noun_chunks:
    print(chunk.text)
